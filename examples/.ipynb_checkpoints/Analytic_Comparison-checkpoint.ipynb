# %%
import numpy as np
from pandas import read_csv

# from average_atom.core.average_atom_new import AverageAtom as AA
from average_atom.core.aa_types import AverageAtomFactory
from average_atom.core.misc import jacobi_relaxation, sor
from average_atom.core.grids import NonUniformGrid
from average_atom.core.physics import ThomasFermi, FermiDirac

import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

plt.rcParams.update({'font.size': 10})
plt.rcParams["figure.figsize"] = (5,3.5)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14

color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# ## Comparison with Thomas Fermi Model Analytic form in
# ###### "Approximate Solution of the Thomas–Fermi Equation for Free Positive Ions" Aleksey A. Mavrin and Alexander V. Demura

# %%
# Aluminum
name='Al'
Z, A = 13, 27 

ρ_solid = 2.699 #g/cc, the solid density of aluminum 
ρ = ρ_solid#8.1 # g/cc
ni_cc = ρ/(A*amu_to_AU*AU_to_g)
ni_AU = ni_cc*invcc_to_AU
rs = rs_from_n(ni_AU)
R  = 10*rs

Ti_eV = 1
Te_eV = 1

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

aa_CS  = AverageAtomFactory.create_model("TFStarret2014", Z, A, Ti_AU, Te_AU, rs, R, name=name, ignore_vxc=True, rmin=5e-4,  Npoints=2000, grid_spacing='geometric',N_stencil_oneside=3)
aa_CS.solve(verbose=True)
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# Initializing, False
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# Initializing, True
# Initializing
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# Initialized
# Solving core.
# Beginning self-consistent electron solver.
# _________________________________
# /home/zach/plasma/average_atom/core/average_atom_new.py:561: RuntimeWarning: divide by zero encountered in divide
#   rel_errs = (np.abs(A @ φe - b)[:-1]/b[:-1])
# __________________________________________
# TF Iteration 0
# 	μ = -4.624017487e-01, change: 7.893119263e-01 (converged=False)
# 	φe Err =       -inf, φe change =  7.623e-01
# 	ne Err =  1.354e-01, ne change =  1.360e-03
# 	Q =  0.000e+00 ->  2.699e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  1.160e-25 (converged=False)
# 	Change =  1.505e+00
# __________________________________________
# TF Iteration 1
# 	μ = -1.299155494e-01, change: 7.190418295e-01 (converged=False)
# 	φe Err =       -inf, φe change =  2.501e-02
# 	ne Err =  9.801e-02, ne change =  6.625e-04
# 	Q =  2.699e+00 ->  2.368e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  1.726e-07 (converged=False)
# 	Change =  7.197e-01
# __________________________________________
# TF Iteration 2
# 	μ = 3.735064143e-02, change: 1.287499392e+00 (converged=False)
# 	φe Err =       -inf, φe change =  1.323e-02
# 	ne Err =  5.493e-02, ne change =  2.894e-04
# 	Q =  2.368e+00 ->  1.880e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  1.447e-03 (converged=False)
# 	Change =  1.248e+00
# __________________________________________
# TF Iteration 3
# 	μ = 1.446327974e-01, change: 2.872297552e+00 (converged=False)
# 	φe Err =       -inf, φe change =  1.015e-02
# 	ne Err =  3.087e-02, ne change =  1.165e-04
# 	Q =  1.880e+00 ->  1.494e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  8.058e-02 (converged=False)
# 	Change =  7.270e-01
# __________________________________________
# TF Iteration 4
# 	μ = 2.224293233e-01, change: 5.378899341e-01 (converged=False)
# 	φe Err =       -inf, φe change =  4.511e-03
# 	ne Err =  2.116e-02, ne change =  4.491e-05
# 	Q =  1.494e+00 ->  1.188e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  3.598e-01 (converged=False)
# 	Change =  2.968e-01
# __________________________________________
# TF Iteration 5
# 	μ = 2.777654302e-01, change: 2.487806291e-01 (converged=False)
# 	φe Err =       -inf, φe change =  1.374e-03
# 	ne Err =  1.649e-02, ne change =  1.738e-05
# 	Q =  1.188e+00 ->  9.219e-01,
# 	Zstar guess =  2.495e+00. Current Zstar:  7.611e-01 (converged=False)
# 	Change =  1.560e-01
# __________________________________________
# TF Iteration 6
# 	μ = 3.151633396e-01, change: 1.346384587e-01 (converged=False)
# 	φe Err =       -inf, φe change =  6.902e-04
# 	ne Err =  1.279e-02, ne change =  7.200e-06
# 	Q =  9.219e-01 ->  6.887e-01,
# 	Zstar guess =  2.495e+00. Current Zstar:  1.182e+00 (converged=False)
# 	Change =  8.963e-02
# __________________________________________
# TF Iteration 7
# 	μ = 3.390909463e-01, change: 7.592128794e-02 (converged=False)
# 	φe Err =       -inf, φe change =  6.845e-04
# 	ne Err =  9.454e-03, ne change =  3.347e-06
# 	Q =  6.887e-01 ->  4.924e-01,
# 	Zstar guess =  2.495e+00. Current Zstar:  1.554e+00 (converged=False)
# 	Change =  5.244e-02
# __________________________________________
# TF Iteration 8
# 	μ = 3.535799828e-01, change: 4.272905736e-02 (converged=False)
# 	φe Err =       -inf, φe change =  5.165e-04
# 	ne Err =  6.623e-03, ne change =  1.720e-06
# 	Q =  4.924e-01 ->  3.367e-01,
# 	Zstar guess =  2.495e+00. Current Zstar:  1.850e+00 (converged=False)
# 	Change =  3.015e-02
# __________________________________________
# TF Iteration 9
# 	μ = 3.618685274e-01, change: 2.344178130e-02 (converged=False)
# 	φe Err =       -inf, φe change =  3.214e-04
# 	ne Err =  4.409e-03, ne change =  9.172e-07
# 	Q =  3.367e-01 ->  2.205e-01,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.066e+00 (converged=False)
# 	Change =  1.674e-02
# __________________________________________
# TF Iteration 25
# 	μ = 3.696796447e-01, change: 1.995052067e-06 (converged=True)
# 	φe Err =       -inf, φe change =  2.450e-08
# 	ne Err =  7.107e-07, ne change =  4.944e-11
# 	Q = -5.631e-05 -> -3.282e-05,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.437e+00 (converged=False)
# 	Change =  1.438e-06
# __________________________________________
# TF Iteration 45
# 	μ = 3.696797364e-01, change: 1.064037747e-12 (converged=True)
# 	φe Err =       -inf, φe change =  1.362e-11
# 	ne Err =  6.928e-12, ne change =  3.812e-14
# 	Q =  7.822e-11 -> -2.578e-10,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.437e+00 (converged=False)
# 	Change =  9.020e-12
# Settin up and solving empty atom
# ________________________
# Generating NPA
# 	Intializing grid
# Initializing, True
# Initializing
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# Initialized
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  1.938e-01
# 	ne Err =  2.267e-01, ne change =  4.358e-01
# 	Q =  0.000e+00 ->  5.772e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  6.069e-01
# __________________________________________
# TF Iteration 1
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  9.639e-02
# 	ne Err =  1.089e-01, ne change =  4.128e-01
# 	Q =  5.772e+02 ->  8.360e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  5.066e-01
# __________________________________________
# TF Iteration 2
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  6.872e-02
# 	ne Err =  4.431e-02, ne change =  3.495e-01
# 	Q =  8.360e+02 ->  9.342e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  4.513e-01
# __________________________________________
# TF Iteration 3
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  5.486e-02
# 	ne Err =  1.641e-02, ne change =  2.382e-01
# 	Q =  9.342e+02 ->  9.491e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  3.837e-01
# __________________________________________
# TF Iteration 4
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  4.633e-02
# 	ne Err =  1.758e-02, ne change =  1.338e-01
# 	Q =  9.491e+02 ->  9.215e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  2.925e-01
# __________________________________________
# TF Iteration 5
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  4.050e-02
# 	ne Err =  2.278e-02, ne change =  7.558e-02
# 	Q =  9.215e+02 ->  8.732e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  1.899e-01
# __________________________________________
# TF Iteration 6
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  3.625e-02
# 	ne Err =  2.501e-02, ne change =  5.408e-02
# 	Q =  8.732e+02 ->  8.160e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  1.021e-01
# __________________________________________
# TF Iteration 7
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  3.302e-02
# 	ne Err =  2.520e-02, ne change =  4.855e-02
# 	Q =  8.160e+02 ->  7.560e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  4.402e-02
# __________________________________________
# TF Iteration 8
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  3.051e-02
# 	ne Err =  2.430e-02, ne change =  4.674e-02
# 	Q =  7.560e+02 ->  6.966e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  4.781e-02
# __________________________________________
# TF Iteration 9
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  2.850e-02
# 	ne Err =  2.288e-02, ne change =  4.520e-02
# 	Q =  6.966e+02 ->  6.397e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  5.959e-02
# __________________________________________
# TF Iteration 25
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  1.943e-02
# 	ne Err =  5.922e-03, ne change =  2.282e-02
# 	Q =  1.761e+02 ->  1.632e+02,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  3.736e-02
# __________________________________________
# TF Iteration 50
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  2.638e-02
# 	ne Err =  1.702e-03, ne change =  1.751e-02
# 	Q =  4.083e+01 ->  3.890e+01,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  3.784e-02
# __________________________________________
# TF Iteration 75
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  4.178e-02
# 	ne Err =  3.599e-04, ne change =  1.475e-02
# 	Q =  1.565e+01 ->  1.533e+01,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  6.372e-02
# __________________________________________
# TF Iteration 100
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  1.349e-03
# 	ne Err =  1.155e-05, ne change =  1.596e-03
# 	Q =  1.293e+01 ->  1.292e+01,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  3.143e-03
# __________________________________________
# TF Iteration 125
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  1.890e-05
# 	ne Err =  1.944e-07, ne change =  2.213e-05
# 	Q =  1.285e+01 ->  1.285e+01,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  4.378e-05
# __________________________________________
# TF Iteration 150
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  2.814e-07
# 	ne Err =  3.097e-09, ne change =  3.289e-07
# 	Q =  1.285e+01 ->  1.285e+01,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  6.521e-07
# __________________________________________
# TF Iteration 175
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  4.269e-09
# 	ne Err =  4.857e-11, ne change =  4.987e-09
# 	Q =  1.285e+01 ->  1.285e+01,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  9.899e-09
# __________________________________________
# TF Iteration 200
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  6.914e-11
# 	ne Err =  7.559e-13, ne change =  7.784e-11
# 	Q =  1.285e+01 ->  1.285e+01,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  1.565e-10
# __________________________________________
# TF Iteration 204
# 	μ = 3.696956522e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =       -inf, φe change =  4.343e-11
# 	ne Err =  4.585e-13, ne change =  4.693e-11
# 	Q =  1.285e+01 ->  1.285e+01,
# 	Zstar guess =  2.437e+00. Current Zstar:  2.437e+00 (converged=True)
# 	Change =  9.576e-11
# Check combination is neutral: 13 = 1.284e+01
# /home/zach/plasma/average_atom/core/aa_types.py:131: RuntimeWarning: divide by zero encountered in log
#   log_nb_data = np.where(self.core_atom.nb==0, np.log(1e-20), np.log(self.core_atom.nb) )

# %%
from average_atom.core.physics import More_TF_Zbar
C_kin = 3/40 * (2*π)**2 * (3/π)**(2/3)
b = 1/4 * ((9*π**2)/(2*Z))**(1/3)
print(f"b =  {b:0.3f}")
x = lambda r: r/b # Approximate Solution of the Thomas–Fermi Equation for Free Positive Ions Aleksey A. Mavrin and Alexander V. Demura

 # 10.232/q**(1/3) * (1 - 0.917 * q**0.257)

Φ0_Mavrin_Demura = lambda x: ((1 + 1.81061 * x**(1/2) + 0.60112 * x) / (1 + 1.81061 * x**(1/2) + 1.39515 * x + 0.77112 * x**(3/2) + 0.21465 * x**2 + 0.04793 * x**(5/2)))**2
z = lambda x: np.log(1+x) 
η0_Mavrin_Demura = lambda x: np.exp(z(x) + 0.3837 * z(x)**2 + 0.0892 * z(x)**3 - 0.0170 * z(x)**4) - 1
q = More_TF_Zbar(aa_CS.Z, n_from_rs(aa_CS.rs), aa_CS.Te)/Z
x0 = (16/π * (1-q)/q)**(2/3)
k = -Φ0_Mavrin_Demura(x0)/η0_Mavrin_Demura(x0)
Φ_Mavrin_Demura = lambda x: Φ0_Mavrin_Demura(x) + k * η0_Mavrin_Demura(x)  
n_Mavrin_Demura = lambda r: Z/(4*π*b**3) * (Φ_Mavrin_Demura(x(r))/x(r) )**1.5


fig, ax = plt.subplots()

geom_factor = 4*π*aa_CS.grid.xs**2
ax.plot(aa_CS.core_atom.grid.xs, geom_factor*aa_CS.core_atom.ne)
ax.plot(aa_CS.core_atom.grid.xs, geom_factor*n_Mavrin_Demura(aa_CS.core_atom.grid.xs))
ax.plot(aa_CS.core_atom.grid.xs, geom_factor*n_Roberts(aa_CS.core_atom.grid.xs),'--' )
ax.plot(aa_CS.core_atom.grid.xs, geom_factor*n_Csavinszky(aa_CS.core_atom.grid.xs),':' )

ax.set_yscale('symlog')
# ax.set_xscale('log')
# Out:
# b =  0.377
# /tmp/ipykernel_35532/728016036.py:16: RuntimeWarning: invalid value encountered in power
#   n_Mavrin_Demura = lambda r: Z/(4*π*b**3) * (Φ_Mavrin_Demura(x(r))/x(r) )**1.5

# %%
from average_atom.core.physics import More_TF_Zbar
C_kin = 3/40 * (2*π)**2 * (3/π)**(2/3)
b = 1/4 * ((9*π**2)/(2*Z))**(1/3)
print(f"b =  {b:0.3f}")
x = lambda r: r/b # Approximate Solution of the Thomas–Fermi Equation for Free Positive Ions Aleksey A. Mavrin and Alexander V. Demura

η_Roberts = 1.905
Φ_Roberts = lambda x: (1+η_Roberts*np.sqrt(x))*np.exp(-η_Roberts*np.sqrt(x))
n_Roberts_func = lambda r: (5/3*C_kin)**(-1.5) * (Z/r*Φ_Roberts(x(r)))**1.5
Φ_Csavinszky = lambda x: ( 0.7111 * np.exp(- 0.175 * x) + 0.2889 * np.exp(-9.5*0.175 * x))**2
n_Csavinszky_func = lambda r: Z/(4*π*b**3) * (Φ_Csavinszky(x(r))/x(r))**1.5

Φ0_Mavrin_Demura = lambda x: ((1 + 1.81061 * x**(1/2) + 0.60112 * x) / (1 + 1.81061 * x**(1/2) + 1.39515 * x + 0.77112 * x**(3/2) + 0.21465 * x**2 + 0.04793 * x**(5/2)))**2
z = lambda x: np.log(1+x) 
η0_Mavrin_Demura = lambda x: np.exp(z(x) + 0.3837 * z(x)**2 + 0.0892 * z(x)**3 - 0.0170 * z(x)**4) - 1
q = More_TF_Zbar(aa_CS.Z, n_from_rs(aa_CS.rs), aa_CS.Te)/Z
x0_func = lambda q: 10.232/q**(1/3) * (1 - 0.917 * q**0.257) if q<=0.45 else 2.960* ((1-q)/q)**(2/3)
x0 = x0_func(q)
k = -Φ0_Mavrin_Demura(x0)/η0_Mavrin_Demura(x0)
Φ_Mavrin_Demura = lambda x: Φ0_Mavrin_Demura(x) + k * η0_Mavrin_Demura(x)  
n_Mavrin_Demura_func = lambda r: np.nan_to_num(Z/(4*π*b**3) * (Φ_Mavrin_Demura(x(r))/x(r) )**1.5)

n_Roberts = n_Roberts_func(aa_CS.core_atom.grid.xs)
n_Csavinszky = n_Csavinszky_func(aa_CS.core_atom.grid.xs)
n_Mavrin_Demura = n_Mavrin_Demura_func(aa_CS.core_atom.grid.xs)

N_Roberts = aa_CS.core_atom.grid.integrate_f(n_Roberts)
N_Csavinszky = aa_CS.core_atom.grid.integrate_f(n_Csavinszky)
N_Mavrin_Demura = aa_CS.core_atom.grid.integrate_f(n_Mavrin_Demura)

print(f"N_R = {N_Roberts:0.3f}, N_C = {N_Csavinszky:0.3f}, N_MD = {N_Mavrin_Demura:0.3f}")


fig, ax = plt.subplots()

geom_factor = 4*π*aa_CS.grid.xs**2
ax.plot(aa_CS.core_atom.grid.xs, geom_factor*aa_CS.core_atom.ne)
ax.plot(aa_CS.core_atom.grid.xs, geom_factor*n_Roberts)
ax.plot(aa_CS.core_atom.grid.xs, geom_factor*n_Csavinszky)
ax.plot(aa_CS.core_atom.grid.xs, geom_factor*n_Mavrin_Demura)

# ax.plot(aa_CS.core_atom.grid.xs, geom_factor*(aa_CS.core_atom.nf))
# ax.plot(aa_CS.core_atom.grid.xs, geom_factor*(aa_CS.core_atom.ne - n_Roberts ))
# ax.plot(aa_CS.core_atom.grid.xs, geom_factor*(aa_CS.core_atom.ne - n_Csavinszky ))
# ax.plot(aa_CS.core_atom.grid.xs, geom_factor*(aa_CS.core_atom.ne - n_Mavrin_Demura ))

ax.set_yscale('symlog', linthresh=1e-1)
ax.set_xscale('log')
# Out:
# b =  0.377
# N_R = 11.626, N_C = 12.567, N_MD = 11.668
