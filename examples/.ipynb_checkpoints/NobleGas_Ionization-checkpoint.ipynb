# %%
import numpy as np
from pandas import read_csv

# from average_atom.core.average_atom_new import AverageAtom as AA
from average_atom.core.aa_types import AverageAtomFactory
from average_atom.core.misc import jacobi_relaxation, sor
from average_atom.core.grids import NonUniformGrid
from average_atom.core.physics import ThomasFermi, FermiDirac

import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

plt.rcParams.update({'font.size': 10})
plt.rcParams["figure.figsize"] = (5,3.5)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14

color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
# Aluminum
name='Xe'
Z, A = 54, 131.293

ni_cc = 1.249e20
ni_AU = ni_cc*invcc_to_AU
rs = rs_from_n(ni_AU)
R  = 10*rs

Ti_eV = 1
Te_eV = 1

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

aa_ZJ  = AverageAtomFactory.create_model("ZJ_ISModel", Z, A, Ti_AU, Te_AU, rs, R, name=name, ignore_vxc=True, Npoints=2000)#
aa_CS  = AverageAtomFactory.create_model("TFStarret2014", Z, A, Ti_AU, Te_AU, rs, R, name=name, ignore_vxc=True, rmin=1e-4, Npoints=2000)#, grid_spacing='quadratic',N_stencil_oneside=3)
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 1.165
# 	Intializing grid
# Initializing, True
# Initializing
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# Initialized
# ________________________
# Generating NPA
# /home/zach/plasma/average_atom/core/average_atom_new.py:256: RuntimeWarning: invalid value encountered in power
#   nb_Mavrin_Demura_func = lambda r: np.nan_to_num(self.Z/(4*π*r_TF**3) * (Φ_Mavrin_Demura(x(r))/x(r) )**1.5)
# Using More TF fit for initial Zstar = 1.165
# 	Intializing grid
# Initializing, False
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 1.165
# 	Intializing grid
# Initializing, True
# Initializing
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# Initialized

# %%
aa_ZJ.solve(verbose=True, picard_alpha=0.2)
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = -3.123004592e+00, change: 2.186131023e+01 (converged=False)
# 	φe Err =  2.093e-11, φe change =  9.910e-01
# 	ne Err =  1.641e-01, ne change =  6.245e-05
# 	Q =  0.000e+00 -> -3.842e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  1.943e+00
# __________________________________________
# TF Iteration 1
# 	μ = -3.118861368e+00, change: 1.326678846e-03 (converged=False)
# 	φe Err =  1.897e-11, φe change =  7.654e-02
# 	ne Err =  2.326e-01, ne change =  1.463e-04
# 	Q = -3.842e+02 -> -3.003e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  9.330e-02
# __________________________________________
# TF Iteration 2
# 	μ = -3.115048699e+00, change: 1.222455482e-03 (converged=False)
# 	φe Err =  1.922e-11, φe change =  2.353e-02
# 	ne Err =  1.663e-01, ne change =  5.335e-05
# 	Q = -3.003e+02 -> -2.336e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  2.245e-02
# __________________________________________
# TF Iteration 3
# 	μ = -3.111808508e+00, change: 1.040173317e-03 (converged=False)
# 	φe Err =  1.975e-11, φe change =  2.666e-02
# 	ne Err =  1.109e-01, ne change =  2.765e-05
# 	Q = -2.336e+02 -> -1.813e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  3.000e-02
# __________________________________________
# TF Iteration 4
# 	μ = -3.109224526e+00, change: 8.303796634e-04 (converged=False)
# 	φe Err =  1.970e-11, φe change =  1.903e-02
# 	ne Err =  8.421e-02, ne change =  6.416e-05
# 	Q = -1.813e+02 -> -1.406e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  2.286e-02
# __________________________________________
# TF Iteration 5
# 	μ = -3.107240337e+00, change: 6.381619317e-04 (converged=False)
# 	φe Err =  2.001e-11, φe change =  1.045e-02
# 	ne Err =  7.613e-02, ne change =  7.017e-05
# 	Q = -1.406e+02 -> -1.090e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  1.313e-02
# __________________________________________
# TF Iteration 6
# 	μ = -3.105698265e+00, change: 4.962834817e-04 (converged=False)
# 	φe Err =  2.040e-11, φe change =  5.140e-03
# 	ne Err =  6.927e-02, ne change =  5.881e-05
# 	Q = -1.090e+02 -> -8.445e+01,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  5.482e-03
# __________________________________________
# TF Iteration 7
# 	μ = -3.104432177e+00, change: 4.076662348e-04 (converged=False)
# 	φe Err =  1.949e-11, φe change =  3.874e-03
# 	ne Err =  5.919e-02, ne change =  4.208e-05
# 	Q = -8.445e+01 -> -6.528e+01,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  1.204e-03
# __________________________________________
# TF Iteration 8
# 	μ = -3.103330088e+00, change: 3.550050118e-04 (converged=False)
# 	φe Err =  2.037e-11, φe change =  3.567e-03
# 	ne Err =  4.813e-02, ne change =  2.688e-05
# 	Q = -6.528e+01 -> -5.020e+01,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  1.028e-03
# __________________________________________
# TF Iteration 9
# 	μ = -3.102333954e+00, change: 3.209886202e-04 (converged=False)
# 	φe Err =  2.115e-11, φe change =  2.937e-03
# 	ne Err =  3.826e-02, ne change =  1.560e-05
# 	Q = -5.020e+01 -> -3.830e+01,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  1.236e-03
# __________________________________________
# TF Iteration 25
# 	μ = -1.076632019e+00, change: 2.266348342e-04 (converged=False)
# 	φe Err =  2.005e-11, φe change =  2.419e-05
# 	ne Err =  1.190e-03, ne change =  1.017e-07
# 	Q =  2.475e+00 ->  2.755e+00,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=True)
# 	Change =  1.731e-04
# __________________________________________
# TF Iteration 50
# 	μ = -5.449714267e-01, change: 1.938634446e-01 (converged=False)
# 	φe Err =  1.939e-11, φe change =  9.367e-07
# 	ne Err =  5.403e-03, ne change =  3.666e-09
# 	Q =  2.867e+00 ->  2.760e+00,
# 	Zstar guess =  2.865e+00. Current Zstar:  1.272e+00 (converged=False)
# 	Change =  1.509e-01
# __________________________________________
# TF Iteration 75
# 	μ = -3.619628082e-01, change: 1.914937870e-04 (converged=False)
# 	φe Err =  1.933e-11, φe change =  7.886e-06
# 	ne Err =  4.704e-05, ne change =  2.116e-08
# 	Q =  1.881e+00 ->  1.821e+00,
# 	Zstar guess =  1.881e+00. Current Zstar:  1.332e+00 (converged=False)
# 	Change =  1.438e-04
# __________________________________________
# TF Iteration 100
# 	μ = -2.194852646e-01, change: 1.335874341e-01 (converged=False)
# 	φe Err =  1.902e-11, φe change =  2.789e-07
# 	ne Err =  1.578e-03, ne change =  1.878e-10
# 	Q =  1.344e+00 ->  1.334e+00,
# 	Zstar guess =  1.404e+00. Current Zstar:  1.340e+00 (converged=False)
# 	Change =  1.010e-01
# __________________________________________
# TF Iteration 125
# 	μ = -1.792173567e-01, change: 6.242664542e-05 (converged=False)
# 	φe Err =  1.915e-11, φe change =  4.235e-06
# 	ne Err =  2.781e-05, ne change =  8.609e-09
# 	Q =  6.263e-01 ->  6.217e-01,
# 	Zstar guess =  1.039e+00. Current Zstar:  1.333e+00 (converged=False)
# 	Change =  4.871e-05
# __________________________________________
# TF Iteration 150
# 	μ = -1.570621441e-01, change: 2.758545120e-02 (converged=False)
# 	φe Err =  1.953e-11, φe change =  5.165e-08
# 	ne Err =  2.090e-04, ne change =  1.491e-10
# 	Q =  2.765e-01 ->  2.236e-01,
# 	Zstar guess =  9.890e-01. Current Zstar:  1.384e+00 (converged=False)
# 	Change =  1.978e-02
# __________________________________________
# TF Iteration 175
# 	μ = -1.523511909e-01, change: 7.385671180e-06 (converged=True)
# 	φe Err =  1.933e-11, φe change =  5.147e-07
# 	ne Err =  1.097e-04, ne change =  1.089e-09
# 	Q =  8.332e-02 ->  4.000e-01,
# 	Zstar guess =  9.746e-01. Current Zstar:  1.065e+00 (converged=False)
# 	Change =  5.768e-06
# __________________________________________
# TF Iteration 200
# 	μ = -1.501350981e-01, change: 3.590287162e-03 (converged=False)
# 	φe Err =  1.963e-11, φe change =  6.899e-09
# 	ne Err =  4.437e-05, ne change =  2.310e-11
# 	Q =  3.671e-02 ->  1.266e-01,
# 	Zstar guess =  9.746e-01. Current Zstar:  9.746e-01 (converged=True)
# 	Change =  2.543e-03
# __________________________________________
# TF Iteration 225
# 	μ = -1.495795824e-01, change: 9.142230297e-07 (converged=True)
# 	φe Err =  1.897e-11, φe change =  6.349e-08
# 	ne Err =  8.696e-07, ne change =  1.374e-10
# 	Q =  1.063e-02 ->  1.093e-02,
# 	Zstar guess =  9.739e-01. Current Zstar:  9.739e-01 (converged=True)
# 	Change =  7.136e-07
# __________________________________________
# TF Iteration 250
# 	μ = -1.492909582e-01, change: 3.802008235e-04 (converged=False)
# 	φe Err =  1.936e-11, φe change =  7.030e-10
# 	ne Err =  2.710e-06, ne change =  2.297e-12
# 	Q =  3.826e-03 ->  3.710e-03,
# 	Zstar guess =  9.740e-01. Current Zstar:  9.740e-01 (converged=False)
# 	Change =  2.689e-04
# __________________________________________
# TF Iteration 275
# 	μ = -1.492317206e-01, change: 9.344639751e-08 (converged=True)
# 	φe Err =  1.903e-11, φe change =  6.512e-09
# 	ne Err =  7.245e-08, ne change =  1.405e-11
# 	Q =  1.072e-03 ->  1.065e-03,
# 	Zstar guess =  9.740e-01. Current Zstar:  9.740e-01 (converged=False)
# 	Change =  7.297e-08
# __________________________________________
# TF Iteration 300
# 	μ = -1.492022634e-01, change: 3.873207518e-05 (converged=False)
# 	φe Err =  1.980e-11, φe change =  6.816e-11
# 	ne Err =  2.771e-07, ne change =  2.008e-13
# 	Q =  3.896e-04 ->  3.930e-04,
# 	Zstar guess =  9.740e-01. Current Zstar:  9.740e-01 (converged=True)
# 	Change =  2.739e-05
# __________________________________________
# TF Iteration 325
# 	μ = -1.491962362e-01, change: 9.516462729e-09 (converged=True)
# 	φe Err =  1.995e-11, φe change =  6.650e-10
# 	ne Err =  1.848e-08, ne change =  1.447e-12
# 	Q =  1.092e-04 ->  1.443e-04,
# 	Zstar guess =  9.740e-01. Current Zstar:  9.740e-01 (converged=False)
# 	Change =  7.433e-09
# __________________________________________
# TF Iteration 350
# 	μ = -1.491932521e-01, change: 4.003636743e-06 (converged=True)
# 	φe Err =  1.879e-11, φe change =  8.614e-12
# 	ne Err =  2.781e-08, ne change =  2.978e-14
# 	Q =  4.033e-05 ->  9.135e-06,
# 	Zstar guess =  9.740e-01. Current Zstar:  9.740e-01 (converged=True)
# 	Change =  2.831e-06
# __________________________________________
# TF Iteration 375
# 	μ = -1.491926257e-01, change: 9.757837871e-10 (converged=True)
# 	φe Err =  1.954e-11, φe change =  6.969e-11
# 	ne Err =  6.242e-10, ne change =  1.458e-13
# 	Q =  1.114e-05 ->  1.064e-05,
# 	Zstar guess =  9.740e-01. Current Zstar:  9.740e-01 (converged=True)
# 	Change =  7.638e-10
# __________________________________________
# TF Iteration 400
# 	μ = -1.491923179e-01, change: 4.036265545e-07 (converged=True)
# 	φe Err =  1.898e-11, φe change =  3.613e-12
# 	ne Err =  2.865e-09, ne change =  7.201e-15
# 	Q =  4.059e-06 ->  3.826e-06,
# 	Zstar guess =  9.740e-01. Current Zstar:  9.740e-01 (converged=True)
# 	Change =  2.854e-07
# __________________________________________
# TF Iteration 425
# 	μ = -1.491922551e-01, change: 9.908363019e-11 (converged=True)
# 	φe Err =  1.922e-11, φe change =  7.614e-12
# 	ne Err =  1.051e-10, ne change =  2.313e-14
# 	Q =  1.136e-06 ->  1.226e-06,
# 	Zstar guess =  9.740e-01. Current Zstar:  9.740e-01 (converged=True)
# 	Change =  7.809e-11
# __________________________________________
# TF Iteration 427
# 	μ = -1.491922551e-01, change: 9.380740629e-11 (converged=True)
# 	φe Err =  1.925e-11, φe change =  2.788e-12
# 	ne Err =  8.987e-11, ne change =  1.109e-14
# 	Q =  1.226e-06 ->  1.163e-06,
# 	Zstar guess =  9.740e-01. Current Zstar:  9.740e-01 (converged=True)
# 	Change =  6.760e-11
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 8.774e+00
# QUIT: Total error infinite.
# Exiting status 1, reverting to best index so far: 0
# Final iter:21, Total Error: 8.774e+00
# /home/zach/plasma/average_atom/core/average_atom_new.py:496: RuntimeWarning: divide by zero encountered in divide
#   rel_errs = (np.abs(A @ φe - b)[:-1]/b[:-1])
# /home/zach/plasma/hnc/hnc/hnc.py:648: RuntimeWarning: overflow encountered in exp
#   hnc_err = np.linalg.norm(- 1 - self.h_r_matrix   + np.exp( -self.βu_r_matrix + self.h_r_matrix - self.c_r_matrix ))/np.sqrt(self.N_bins*self.N_species**2)
# /home/zach/plasma/hnc/hnc/hnc.py:432: RuntimeWarning: overflow encountered in exp
#   tot_eqn =  1 + h_r_matrix  - np.exp(-self.βu_s_r_matrix + h_r_matrix - c_s_r_matrix )
# /home/zach/plasma/hnc/hnc/hnc.py:518: RuntimeWarning: overflow encountered in exp
#   h_r_matrix = -1 + np.exp(γs_r_matrix - self.βu_s_r_matrix) # 2. γ_r,u_s_r  -> h_r   (HNC)
# /home/zach/plasma/hnc/hnc/hnc.py:656: RuntimeWarning: invalid value encountered in subtract
#   Δ_err = np.array(self.tot_err_list[-iters_to_check:-2]) - np.array(self.tot_err_list[-iters_to_check + 1:-1])

# %%
aa_CS.solve(verbose=True, picard_alpha=0.1)
# Out:
# Solving core.
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = -4.017906497e+00, change: 2.841225483e+01 (converged=False)
# 	φe Err =  3.105e-11, φe change =  9.920e-01
# 	ne Err =  8.835e-02, ne change =  8.145e-05
# 	Q =  0.000e+00 -> -1.952e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.165e+00 (converged=False)
# 	Change =  1.955e+00
# __________________________________________
# TF Iteration 1
# 	μ = -4.017902235e+00, change: 1.060891010e-06 (converged=True)
# 	φe Err =  2.976e-11, φe change =  4.253e-02
# 	ne Err =  1.611e-01, ne change =  6.690e-05
# 	Q = -1.952e+02 -> -1.727e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.048e+00 (converged=False)
# 	Change =  4.965e-02
# __________________________________________
# TF Iteration 2
# 	μ = -4.017897359e+00, change: 1.213536528e-06 (converged=True)
# 	φe Err =  3.040e-11, φe change =  3.619e-03
# 	ne Err =  1.434e-01, ne change =  6.054e-05
# 	Q = -1.727e+02 -> -1.525e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  9.434e-01 (converged=False)
# 	Change =  8.915e-04
# __________________________________________
# TF Iteration 3
# 	μ = -4.017887564e+00, change: 2.437643370e-06 (converged=True)
# 	φe Err =  3.034e-11, φe change =  8.152e-03
# 	ne Err =  1.158e-01, ne change =  5.556e-05
# 	Q = -1.525e+02 -> -1.345e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  8.490e-01 (converged=False)
# 	Change =  8.581e-03
# __________________________________________
# TF Iteration 4
# 	μ = -4.017859905e+00, change: 6.883999981e-06 (converged=True)
# 	φe Err =  3.205e-11, φe change =  8.425e-03
# 	ne Err =  9.052e-02, ne change =  5.107e-05
# 	Q = -1.345e+02 -> -1.185e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  7.641e-01 (converged=False)
# 	Change =  9.381e-03
# __________________________________________
# TF Iteration 5
# 	μ = -4.017740788e+00, change: 2.964703900e-05 (converged=False)
# 	φe Err =  3.068e-11, φe change =  7.044e-03
# 	ne Err =  7.194e-02, ne change =  4.683e-05
# 	Q = -1.185e+02 -> -1.045e+02,
# 	Zstar guess =  1.165e+00. Current Zstar:  6.877e-01 (converged=False)
# 	Change =  8.072e-03
# __________________________________________
# TF Iteration 6
# 	μ = -4.016600312e+00, change: 2.838598659e-04 (converged=False)
# 	φe Err =  2.916e-11, φe change =  5.237e-03
# 	ne Err =  6.099e-02, ne change =  4.275e-05
# 	Q = -1.045e+02 -> -9.210e+01,
# 	Zstar guess =  1.165e+00. Current Zstar:  6.190e-01 (converged=False)
# 	Change =  6.311e-03
# __________________________________________
# TF Iteration 7
# 	μ = 9.577094305e-02, change: 1.023843782e+00 (converged=False)
# 	φe Err =  2.857e-11, φe change =  3.546e-03
# 	ne Err =  8.593e-02, ne change =  3.885e-05
# 	Q = -9.210e+01 -> -8.121e+01,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.571e-01 (converged=False)
# 	Change =  1.028e+00
# __________________________________________
# TF Iteration 8
# 	μ = -5.393281358e-03, change: 1.056314381e+00 (converged=False)
# 	φe Err =  3.017e-11, φe change =  2.221e-03
# 	ne Err =  8.680e-02, ne change =  3.647e-05
# 	Q = -8.121e+01 -> -7.362e+01,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.880e+01 (converged=False)
# 	Change =  1.057e+00
# __________________________________________
# TF Iteration 9
# 	μ = 6.701862688e-02, change: 1.342631757e+01 (converged=False)
# 	φe Err =  3.075e-11, φe change =  3.994e-03
# 	ne Err =  7.128e-02, ne change =  3.223e-05
# 	Q = -7.362e+01 -> -6.592e+01,
# 	Zstar guess =  1.165e+00. Current Zstar:  2.021e+01 (converged=False)
# 	Change =  1.081e+00
# __________________________________________
# TF Iteration 25
# 	μ = -2.317677473e-03, change: 1.654881821e+00 (converged=False)
# 	φe Err =  2.971e-11, φe change =  1.021e-04
# 	ne Err =  9.240e-03, ne change =  5.430e-06
# 	Q = -1.372e+01 -> -1.238e+01,
# 	Zstar guess =  1.165e+00. Current Zstar:  6.496e+01 (converged=False)
# 	Change =  1.384e+00
# __________________________________________
# TF Iteration 50
# 	μ = -1.190851338e-01, change: 2.441976062e-02 (converged=False)
# 	φe Err =  2.967e-11, φe change =  4.282e-06
# 	ne Err =  8.210e-04, ne change =  3.920e-07
# 	Q = -1.150e+00 -> -1.048e+00,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.007e+01 (converged=False)
# 	Change =  1.706e-02
# __________________________________________
# TF Iteration 75
# 	μ = -1.531418044e-01, change: 5.040726425e-03 (converged=False)
# 	φe Err =  3.162e-11, φe change =  1.854e-07
# 	ne Err =  1.039e-04, ne change =  2.791e-08
# 	Q = -1.269e-01 -> -1.173e-01,
# 	Zstar guess =  1.165e+00. Current Zstar:  1.586e+00 (converged=False)
# 	Change =  3.555e-03
# __________________________________________
# TF Iteration 100
# 	μ = -1.630097064e-01, change: 1.148324966e-03 (converged=False)
# 	φe Err =  3.043e-11, φe change =  3.003e-08
# 	ne Err =  2.031e-05, ne change =  1.976e-09
# 	Q = -2.099e-02 -> -1.963e-02,
# 	Zstar guess =  1.165e+00. Current Zstar:  6.762e-01 (converged=False)
# 	Change =  8.116e-04
# __________________________________________
# TF Iteration 125
# 	μ = -1.645982583e-01, change: 1.834449711e-04 (converged=False)
# 	φe Err =  3.098e-11, φe change =  9.443e-09
# 	ne Err =  5.854e-06, ne change =  1.428e-10
# 	Q = -3.400e-03 -> -3.176e-03,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.604e-01 (converged=False)
# 	Change =  1.297e-04
# __________________________________________
# TF Iteration 150
# 	μ = -1.649602063e-01, change: 3.491433421e-05 (converged=False)
# 	φe Err =  2.831e-11, φe change =  2.956e-09
# 	ne Err =  1.750e-06, ne change =  1.004e-11
# 	Q = -6.399e-04 -> -5.984e-04,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.433e-01 (converged=False)
# 	Change =  2.469e-05
# __________________________________________
# TF Iteration 175
# 	μ = -1.646721583e-01, change: 1.686319505e-04 (converged=False)
# 	φe Err =  2.991e-11, φe change =  7.679e-08
# 	ne Err =  9.590e-06, ne change =  9.966e-12
# 	Q =  4.400e-04 ->  5.181e-04,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.419e-01 (converged=False)
# 	Change =  1.193e-04
# __________________________________________
# TF Iteration 200
# 	μ = -1.644500712e-01, change: 1.464196489e-05 (converged=False)
# 	φe Err =  3.067e-11, φe change =  2.097e-09
# 	ne Err =  7.745e-07, ne change =  1.304e-13
# 	Q =  2.754e-04 ->  2.586e-04,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.476e-01 (converged=False)
# 	Change =  1.036e-05
# __________________________________________
# TF Iteration 225
# 	μ = -1.644240255e-01, change: 2.276466912e-06 (converged=True)
# 	φe Err =  3.050e-11, φe change =  1.706e-10
# 	ne Err =  1.508e-07, ne change =  7.579e-15
# 	Q =  5.085e-05 ->  4.740e-05,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.488e-01 (converged=False)
# 	Change =  1.610e-06
# __________________________________________
# TF Iteration 250
# 	μ = -1.644198548e-01, change: 3.747927533e-07 (converged=True)
# 	φe Err =  3.195e-11, φe change =  2.611e-11
# 	ne Err =  6.239e-08, ne change =  1.018e-15
# 	Q =  8.680e-06 ->  8.087e-06,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.490e-01 (converged=False)
# 	Change =  2.650e-07
# __________________________________________
# TF Iteration 275
# 	μ = -1.644191634e-01, change: 6.272534314e-08 (converged=True)
# 	φe Err =  3.148e-11, φe change =  6.466e-12
# 	ne Err =  2.876e-08, ne change =  1.719e-15
# 	Q =  1.500e-06 ->  1.400e-06,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.491e-01 (converged=False)
# 	Change =  4.436e-08
# __________________________________________
# TF Iteration 300
# 	μ = -1.644190470e-01, change: 1.067163580e-08 (converged=True)
# 	φe Err =  3.187e-11, φe change =  5.288e-12
# 	ne Err =  1.362e-08, ne change =  8.546e-16
# 	Q =  2.757e-07 ->  2.581e-07,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.491e-01 (converged=False)
# 	Change =  7.547e-09
# __________________________________________
# TF Iteration 325
# 	μ = -1.644190270e-01, change: 1.875511857e-09 (converged=True)
# 	φe Err =  3.013e-11, φe change =  1.687e-12
# 	ne Err =  6.553e-09, ne change =  1.632e-15
# 	Q =  5.753e-08 ->  5.424e-08,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.491e-01 (converged=False)
# 	Change =  1.327e-09
# __________________________________________
# TF Iteration 350
# 	μ = -1.644190234e-01, change: 3.547617755e-10 (converged=True)
# 	φe Err =  2.937e-11, φe change =  8.115e-12
# 	ne Err =  3.192e-09, ne change =  1.213e-15
# 	Q =  1.471e-08 ->  1.400e-08,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.491e-01 (converged=False)
# 	Change =  2.548e-10
# __________________________________________
# TF Iteration 375
# 	μ = -1.644190227e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  2.917e-11, φe change =  3.792e-12
# 	ne Err =  1.570e-09, ne change =  1.642e-15
# 	Q =  4.879e-09 ->  4.724e-09,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.491e-01 (converged=False)
# 	Change =  1.836e-12
# __________________________________________
# TF Iteration 400
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.024e-11, φe change =  5.439e-12
# 	ne Err =  7.784e-10, ne change =  5.283e-16
# 	Q =  2.332e-09 ->  2.280e-09,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.491e-01 (converged=False)
# 	Change =  2.627e-12
# __________________________________________
# TF Iteration 425
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.038e-11, φe change =  4.397e-12
# 	ne Err =  3.885e-10, ne change =  2.133e-15
# 	Q =  1.521e-09 ->  1.507e-09,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.491e-01 (converged=False)
# 	Change =  2.048e-12
# __________________________________________
# TF Iteration 450
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.030e-11, φe change =  1.321e-14
# 	ne Err =  1.950e-10, ne change =  1.276e-16
# 	Q =  1.300e-09 ->  1.295e-09,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.491e-01 (converged=False)
# 	Change =  2.182e-15
# __________________________________________
# TF Iteration 475
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.030e-11, φe change =  6.172e-15
# 	ne Err =  9.837e-11, ne change =  5.036e-17
# 	Q =  1.194e-09 ->  1.191e-09,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.491e-01 (converged=False)
# 	Change =  1.401e-15
# __________________________________________
# TF Iteration 476
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.030e-11, φe change =  6.172e-15
# 	ne Err =  9.837e-11, ne change =  5.036e-17
# 	Q =  1.194e-09 ->  1.191e-09,
# 	Zstar guess =  1.165e+00. Current Zstar:  5.491e-01 (converged=False)
# 	Change =  1.401e-15
# Settin up and solving empty atom
# ________________________
# Generating NPA
# 	Intializing grid
# Initializing, True
# Initializing
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# Initialized
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  2.542e-04, φe change =  2.921e-01
# 	ne Err =  8.362e-01, ne change =  7.400e-02
# 	Q =  0.000e+00 ->  5.903e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  3.531e-01
# __________________________________________
# TF Iteration 1
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.148e-04, φe change =  1.488e-01
# 	ne Err =  8.283e-01, ne change =  7.411e-02
# 	Q =  5.903e+01 ->  6.460e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  2.186e-01
# __________________________________________
# TF Iteration 2
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.448e-04, φe change =  1.081e-01
# 	ne Err =  8.240e-01, ne change =  7.408e-02
# 	Q =  6.460e+01 ->  6.969e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.797e-01
# __________________________________________
# TF Iteration 3
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.275e-04, φe change =  8.814e-02
# 	ne Err =  7.992e-01, ne change =  7.405e-02
# 	Q =  6.969e+01 ->  7.434e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.606e-01
# __________________________________________
# TF Iteration 4
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.397e-04, φe change =  7.627e-02
# 	ne Err =  7.711e-01, ne change =  7.400e-02
# 	Q =  7.434e+01 ->  7.850e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.491e-01
# __________________________________________
# TF Iteration 5
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.676e-04, φe change =  6.847e-02
# 	ne Err =  7.396e-01, ne change =  7.394e-02
# 	Q =  7.850e+01 ->  8.223e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.416e-01
# __________________________________________
# TF Iteration 6
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.594e-04, φe change =  6.307e-02
# 	ne Err =  7.047e-01, ne change =  7.387e-02
# 	Q =  8.223e+01 ->  8.556e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.363e-01
# __________________________________________
# TF Iteration 7
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.280e-04, φe change =  5.921e-02
# 	ne Err =  6.664e-01, ne change =  7.378e-02
# 	Q =  8.556e+01 ->  8.854e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.325e-01
# __________________________________________
# TF Iteration 8
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.606e-04, φe change =  5.643e-02
# 	ne Err =  6.251e-01, ne change =  7.367e-02
# 	Q =  8.854e+01 ->  9.119e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.298e-01
# __________________________________________
# TF Iteration 9
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.305e-04, φe change =  5.444e-02
# 	ne Err =  5.810e-01, ne change =  7.354e-02
# 	Q =  9.119e+01 ->  9.354e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.278e-01
# __________________________________________
# TF Iteration 25
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  4.071e-04, φe change =  7.308e-02
# 	ne Err =  1.485e-01, ne change =  5.428e-02
# 	Q =  1.052e+02 ->  1.048e+02,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.291e-01
# __________________________________________
# TF Iteration 50
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  5.235e-04, φe change =  2.787e-02
# 	ne Err =  4.164e-01, ne change =  4.997e-02
# 	Q =  6.813e+01 ->  6.553e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  6.369e-02
# __________________________________________
# TF Iteration 75
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  3.304e-04, φe change =  6.971e-02
# 	ne Err =  6.672e-02, ne change =  1.656e-02
# 	Q =  7.405e+01 ->  7.432e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  8.844e-02
# __________________________________________
# TF Iteration 100
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  7.408e-04, φe change =  2.151e-02
# 	ne Err =  7.203e-03, ne change =  4.272e-03
# 	Q =  7.054e+01 ->  7.052e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  2.613e-02
# __________________________________________
# TF Iteration 125
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.434e-03, φe change =  7.219e-03
# 	ne Err =  1.328e-03, ne change =  1.242e-04
# 	Q =  7.151e+01 ->  7.150e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  7.737e-03
# __________________________________________
# TF Iteration 150
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.404e-03, φe change =  1.417e-03
# 	ne Err =  5.523e-04, ne change =  8.730e-05
# 	Q =  7.130e+01 ->  7.130e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.581e-03
# __________________________________________
# TF Iteration 175
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.496e-03, φe change =  2.249e-04
# 	ne Err =  1.444e-04, ne change =  2.656e-05
# 	Q =  7.134e+01 ->  7.134e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  2.629e-04
# __________________________________________
# TF Iteration 200
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.306e-03, φe change =  2.620e-05
# 	ne Err =  2.912e-05, ne change =  6.184e-06
# 	Q =  7.133e+01 ->  7.133e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  3.342e-05
# __________________________________________
# TF Iteration 225
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.431e-03, φe change =  1.091e-06
# 	ne Err =  4.805e-06, ne change =  1.127e-06
# 	Q =  7.133e+01 ->  7.133e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.893e-06
# __________________________________________
# TF Iteration 250
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.359e-03, φe change =  6.752e-07
# 	ne Err =  5.853e-07, ne change =  1.659e-07
# 	Q =  7.133e+01 ->  7.133e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  8.835e-07
# __________________________________________
# TF Iteration 275
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.332e-03, φe change =  2.530e-07
# 	ne Err =  3.074e-08, ne change =  1.612e-08
# 	Q =  7.133e+01 ->  7.133e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  2.848e-07
# __________________________________________
# TF Iteration 300
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.311e-03, φe change =  6.202e-08
# 	ne Err =  1.145e-08, ne change =  9.830e-10
# 	Q =  7.133e+01 ->  7.133e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  6.610e-08
# __________________________________________
# TF Iteration 325
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.369e-03, φe change =  1.207e-08
# 	ne Err =  4.841e-09, ne change =  7.576e-10
# 	Q =  7.133e+01 ->  7.133e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  1.348e-08
# __________________________________________
# TF Iteration 350
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.377e-03, φe change =  1.888e-09
# 	ne Err =  1.240e-09, ne change =  2.336e-10
# 	Q =  7.133e+01 ->  7.133e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  2.218e-09
# __________________________________________
# TF Iteration 375
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.319e-03, φe change =  2.130e-10
# 	ne Err =  2.482e-10, ne change =  5.263e-11
# 	Q =  7.133e+01 ->  7.133e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  2.735e-10
# __________________________________________
# TF Iteration 396
# 	μ = -1.644190226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  1.334e-03, φe change =  7.947e-11
# 	ne Err =  6.479e-11, ne change =  1.284e-11
# 	Q =  7.133e+01 ->  7.133e+01,
# 	Zstar guess =  5.491e-01. Current Zstar:  5.491e-01 (converged=True)
# 	Change =  9.612e-11
# Check combination is neutral: 54 = 7.132e+01
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: nan
# QUIT: c_r is nan.
# Exiting status 1, reverting to best index so far: 0
# Final iter:1, Total Error: nan
# /home/zach/plasma/average_atom/core/aa_types.py:129: RuntimeWarning: invalid value encountered in log
#   log_nb_data = np.where(self.core_atom.nb==0, np.log(1e-20), np.log(self.core_atom.nb) )

# %%
# aa_CS.core_atom.ne_bar = 1e-12
# aa_CS.core_atom.make_plots()
aa_ZJ.make_plots()
# Out:
# (<Figure size 4000x1600 with 2 Axes>,
#  array([<Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$\\phi$ [A.U.]'>,
#         <Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$n$ [A.U.]'>],
#        dtype=object))

# %%
from importlib import reload
try:
    reload(plotting)
except NameError as e:
    from average_atom.core import plotting as plotting
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)
    
from average_atom.core.plotting import compare_aa, plot_convergence, plot_Uei, plot_Uii, plot_hii

# fig, axs = plot_Uei([aa_CS, aa_ZJ])
# fig, axs = plot_Uii([aa_CS, aa_ZJ])
# fig, axs = plot_hii([aa_CS, aa_ZJ])
# fig, axs = plot_Uei([ aa_ZJ])
# fig, axs = plot_Uii([ aa_ZJ])
# fig, axs = plot_hii([ aa_ZJ])
compare_aa([aa_ZJ])
# Out:
# array([<Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$4 \\pi r^2 n_e(r) $ [A.U.]'>,
#        <Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$4 \\pi r^2 n_e(r) $ [A.U.]'>],
#       dtype=object)

# %% [markdown]
# ### EOS

# %%
def get_E(aa):
    βVeff = aa.get_βVeff(aa.φe, aa.ne, aa.ne_bar)
    η = aa.μ/aa.Te - βVeff
    βU = aa.grid.integrate_f(βVeff*aa.ne)
    
    φ_from_e_only = aa.get_φe(-aa.ne)[0] 
    φ_from_i_only = aa.get_φe(aa.ρi)[0] + aa.φion 
    U = -aa.grid.integrate_f(aa.ne * (0.5*φ_from_e_only + φ_from_i_only))

    I_onehalf = FermiDirac.Ionehalf(η)
    I_threehalf = FermiDirac.Ithreehalf(η)
    
    K = (2*aa.Te)**1.5/(2*π**2) * aa.Te * aa.grid.integrate_f( I_threehalf)
    return U, K, (U + K)

def get_P(aa):
    P = (2*aa.Te)**2.5/(6*π**2) * FermiDirac.Ithreehalf(aa.μ/aa.Te)
    return P

def print_EOS(aa):
    Ee_pot, Ee_K, Ee = get_E(aa)
    P_e =  get_P(aa)
    print(f"Ee_pot_density = {Ee_pot*aa.ni_bar:0.3e} [au], Ee_K = {Ee_K*aa.ni_bar:0.3e} [au], Ee_tot = {Ee*aa.ni_bar:0.3e} [au]")
    print(f"P_e = {P_e:0.3e} [au], {P_e*AU_to_bar/1e6:0.3e} [Mbar]")
    print(f"Virial if {Ee_K:0.3e} = {3/2*P_e*aa.Vol - 0.5*Ee_pot:0.3e} --->  off by {100*Ee_K/(3/2*P_e*aa.Vol - 0.5*Ee_pot) - 100:0.3e} % ")
    
    print(f"\nβEe_pot/Z = {Ee_pot/aa.Te/aa.Z:0.3f}, βEe_K/Z = {Ee_K/aa.Te/aa.Z:0.3f}, βEe_tot/Z = {Ee/aa.Te/aa.Z:0.3f}")
    print(f"βP_e Ω/Z = {P_e*aa.Vol/aa.Te/aa.Z:0.3f}")
    # print(f"Virial if {Ee_K:0.3e} = {3/2*P_e*aa.Vol - 0.5*Ee_pot:0.3e}")

print_EOS(aa_ZJ)
# Out:
# Ee_pot_density = -2.857e-01 [au], Ee_K = 1.421e-01 [au], Ee_tot = -1.436e-01 [au]
# P_e = 1.911e-07 [au], 5.622e-05 [Mbar]
# Virial if 7.677e+03 = 7.719e+03 --->  off by -5.444e-01 %
#
# βEe_pot/Z = -7779.611, βEe_K/Z = 3868.636, βEe_tot/Z = -3910.974
# βP_e Ω/Z = 0.005
# /home/zach/plasma/average_atom/core/average_atom_new.py:496: RuntimeWarning: divide by zero encountered in divide
#   rel_errs = (np.abs(A @ φe - b)[:-1]/b[:-1])
# /home/zach/plasma/average_atom/core/average_atom_new.py:496: RuntimeWarning: invalid value encountered in divide
#   rel_errs = (np.abs(A @ φe - b)[:-1]/b[:-1])
