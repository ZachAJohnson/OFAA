# %%
import numpy as np
import pandas as pd


from average_atom.core.average_atom_kspace import NeutralPseudoAtom as NPA
from average_atom.core.misc import jacobi_relaxation, sor
from average_atom.core.grids import FourierGrid
from average_atom.core.physics import ThomasFermi, FermiDirac

from importlib import reload
try:
    reload(physics)
    reload(grids)
    reload(average_atom_geometric)
#     reload(average_atom)
    reload(misc)
except NameError as e:
    from average_atom.core import physics as physics
    from average_atom.core import average_atom_kspace as average_atom
    from average_atom.core import misc as misc
    from average_atom.core import grids as grids
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)

import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

import cProfile

plt.rcParams.update({'font.size': 10})
plt.rcParams["figure.figsize"] = (5,3.5)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14

color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# Error:  name 'physics' is not defined

# %%
# Aluminuma
name='Al'
Z, A = 13, 27 

ρ_solid = 2.699 #g/cc, the solid density of aluminum 
ρ = ρ_solid#8.1 # g/cc
ni_cc = ρ/(A*amu_to_AU*AU_to_g)
ni_AU = ni_cc*invcc_to_AU
rs = rs_from_n(ni_AU)

Ti_eV = 1 
Te_eV = 1

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

# Hydrogen
# name='H'
# Z, A = 1, 1.00784

# Te_eV = 2 
# Te_AU = Te_eV*eV_to_AU

# Ti_eV = 2
# Ti_AU = Ti_eV*eV_to_AU

# ρ_gpercc = 1
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)


####
R = 10*rs
rmin = rs/1000
ignore_vxc = True
fixed_Zstar = True

aa_kwargs = {'initialize':True, 'gradient_correction':None, 'μ_init' : 0.158, 'Zstar_init' : 'More', 'rmin': rmin,'Npoints':1000,
             'name':name, 'ignore_vxc':ignore_vxc, 'fixed_Zstar':fixed_Zstar, 'iet_R_over_rs':R/rs, 'iet_N_bins':5000, 'use_full_ne_for_nf':False,
            'gii_init_type': 'step'}
npa_kwargs = {'initialize':True, 'gradient_correction':None,'μ_init' : 0.158, 'Zstar_init' : 'More', 'rmin':1e-2 ,'Npoints':10000, 
              'name':name,'ignore_vxc':ignore_vxc, 'fixed_Zstar':fixed_Zstar, 'iet_R_over_rs':R/rs, 'iet_N_bins':10000, 'use_full_ne_for_nf':False,
             'gii_init_type': 'step', 'grid_spacing':'linear'}

aa = NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aa_kwargs)
npa = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)
# npa_2 = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities

# %%
# %%time
npa.solve_TF(verbose=True, picard_alpha=0.01, tol=1e-12, nmax = 1000, n_wait_update_Zstar= 200)
npa.set_uii_eff()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 3.756522950e-01, change: 1.371433611e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.891e-05
# 	ne Err =  9.791e-04, ne change =  1.260e-03
# 	Q =  0.000e+00 ->  7.429e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.145e-03
# __________________________________________
# TF Iteration 1
# 	μ = 3.756523463e-01, change: 1.366674609e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.889e-04
# 	ne Err =  9.655e-04, ne change =  1.245e-03
# 	Q =  7.429e-03 ->  7.359e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.147e-03
# __________________________________________
# TF Iteration 2
# 	μ = 3.756523667e-01, change: 5.433424510e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.869e-04
# 	ne Err =  9.521e-04, ne change =  1.230e-03
# 	Q =  7.359e-03 ->  7.288e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.134e-03
# __________________________________________
# TF Iteration 3
# 	μ = 3.756524157e-01, change: 1.305033139e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.849e-04
# 	ne Err =  9.389e-04, ne change =  1.216e-03
# 	Q =  7.288e-03 ->  7.220e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.121e-03
# __________________________________________
# TF Iteration 4
# 	μ = 3.756524444e-01, change: 7.638435506e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.829e-04
# 	ne Err =  9.258e-04, ne change =  1.202e-03
# 	Q =  7.220e-03 ->  7.150e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.108e-03
# __________________________________________
# TF Iteration 5
# 	μ = 3.756524910e-01, change: 1.240876768e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.810e-04
# 	ne Err =  9.130e-04, ne change =  1.187e-03
# 	Q =  7.150e-03 ->  7.083e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.095e-03
# __________________________________________
# TF Iteration 6
# 	μ = 3.756525244e-01, change: 8.889602032e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.790e-04
# 	ne Err =  9.004e-04, ne change =  1.173e-03
# 	Q =  7.083e-03 ->  7.016e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.083e-03
# __________________________________________
# TF Iteration 7
# 	μ = 3.756525691e-01, change: 1.190077519e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.771e-04
# 	ne Err =  8.880e-04, ne change =  1.160e-03
# 	Q =  7.016e-03 ->  6.950e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.070e-03
# __________________________________________
# TF Iteration 8
# 	μ = 3.756526053e-01, change: 9.633972975e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.752e-04
# 	ne Err =  8.758e-04, ne change =  1.146e-03
# 	Q =  6.950e-03 ->  6.884e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.058e-03
# __________________________________________
# TF Iteration 9
# 	μ = 3.756526487e-01, change: 1.153958074e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.734e-04
# 	ne Err =  8.638e-04, ne change =  1.133e-03
# 	Q =  6.884e-03 ->  6.820e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.046e-03
# __________________________________________
# TF Iteration 25
# 	μ = 3.756532875e-01, change: 1.042345095e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.458e-04
# 	ne Err =  6.940e-04, ne change =  9.408e-04
# 	Q =  5.920e-03 ->  5.865e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  8.713e-04
# __________________________________________
# TF Iteration 50
# 	μ = 3.756541737e-01, change: 8.376773697e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.108e-04
# 	ne Err =  4.974e-04, ne change =  7.093e-04
# 	Q =  4.682e-03 ->  4.639e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.582e-04
# __________________________________________
# TF Iteration 75
# 	μ = 3.756548449e-01, change: 6.067639036e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.400e-05
# 	ne Err =  3.596e-04, ne change =  5.385e-04
# 	Q =  3.701e-03 ->  3.666e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.997e-04
# __________________________________________
# TF Iteration 100
# 	μ = 3.756553237e-01, change: 4.305222978e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.353e-05
# 	ne Err =  2.618e-04, ne change =  4.110e-04
# 	Q =  2.921e-03 ->  2.893e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.809e-04
# __________________________________________
# TF Iteration 125
# 	μ = 3.756556658e-01, change: 3.106606972e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.800e-05
# 	ne Err =  1.918e-04, ne change =  3.150e-04
# 	Q =  2.302e-03 ->  2.280e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.912e-04
# __________________________________________
# TF Iteration 150
# 	μ = 3.756559154e-01, change: 2.289983647e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.624e-05
# 	ne Err =  1.412e-04, ne change =  2.421e-04
# 	Q =  1.812e-03 ->  1.795e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.232e-04
# __________________________________________
# TF Iteration 175
# 	μ = 3.756561007e-01, change: 1.711401998e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.735e-05
# 	ne Err =  1.044e-04, ne change =  1.865e-04
# 	Q =  1.426e-03 ->  1.412e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.714e-04
# __________________________________________
# TF Iteration 200
# 	μ = 3.756562398e-01, change: 1.287753570e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.065e-05
# 	ne Err =  7.753e-05, ne change =  1.439e-04
# 	Q =  1.121e-03 ->  1.111e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.318e-04
# __________________________________________
# TF Iteration 225
# 	μ = 3.756563446e-01, change: 9.719712368e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.560e-05
# 	ne Err =  5.776e-05, ne change =  1.112e-04
# 	Q =  8.813e-04 ->  8.729e-04,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.015e-04
# __________________________________________
# TF Iteration 250
# 	μ = 3.756564237e-01, change: 7.348441189e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.178e-05
# 	ne Err =  4.317e-05, ne change =  8.603e-05
# 	Q =  6.925e-04 ->  6.858e-04,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.825e-05
# __________________________________________
# TF Iteration 275
# 	μ = 3.756564836e-01, change: 5.564393835e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.908e-06
# 	ne Err =  3.236e-05, ne change =  6.660e-05
# 	Q =  5.439e-04 ->  5.386e-04,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.037e-05
# __________________________________________
# TF Iteration 300
# 	μ = 3.756565290e-01, change: 4.221361039e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.738e-06
# 	ne Err =  2.431e-05, ne change =  5.160e-05
# 	Q =  4.270e-04 ->  4.229e-04,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.660e-05
# __________________________________________
# TF Iteration 325
# 	μ = 3.756565635e-01, change: 3.208692867e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.100e-06
# 	ne Err =  1.831e-05, ne change =  3.999e-05
# 	Q =  3.352e-04 ->  3.319e-04,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.599e-05
# __________________________________________
# TF Iteration 350
# 	μ = 3.756565898e-01, change: 2.443810487e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.862e-06
# 	ne Err =  1.382e-05, ne change =  3.101e-05
# 	Q =  2.630e-04 ->  2.605e-04,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.781e-05
# __________________________________________
# TF Iteration 375
# 	μ = 3.756566098e-01, change: 1.864674637e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.927e-06
# 	ne Err =  1.045e-05, ne change =  2.405e-05
# 	Q =  2.063e-04 ->  2.043e-04,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.150e-05
# __________________________________________
# TF Iteration 400
# 	μ = 3.756566250e-01, change: 1.425143115e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.220e-06
# 	ne Err =  7.919e-06, ne change =  1.866e-05
# 	Q =  1.618e-04 ->  1.603e-04,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.662e-05
# __________________________________________
# TF Iteration 425
# 	μ = 3.756566367e-01, change: 1.090777468e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.684e-06
# 	ne Err =  6.009e-06, ne change =  1.448e-05
# 	Q =  1.269e-04 ->  1.257e-04,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.286e-05
# __________________________________________
# TF Iteration 450
# 	μ = 3.756566456e-01, change: 8.359144488e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.279e-06
# 	ne Err =  4.566e-06, ne change =  1.124e-05
# 	Q =  9.948e-05 ->  9.852e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  9.945e-06
# __________________________________________
# TF Iteration 475
# 	μ = 3.756566525e-01, change: 6.412823605e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.714e-07
# 	ne Err =  3.474e-06, ne change =  8.723e-06
# 	Q =  7.798e-05 ->  7.722e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.695e-06
# __________________________________________
# TF Iteration 500
# 	μ = 3.756566578e-01, change: 4.924378683e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.384e-07
# 	ne Err =  2.647e-06, ne change =  6.772e-06
# 	Q =  6.112e-05 ->  6.052e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  5.955e-06
# __________________________________________
# TF Iteration 525
# 	μ = 3.756566618e-01, change: 3.784588198e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.616e-07
# 	ne Err =  2.019e-06, ne change =  5.257e-06
# 	Q =  4.789e-05 ->  4.743e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.609e-06
# __________________________________________
# TF Iteration 550
# 	μ = 3.756566649e-01, change: 2.910831576e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.274e-07
# 	ne Err =  1.541e-06, ne change =  4.082e-06
# 	Q =  3.752e-05 ->  3.716e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.568e-06
# __________________________________________
# TF Iteration 575
# 	μ = 3.756566673e-01, change: 2.240381214e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.254e-07
# 	ne Err =  1.177e-06, ne change =  3.169e-06
# 	Q =  2.940e-05 ->  2.911e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.763e-06
# __________________________________________
# TF Iteration 600
# 	μ = 3.756566692e-01, change: 1.725422027e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.479e-07
# 	ne Err =  9.005e-07, ne change =  2.461e-06
# 	Q =  2.303e-05 ->  2.280e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.139e-06
# __________________________________________
# TF Iteration 625
# 	μ = 3.756566706e-01, change: 2.631614926e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.890e-07
# 	ne Err =  6.892e-07, ne change =  1.911e-06
# 	Q =  1.805e-05 ->  1.788e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.657e-06
# __________________________________________
# TF Iteration 650
# 	μ = 3.756566716e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.441e-07
# 	ne Err =  5.278e-07, ne change =  1.484e-06
# 	Q =  1.416e-05 ->  1.402e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.283e-06
# __________________________________________
# TF Iteration 675
# 	μ = 3.756566724e-01, change: 1.950068995e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.099e-07
# 	ne Err =  4.045e-07, ne change =  1.152e-06
# 	Q =  1.110e-05 ->  1.100e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  9.937e-07
# __________________________________________
# TF Iteration 700
# 	μ = 3.756566730e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.389e-08
# 	ne Err =  3.102e-07, ne change =  8.949e-07
# 	Q =  8.734e-06 ->  8.652e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.697e-07
# __________________________________________
# TF Iteration 725
# 	μ = 3.756566735e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.406e-08
# 	ne Err =  2.380e-07, ne change =  6.949e-07
# 	Q =  6.898e-06 ->  6.829e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  5.962e-07
# __________________________________________
# TF Iteration 750
# 	μ = 3.756566738e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.893e-08
# 	ne Err =  1.827e-07, ne change =  5.397e-07
# 	Q =  5.471e-06 ->  5.417e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.619e-07
# __________________________________________
# TF Iteration 775
# 	μ = 3.756566741e-01, change: 1.722957332e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.739e-08
# 	ne Err =  1.403e-07, ne change =  4.192e-07
# 	Q =  4.362e-06 ->  4.325e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.580e-07
# __________________________________________
# TF Iteration 800
# 	μ = 3.756566742e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.858e-08
# 	ne Err =  1.078e-07, ne change =  3.255e-07
# 	Q =  3.502e-06 ->  3.473e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.773e-07
# __________________________________________
# TF Iteration 825
# 	μ = 3.756566743e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.186e-08
# 	ne Err =  8.285e-08, ne change =  2.528e-07
# 	Q =  2.839e-06 ->  2.817e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.149e-07
# __________________________________________
# TF Iteration 850
# 	μ = 3.756566745e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.672e-08
# 	ne Err =  6.371e-08, ne change =  1.964e-07
# 	Q =  2.320e-06 ->  2.303e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.665e-07
# __________________________________________
# TF Iteration 875
# 	μ = 3.756566745e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.280e-08
# 	ne Err =  4.900e-08, ne change =  1.525e-07
# 	Q =  1.924e-06 ->  1.911e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.291e-07
# __________________________________________
# TF Iteration 900
# 	μ = 3.756566746e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.796e-09
# 	ne Err =  3.770e-08, ne change =  1.185e-07
# 	Q =  1.615e-06 ->  1.605e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.000e-07
# __________________________________________
# TF Iteration 925
# 	μ = 3.756566746e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.501e-09
# 	ne Err =  2.902e-08, ne change =  9.202e-08
# 	Q =  1.378e-06 ->  1.369e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.753e-08
# __________________________________________
# TF Iteration 950
# 	μ = 3.756566746e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.746e-09
# 	ne Err =  2.234e-08, ne change =  7.147e-08
# 	Q =  1.198e-06 ->  1.192e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.009e-08
# __________________________________________
# TF Iteration 975
# 	μ = 3.756566746e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.403e-09
# 	ne Err =  1.720e-08, ne change =  5.552e-08
# 	Q =  1.068e-06 ->  1.063e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.658e-08
# __________________________________________
# TF Iteration 1000
# 	mu =     0.3757, change: 0.0000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.410e-09
# 	ne Err =  1.339e-08, ne change =  4.356e-08
# 	Q =  9.498e-07 ->  9.457e-07,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.648e-08
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 1.111e+08
# QUIT: Total error infinite.
# Exiting status 1, reverting to best index so far: 0
# Final iter:21, Total Error: 1.111e+08
# CPU times: user 7.61 s, sys: 12.1 ms, total: 7.62 s
# Wall time: 7.64 s

# %%
# %%time
from scipy.interpolate import interp1d
aa.solve_TF(verbose=True, picard_alpha=0.2, tol=1e-12)
aa.set_uii_eff()
# aa.iet.HNC_solve(iters_to_wait=1e5, alpha_Picard=1e-2, tol=1e-12, verbose=False, num_iterations=1e5)
# aa.gii = interp1d(aa.iet.r_array*aa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(aa.grid.xs)
# # npa_2.gii = interp1d(npa.iet.r_array*npa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(npa.grid.xs)
# aa.make_ρi()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 9.216271689e-01, change: 1.420047167e+00 (converged=False)
# 	φe Err =  0.000e+00, φe change =  7.148e-01
# 	ne Err =  7.180e-01, ne change =  4.048e-03
# 	Q =  0.000e+00 ->  2.109e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.945e+00
# __________________________________________
# TF Iteration 1
# 	μ = 4.873307920e-01, change: 4.712278366e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.005e-01
# 	ne Err =  3.821e-01, ne change =  2.482e-03
# 	Q =  2.109e+00 ->  2.697e-01,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  5.335e-01
# __________________________________________
# TF Iteration 2
# 	μ = 5.210519337e-01, change: 6.919559022e-02 (converged=False)
# 	φe Err =  0.000e+00, φe change =  3.587e-02
# 	ne Err =  2.593e-01, ne change =  1.843e-03
# 	Q =  2.697e-01 ->  3.094e-01,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.515e-02
# __________________________________________
# TF Iteration 3
# 	μ = 4.266460866e-01, change: 1.811831817e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  3.396e-02
# 	ne Err =  1.561e-01, ne change =  1.316e-03
# 	Q =  3.094e-01 -> -1.491e-02,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.759e-01
# __________________________________________
# TF Iteration 4
# 	μ = 4.112366387e-01, change: 3.611763544e-02 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.834e-02
# 	ne Err =  1.031e-01, ne change =  9.732e-04
# 	Q = -1.491e-02 -> -5.270e-02,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.234e-02
# __________________________________________
# TF Iteration 5
# 	μ = 4.112171161e-01, change: 4.747301925e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.344e-02
# 	ne Err =  7.338e-02, ne change =  7.167e-04
# 	Q = -5.270e-02 -> -1.036e-01,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.296e-02
# __________________________________________
# TF Iteration 6
# 	μ = 4.112171161e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.291e-03
# 	ne Err =  5.283e-02, ne change =  5.328e-04
# 	Q = -1.036e-01 -> -1.647e-01,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.389e-03
# __________________________________________
# TF Iteration 7
# 	μ = 4.112171161e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.166e-03
# 	ne Err =  3.753e-02, ne change =  4.000e-04
# 	Q = -1.647e-01 -> -2.129e-01,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.124e-03
# __________________________________________
# TF Iteration 8
# 	μ = 4.112171161e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.407e-03
# 	ne Err =  2.651e-02, ne change =  3.022e-04
# 	Q = -2.129e-01 -> -2.459e-01,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.531e-03
# __________________________________________
# TF Iteration 9
# 	μ = 4.112171161e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.321e-03
# 	ne Err =  1.875e-02, ne change =  2.295e-04
# 	Q = -2.459e-01 -> -2.669e-01,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.665e-03
# __________________________________________
# TF Iteration 25
# 	μ = 3.768936035e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.596e-05
# 	ne Err =  1.501e-03, ne change =  3.768e-06
# 	Q = -6.941e-02 -> -6.531e-02,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.757e-05
# __________________________________________
# TF Iteration 50
# 	μ = 3.699609899e-01, change: 2.446229601e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.320e-07
# 	ne Err =  6.720e-04, ne change =  9.964e-09
# 	Q = -1.253e-02 -> -1.233e-02,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.732e-03
# __________________________________________
# TF Iteration 75
# 	μ = 3.693342346e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.935e-07
# 	ne Err =  3.263e-05, ne change =  2.569e-09
# 	Q = -1.569e-03 -> -1.480e-03,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.604e-07
# __________________________________________
# TF Iteration 100
# 	μ = 3.691750322e-01, change: 5.632091224e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.989e-09
# 	ne Err =  1.539e-05, ne change =  3.703e-11
# 	Q = -2.871e-04 -> -2.823e-04,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.983e-05
# __________________________________________
# TF Iteration 125
# 	μ = 3.691606691e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.725e-09
# 	ne Err =  7.475e-07, ne change =  5.942e-11
# 	Q = -3.595e-05 -> -3.391e-05,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  8.260e-09
# __________________________________________
# TF Iteration 150
# 	μ = 3.691570208e-01, change: 1.290782659e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.289e-10
# 	ne Err =  3.527e-07, ne change =  8.490e-13
# 	Q = -6.579e-06 -> -6.470e-06,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  9.127e-07
# __________________________________________
# TF Iteration 175
# 	μ = 3.691566917e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.541e-10
# 	ne Err =  1.713e-08, ne change =  1.362e-12
# 	Q = -8.238e-07 -> -7.770e-07,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.893e-10
# __________________________________________
# TF Iteration 200
# 	μ = 3.691566081e-01, change: 2.957984213e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.246e-12
# 	ne Err =  8.082e-09, ne change =  1.945e-14
# 	Q = -1.508e-07 -> -1.483e-07,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.092e-08
# __________________________________________
# TF Iteration 225
# 	μ = 3.691566005e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.532e-12
# 	ne Err =  3.925e-10, ne change =  3.121e-14
# 	Q = -1.888e-08 -> -1.781e-08,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.337e-12
# __________________________________________
# TF Iteration 250
# 	μ = 3.691565986e-01, change: 6.778506645e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.203e-13
# 	ne Err =  1.852e-10, ne change =  4.511e-16
# 	Q = -3.455e-09 -> -3.397e-09,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.793e-10
# __________________________________________
# TF Iteration 275
# 	μ = 3.691565985e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.709e-15
# 	ne Err =  1.728e-12, ne change =  3.335e-17
# 	Q = -7.200e-10 -> -7.163e-10,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.082e-15
# __________________________________________
# TF Iteration 279
# 	mu =     0.3692, change: 0.0000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.912e-15
# 	ne Err =  8.507e-13, ne change =  2.106e-17
# 	Q = -7.113e-10 -> -7.095e-10,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  8.956e-16
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 4.839e+02
# QUIT: Total error infinite.
# Exiting status 1, reverting to best index so far: 16
# Final iter:21, Total Error: 9.821e+01

# %%
# fig, axs  = plt.subplots(1,2,figsize=(10,4))

# colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# short_distance_weight = np.exp(-(0.08*npa.kTF*npa.grid.xs)**4)
# for ax in axs:
#     # ax.plot(npa.iet.r_array*rs, npa.iet.h_r_matrix[0,0], color=colors[0], label=r"NPA: $u_Y$")
#     ax.plot(npa.grid.xs, npa.gii-1, color=colors[0], label=r"NPA: $u_Y$")
#     # ax.plot(npa_2.grid.xs, npa_2.gii-1,'--', color=colors[0], label=r"NPA: $u_{AA}$",zorder=10)
#     ax.plot(aa.iet.r_array*rs, aa.iet.h_r_matrix[0,0],color=colors[1],  label=r"$u_{AA}$")
#     # ax.plot(npa.grid.xs, short_distance_weight*(npa.gii-1),'--',color=colors[3],  label=r"$u_Y$ damped")
    			

#     # ax.plot(aa.grid.xs, aa.gii-1,'--',color=colors[3],  label=r"$u_Y$")
#     ax.axvline(npa.iet.r_array[-1]*rs,color='k')
    
# ax = axs[0]
# ax.set_xlabel(r"$r/r_i$",fontsize=12)
# ax.set_ylabel("h(r)",fontsize=12)
# ax.set_xlim(0,3*rs)

# ax = axs[1]
# ax.set_xlabel(r"$r/r_i$",fontsize=12)
# ax.set_ylabel("h(r)",fontsize=12)
# ax.set_xscale('log')
# ax.set_xlim(0.5,None)
# ax.set_yscale('symlog', linthresh=1e-6)
# for ax in axs:
#     ax.legend(fontsize=12)
#     ax.tick_params(labelsize=12)


# plt.tight_layout()

# %%
# ρ_iet = interp1d(npa.grid.xs, npa.ρi - npa.ne, bounds_error=False, fill_value=( (npa.ρi - npa.ne)[0],  (npa.ρi - npa.ne)[-1]))(npa.iet.r_array*rs)
# δφe_k = 4*π*npa.iet.FT_r_2_k(ρ_iet)/(npa.iet.k_array/rs)**2
# δφe_r = npa.iet.FT_k_2_r(δφe_k)
# φe = interp1d(npa.iet.r_array*rs, δφe_r, bounds_error=False, fill_value='extrapolate')(npa.grid.xs)
# ne_iet = npa.get_ne_TF(φe-φe[-1], npa.ne, npa.μ, npa.ne_bar)

# %%
# fig, ax = plt.subplots(figsize=(5,3.5))

# # φ
# # ax.plot(npa.grid.xs, φe)
# # ax.plot(npa.grid.xs, npa.φe)

# # n
# ax.plot(npa.grid.xs, npa.ne)
# ax.plot(npa.grid.xs, ne_iet)


# ax.set_yscale('symlog', linthresh=1e-8)
# ax.set_xscale('log')

# %% [markdown]
# ### Thomas Fermi (TF)

# %%
# 2000: -5.419e-02, 4000: 1.592e-02

# %%
# %%time
# npa_2.solve_TF(verbose=True, picard_alpha=0.2, num_10folds_per_rs=0.5, tol=1e-7, nmax = 1000, n_wait_update_Zstar= 200)
# npa_2.set_uii_eff()

# %% [markdown]
# ### EOS

# %%
def get_Eii(aa):
    βVeff = aa.get_βVeff(aa.φe, aa.ne, aa.ne_bar)
    η = aa.μ/aa.Te - βVeff
    βU = aa.grid.integrate_f(βVeff*aa.ne)
    I_onehalf = FermiDirac.Ionehalf(η)
    I_threehalf = FermiDirac.Ithreehalf(η)
    
    βK = (2*aa.Te)**1.5/π**2 * aa.grid.integrate_f( η*I_onehalf - 2/3 * I_threehalf   )
    return βU, βK, βU + βK

def get_ETF(aa):
    
def get_Exc(aa):
    aa.vxc

def get_E_Hartree(aa):
    
    
    

# get_E(aa_tfd), get_E(npa_tfd)

# %%
def get_P(aa):
    aa_old_βu = aa.iet.βu_r_matrix.copy()
    # aa.iet.set_βu_matrix( np.array([[1/aa.Ti * aa.Zstar**2/(aa.iet.r_array*aa.rs) ]] ))
    P_id_hnc, P_ex_hnc, P_hnc = aa.iet.ideal_pressure(), aa.iet.excess_pressure(), aa.iet.total_pressure()
    P_id_AU, P_ex_AU, P_AU  = P_id_hnc/rs**3, P_ex_hnc/rs**3, P_hnc/rs**3
    aa.iet.set_βu_matrix(aa_old_βu)
    return P_id_AU, P_ex_AU, P_AU

aa_P_ions = get_P(aa_tfd)
aa_P_ions[1]/aa_P_ions[0]

# %% [markdown]
# ## Comparison

# %%
npa.make_plots()
# Out:
# (<Figure size 4000x1600 with 2 Axes>,
#  array([<Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$\\phi$ [A.U.]'>,
#         <Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$n$ [A.U.]'>],
#        dtype=object))

# %%
def plot_convergence(aa, axs=None):
    if axs is None:
        fig, axs = plt.subplots(ncols=3,figsize=(18,5),facecolor='w', dpi=200)
    
    # ELectric potential
    slice_by_num = 10
    ax = axs[0]
    colors = plt.cm.coolwarm(np.linspace(0, 1,len(aa.φe_list[::slice_by_num])))
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        if i ==0 or i==len(aa.φe_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, (φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\phi_e$'.format(i))
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\vec E$'.format(i))
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1, label=r'$\beta V_{{\rm eff}}$'.format(i))
        else:
            ax.plot(aa.grid.xs, φe+aa.φion,linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1)
    # ax.plot(aa.grid.xs, aa.get_φe( (aa.ρi - aa.ne) )[0] + aa.φion  ,'k:', label=r'$\phi$ check') 
    ax.set_yscale('symlog',linthresh=1e-10)
    ax.plot(aa.grid.xs, aa.φe_init + aa.φion, 'k:')

    # number density
    ax = axs[1]
    for i, (ne, ρi) in enumerate(zip(aa.ne_list[::slice_by_num], aa.ρi_list[::slice_by_num])):
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            if i==0: 
                ne_bar_0 = ne[-1]
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1, label=r'$Q(r)$'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, -ne + 0*ρi + ne[-1],linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ne_bar_0,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ρi[-1] + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # pass
        else:
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1)
            # print(ne[-1]-ne_bar_0)
            # ax.plot(aa.grid.xs, -ne + ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ne + ne_bar_0 ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ρi[-1]+ ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            pass
    # for i in range(int(aa.R/aa.rs)):
    #     ax.axvline(aa.rs*i, color='k', linestyle='--', alpha=0.2)
    # ax.set_xscale('log')
    # ax.plot(aa.grid.xs, (aa.gii)-1, 'k:')
    ax.set_yscale('symlog',linthresh=1e-4)

            
    # number density
    ax = axs[2]
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        ne_TF = aa.get_ne_TF(φe, ne, μ, ne_bar)
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            # ax.plot(aa.grid.xs, ne - 0*ne_TF,linewidth=1,color=colors[i],alpha=1, label=r'$n_e/n_e^{{TF}}-1$, iter: {0}'.format(i))
            ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1, label=r'$n_e^{{TF}} - n_e^{{TF}}[-1]$, iter: {0}'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, ne-ne[-1],linewidth=1,color=colors[i],linestyle='--',alpha=1, label=r'$n_e - n_e[-1]$, iter: {0}'.format(i))
            # pass
        else:
            # ax.plot(aa.grid.xs, ne - 0*ne_TF, linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, ne-ne[-1], linewidth=1,linestyle='--',color=colors[i],alpha=0.5)
            

            # print(np.abs(ne/ne_TF-1))
            # print(np.where( np.abs(ne/ne_TF-1)>1e-6 ))
            # print(aa.grid.xs[np.where( np.abs(ne/ne_TF-1) > 1e-8)][0]/10, 1/(np.sum(aa.grid.xs*np.abs(ne/ne_TF-1))/np.sum(np.abs(ne/ne_TF-1))))
    # ax.set_ylim()
    # ax.plot(aa.grid.xs, npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar) - npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar)[-1] , 'k:')
    ax.plot(aa.grid.xs, aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar) - aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar)[-1] , 'k:')
    ax.set_yscale('symlog',linthresh=1e-10)
    # ax.set_xscale('log')
    for ax in axs:
        ax.legend(fontsize=14)
        ax.tick_params(labelsize=14)
        ax.plot(aa.grid.xs, np.zeros_like(aa.ne),'k', alpha=0.2)
    plt.tight_layout()
    
# plot_convergence(aa)
plot_convergence(npa)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

petrov = pd.read_csv("../data/GP_TFDW_Al_1eV_solid.dat",header=0, comment='#', delim_whitespace=True)

def compare_aa(aa_list, axs=None, name=''):
    eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
    if axs is None:
        fig, axs = plt.subplots(ncols=2,figsize=(20,8),facecolor='w')

    # Density * 4pi r^2 plot
    for ax in axs:
        for aa, color in zip( aa_list, colors):
            factor = 4*np.pi*aa.grid.xs**2
            ax.plot(np.array(petrov['r/R'])*rs, 4*π*(np.array(petrov['r/R'])*rs)**2*(petrov['ne']/m_to_AU**3), 'k--', label="Petrov AA")
            ax.plot(aa.grid.xs, aa.ne*factor ,'-',color=color, label=r'$n_e$: '+ name)
            ax.plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
            ax.plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
            if aa.rs != aa.R:
                ax.plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
                ax.plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)
        # axs[0].plot(aa.grid.xs, aa.δn_f*factor,'--',color='g',  label=r'$n_e^{sc}$: ' + name)


    axs[0].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[0].set_ylim(0, 1e3)
    axs[0].set_yscale('symlog',linthresh=1e-1)
    axs[0].set_xscale('log')
    axs[0].set_xlim(aa.grid.xs[0],aa.grid.xs[-1])

    axs[1].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[1].set_ylim(0, 13)
    axs[1].set_xlim(0, np.min([aa.R,1.3*aa.rs]))

        
    for ax in axs:
        ax.set_xlabel(r'$|r-R_1|$ [A.U.]',fontsize=20)
        ax.legend(loc="upper right",fontsize=20,labelspacing = 0.1)
        ax.tick_params(labelsize=20)
        ax.grid(which='both',alpha=0.4)

        # make textbox
        text = ("{0}\n".format(aa.name)+ 
            r"$r_s$ = " + "{0},    ".format(np.round(aa.rs,2)) +
            r"$R_{NPA}$ = " + "{0}\n".format(aa.R)  +
                r"$T_e$ = " + "{0} [A.U.] = {1} eV\n".format(np.round(aa.Te,2),np.round(aa.Te/eV,2)) + r"$\mu$ = " + "{0} [A.U.]\n".format(np.round(aa.μ,2)) +
                r"$Z^\ast = $" + "{0}".format(np.round(aa.Zstar,2))  )

        props = dict(boxstyle='round', facecolor='w')
        ax.text(0.25,0.95, text, fontsize=15, transform=ax.transAxes, verticalalignment='top', bbox=props)

    plt.tight_layout()
    name = "NPA_densities_{0}_rs{1}_{2}eV_R{3}.png".format(aa.name, np.round(aa.rs,2), np.round(aa.Te/eV,2) ,np.round(aa.R))
    plt.savefig("/home/zach/plasma/atomic_forces/average_atom/media/" + name, dpi=300, bbox_inches='tight',facecolor="w")
    
    
    return axs


axs = compare_aa([aa, npa])#, npa_2])
for ax in axs:
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), fontsize=16, loc='upper right')
# axs[1].set_ylim(1e-5,1e3)

# %% [markdown]
# ## HNC and FT

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# axs[0].plot(aa.iet.k_array/rs, aa.Uei_iet_k*(aa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.k_array/rs, npa.Uei_iet_k*(npa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[1], label="NPA") # Need to muultiply by some rs power???
# axs[0].plot(aa.iet.k_array/rs, aa.Zstar*np.ones_like(aa.iet.k_array),':', color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(npa.iet.k_array/rs, npa.Zstar*np.ones_like(npa.iet.k_array),':',color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")

# axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$k$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

# axs[1].plot(aa.iet.k_array/rs, aa.uii_k_eff_iet,'-', color=colors[0], label="AA")
# axs[1].plot(aa.iet.k_array/rs, 4*π*aa.Zstar**2/(aa.iet.k_array/rs)**2,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, 1/(aa.iet.k_array**2/rs**2/(4*π*aa.Zstar**2) + 1/aa.uii_k_eff_iet[0] ),'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, uii_test,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))


# axs[1].plot(npa.iet.k_array/rs, npa.uii_k_eff_iet,color=colors[1], label="NPA")
axs[1].plot(npa.iet.k_array/rs, 4*π*npa.Zstar**2/(npa.iet.k_array/rs)**2,'--', color=colors[1], label=r"NPA: $u_{{ii}}^0$, Z={0:0.3f}".format(npa.Zstar))



axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_ylim(0,1e5)
axs[1].set_xscale('log')
axs[1].set_xlabel(r"$k$ [au]")
axs[1].set_ylabel(r"$u^{\rm eff}_{ii}$ [au]")


for ax in axs:
    ax.legend(fontsize=12)
plt.tight_layout()

# %%
uii_test = aa.iet.FT_k_2_r(aa.uii_k_eff_iet)/rs**3

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.r_array*rs, -aa.Zstar/(aa.iet.r_array*rs), color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(aa.iet.r_array*rs, -aa.Uei_iet ,':',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.r_array*rs, -npa.Zstar/(npa.iet.r_array*rs),color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(npa.iet.r_array*rs, -npa.Uei_iet ,':',color=colors[1], label="NPA") # Need to muultiply by some rs power???
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Zstar/(npa.iet.r_array*rs),color=colors[2], label=f"Coulomb, Z={npa.Zstar:0.3f}")
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Uei_iet ,':',color=colors[2], label=r"NPA: $g_{AA}$") # Need to muultiply by some rs power???



axs[0].set_yscale('symlog',linthresh=1e-1)
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$r$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.r_array*rs, 1/aa.Te * aa.uii_r_eff_iet, color=colors[0],linestyle='-', label='AA')
axs[1].plot(aa.iet.r_array*rs, 1/aa.Te *aa.Zstar**2/(aa.iet.r_array*rs ), color=colors[0] ,linestyle='--', label=f'Coulomb Z={aa.Zstar:0.3f}')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.uii_r_eff_iet, color=colors[1],linestyle='-', label='NPA')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.Zstar**2/(npa.iet.r_array*rs ), color=colors[1],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )
# axs[1].plot(npa_2.iet.r_array*rs, npa_2.uii_r_eff_iet, color=colors[2],linestyle='-', label=r"NPA: $g_{AA}$")
# axs[1].plot(npa_2.iet.r_array*rs, npa_2.Zstar**2/(npa_2.iet.r_array*rs ), color=colors[2],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )

axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_xscale('log')
axs[1].set_ylabel(r"$\beta U_{ii}$ [au]")
axs[1].set_xlabel(r"$r$ [au]")
axs[1].set_xlim(1,None)


for ax in axs:
    ax.legend(fontsize=10)
plt.tight_layout()

# %%
npa.make_gii()
npa.make_ρi()
# npa_2.make_gii()
# npa_2.make_ρi()

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, axs  = plt.subplots(1,2, figsize=(8,4))

# Data from community TCCW
upper_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Upper.txt", delim_whitespace=True, header=1)
lower_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Lower.txt", delim_whitespace=True, header=1)

ax = axs[0]
ax.fill_between(lower_data['r/ri'],lower_data['gii'], PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')

# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0] + 1, label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("g(r)")
ax.set_xlim(0.7,3)
# ax.set_ylim(0,2)
ax.legend(fontsize=10)

ax = axs[1]
ax.fill_between(lower_data['r/ri'],lower_data['gii']-1, PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')
# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii-1, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii-1, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0], label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("h(r)")
ax.set_xlim(0.7,10)
ax.set_ylim(0,2.5)
ax.set_yscale('symlog', linthresh=1e-4)

ax.legend(fontsize=8, loc='upper right')
plt.tight_layout()
