# %%
import numpy as np
import pandas as pd


from average_atom.core.average_atom_kspace import NeutralPseudoAtom as NPA
from average_atom.core.misc import jacobi_relaxation, sor
from average_atom.core.grids import FourierGrid
from average_atom.core.physics import ThomasFermi, FermiDirac

from importlib import reload
try:
    reload(physics)
    reload(grids)
    reload(average_atom_geometric)
#     reload(average_atom)
    reload(misc)
except NameError as e:
    from average_atom.core import physics as physics
    from average_atom.core import average_atom_kspace as average_atom
    from average_atom.core import misc as misc
    from average_atom.core import grids as grids
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)

import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

import cProfile

plt.rcParams.update({'font.size': 10})
plt.rcParams["figure.figsize"] = (5,3.5)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14

color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# Error:  name 'physics' is not defined
# ModuleNotFoundError: No module named 'mendeleev'

# %%
# Aluminum
name='Al'
Z, A = 13, 27 

ρ_solid = 2.699 #g/cc, the solid density of aluminum 
ρ = 2.32*ρ_solid#8.1 # g/cc
ni_cc = ρ/(A*amu_to_AU*AU_to_g)
ni_AU = ni_cc*invcc_to_AU
rs = rs_from_n(ni_AU)

Ti_eV = 1.75
Te_eV = 1.75

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

# Hydrogen
# name='H'
# Z, A = 1, 1.00784

# Te_eV = 2 
# Te_AU = Te_eV*eV_to_AU

# Ti_eV = 2
# Ti_AU = Ti_eV*eV_to_AU

# ρ_gpercc = 1
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)

# Carbon
# name = 'C'
# Z, A = 6, 12.011

# ρ_gpercc = 2.267
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)

# Ti_eV = 0.5 
# Te_eV = 0.5

# Te_AU = Te_eV*eV_to_AU
# Ti_AU = Ti_eV*eV_to_AU


####
R = 10*rs
ignore_vxc = False
fixed_Zstar = False
Zstar_init = 'More'

aa_kwargs = {'initialize':True, 'gradient_correction':None, 'μ_init' : 0.158, 'Zstar_init' : Zstar_init, 'Npoints':1000,
             'name':name, 'ignore_vxc':ignore_vxc, 'fixed_Zstar':fixed_Zstar, 'iet_R_over_rs':R/rs, 'iet_N_bins':5000, 'use_full_ne_for_nf':False,
            'gii_init_type': 'step'}

# aaW_kwargs = aa_kwargs.copy()
# aaW_kwargs.update({'gradient_correction':'W', 'Weizsacker_λ':1/9})

npa_kwargs = aa_kwargs.copy()
npa_kwargs.update({'Npoints':10000, 'iet_N_bins':10000, 'gii_init_type': 'iet', 'grid_spacing':'linear'})

# npaW_kwargs = npa_kwargs.copy()
# npaW_kwargs.update({'gradient_correction':'W', 'Weizsacker_λ':1/9})

aa = NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aa_kwargs)
# aaW =NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aaW_kwargs)
npa = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)                           
# npaW = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npaW_kwargs)
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 3.519
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 3.519
# 	Intializing grid
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 1.044e+03
# Exiting status 0, reverting to best index so far: 2992
# Final iter:2993, Total Error: 9.945e-13
# Intialized Potentials and Densities

# %%
fig, axs  = plt.subplots(1,2,figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

short_distance_weight = np.exp(-(0.08*npa.kTF*npa.grid.xs)**4)
for ax in axs:
    # ax.plot(npa.iet.r_array*rs, npa.iet.h_r_matrix[0,0], color=colors[0], label=r"NPA: $u_Y$")
    ax.plot(npa.grid.xs, npa.gii-1, color=colors[0], label=r"NPA: $u_Y$")
    # ax.plot(npa_2.grid.xs, npa_2.gii-1,'--', color=colors[0], label=r"NPA: $u_{AA}$",zorder=10)
    ax.plot(aa.iet.r_array*rs, aa.iet.h_r_matrix[0,0],color=colors[1],  label=r"$u_{AA}$")
    # ax.plot(npa.grid.xs, short_distance_weight*(npa.gii-1),'--',color=colors[3],  label=r"$u_Y$ damped")
    			

    # ax.plot(aa.grid.xs, aa.gii-1,'--',color=colors[3],  label=r"$u_Y$")
    ax.axvline(npa.iet.r_array[-1]*rs,color='k')
    
ax = axs[0]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xlim(0,3*rs)

ax = axs[1]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xscale('log')
ax.set_xlim(0.5,None)
ax.set_yscale('symlog', linthresh=1e-6)
for ax in axs:
    ax.legend(fontsize=12)
    ax.tick_params(labelsize=12)


plt.tight_layout()

# %% [markdown]
# ### Thomas Fermi (TF)

# %%
# %%time
from scipy.interpolate import interp1d
aa.solve_TF(verbose=True, picard_alpha=0.2, tol=1e-9, n_wait_update_Zstar= 100)
aa.set_uii_eff()
# aa.iet.HNC_solve(iters_to_wait=1e5, alpha_Picard=1e-2, tol=1e-12, verbose=False, num_iterations=1e5)
# aa.gii = interp1d(aa.iet.r_array*aa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(aa.grid.xs)
# npa_2.gii = interp1d(aa.iet.r_array*aa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(npa.grid.xs)
# aa.make_ρi()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 2.830897400e+00, change: 2.408691512e+00 (converged=False)
# 	φe Err =  0.000e+00, φe change =  7.253e-01
# 	ne Err =  7.068e-01, ne change =  2.424e-03
# 	Q =  0.000e+00 -> -8.095e+00,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  1.387e+00
# __________________________________________
# TF Iteration 1
# 	μ = 2.144812904e+00, change: 2.423558325e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.082e-01
# 	ne Err =  4.696e-01, ne change =  1.379e-03
# 	Q = -8.095e+00 -> -7.752e+00,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  3.165e-01
# __________________________________________
# TF Iteration 2
# 	μ = 1.814611181e+00, change: 1.539536254e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  6.253e-02
# 	ne Err =  3.286e-01, ne change =  9.318e-04
# 	Q = -7.752e+00 -> -6.802e+00,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  1.870e-01
# __________________________________________
# TF Iteration 3
# 	μ = 1.525291782e+00, change: 1.594387837e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  4.844e-02
# 	ne Err =  2.522e-01, ne change =  6.149e-04
# 	Q = -6.802e+00 -> -5.963e+00,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  1.774e-01
# __________________________________________
# TF Iteration 4
# 	μ = 1.323460897e+00, change: 1.323228035e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  3.301e-02
# 	ne Err =  2.220e-01, ne change =  4.143e-04
# 	Q = -5.963e+00 -> -5.130e+00,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  1.383e-01
# __________________________________________
# TF Iteration 5
# 	μ = 1.323332618e+00, change: 9.692678317e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.322e-02
# 	ne Err =  1.387e-01, ne change =  2.811e-04
# 	Q = -5.130e+00 -> -4.370e+00,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  2.778e-02
# __________________________________________
# TF Iteration 6
# 	μ = 1.323332618e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.605e-02
# 	ne Err =  8.408e-02, ne change =  1.831e-04
# 	Q = -4.370e+00 -> -3.948e+00,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  1.956e-02
# __________________________________________
# TF Iteration 7
# 	μ = 1.323332618e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.094e-03
# 	ne Err =  5.736e-02, ne change =  1.256e-04
# 	Q = -3.948e+00 -> -3.700e+00,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  9.906e-03
# __________________________________________
# TF Iteration 8
# 	μ = 1.323332618e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.079e-03
# 	ne Err =  4.283e-02, ne change =  8.969e-05
# 	Q = -3.700e+00 -> -3.546e+00,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  4.989e-03
# __________________________________________
# TF Iteration 9
# 	μ = 1.323332618e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.104e-03
# 	ne Err =  3.355e-02, ne change =  6.598e-05
# 	Q = -3.546e+00 -> -3.442e+00,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  2.551e-03
# __________________________________________
# TF Iteration 25
# 	μ = 8.270323584e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.903e-04
# 	ne Err =  2.381e-02, ne change =  1.738e-06
# 	Q = -6.437e-01 -> -5.832e-01,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  4.144e-04
# __________________________________________
# TF Iteration 50
# 	μ = 7.618369224e-01, change: 6.257385213e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.713e-06
# 	ne Err =  3.054e-03, ne change =  3.307e-08
# 	Q = -4.894e-02 -> -4.659e-02,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  4.440e-03
# __________________________________________
# TF Iteration 75
# 	μ = 7.598346720e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.055e-06
# 	ne Err =  1.055e-04, ne change =  5.457e-09
# 	Q = -2.395e-03 -> -2.145e-03,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  1.516e-06
# __________________________________________
# TF Iteration 100
# 	μ = 7.596220721e-01, change: 1.942653453e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.522e-08
# 	ne Err =  9.803e-06, ne change =  1.056e-10
# 	Q = -1.548e-04 -> -1.468e-04,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  1.374e-05
# __________________________________________
# TF Iteration 125
# 	μ = 7.892591082e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.725e-05
# 	ne Err =  9.421e-04, ne change =  1.007e-07
# 	Q =  3.193e-02 ->  2.937e-02,
# 	Zstar guess =  4.720e+00. Current Zstar:  4.721e+00 (converged=False)
# 	Change =  2.491e-05
# __________________________________________
# TF Iteration 150
# 	μ = 7.932495223e-01, change: 3.776198135e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.200e-07
# 	ne Err =  1.727e-04, ne change =  1.279e-09
# 	Q =  2.825e-03 ->  2.722e-03,
# 	Zstar guess =  4.728e+00. Current Zstar:  4.728e+00 (converged=False)
# 	Change =  2.670e-04
# __________________________________________
# TF Iteration 175
# 	μ = 7.933925739e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.259e-08
# 	ne Err =  6.253e-06, ne change =  4.412e-10
# 	Q =  1.726e-04 ->  1.562e-04,
# 	Zstar guess =  4.729e+00. Current Zstar:  4.729e+00 (converged=False)
# 	Change =  1.192e-07
# __________________________________________
# TF Iteration 200
# 	μ = 7.934115673e-01, change: 2.010933896e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.266e-09
# 	ne Err =  9.447e-07, ne change =  7.581e-12
# 	Q =  1.536e-05 ->  1.475e-05,
# 	Zstar guess =  4.729e+00. Current Zstar:  4.729e+00 (converged=False)
# 	Change =  1.422e-06
# __________________________________________
# TF Iteration 225
# 	μ = 7.934123257e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.358e-10
# 	ne Err =  3.291e-08, ne change =  2.321e-12
# 	Q =  9.342e-07 ->  8.440e-07,
# 	Zstar guess =  4.729e+00. Current Zstar:  4.729e+00 (converged=False)
# 	Change =  6.280e-10
# __________________________________________
# TF Iteration 250
# 	μ = 7.934124283e-01, change: 1.085746204e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.577e-12
# 	ne Err =  5.108e-09, ne change =  3.842e-14
# 	Q =  8.315e-08 ->  7.970e-08,
# 	Zstar guess =  4.729e+00. Current Zstar:  4.729e+00 (converged=False)
# 	Change =  7.679e-09
# __________________________________________
# TF Iteration 259
# 	μ = 7.934124283e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.813e-12
# 	ne Err =  8.550e-10, ne change =  3.459e-14
# 	Q =  3.240e-08 ->  3.067e-08,
# 	Zstar guess =  4.729e+00. Current Zstar:  4.729e+00 (converged=False)
# 	Change =  8.627e-13
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 1.264e+03
# Exiting status 0, reverting to best index so far: 7187
# Final iter:7188, Total Error: 9.969e-13
# CPU times: user 59 s, sys: 19.8 ms, total: 59 s
# Wall time: 59 s

# %%
# %%time
transition_func = 1/(1 + np.exp(-(npa.grid.xs-2*npa.rs)/(2*(rs/4)**2)))
aa_ne_extended = np.zeros_like(npa.ne)
aa_ne_extended[:len(aa.ne)] = aa.ne.copy()
aa_ne_extended[len(aa.ne):] = aa.ne.copy()[-1]
npa.ne = aa_ne_extended * (1-transition_func) + transition_func * npa.ρi 
npa.μ = aa.μ
npa.Zstar = aa.Zstar

npa.solve_TF(verbose=True, picard_alpha=1e-2, tol=1e-9, nmax = 5000, n_wait_update_Zstar= 500)
npa.set_uii_eff()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 7.170939289e-01, change: 9.619019906e-02 (converged=False)
# 	φe Err =  0.000e+00, φe change =  3.822e-01
# 	ne Err =  1.212e-01, ne change =  8.369e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.729e+00. Current Zstar:  3.519e+00 (converged=False)
# 	Change =  1.121e-01
# __________________________________________
# TF Iteration 1
# 	μ = 8.139393963e-01, change: 1.350526946e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  3.828e-02
# 	ne Err =  3.258e-02, ne change =  6.558e-06
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  3.519e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  1.724e-01
# __________________________________________
# TF Iteration 2
# 	μ = 8.257617833e-01, change: 1.452489841e-02 (converged=False)
# 	φe Err =  0.000e+00, φe change =  8.804e-03
# 	ne Err =  2.084e-02, ne change =  6.411e-06
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.512e+00 (converged=False)
# 	Change =  2.610e-02
# __________________________________________
# TF Iteration 3
# 	μ = 8.319183992e-01, change: 7.455680243e-03 (converged=False)
# 	φe Err =  0.000e+00, φe change =  5.891e-03
# 	ne Err =  1.624e-02, ne change =  6.135e-06
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  3.512e+00. Current Zstar:  3.512e+00 (converged=False)
# 	Change =  1.525e-02
# __________________________________________
# TF Iteration 4
# 	μ = 8.344964658e-01, change: 3.098941697e-03 (converged=False)
# 	φe Err =  0.000e+00, φe change =  3.786e-03
# 	ne Err =  1.440e-02, ne change =  5.934e-06
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  3.512e+00. Current Zstar:  3.512e+00 (converged=False)
# 	Change =  8.125e-03
# __________________________________________
# TF Iteration 5
# 	μ = 8.344972043e-01, change: 8.849444446e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.569e-03
# 	ne Err =  1.310e-02, ne change =  5.775e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.512e+00. Current Zstar:  3.512e+00 (converged=False)
# 	Change =  3.657e-03
# __________________________________________
# TF Iteration 6
# 	μ = 8.344972043e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.840e-03
# 	ne Err =  1.176e-02, ne change =  5.643e-06
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  3.512e+00. Current Zstar:  3.512e+00 (converged=False)
# 	Change =  2.342e-03
# __________________________________________
# TF Iteration 7
# 	μ = 8.344972043e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.380e-03
# 	ne Err =  1.053e-02, ne change =  5.533e-06
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  3.512e+00. Current Zstar:  3.512e+00 (converged=False)
# 	Change =  1.566e-03
# __________________________________________
# TF Iteration 8
# 	μ = 8.344972043e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.079e-03
# 	ne Err =  9.506e-03, ne change =  5.438e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.512e+00. Current Zstar:  3.512e+00 (converged=False)
# 	Change =  1.099e-03
# __________________________________________
# TF Iteration 9
# 	μ = 8.344972043e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.692e-04
# 	ne Err =  8.724e-03, ne change =  5.352e-06
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  3.512e+00. Current Zstar:  3.512e+00 (converged=False)
# 	Change =  8.090e-04
# __________________________________________
# TF Iteration 25
# 	μ = 8.295402893e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.020e-04
# 	ne Err =  2.936e-03, ne change =  4.483e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  3.551e-05
# __________________________________________
# TF Iteration 50
# 	μ = 8.295501008e-01, change: 7.002346724e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.450e-05
# 	ne Err =  1.507e-03, ne change =  3.580e-06
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  8.057e-05
# __________________________________________
# TF Iteration 75
# 	μ = 8.295557840e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.581e-05
# 	ne Err =  9.303e-04, ne change =  2.828e-06
# 	Q = -4.547e-13 -> -4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  1.863e-05
# __________________________________________
# TF Iteration 100
# 	μ = 8.295308624e-01, change: 7.486207667e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.184e-05
# 	ne Err =  6.109e-04, ne change =  2.211e-06
# 	Q = -4.547e-13 ->  4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  1.451e-05
# __________________________________________
# TF Iteration 125
# 	μ = 8.295242839e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.004e-06
# 	ne Err =  4.156e-04, ne change =  1.717e-06
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  4.570e-06
# __________________________________________
# TF Iteration 150
# 	μ = 8.295212481e-01, change: 7.029494452e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.581e-06
# 	ne Err =  2.896e-04, ne change =  1.330e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  2.891e-06
# __________________________________________
# TF Iteration 175
# 	μ = 8.295205562e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.388e-06
# 	ne Err =  2.055e-04, ne change =  1.029e-06
# 	Q = -4.547e-13 -> -4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  1.361e-06
# __________________________________________
# TF Iteration 200
# 	μ = 8.295198933e-01, change: 2.413137002e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.651e-06
# 	ne Err =  1.479e-04, ne change =  7.958e-07
# 	Q = -4.547e-13 -> -4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  1.015e-06
# __________________________________________
# TF Iteration 225
# 	μ = 8.295195330e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.144e-06
# 	ne Err =  1.076e-04, ne change =  6.158e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  6.762e-07
# __________________________________________
# TF Iteration 250
# 	μ = 8.295190924e-01, change: 1.604656208e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.877e-07
# 	ne Err =  7.905e-05, ne change =  4.767e-07
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  6.474e-07
# __________________________________________
# TF Iteration 275
# 	μ = 8.295188663e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.401e-07
# 	ne Err =  5.851e-05, ne change =  3.693e-07
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  4.089e-07
# __________________________________________
# TF Iteration 300
# 	μ = 8.295186155e-01, change: 8.818436281e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.700e-07
# 	ne Err =  4.358e-05, ne change =  2.862e-07
# 	Q = -4.547e-13 -> -4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  3.713e-07
# __________________________________________
# TF Iteration 325
# 	μ = 8.295184952e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.542e-07
# 	ne Err =  3.263e-05, ne change =  2.220e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  2.319e-07
# __________________________________________
# TF Iteration 350
# 	μ = 8.295183652e-01, change: 4.549991028e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.758e-07
# 	ne Err =  2.455e-05, ne change =  1.722e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  2.061e-07
# __________________________________________
# TF Iteration 375
# 	μ = 8.295183030e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.228e-07
# 	ne Err =  1.854e-05, ne change =  1.337e-07
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  1.306e-07
# __________________________________________
# TF Iteration 400
# 	μ = 8.295182347e-01, change: 2.411130029e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.688e-08
# 	ne Err =  1.405e-05, ne change =  1.038e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  1.155e-07
# __________________________________________
# TF Iteration 425
# 	μ = 8.295182013e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.226e-08
# 	ne Err =  1.068e-05, ne change =  8.063e-08
# 	Q = -4.547e-13 -> -4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  7.443e-08
# __________________________________________
# TF Iteration 450
# 	μ = 8.295181638e-01, change: 1.337309552e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.522e-08
# 	ne Err =  8.136e-06, ne change =  6.264e-08
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  6.596e-08
# __________________________________________
# TF Iteration 475
# 	μ = 8.295181450e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.324e-08
# 	ne Err =  6.213e-06, ne change =  4.868e-08
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  4.305e-08
# __________________________________________
# TF Iteration 500
# 	μ = 8.295181237e-01, change: 7.658415790e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.471e-08
# 	ne Err =  4.755e-06, ne change =  3.783e-08
# 	Q = -4.547e-13 -> -4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  3.860e-08
# __________________________________________
# TF Iteration 525
# 	μ = 8.295181129e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.853e-08
# 	ne Err =  3.646e-06, ne change =  2.940e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  2.598e-08
# __________________________________________
# TF Iteration 550
# 	μ = 8.295181005e-01, change: 4.455321223e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.400e-08
# 	ne Err =  2.800e-06, ne change =  2.286e-08
# 	Q = -4.547e-13 -> -4.547e-13,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  2.345e-08
# __________________________________________
# TF Iteration 575
# 	μ = 8.295180942e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.063e-08
# 	ne Err =  2.154e-06, ne change =  1.777e-08
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  3.513e+00. Current Zstar:  3.513e+00 (converged=False)
# 	Change =  1.586e-08
# __________________________________________
# TF Iteration 600
# 	μ = 8.516659148e-01, change: 2.669962959e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.115e-09
# 	ne Err =  2.080e-05, ne change =  4.537e-06
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  4.916e+00. Current Zstar:  3.654e+00 (converged=False)
# 	Change =  1.884e-02
# __________________________________________
# TF Iteration 625
# 	μ = 8.516683172e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.014e-05
# 	ne Err =  1.438e-04, ne change =  2.145e-08
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  3.653e+00. Current Zstar:  3.653e+00 (converged=False)
# 	Change =  2.591e-05
# __________________________________________
# TF Iteration 650
# 	μ = 8.516570488e-01, change: 2.902964716e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.225e-06
# 	ne Err =  8.355e-05, ne change =  2.765e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.653e+00. Current Zstar:  3.653e+00 (converged=False)
# 	Change =  8.340e-06
# __________________________________________
# TF Iteration 675
# 	μ = 8.516573517e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.835e-06
# 	ne Err =  5.503e-05, ne change =  2.819e-08
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  3.653e+00. Current Zstar:  3.653e+00 (converged=False)
# 	Change =  2.014e-06
# __________________________________________
# TF Iteration 700
# 	μ = 9.894733394e-01, change: 1.618200714e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.216e-06
# 	ne Err =  1.293e-04, ne change =  2.955e-05
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.972e+00. Current Zstar:  4.568e+00 (converged=False)
# 	Change =  1.070e-01
# __________________________________________
# TF Iteration 725
# 	μ = 9.895110229e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.981e-04
# 	ne Err =  7.966e-04, ne change =  1.450e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.567e+00. Current Zstar:  4.567e+00 (converged=False)
# 	Change =  1.707e-04
# __________________________________________
# TF Iteration 750
# 	μ = 9.894219874e-01, change: 1.076618068e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.456e-05
# 	ne Err =  4.660e-04, ne change =  1.506e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.567e+00. Current Zstar:  4.567e+00 (converged=False)
# 	Change =  4.922e-05
# __________________________________________
# TF Iteration 775
# 	μ = 9.894268695e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.882e-05
# 	ne Err =  3.047e-04, ne change =  1.621e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.567e+00. Current Zstar:  4.567e+00 (converged=False)
# 	Change =  1.339e-05
# __________________________________________
# TF Iteration 800
# 	μ = 1.146435569e+00, change: 1.586826222e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.084e-06
# 	ne Err =  2.665e-04, ne change =  3.629e-05
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.293e+00. Current Zstar:  5.689e+00 (converged=False)
# 	Change =  1.054e-01
# __________________________________________
# TF Iteration 825
# 	μ = 1.146495205e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.442e-04
# 	ne Err =  8.893e-04, ne change =  1.430e-07
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  5.688e+00. Current Zstar:  5.688e+00 (converged=False)
# 	Change =  2.095e-04
# __________________________________________
# TF Iteration 850
# 	μ = 1.146376428e+00, change: 5.795238676e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.782e-05
# 	ne Err =  5.368e-04, ne change =  2.298e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.688e+00. Current Zstar:  5.688e+00 (converged=False)
# 	Change =  5.571e-05
# __________________________________________
# TF Iteration 875
# 	μ = 1.146384470e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.371e-05
# 	ne Err =  3.523e-04, ne change =  2.289e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.688e+00. Current Zstar:  5.688e+00 (converged=False)
# 	Change =  1.671e-05
# __________________________________________
# TF Iteration 900
# 	μ = 1.131371935e+00, change: 1.309801836e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.059e-05
# 	ne Err =  2.313e-04, ne change =  3.572e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.608e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  9.495e-03
# __________________________________________
# TF Iteration 925
# 	μ = 1.131366099e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.280e-05
# 	ne Err =  1.253e-04, ne change =  1.351e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  1.916e-05
# __________________________________________
# TF Iteration 950
# 	μ = 1.131377465e+00, change: 4.993201852e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.325e-06
# 	ne Err =  7.878e-05, ne change =  6.287e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  5.316e-06
# __________________________________________
# TF Iteration 975
# 	μ = 1.131376651e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.282e-06
# 	ne Err =  5.388e-05, ne change =  3.128e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  1.814e-06
# __________________________________________
# TF Iteration 1000
# 	μ = 1.130867237e+00, change: 4.500386056e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.743e-06
# 	ne Err =  3.745e-05, ne change =  1.202e-07
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  5.574e+00. Current Zstar:  5.573e+00 (converged=False)
# 	Change =  3.246e-04
# __________________________________________
# TF Iteration 1025
# 	μ = 1.130867107e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.591e-06
# 	ne Err =  2.538e-05, ne change =  8.260e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.573e+00. Current Zstar:  5.573e+00 (converged=False)
# 	Change =  1.049e-06
# __________________________________________
# TF Iteration 1050
# 	μ = 1.130867555e+00, change: 2.647665887e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.387e-07
# 	ne Err =  1.798e-05, ne change =  3.233e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.573e+00. Current Zstar:  5.573e+00 (converged=False)
# 	Change =  3.671e-07
# __________________________________________
# TF Iteration 1075
# 	μ = 1.130867533e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.135e-07
# 	ne Err =  1.284e-05, ne change =  1.479e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.573e+00. Current Zstar:  5.573e+00 (converged=False)
# 	Change =  1.443e-07
# __________________________________________
# TF Iteration 1100
# 	μ = 1.131117802e+00, change: 2.213161249e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.519e-07
# 	ne Err =  9.347e-06, ne change =  5.957e-08
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  5.576e+00. Current Zstar:  5.575e+00 (converged=False)
# 	Change =  1.593e-04
# __________________________________________
# TF Iteration 1125
# 	μ = 1.131117901e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.632e-07
# 	ne Err =  7.334e-06, ne change =  1.345e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.575e+00. Current Zstar:  5.575e+00 (converged=False)
# 	Change =  3.053e-07
# __________________________________________
# TF Iteration 1150
# 	μ = 1.131117708e+00, change: 8.494037362e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.321e-07
# 	ne Err =  5.282e-06, ne change =  8.525e-10
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  5.575e+00. Current Zstar:  5.575e+00 (converged=False)
# 	Change =  7.448e-08
# __________________________________________
# TF Iteration 1175
# 	μ = 1.131117723e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.076e-08
# 	ne Err =  3.821e-06, ne change =  6.548e-10
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  5.575e+00. Current Zstar:  5.575e+00 (converged=False)
# 	Change =  2.007e-08
# __________________________________________
# TF Iteration 1200
# 	μ = 1.131519481e+00, change: 3.551810020e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.632e-08
# 	ne Err =  2.987e-06, ne change =  9.553e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.576e+00. Current Zstar:  5.578e+00 (converged=False)
# 	Change =  2.556e-04
# __________________________________________
# TF Iteration 1225
# 	μ = 1.131519646e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.265e-07
# 	ne Err =  3.515e-06, ne change =  8.236e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.578e+00. Current Zstar:  5.578e+00 (converged=False)
# 	Change =  5.390e-07
# __________________________________________
# TF Iteration 1250
# 	μ = 1.131519333e+00, change: 1.452591303e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.743e-07
# 	ne Err =  2.388e-06, ne change =  2.897e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.578e+00. Current Zstar:  5.578e+00 (converged=False)
# 	Change =  1.412e-07
# __________________________________________
# TF Iteration 1275
# 	μ = 1.131519355e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.479e-08
# 	ne Err =  1.687e-06, ne change =  3.305e-10
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  5.578e+00. Current Zstar:  5.578e+00 (converged=False)
# 	Change =  4.176e-08
# __________________________________________
# TF Iteration 1300
# 	μ = 1.131413949e+00, change: 9.316138326e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.248e-08
# 	ne Err =  1.146e-06, ne change =  2.506e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  6.706e-05
# __________________________________________
# TF Iteration 1325
# 	μ = 1.131413904e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.617e-07
# 	ne Err =  7.515e-07, ne change =  2.869e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  1.367e-07
# __________________________________________
# TF Iteration 1350
# 	μ = 1.131413985e+00, change: 3.808339422e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.597e-08
# 	ne Err =  4.875e-07, ne change =  7.993e-11
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  3.569e-08
# __________________________________________
# TF Iteration 1375
# 	μ = 1.131413980e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.675e-08
# 	ne Err =  3.479e-07, ne change =  9.051e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  1.072e-08
# __________________________________________
# TF Iteration 1400
# 	μ = 1.131417904e+00, change: 3.469683167e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.344e-09
# 	ne Err =  2.561e-07, ne change =  9.300e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  2.500e-06
# __________________________________________
# TF Iteration 1425
# 	μ = 1.131417906e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.488e-09
# 	ne Err =  1.939e-07, ne change =  6.672e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  4.337e-09
# __________________________________________
# TF Iteration 1450
# 	μ = 1.131417903e+00, change: 3.722577802e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.761e-09
# 	ne Err =  1.447e-07, ne change =  4.278e-11
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  1.172e-09
# __________________________________________
# TF Iteration 1475
# 	μ = 1.131417904e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.947e-09
# 	ne Err =  1.084e-07, ne change =  2.884e-11
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  5.375e-10
# __________________________________________
# TF Iteration 1500
# 	μ = 1.131424600e+00, change: 5.918677362e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.439e-09
# 	ne Err =  8.363e-08, ne change =  1.591e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  4.260e-06
# __________________________________________
# TF Iteration 1525
# 	μ = 1.131424603e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.065e-08
# 	ne Err =  7.692e-08, ne change =  1.941e-11
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  9.148e-09
# __________________________________________
# TF Iteration 1550
# 	μ = 1.131424598e+00, change: 2.387905429e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.065e-09
# 	ne Err =  5.568e-08, ne change =  1.232e-11
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  2.472e-09
# __________________________________________
# TF Iteration 1575
# 	μ = 1.131424598e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.193e-09
# 	ne Err =  4.131e-08, ne change =  1.186e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  7.554e-10
# __________________________________________
# TF Iteration 1600
# 	μ = 1.131420500e+00, change: 3.621868573e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.199e-10
# 	ne Err =  2.938e-08, ne change =  9.747e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  2.607e-06
# __________________________________________
# TF Iteration 1625
# 	μ = 1.131420498e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.292e-09
# 	ne Err =  2.654e-08, ne change =  1.148e-11
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  5.366e-09
# __________________________________________
# TF Iteration 1650
# 	μ = 1.131420501e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.733e-09
# 	ne Err =  1.720e-08, ne change =  3.689e-12
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  1.280e-09
# __________________________________________
# TF Iteration 1675
# 	μ = 1.131420501e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.070e-10
# 	ne Err =  1.238e-08, ne change =  3.017e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  4.051e-10
# __________________________________________
# TF Iteration 1700
# 	μ = 1.131420691e+00, change: 1.672110426e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.675e-10
# 	ne Err =  9.189e-09, ne change =  4.484e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  1.205e-07
# __________________________________________
# TF Iteration 1725
# 	μ = 1.131420691e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.882e-10
# 	ne Err =  6.872e-09, ne change =  1.905e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  2.256e-10
# __________________________________________
# TF Iteration 1750
# 	μ = 1.131420691e+00, change: 6.680211939e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.263e-10
# 	ne Err =  5.243e-09, ne change =  1.431e-12
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  6.200e-11
# __________________________________________
# TF Iteration 1775
# 	μ = 1.131420691e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.991e-11
# 	ne Err =  4.026e-09, ne change =  1.223e-12
# 	Q =  0.000e+00 -> -1.819e-12,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  2.607e-11
# __________________________________________
# TF Iteration 1800
# 	μ = 1.131420792e+00, change: 8.924571682e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.560e-11
# 	ne Err =  3.108e-09, ne change =  2.404e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  6.424e-08
# __________________________________________
# TF Iteration 1825
# 	μ = 1.131420792e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.725e-10
# 	ne Err =  2.449e-09, ne change =  8.764e-13
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  1.426e-10
# __________________________________________
# TF Iteration 1850
# 	μ = 1.131420792e+00, change: 2.341460359e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.617e-11
# 	ne Err =  1.885e-09, ne change =  8.630e-13
# 	Q = -9.095e-13 ->  9.095e-13,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  3.819e-11
# __________________________________________
# TF Iteration 1875
# 	μ = 1.131420792e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.660e-11
# 	ne Err =  1.458e-09, ne change =  7.461e-13
# 	Q = -9.095e-13 -> -9.095e-13,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  1.450e-11
# __________________________________________
# TF Iteration 1900
# 	μ = 1.131420758e+00, change: 2.942826183e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.642e-11
# 	ne Err =  1.125e-09, ne change =  7.914e-12
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  2.118e-08
# __________________________________________
# TF Iteration 1916
# 	μ = 1.131420758e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.965e-11
# 	ne Err =  9.900e-10, ne change =  6.320e-13
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  5.577e+00. Current Zstar:  5.577e+00 (converged=False)
# 	Change =  8.912e-11
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 2.572e+03
# Exiting status 0, reverting to best index so far: 8645
# Final iter:8646, Total Error: 9.984e-13
# CPU times: user 1min, sys: 404 ms, total: 1min
# Wall time: 1min

# %%
# cutoff_point = 0.02
# cutoff_index = np.argmin(np.abs(  cutoff_point - np.array([aa.grid.integrate_f(aa.ne, end_index = i) for i in range(len(aa.ne))])))
# guess_tfdw_ne = 1/(  1/aa.ne + 1/aa.ne[cutoff_index])
# aaW.ne = guess_tfdw_ne.copy()
# aaW.μ  = aa.μ
# aaW.Zstar = aa.Zstar

# aaW.solve_TF(verbose=True, picard_alpha=1e-3, tol=1e-9)
# aaW.set_uii_eff()

# %%
# %%time
# cutoff_point = 0.02
# cutoff_index = np.argmin(np.abs(  cutoff_point - np.array([npa.grid.integrate_f(npa.ne, end_index = i) for i in range(len(npa.ne))])))
# guess_tfdw_ne = 1/(  1/npa.ne + 1/npa.ne[cutoff_index])

# npaW.ne = guess_tfdw_ne.copy()
# npaW.μ  = npa.μ
# npaW.Zstar = npa.Zstar
# npaW.φe = npa.φe.copy()
# # npaW.solve_TF(verbose=True, picard_alpha=1e-2, tol=1e-9, nmax = 5000, n_wait_update_Zstar= 500)
# # npaW.set_uii_eff()

# %% [markdown]
# ### EOS

# %%
def get_Eii(aa):
    βVeff = aa.get_βVeff(aa.φe, aa.ne, aa.ne_bar)
    η = aa.μ/aa.Te - βVeff
    βU = aa.grid.integrate_f(βVeff*aa.ne)
    I_onehalf = FermiDirac.Ionehalf(η)
    I_threehalf = FermiDirac.Ithreehalf(η)
    
    βK = (2*aa.Te)**1.5/π**2 * aa.grid.integrate_f( η*I_onehalf - 2/3 * I_threehalf   )
    return βU, βK, βU + βK

def get_ETF(aa):
    
def get_Exc(aa):
    aa.vxc

def get_E_Hartree(aa):
    
    
    

# get_E(aa_tfd), get_E(npa_tfd)
# Out:
#   Cell In[24], line 13
#     def get_Exc(aa):
#     ^
# IndentationError: expected an indented block after function definition on line 11

# %%
def get_P(aa):
    aa_old_βu = aa.iet.βu_r_matrix.copy()
    # aa.iet.set_βu_matrix( np.array([[1/aa.Ti * aa.Zstar**2/(aa.iet.r_array*aa.rs) ]] ))
    P_id_hnc, P_ex_hnc, P_hnc = aa.iet.ideal_pressure(), aa.iet.excess_pressure(), aa.iet.total_pressure()
    P_id_AU, P_ex_AU, P_AU  = P_id_hnc/rs**3, P_ex_hnc/rs**3, P_hnc/rs**3
    aa.iet.set_βu_matrix(aa_old_βu)
    return P_id_AU, P_ex_AU, P_AU

aa_P_ions = get_P(aa_tfd)
aa_P_ions[1]/aa_P_ions[0]

# %% [markdown]
# ## Comparison

# %%
npa.make_plots()
# Out:
# (<Figure size 4000x1600 with 2 Axes>,
#  array([<Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$\\phi$ [A.U.]'>,
#         <Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$n$ [A.U.]'>],
#        dtype=object))

# %%
def plot_convergence(aa, axs=None):
    if axs is None:
        fig, axs = plt.subplots(ncols=3,figsize=(18,5),facecolor='w', dpi=200)
    
    # ELectric potential
    slice_by_num = 100
    ax = axs[0]
    colors = plt.cm.coolwarm(np.linspace(0, 1,len(aa.φe_list[::slice_by_num])))
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        if i ==0 or i==len(aa.φe_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, (φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\phi_e$'.format(i))
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\vec E$'.format(i))
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1, label=r'$\beta V_{{\rm eff}}$'.format(i))
        else:
            ax.plot(aa.grid.xs, φe+aa.φion,linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1)
    # ax.plot(aa.grid.xs, aa.get_φe( (aa.ρi - aa.ne) )[0] + aa.φion  ,'k:', label=r'$\phi$ check') 
    ax.set_yscale('symlog',linthresh=1e-10)
    ax.plot(aa.grid.xs, aa.φe_init + aa.φion, 'k:')

    # number density
    ax = axs[1]
    for i, (ne, ρi) in enumerate(zip(aa.ne_list[::slice_by_num], aa.ρi_list[::slice_by_num])):
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            if i==0: 
                ne_bar_0 = ne[-1]
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1, label=r'$Q(r)$'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, -ne + 0*ρi + ne[-1],linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ne_bar_0,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ρi[-1] + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # pass
        else:
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1)
            # print(ne[-1]-ne_bar_0)
            # ax.plot(aa.grid.xs, -ne + ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ne + ne_bar_0 ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ρi[-1]+ ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            pass
    # for i in range(int(aa.R/aa.rs)):
    #     ax.axvline(aa.rs*i, color='k', linestyle='--', alpha=0.2)
    # ax.set_xscale('log')
    # ax.plot(aa.grid.xs, (aa.gii)-1, 'k:')
    ax.set_yscale('symlog',linthresh=1e-4)

            
    # number density
    ax = axs[2]
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        ne_TF = aa.get_ne_TF(φe, ne, μ, ne_bar)
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            # ax.plot(aa.grid.xs, ne - ne_TF,linewidth=1,color=colors[i],alpha=1, label=r'$n_e/n_e^{{TF}}-1$, iter: {0}'.format(i))
            # ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1, label=r'$n_e^{{TF}} - n_e^{{TF}}[-1]$, iter: {0}'.format(i*slice_by_num))
            ax.plot(aa.grid.xs, ne-0*ne[-1],linewidth=1,color=colors[i],linestyle='--',alpha=1, label=r'$n_e - n_e[-1]$, iter: {0}'.format(i))
            # pass
        else:
            # ax.plot(aa.grid.xs, ne - ne_TF, linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1)
            ax.plot(aa.grid.xs, ne-0*ne[-1], linewidth=1,linestyle='--',color=colors[i],alpha=0.5)
            

            # print(np.abs(ne/ne_TF-1))
            # print(np.where( np.abs(ne/ne_TF-1)>1e-6 ))
            # print(aa.grid.xs[np.where( np.abs(ne/ne_TF-1) > 1e-8)][0]/10, 1/(np.sum(aa.grid.xs*np.abs(ne/ne_TF-1))/np.sum(np.abs(ne/ne_TF-1))))
    # ax.set_ylim()
    # ax.plot(aa.grid.xs, npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar) - npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar)[-1] , 'k:')
    ax.plot(aa.grid.xs, aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar) - aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar)[-1] , 'k:')
    ax.set_yscale('symlog',linthresh=1e-10)
    # ax.set_xscale('log')
    for ax in axs:
        ax.legend(fontsize=14)
        ax.tick_params(labelsize=14)
        ax.plot(aa.grid.xs, np.zeros_like(aa.ne),'k', alpha=0.2)
    plt.tight_layout()
    
# plot_convergence(aa)
plot_convergence(npa)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

petrov = pd.read_csv("../data/George_Petrov/GP_TFDW_Al_1eV_solid.dat",header=0, comment='#', delim_whitespace=True)

def compare_aa(aa_list, axs=None, name=''):
    eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
    if axs is None:
        fig, axs = plt.subplots(ncols=2,figsize=(20,8),facecolor='w')

    # Density * 4pi r^2 plot
    for ax in axs:
        for aa, color in zip( aa_list, colors):
            factor = 4*np.pi*aa.grid.xs**2
            ax.plot(np.array(petrov['r/R'])*rs, 4*π*(np.array(petrov['r/R'])*rs)**2*(petrov['ne']/m_to_AU**3), 'k--', label="Petrov AA")
            ax.plot(aa.grid.xs, aa.ne*factor ,'--.',color=color, label=r'$n_e$: '+ name)
            try:
                ax.plot(npa.grid.xs, (aa_ne_extended * (1-transition_func) + transition_func * npa.ρi )*factor ,'-',color='b', label=r'$n_e$: '+ name)
            except:
                pass
            ax.plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
            ax.plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
            if aa.rs != aa.R:
                ax.plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
                ax.plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)
        # axs[0].plot(aa.grid.xs, aa.δn_f*factor,'--',color='g',  label=r'$n_e^{sc}$: ' + name)


    axs[0].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[0].set_ylim(0, 1e3)
    axs[0].set_yscale('symlog',linthresh=1e-1)
    axs[0].set_xscale('log')
    axs[0].set_xlim(aa.grid.xs[0],aa.grid.xs[-1])

    axs[1].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[1].set_ylim(0, 13)
    axs[1].set_xlim(0, np.min([aa.R,1.3*aa.rs]))

        
    for ax in axs:
        ax.set_xlabel(r'$|r-R_1|$ [A.U.]',fontsize=20)
        ax.legend(loc="upper right",fontsize=20,labelspacing = 0.1)
        ax.tick_params(labelsize=20)
        ax.grid(which='both',alpha=0.4)

        # make textbox
        text = ("{0}\n".format(aa.name)+ 
            r"$r_s$ = " + "{0},    ".format(np.round(aa.rs,2)) +
            r"$R_{NPA}$ = " + "{0}\n".format(aa.R)  +
                r"$T_e$ = " + "{0} [A.U.] = {1} eV\n".format(np.round(aa.Te,2),np.round(aa.Te/eV,2)) + r"$\mu$ = " + "{0} [A.U.]\n".format(np.round(aa.μ,2)) +
                r"$Z^\ast = $" + "{0}".format(np.round(aa.Zstar,2))  )

        props = dict(boxstyle='round', facecolor='w')
        ax.text(0.25,0.95, text, fontsize=15, transform=ax.transAxes, verticalalignment='top', bbox=props)

    plt.tight_layout()
    name = "NPA_densities_{0}_rs{1}_{2}eV_R{3}.png".format(aa.name, np.round(aa.rs,2), np.round(aa.Te/eV,2) ,np.round(aa.R))
    plt.savefig("/home/zach/plasma/atomic_forces/average_atom/media/" + name, dpi=300, bbox_inches='tight',facecolor="w")
    
    
    return axs


axs = compare_aa([aa,npa])#, npa_2])
for ax in axs:
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), fontsize=16, loc='upper right')
# axs[1].set_ylim(1e-5,1e3)

# %% [markdown]
# ## HNC and FT

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.k_array/rs, aa.Uei_iet_k*(aa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.k_array/rs, npa.Uei_iet_k*(npa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[1], label="NPA") # Need to muultiply by some rs power???
# axs[0].plot(npa_2.iet.k_array/rs, npa_2.Uei_iet_k*(npa_2.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[2], label="NPA 2") # Need to muultiply by some rs power???
axs[0].plot(aa.iet.k_array/rs, aa.Zstar*np.ones_like(aa.iet.k_array),':', color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(npa.iet.k_array/rs, npa.Zstar*np.ones_like(npa.iet.k_array),':',color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
# axs[0].plot(npa_2.iet.k_array/rs, npa_2.Zstar*np.ones_like(npa_2.iet.k_array),':',color=colors[2], label=f"Coulomb, Z={npa_2.Zstar:0.3f}")

# axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$k$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

# axs[1].plot(aa.iet.k_array/rs, aa.uii_k_eff_iet,'-', color=colors[0], label="AA")
# axs[1].plot(aa.iet.k_array/rs, 4*π*aa.Zstar**2/(aa.iet.k_array/rs)**2,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, 1/(aa.iet.k_array**2/rs**2/(4*π*aa.Zstar**2) + 1/aa.uii_k_eff_iet[0] ),'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, uii_test,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))


# axs[1].plot(npa.iet.k_array/rs, npa.uii_k_eff_iet,color=colors[1], label="NPA")
axs[1].plot(npa.iet.k_array/rs, 4*π*npa.Zstar**2/(npa.iet.k_array/rs)**2,'--', color=colors[1], label=r"NPA: $u_{{ii}}^0$, Z={0:0.3f}".format(npa.Zstar))



axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_ylim(0,1e5)
axs[1].set_xscale('log')
axs[1].set_xlabel(r"$k$ [au]")
axs[1].set_ylabel(r"$u^{\rm eff}_{ii}$ [au]")


for ax in axs:
    ax.legend(fontsize=12)
plt.tight_layout()

# %%
uii_test = aa.iet.FT_k_2_r(aa.uii_k_eff_iet)/rs**3

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.r_array*rs, -aa.Zstar/(aa.iet.r_array*rs), color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(aa.iet.r_array*rs, -aa.Uei_iet ,':',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.r_array*rs, -npa.Zstar/(npa.iet.r_array*rs),color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(npa.iet.r_array*rs, -npa.Uei_iet ,':',color=colors[1], label="NPA") # Need to muultiply by some rs power???
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Zstar/(npa.iet.r_array*rs),color=colors[2], label=f"Coulomb, Z={npa_2.Zstar:0.3f}")
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Uei_iet ,':',color=colors[2], label=r"NPA: $g_{AA}$") # Need to muultiply by some rs power???

axs[0].set_yscale('symlog',linthresh=1e-1)
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$r$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.r_array*rs, 1/aa.Te * aa.uii_r_eff_iet, color=colors[0],linestyle='-', label='AA')
axs[1].plot(aa.iet.r_array*rs, 1/aa.Te *aa.Zstar**2/(aa.iet.r_array*rs ), color=colors[0] ,linestyle='--', label=f'Coulomb Z={aa.Zstar:0.3f}')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.uii_r_eff_iet, color=colors[1],linestyle='-', label='NPA')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.Zstar**2/(npa.iet.r_array*rs ), color=colors[1],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )
# axs[1].plot(npa_2.iet.r_array*rs, 1/npa.Te *npa_2.uii_r_eff_iet, color=colors[2],linestyle='-', label=r"NPA: $g_{AA}$")
# axs[1].plot(npa_2.iet.r_array*rs, 1/npa.Te *npa_2.Zstar**2/(npa_2.iet.r_array*rs ), color=colors[2],linestyle='--', label=f'Coulomb Z={npa_2.Zstar:0.3f}' )

axs[1].set_yscale('symlog',linthresh=1e0)
axs[1].set_xscale('log')
axs[1].set_ylabel(r"$\beta U_{ii}$ [au]")
axs[1].set_xlabel(r"$r$ [au]")
axs[1].set_xlim(1,None)


for ax in axs:
    ax.legend(fontsize=10)
plt.tight_layout()

# %%
npa.make_gii()
npa.make_ρi()
# npa_2.make_gii()
# npa_2.make_ρi()
# Out:
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 9.984e-13
# Exiting status 0, reverting to best index so far: 1
# Final iter:2, Total Error: 9.961e-13

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, axs  = plt.subplots(1,2, figsize=(8,4))

# Data from community TCCW
upper_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Upper.txt", delim_whitespace=True, header=1)
lower_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Lower.txt", delim_whitespace=True, header=1)

ax = axs[0]
ax.fill_between(lower_data['r/ri'],lower_data['gii'], PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')

# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0] + 1, label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)
ax.plot(npa.iet.r_array, npa.iet.h_r_matrix[0,0] + 1, label=r"NPA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("g(r)")
ax.set_xlim(0.7,3)
# ax.set_ylim(0,2)
ax.legend(fontsize=10)

ax = axs[1]
ax.fill_between(lower_data['r/ri'],lower_data['gii']-1, PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')
# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii-1, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0], label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)
ax.plot(npa.iet.r_array, npa.iet.h_r_matrix[0,0], label=r"NPA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii-1, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("h(r)")
ax.set_xlim(0.7,10)
ax.set_ylim(-2.5,2.5)
ax.set_yscale('symlog', linthresh=1e-4)

ax.legend(fontsize=8, loc='upper right')
plt.tight_layout()

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, ax = plt.subplots(figsize=(5,3.5))#1,1, figsize=(8,4))

# Average atom effective potential to gii

ax.plot(aa.iet.k_array/rs/AU_to_Angstrom, aa.iet.S_k_matrix[0,0],'-', label="OFAA")
ax.plot(npa.iet.k_array/rs/AU_to_Angstrom, npa.iet.S_k_matrix[0,0],'-', label=r"OFNPA (Yukawa $g^0_{ii}$)")
# ax.plot(npa_2.iet.k_array/rs, npa_2.iet.S_k_matrix[0,0],'-', label=r"OFNPA (OFAA $g^0_{ii}$)")

ax.set_xlabel(r"$k r_i$")
ax.set_ylabel(r"$S_{ii}(k)$")
ax.legend(fontsize=12, loc='lower right')

ax.set_xlim(0,10)
ax.set_ylim(1-3/12,1.5+5/12)
plt.tight_layout()
