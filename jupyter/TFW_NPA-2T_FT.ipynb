# %%
import numpy as np
import pandas as pd


from average_atom.core.average_atom_kspace import NeutralPseudoAtom as NPA
from average_atom.core.misc import jacobi_relaxation, sor
from average_atom.core.grids import FourierGrid
from average_atom.core.physics import ThomasFermi, FermiDirac

from importlib import reload
try:
    reload(physics)
    reload(grids)
    reload(average_atom_geometric)
#     reload(average_atom)
    reload(misc)
except NameError as e:
    from average_atom.core import physics as physics
    from average_atom.core import average_atom_kspace as average_atom
    from average_atom.core import misc as misc
    from average_atom.core import grids as grids
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)

import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

import cProfile

plt.rcParams.update({'font.size': 10})
plt.rcParams["figure.figsize"] = (5,3.5)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14

color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# Error:  name 'physics' is not defined
# ModuleNotFoundError: No module named 'mendeleev'

# %%
# Aluminum
name='Al'
Z, A = 13, 27 

ρ_solid = 2.699 #g/cc, the solid density of aluminum 
ρ = ρ_solid#2.32*ρ_solid#8.1 # g/cc
ni_cc = ρ/(A*amu_to_AU*AU_to_g)
ni_AU = ni_cc*invcc_to_AU
rs = rs_from_n(ni_AU)

Ti_eV = 1#.75
Te_eV = 1#.75

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

# Hydrogen
# name='H'
# Z, A = 1, 1.00784

# Te_eV = 2 
# Te_AU = Te_eV*eV_to_AU

# Ti_eV = 2
# Ti_AU = Ti_eV*eV_to_AU

# ρ_gpercc = 1
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)

# Carbon
# name = 'C'
# Z, A = 6, 12.011

# ρ_gpercc = 2.267
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)

# Ti_eV = 0.5 
# Te_eV = 0.5

# Te_AU = Te_eV*eV_to_AU
# Ti_AU = Ti_eV*eV_to_AU


####
R = 10*rs
ignore_vxc = True
fixed_Zstar = False
Zstar_init = 'More'

aa_kwargs = {'initialize':True, 'gradient_correction':None, 'μ_init' : 0.158, 'Zstar_init' : Zstar_init, 'Npoints':1000,
             'name':name, 'ignore_vxc':ignore_vxc, 'fixed_Zstar':fixed_Zstar, 'iet_R_over_rs':R/rs, 'iet_N_bins':5000, 'use_full_ne_for_nf':False,
            'gii_init_type': 'step'}

aaW_kwargs = aa_kwargs.copy()
aaW_kwargs.update({'gradient_correction':'W', 'Weizsacker_λ':1/5})

npa_kwargs = aa_kwargs.copy()
npa_kwargs.update({'Npoints':10000, 'iet_N_bins':10000, 'gii_init_type': 'iet', 'grid_spacing':'linear'})

npaW_kwargs = npa_kwargs.copy()
npaW_kwargs.update({'gradient_correction':'W', 'Weizsacker_λ':1/5})

aa = NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aa_kwargs)
aaW =NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aaW_kwargs)
npa = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)                           
npaW = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npaW_kwargs)
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 6.985e+02
# Exiting status 0, reverting to best index so far: 1236
# Final iter:1237, Total Error: 9.838e-13
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 6.985e+02
# Exiting status 0, reverting to best index so far: 1236
# Final iter:1237, Total Error: 9.838e-13
# Intialized Potentials and Densities

# %%
fig, axs  = plt.subplots(1,2,figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

short_distance_weight = np.exp(-(0.08*npa.kTF*npa.grid.xs)**4)
for ax in axs:
    # ax.plot(npa.iet.r_array*rs, npa.iet.h_r_matrix[0,0], color=colors[0], label=r"NPA: $u_Y$")
    ax.plot(npa.grid.xs, npa.gii-1, color=colors[0], label=r"NPA: $u_Y$")
    # ax.plot(npa_2.grid.xs, npa_2.gii-1,'--', color=colors[0], label=r"NPA: $u_{AA}$",zorder=10)
    ax.plot(aa.iet.r_array*rs, aa.iet.h_r_matrix[0,0],color=colors[1],  label=r"$u_{AA}$")
    # ax.plot(npa.grid.xs, short_distance_weight*(npa.gii-1),'--',color=colors[3],  label=r"$u_Y$ damped")
    			

    # ax.plot(aa.grid.xs, aa.gii-1,'--',color=colors[3],  label=r"$u_Y$")
    ax.axvline(npa.iet.r_array[-1]*rs,color='k')
    
ax = axs[0]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xlim(0,3*rs)

ax = axs[1]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xscale('log')
ax.set_xlim(0.5,None)
ax.set_yscale('symlog', linthresh=1e-6)
for ax in axs:
    ax.legend(fontsize=12)
    ax.tick_params(labelsize=12)


plt.tight_layout()

# %% [markdown]
# ### Thomas Fermi (TF)

# %%
# %%time
from scipy.interpolate import interp1d
aa.solve_TF(verbose=True, picard_alpha=0.2, tol=1e-9, n_wait_update_Zstar= 100)
aa.set_uii_eff()
# aa.iet.HNC_solve(iters_to_wait=1e5, alpha_Picard=1e-2, tol=1e-12, verbose=False, num_iterations=1e5)
# aa.gii = interp1d(aa.iet.r_array*aa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(aa.grid.xs)
# npa_2.gii = interp1d(aa.iet.r_array*aa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(npa.grid.xs)
# aa.make_ρi()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 2.177952944e+00, change: 4.797652533e+00 (converged=False)
# 	φe Err =  0.000e+00, φe change =  7.826e-01
# 	ne Err =  8.577e-01, ne change =  4.961e-03
# 	Q =  0.000e+00 -> -1.201e+01,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.586e+00
# __________________________________________
# TF Iteration 1
# 	μ = 1.839706426e+00, change: 1.553047871e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.259e-01
# 	ne Err =  6.646e-01, ne change =  3.103e-03
# 	Q = -1.201e+01 -> -1.054e+01,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.630e-01
# __________________________________________
# TF Iteration 2
# 	μ = 1.568357389e+00, change: 1.474958360e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.007e-01
# 	ne Err =  4.763e-01, ne change =  2.035e-03
# 	Q = -1.054e+01 -> -9.240e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.263e-01
# __________________________________________
# TF Iteration 3
# 	μ = 1.256393223e+00, change: 1.989114015e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  7.632e-02
# 	ne Err =  3.246e-01, ne change =  1.337e-03
# 	Q = -9.240e+00 -> -8.388e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.429e-01
# __________________________________________
# TF Iteration 4
# 	μ = 1.032452404e+00, change: 1.782410275e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  4.789e-02
# 	ne Err =  2.792e-01, ne change =  9.154e-04
# 	Q = -8.388e+00 -> -7.396e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.933e-01
# __________________________________________
# TF Iteration 5
# 	μ = 1.032315639e+00, change: 1.324654606e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.093e-02
# 	ne Err =  1.572e-01, ne change =  6.420e-04
# 	Q = -7.396e+00 -> -6.399e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.721e-02
# __________________________________________
# TF Iteration 6
# 	μ = 1.032315639e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.977e-02
# 	ne Err =  8.561e-02, ne change =  4.460e-04
# 	Q = -6.399e+00 -> -5.962e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.454e-02
# __________________________________________
# TF Iteration 7
# 	μ = 1.032315639e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.017e-03
# 	ne Err =  5.950e-02, ne change =  3.266e-04
# 	Q = -5.962e+00 -> -5.747e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  9.886e-03
# __________________________________________
# TF Iteration 8
# 	μ = 1.032315639e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.402e-03
# 	ne Err =  4.556e-02, ne change =  2.463e-04
# 	Q = -5.747e+00 -> -5.620e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.072e-03
# __________________________________________
# TF Iteration 9
# 	μ = 1.032315639e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.658e-03
# 	ne Err =  3.562e-02, ne change =  1.885e-04
# 	Q = -5.620e+00 -> -5.535e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.864e-03
# __________________________________________
# TF Iteration 25
# 	μ = 5.184992025e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.481e-04
# 	ne Err =  3.155e-02, ne change =  2.189e-06
# 	Q = -1.409e+00 -> -1.323e+00,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.895e-04
# __________________________________________
# TF Iteration 50
# 	μ = 3.848076615e-01, change: 4.375582556e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.502e-06
# 	ne Err =  1.326e-02, ne change =  3.188e-08
# 	Q = -2.466e-01 -> -2.423e-01,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.162e-02
# __________________________________________
# TF Iteration 75
# 	μ = 3.726161564e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.717e-06
# 	ne Err =  6.389e-04, ne change =  5.048e-08
# 	Q = -3.061e-02 -> -2.887e-02,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.015e-06
# __________________________________________
# TF Iteration 100
# 	μ = 3.695156808e-01, change: 1.094924394e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.946e-07
# 	ne Err =  2.999e-04, ne change =  7.221e-10
# 	Q = -5.594e-03 -> -5.501e-03,
# 	Zstar guess =  2.495e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.747e-04
# KeyboardInterrupt

# %%
# %%time
transition_func = 1/(1 + np.exp(-(npa.grid.xs-2*npa.rs)/(2*(rs/4)**2)))
aa_ne_extended = np.zeros_like(npa.ne)
aa_ne_extended[:len(aa.ne)] = aa.ne.copy()
aa_ne_extended[len(aa.ne):] = aa.ne.copy()[-1]
npa.ne = aa_ne_extended * (1-transition_func) + transition_func * npa.ρi 
npa.μ = aa.μ
npa.Zstar = aa.Zstar

npa.solve_TF(verbose=True, picard_alpha=1e-2, tol=1e-9, nmax = 5000, n_wait_update_Zstar= 500)
npa.set_uii_eff()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 3.597535104e-01, change: 2.641882583e-02 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.267e-02
# 	ne Err =  3.606e-02, ne change =  3.500e-05
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.773e+00. Current Zstar:  2.494e+00 (converged=False)
# 	Change =  4.265e-02
# __________________________________________
# TF Iteration 1
# 	μ = 3.740006345e-01, change: 3.960246027e-02 (converged=False)
# 	φe Err =  0.000e+00, φe change =  6.902e-03
# 	ne Err =  8.449e-03, ne change =  3.434e-05
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  2.494e+00. Current Zstar:  2.492e+00 (converged=False)
# 	Change =  4.238e-02
# __________________________________________
# TF Iteration 2
# 	μ = 3.756001027e-01, change: 4.276645559e-03 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.676e-03
# 	ne Err =  5.593e-03, ne change =  3.396e-05
# 	Q =  4.547e-13 ->  0.000e+00,
# 	Zstar guess =  2.492e+00. Current Zstar:  2.492e+00 (converged=False)
# 	Change =  6.081e-03
# __________________________________________
# TF Iteration 3
# 	μ = 3.762257478e-01, change: 1.665721447e-03 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.058e-03
# 	ne Err =  4.781e-03, ne change =  3.356e-05
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  2.492e+00. Current Zstar:  2.492e+00 (converged=False)
# 	Change =  2.951e-03
# __________________________________________
# TF Iteration 4
# 	μ = 3.763715155e-01, change: 3.874472859e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.942e-04
# 	ne Err =  4.276e-03, ne change =  3.318e-05
# 	Q =  4.547e-13 ->  0.000e+00,
# 	Zstar guess =  2.492e+00. Current Zstar:  2.492e+00 (converged=False)
# 	Change =  1.319e-03
# __________________________________________
# TF Iteration 5
# 	μ = 3.763715155e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.967e-04
# 	ne Err =  3.764e-03, ne change =  3.281e-05
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  2.492e+00. Current Zstar:  2.492e+00 (converged=False)
# 	Change =  6.654e-04
# __________________________________________
# TF Iteration 6
# 	μ = 3.763715155e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.809e-04
# 	ne Err =  3.323e-03, ne change =  3.244e-05
# 	Q =  4.547e-13 ->  0.000e+00,
# 	Zstar guess =  2.492e+00. Current Zstar:  2.492e+00 (converged=False)
# 	Change =  4.613e-04
# __________________________________________
# TF Iteration 7
# 	μ = 3.763715155e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.068e-04
# 	ne Err =  3.009e-03, ne change =  3.209e-05
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  2.492e+00. Current Zstar:  2.492e+00 (converged=False)
# 	Change =  3.465e-04
# __________________________________________
# TF Iteration 8
# 	μ = 3.763715155e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.555e-04
# 	ne Err =  2.821e-03, ne change =  3.174e-05
# 	Q =  4.547e-13 ->  4.547e-13,
# 	Zstar guess =  2.492e+00. Current Zstar:  2.492e+00 (converged=False)
# 	Change =  2.781e-04
# __________________________________________
# TF Iteration 9
# 	μ = 3.763715155e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.173e-04
# 	ne Err =  2.731e-03, ne change =  3.140e-05
# 	Q =  4.547e-13 ->  4.547e-13,
# 	Zstar guess =  2.492e+00. Current Zstar:  2.492e+00 (converged=False)
# 	Change =  2.340e-04
# __________________________________________
# TF Iteration 25
# 	μ = 3.753971684e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.260e-05
# 	ne Err =  5.708e-04, ne change =  2.653e-05
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  6.155e-05
# __________________________________________
# TF Iteration 50
# 	μ = 3.754232879e-01, change: 5.775981902e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.734e-05
# 	ne Err =  2.611e-04, ne change =  2.048e-05
# 	Q =  4.547e-13 ->  4.547e-13,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  3.199e-05
# __________________________________________
# TF Iteration 75
# 	μ = 3.754198119e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.044e-05
# 	ne Err =  1.504e-04, ne change =  1.584e-05
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  1.913e-05
# __________________________________________
# TF Iteration 100
# 	μ = 3.754171564e-01, change: 1.247810934e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.677e-06
# 	ne Err =  9.187e-05, ne change =  1.226e-05
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  1.494e-05
# __________________________________________
# TF Iteration 125
# 	μ = 3.754167466e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.369e-06
# 	ne Err =  5.797e-05, ne change =  9.489e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  1.049e-05
# __________________________________________
# TF Iteration 150
# 	μ = 3.754165392e-01, change: 1.332313003e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.909e-06
# 	ne Err =  3.755e-05, ne change =  7.350e-06
# 	Q =  4.547e-13 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  7.984e-06
# __________________________________________
# TF Iteration 175
# 	μ = 3.754164615e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.970e-06
# 	ne Err =  2.490e-05, ne change =  5.696e-06
# 	Q = -4.547e-13 ->  4.547e-13,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  5.964e-06
# __________________________________________
# TF Iteration 200
# 	μ = 3.754163788e-01, change: 6.336853176e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.355e-06
# 	ne Err =  1.688e-05, ne change =  4.415e-06
# 	Q =  4.547e-13 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  4.573e-06
# __________________________________________
# TF Iteration 225
# 	μ = 3.754163409e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.449e-07
# 	ne Err =  1.166e-05, ne change =  3.423e-06
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  3.450e-06
# __________________________________________
# TF Iteration 250
# 	μ = 3.754163034e-01, change: 2.775961294e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.675e-07
# 	ne Err =  8.191e-06, ne change =  2.655e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  2.655e-06
# __________________________________________
# TF Iteration 275
# 	μ = 3.754162873e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.769e-07
# 	ne Err =  5.830e-06, ne change =  2.059e-06
# 	Q =  4.547e-13 ->  4.547e-13,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  2.018e-06
# __________________________________________
# TF Iteration 300
# 	μ = 3.754162717e-01, change: 1.151656959e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.439e-07
# 	ne Err =  4.195e-06, ne change =  1.597e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  1.556e-06
# __________________________________________
# TF Iteration 325
# 	μ = 3.754162650e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.500e-07
# 	ne Err =  3.044e-06, ne change =  1.239e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  1.189e-06
# __________________________________________
# TF Iteration 350
# 	μ = 3.754162583e-01, change: 5.042630868e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.829e-07
# 	ne Err =  2.223e-06, ne change =  9.614e-07
# 	Q =  4.547e-13 ->  4.547e-13,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  9.183e-07
# __________________________________________
# TF Iteration 375
# 	μ = 3.754162553e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.346e-07
# 	ne Err =  1.631e-06, ne change =  7.460e-07
# 	Q =  4.547e-13 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  7.043e-07
# __________________________________________
# TF Iteration 400
# 	μ = 3.754162521e-01, change: 2.369525132e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.950e-08
# 	ne Err =  1.202e-06, ne change =  5.789e-07
# 	Q =  4.547e-13 ->  4.547e-13,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  5.443e-07
# __________________________________________
# TF Iteration 425
# 	μ = 3.754162507e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.385e-08
# 	ne Err =  8.883e-07, ne change =  4.493e-07
# 	Q =  4.547e-13 ->  4.547e-13,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  4.184e-07
# __________________________________________
# TF Iteration 450
# 	μ = 3.754162492e-01, change: 1.168653174e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.500e-08
# 	ne Err =  6.580e-07, ne change =  3.487e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  3.236e-07
# __________________________________________
# TF Iteration 475
# 	μ = 3.754162485e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.107e-08
# 	ne Err =  4.883e-07, ne change =  2.707e-07
# 	Q =  4.547e-13 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  2.492e-07
# __________________________________________
# TF Iteration 500
# 	μ = 3.754162477e-01, change: 5.921352297e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.075e-08
# 	ne Err =  3.630e-07, ne change =  2.101e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  1.928e-07
# __________________________________________
# TF Iteration 525
# 	μ = 3.754162473e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.307e-08
# 	ne Err =  2.702e-07, ne change =  1.631e-07
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  1.486e-07
# __________________________________________
# TF Iteration 550
# 	μ = 3.754162469e-01, change: 3.048761243e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.734e-08
# 	ne Err =  2.014e-07, ne change =  1.266e-07
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  1.151e-07
# __________________________________________
# TF Iteration 575
# 	μ = 3.754162468e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.305e-08
# 	ne Err =  1.502e-07, ne change =  9.827e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.493e+00 (converged=False)
# 	Change =  8.876e-08
# __________________________________________
# TF Iteration 600
# 	μ = 3.890317281e-01, change: 3.626769376e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.843e-09
# 	ne Err =  3.276e-05, ne change =  2.899e-06
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  3.840e+00. Current Zstar:  2.627e+00 (converged=False)
# 	Change =  2.532e-02
# __________________________________________
# TF Iteration 625
# 	μ = 3.890419218e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.881e-05
# 	ne Err =  1.330e-04, ne change =  6.092e-08
# 	Q =  4.547e-13 ->  0.000e+00,
# 	Zstar guess =  2.627e+00. Current Zstar:  2.627e+00 (converged=False)
# 	Change =  1.681e-05
# __________________________________________
# TF Iteration 650
# 	μ = 3.890324963e-01, change: 6.812326822e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.916e-06
# 	ne Err =  5.984e-05, ne change =  6.058e-08
# 	Q =  4.547e-13 ->  4.547e-13,
# 	Zstar guess =  2.627e+00. Current Zstar:  2.627e+00 (converged=False)
# 	Change =  3.587e-06
# __________________________________________
# TF Iteration 675
# 	μ = 3.890331333e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.151e-06
# 	ne Err =  3.363e-05, ne change =  4.802e-08
# 	Q =  4.547e-13 ->  0.000e+00,
# 	Zstar guess =  2.627e+00. Current Zstar:  2.627e+00 (converged=False)
# 	Change =  7.528e-07
# __________________________________________
# TF Iteration 700
# 	μ = 4.522833851e-01, change: 1.625827235e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.604e-07
# 	ne Err =  1.232e-04, ne change =  1.412e-05
# 	Q =  4.547e-13 ->  0.000e+00,
# 	Zstar guess =  3.903e+00. Current Zstar:  3.285e+00 (converged=False)
# 	Change =  1.067e-01
# __________________________________________
# TF Iteration 725
# 	μ = 4.523321108e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.338e-05
# 	ne Err =  5.466e-04, ne change =  4.855e-08
# 	Q =  4.547e-13 ->  9.095e-13,
# 	Zstar guess =  3.284e+00. Current Zstar:  3.284e+00 (converged=False)
# 	Change =  8.348e-05
# __________________________________________
# TF Iteration 750
# 	μ = 4.522875605e-01, change: 9.717128922e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.959e-05
# 	ne Err =  2.488e-04, ne change =  1.105e-07
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  3.284e+00. Current Zstar:  3.284e+00 (converged=False)
# 	Change =  1.601e-05
# __________________________________________
# TF Iteration 775
# 	μ = 4.522906970e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.788e-06
# 	ne Err =  1.397e-04, ne change =  9.179e-08
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  3.284e+00. Current Zstar:  3.284e+00 (converged=False)
# 	Change =  3.646e-06
# __________________________________________
# TF Iteration 800
# 	μ = 5.255659929e-01, change: 1.620082872e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.838e-06
# 	ne Err =  1.454e-04, ne change =  1.766e-05
# 	Q =  4.547e-13 ->  9.095e-13,
# 	Zstar guess =  4.172e+00. Current Zstar:  4.106e+00 (converged=False)
# 	Change =  1.065e-01
# __________________________________________
# TF Iteration 825
# 	μ = 5.256196134e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.176e-04
# 	ne Err =  5.854e-04, ne change =  6.088e-08
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.105e+00. Current Zstar:  4.105e+00 (converged=False)
# 	Change =  1.043e-04
# __________________________________________
# TF Iteration 850
# 	μ = 5.255692689e-01, change: 4.205922911e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.491e-05
# 	ne Err =  2.755e-04, ne change =  1.431e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.105e+00. Current Zstar:  4.105e+00 (converged=False)
# 	Change =  2.232e-05
# __________________________________________
# TF Iteration 875
# 	μ = 5.255727546e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.569e-06
# 	ne Err =  1.565e-04, ne change =  1.165e-07
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.105e+00. Current Zstar:  4.105e+00 (converged=False)
# 	Change =  4.607e-06
# __________________________________________
# TF Iteration 900
# 	μ = 5.687440071e-01, change: 8.214119521e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.851e-06
# 	ne Err =  1.229e-04, ne change =  1.102e-05
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.446e+00. Current Zstar:  4.617e+00 (converged=False)
# 	Change =  5.628e-02
# __________________________________________
# TF Iteration 925
# 	μ = 5.687733105e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.260e-05
# 	ne Err =  3.453e-04, ne change =  5.342e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.617e+00. Current Zstar:  4.617e+00 (converged=False)
# 	Change =  6.381e-05
# __________________________________________
# TF Iteration 950
# 	μ = 5.687447509e-01, change: 3.138083887e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.546e-05
# 	ne Err =  1.699e-04, ne change =  1.020e-07
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.617e+00. Current Zstar:  4.617e+00 (converged=False)
# 	Change =  1.411e-05
# __________________________________________
# TF Iteration 975
# 	μ = 5.687466655e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.955e-06
# 	ne Err =  9.866e-05, ne change =  7.976e-08
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.617e+00. Current Zstar:  4.617e+00 (converged=False)
# 	Change =  2.799e-06
# __________________________________________
# TF Iteration 1000
# 	μ = 5.660582457e-01, change: 4.726798054e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.672e-06
# 	ne Err =  5.922e-05, ne change =  6.953e-07
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.594e+00. Current Zstar:  4.584e+00 (converged=False)
# 	Change =  3.384e-03
# __________________________________________
# TF Iteration 1025
# 	μ = 5.660563732e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.114e-06
# 	ne Err =  3.482e-05, ne change =  3.243e-08
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.584e+00. Current Zstar:  4.584e+00 (converged=False)
# 	Change =  4.268e-06
# __________________________________________
# TF Iteration 1050
# 	μ = 5.660581668e-01, change: 1.912289288e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.549e-06
# 	ne Err =  1.997e-05, ne change =  1.430e-08
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.584e+00. Current Zstar:  4.584e+00 (converged=False)
# 	Change =  1.127e-06
# __________________________________________
# TF Iteration 1075
# 	μ = 5.660580570e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.827e-07
# 	ne Err =  1.284e-05, ne change =  6.837e-09
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.584e+00. Current Zstar:  4.584e+00 (converged=False)
# 	Change =  3.480e-07
# __________________________________________
# TF Iteration 1100
# 	μ = 5.662279559e-01, change: 3.001279744e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.550e-07
# 	ne Err =  8.624e-06, ne change =  4.452e-08
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.586e+00. Current Zstar:  4.586e+00 (converged=False)
# 	Change =  2.145e-04
# __________________________________________
# TF Iteration 1125
# 	μ = 5.662280749e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.603e-07
# 	ne Err =  6.187e-06, ne change =  1.661e-09
# 	Q =  9.095e-13 ->  1.819e-12,
# 	Zstar guess =  4.586e+00. Current Zstar:  4.586e+00 (converged=False)
# 	Change =  1.941e-07
# __________________________________________
# TF Iteration 1150
# 	μ = 5.662279608e-01, change: 1.163915408e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.164e-07
# 	ne Err =  4.180e-06, ne change =  1.109e-09
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.586e+00. Current Zstar:  4.586e+00 (converged=False)
# 	Change =  2.719e-08
# __________________________________________
# TF Iteration 1175
# 	μ = 5.662279674e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.528e-08
# 	ne Err =  2.853e-06, ne change =  6.831e-10
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.586e+00. Current Zstar:  4.586e+00 (converged=False)
# 	Change =  7.277e-09
# __________________________________________
# TF Iteration 1200
# 	μ = 5.663799577e-01, change: 2.684272207e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.840e-08
# 	ne Err =  2.043e-06, ne change =  3.944e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.587e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  1.917e-04
# __________________________________________
# TF Iteration 1225
# 	μ = 5.663800606e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.510e-07
# 	ne Err =  1.946e-06, ne change =  3.363e-10
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  2.211e-07
# __________________________________________
# TF Iteration 1250
# 	μ = 5.663799594e-01, change: 1.141180039e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.598e-08
# 	ne Err =  1.224e-06, ne change =  3.730e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  4.735e-08
# __________________________________________
# TF Iteration 1275
# 	μ = 5.663799662e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.237e-08
# 	ne Err =  8.234e-07, ne change =  2.952e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  8.597e-09
# __________________________________________
# TF Iteration 1300
# 	μ = 5.663187311e-01, change: 1.081161560e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.354e-08
# 	ne Err =  5.350e-07, ne change =  1.588e-08
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  7.722e-05
# __________________________________________
# TF Iteration 1325
# 	μ = 5.663186891e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.050e-07
# 	ne Err =  5.200e-07, ne change =  1.563e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  9.142e-08
# __________________________________________
# TF Iteration 1350
# 	μ = 5.663187299e-01, change: 4.531926168e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.293e-08
# 	ne Err =  2.657e-07, ne change =  9.278e-11
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  2.062e-08
# __________________________________________
# TF Iteration 1375
# 	μ = 5.663187272e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.560e-09
# 	ne Err =  1.667e-07, ne change =  7.964e-11
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  4.496e-09
# __________________________________________
# TF Iteration 1400
# 	μ = 5.663254202e-01, change: 1.181821710e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.806e-09
# 	ne Err =  1.130e-07, ne change =  1.731e-09
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  8.441e-06
# __________________________________________
# TF Iteration 1425
# 	μ = 5.663254249e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.140e-08
# 	ne Err =  8.960e-08, ne change =  4.402e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  1.007e-08
# __________________________________________
# TF Iteration 1450
# 	μ = 5.663254204e-01, change: 4.827718225e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.752e-09
# 	ne Err =  5.877e-08, ne change =  3.354e-11
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  2.394e-09
# __________________________________________
# TF Iteration 1475
# 	μ = 5.663254206e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.030e-09
# 	ne Err =  4.151e-08, ne change =  2.860e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  6.038e-10
# __________________________________________
# TF Iteration 1500
# 	μ = 5.663265168e-01, change: 1.935519828e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.554e-10
# 	ne Err =  3.009e-08, ne change =  2.851e-10
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  1.382e-06
# __________________________________________
# TF Iteration 1525
# 	μ = 5.663265175e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.997e-09
# 	ne Err =  2.362e-08, ne change =  1.964e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  1.715e-09
# __________________________________________
# TF Iteration 1550
# 	μ = 5.663265167e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.059e-10
# 	ne Err =  1.649e-08, ne change =  1.722e-11
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  3.541e-10
# __________________________________________
# TF Iteration 1575
# 	μ = 5.663265167e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.156e-10
# 	ne Err =  1.179e-08, ne change =  1.399e-11
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  1.081e-10
# __________________________________________
# TF Iteration 1600
# 	μ = 5.663264795e-01, change: 6.572645772e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.317e-10
# 	ne Err =  8.483e-09, ne change =  1.457e-11
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  4.696e-08
# __________________________________________
# TF Iteration 1625
# 	μ = 5.663264795e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.030e-10
# 	ne Err =  6.117e-09, ne change =  8.740e-12
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  5.329e-11
# __________________________________________
# TF Iteration 1650
# 	μ = 5.663264795e-01, change: 1.221245327e-15 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.401e-11
# 	ne Err =  4.430e-09, ne change =  6.811e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  1.217e-11
# __________________________________________
# TF Iteration 1675
# 	μ = 5.663264795e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.536e-11
# 	ne Err =  3.219e-09, ne change =  5.337e-12
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  7.244e-12
# __________________________________________
# TF Iteration 1700
# 	μ = 5.663264978e-01, change: 3.239690649e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.253e-11
# 	ne Err =  2.348e-09, ne change =  6.416e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  2.314e-08
# __________________________________________
# TF Iteration 1725
# 	μ = 5.663264978e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.034e-11
# 	ne Err =  1.722e-09, ne change =  3.283e-12
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  3.280e-11
# __________________________________________
# TF Iteration 1750
# 	μ = 5.663264978e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.843e-11
# 	ne Err =  1.258e-09, ne change =  2.597e-12
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  9.888e-12
# __________________________________________
# TF Iteration 1770
# 	μ = 5.663264978e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.334e-11
# 	ne Err =  9.915e-10, ne change =  2.157e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.588e+00. Current Zstar:  4.588e+00 (converged=False)
# 	Change =  5.766e-12
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 2.311e+03
# Exiting status 0, reverting to best index so far: 5261
# Final iter:5262, Total Error: 9.989e-13
# CPU times: user 22.6 s, sys: 536 ms, total: 23.1 s
# Wall time: 23.1 s

# %%
# aaW =NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aaW_kwargs)



# cutoff_point = 0.02
# cutoff_index = np.argmin(np.abs(  cutoff_point - np.array([aa.grid.integrate_f(aa.ne, end_index = i) for i in range(len(aa.ne))])))
# guess_tfdw_ne = 1/(  1/aa.ne + 1/aa.ne[cutoff_index])
# aaW.ne = guess_tfdw_ne.copy()
# aaW.μ  = aa.μ
# aaW.Zstar = aa.Zstar

# # aaW.solve_TF(verbose=True, nmax=50, picard_alpha=1e-3, tol=1e-9)
# # aaW.set_uii_eff()

# %%
# %%time
npaW = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npaW_kwargs)


# cutoff_point = 0.02
# cutoff_index = np.argmin(np.abs(  cutoff_point - np.array([npa.grid.integrate_f(npa.ne, end_index = i) for i in range(len(npa.ne))])))
# guess_tfdw_ne = 1/(  1/npa.ne + 1/npa.ne[cutoff_index])
# npaW.get_Q()
# guess_tfdw_ne *= npaW.Qion/npaW.grid.integrate_f(guess_tfdw_ne)
# npaW.ne = guess_tfdw_ne.copy()
# npaW.μ  = npa.μ
# npaW.Zstar = npa.Zstar
# npaW.φe = npa.φe.copy()

# npaW.solve_TF(verbose=True, picard_alpha=1, tol=1e-9, nmax = 1, n_wait_update_Zstar= 500)
# npaW.set_uii_eff()
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 6.985e+02
# Exiting status 0, reverting to best index so far: 1236
# Final iter:1237, Total Error: 9.838e-13
# Intialized Potentials and Densities
# CPU times: user 1.44 s, sys: 3.85 ms, total: 1.44 s
# Wall time: 1.44 s

# %% [markdown]
# ### EOS

# %%
def get_Eii(aa):
    βVeff = aa.get_βVeff(aa.φe, aa.ne, aa.ne_bar)
    η = aa.μ/aa.Te - βVeff
    βU = aa.grid.integrate_f(βVeff*aa.ne)
    I_onehalf = FermiDirac.Ionehalf(η)
    I_threehalf = FermiDirac.Ithreehalf(η)
    
    βK = (2*aa.Te)**1.5/π**2 * aa.grid.integrate_f( η*I_onehalf - 2/3 * I_threehalf   )
    return βU, βK, βU + βK

def get_ETF(aa):
    
def get_Exc(aa):
    aa.vxc

def get_E_Hartree(aa):
    
    
    

# get_E(aa_tfd), get_E(npa_tfd)
# Out:
#   Cell In[8], line 13
#     def get_Exc(aa):
#     ^
# IndentationError: expected an indented block after function definition on line 11

# %%
def get_P(aa):
    aa_old_βu = aa.iet.βu_r_matrix.copy()
    # aa.iet.set_βu_matrix( np.array([[1/aa.Ti * aa.Zstar**2/(aa.iet.r_array*aa.rs) ]] ))
    P_id_hnc, P_ex_hnc, P_hnc = aa.iet.ideal_pressure(), aa.iet.excess_pressure(), aa.iet.total_pressure()
    P_id_AU, P_ex_AU, P_AU  = P_id_hnc/rs**3, P_ex_hnc/rs**3, P_hnc/rs**3
    aa.iet.set_βu_matrix(aa_old_βu)
    return P_id_AU, P_ex_AU, P_AU

aa_P_ions = get_P(aa_tfd)
aa_P_ions[1]/aa_P_ions[0]

# %% [markdown]
# ## Comparison

# %%
npaW.φe, poisson_err = npaW.get_φe(npaW.ρi - npaW.ne)
npaW.make_plots()
# Out:
# (<Figure size 4000x1600 with 2 Axes>,
#  array([<Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$\\phi$ [A.U.]'>,
#         <Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$n$ [A.U.]'>],
#        dtype=object))

# %%
def plot_convergence(aa, axs=None):
    if axs is None:
        fig, axs = plt.subplots(ncols=3,figsize=(18,5),facecolor='w', dpi=200)
    
    # ELectric potential
    slice_by_num = 1
    ax = axs[0]
    colors = plt.cm.coolwarm(np.linspace(0, 1,len(aa.φe_list[::slice_by_num])))
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        if i ==0 or i==len(aa.φe_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, (φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\phi_e$'.format(i))
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\vec E$'.format(i))
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1, label=r'$\beta V_{{\rm eff}}$'.format(i))
        else:
            ax.plot(aa.grid.xs, φe+aa.φion,linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1)
    # ax.plot(aa.grid.xs, aa.get_φe( (aa.ρi - aa.ne) )[0] + aa.φion  ,'k:', label=r'$\phi$ check') 
    ax.set_yscale('symlog',linthresh=1e-10)
    ax.plot(aa.grid.xs, aa.φe_init + aa.φion, 'k:')

    # number density
    ax = axs[1]
    for i, (ne, ρi) in enumerate(zip(aa.ne_list[::slice_by_num], aa.ρi_list[::slice_by_num])):
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            if i==0: 
                ne_bar_0 = ne[-1]
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1, label=r'$Q(r)$'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, -ne + 0*ρi + ne[-1],linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ne_bar_0,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ρi[-1] + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # pass
        else:
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1)
            # print(ne[-1]-ne_bar_0)
            # ax.plot(aa.grid.xs, -ne + ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ne + ne_bar_0 ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ρi[-1]+ ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            pass
    # for i in range(int(aa.R/aa.rs)):
    #     ax.axvline(aa.rs*i, color='k', linestyle='--', alpha=0.2)
    # ax.set_xscale('log')
    # ax.plot(aa.grid.xs, (aa.gii)-1, 'k:')
    ax.set_yscale('symlog',linthresh=1e-4)

            
    # number density
    ax = axs[2]
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        ne_TF = aa.get_ne_TF(φe, ne, μ, ne_bar)
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            # ax.plot(aa.grid.xs, ne - ne_TF,linewidth=1,color=colors[i],alpha=1, label=r'$n_e/n_e^{{TF}}-1$, iter: {0}'.format(i))
            # ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1, label=r'$n_e^{{TF}} - n_e^{{TF}}[-1]$, iter: {0}'.format(i*slice_by_num))
            ax.plot(aa.grid.xs, ne-0*ne[-1],linewidth=1,color=colors[i],linestyle='--',alpha=1, label=r'$n_e - n_e[-1]$, iter: {0}'.format(i))
            # pass
        else:
            # ax.plot(aa.grid.xs, ne - ne_TF, linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1)
            ax.plot(aa.grid.xs, ne-0*ne[-1], linewidth=1,linestyle='--',color=colors[i],alpha=0.5)
            

            # print(np.abs(ne/ne_TF-1))
            # print(np.where( np.abs(ne/ne_TF-1)>1e-6 ))
            # print(aa.grid.xs[np.where( np.abs(ne/ne_TF-1) > 1e-8)][0]/10, 1/(np.sum(aa.grid.xs*np.abs(ne/ne_TF-1))/np.sum(np.abs(ne/ne_TF-1))))
    # ax.set_ylim()
    # ax.plot(aa.grid.xs, npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar) - npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar)[-1] , 'k:')
    ax.plot(aa.grid.xs, aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar) - aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar)[-1] , 'k:')
    ax.set_yscale('symlog',linthresh=1e-10)
    # ax.set_xscale('log')
    for ax in axs:
        ax.legend(fontsize=14)
        ax.tick_params(labelsize=14)
        ax.plot(aa.grid.xs, np.zeros_like(aa.ne),'k', alpha=0.2)
    plt.tight_layout()
    
# plot_convergence(aa)
plot_convergence(npaW)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

petrov = pd.read_csv("../data/George_Petrov/GP_TFDW_Al_1eV_solid.dat",header=0, comment='#', delim_whitespace=True)

def compare_aa(aa_list, axs=None, name=''):
    eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
    if axs is None:
        fig, axs = plt.subplots(ncols=2,figsize=(20,8),facecolor='w')

    # Density * 4pi r^2 plot
    for ax in axs:
        for aa, color in zip( aa_list, colors):
            factor = 4*np.pi*aa.grid.xs**2
            ax.plot(np.array(petrov['r/R'])*rs, 4*π*(np.array(petrov['r/R'])*rs)**2*(petrov['ne']/m_to_AU**3), 'k--', label="Petrov AA")
            ax.plot(aa.grid.xs, aa.ne*factor ,'--.',color=color, label=r'$n_e$: '+ name)
            # try:
            #     ax.plot(npa.grid.xs, (aa_ne_extended * (1-transition_func) + transition_func * npa.ρi )*factor ,'-',color='b', label=r'$n_e$: '+ name)
            # except:
            #     pass
            ax.plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
            ax.plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
            if aa.rs != aa.R:
                ax.plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
                ax.plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)
        # axs[0].plot(aa.grid.xs, aa.δn_f*factor,'--',color='g',  label=r'$n_e^{sc}$: ' + name)
    for ax in axs:
        # ax.plot(aa.grid.xs, aa.ne_check*factor, 'k')
        ax.plot(aa.grid.xs, aa.get_ne_W(aa.φe, aa.ne, aa.μ, aa.ne_bar)*factor, 'r')
        ax.plot(aa.grid.xs, aa.get_ne_TF(aa.φe, aa.ne, aa.μ, aa.ne_bar)*factor, 'r--')
    
    axs[0].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[0].set_ylim(0, 1e3)
    axs[0].set_yscale('symlog',linthresh=1e-1)
    axs[0].set_xscale('log')
    axs[0].set_xlim(aa.grid.xs[0],aa.grid.xs[-1])

    axs[1].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[1].set_ylim(0, 13)
    axs[1].set_xlim(0, np.min([aa.R,1.3*aa.rs]))

        
    for ax in axs:
        ax.set_xlabel(r'$|r-R_1|$ [A.U.]',fontsize=20)
        ax.legend(loc="upper right",fontsize=20,labelspacing = 0.1)
        ax.tick_params(labelsize=20)
        ax.grid(which='both',alpha=0.4)

        # make textbox
        text = ("{0}\n".format(aa.name)+ 
            r"$r_s$ = " + "{0},    ".format(np.round(aa.rs,2)) +
            r"$R_{NPA}$ = " + "{0}\n".format(aa.R)  +
                r"$T_e$ = " + "{0} [A.U.] = {1} eV\n".format(np.round(aa.Te,2),np.round(aa.Te/eV,2)) + r"$\mu$ = " + "{0} [A.U.]\n".format(np.round(aa.μ,2)) +
                r"$Z^\ast = $" + "{0}".format(np.round(aa.Zstar,2))  )

        props = dict(boxstyle='round', facecolor='w')
        ax.text(0.25,0.95, text, fontsize=15, transform=ax.transAxes, verticalalignment='top', bbox=props)

    plt.tight_layout()
    name = "NPA_densities_{0}_rs{1}_{2}eV_R{3}.png".format(aa.name, np.round(aa.rs,2), np.round(aa.Te/eV,2) ,np.round(aa.R))
    plt.savefig("/home/zach/plasma/atomic_forces/average_atom/media/" + name, dpi=300, bbox_inches='tight',facecolor="w")
    
    
    return axs


axs = compare_aa([npaW])#,npa])#, npa_2])
for ax in axs:
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), fontsize=16, loc='upper right')
# axs[1].set_ylim(1e-5,1e3)

# %% [markdown]
# ## HNC and FT

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.k_array/rs, aa.Uei_iet_k*(aa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.k_array/rs, npa.Uei_iet_k*(npa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[1], label="NPA") # Need to muultiply by some rs power???
# axs[0].plot(npa_2.iet.k_array/rs, npa_2.Uei_iet_k*(npa_2.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[2], label="NPA 2") # Need to muultiply by some rs power???
axs[0].plot(aa.iet.k_array/rs, aa.Zstar*np.ones_like(aa.iet.k_array),':', color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(npa.iet.k_array/rs, npa.Zstar*np.ones_like(npa.iet.k_array),':',color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
# axs[0].plot(npa_2.iet.k_array/rs, npa_2.Zstar*np.ones_like(npa_2.iet.k_array),':',color=colors[2], label=f"Coulomb, Z={npa_2.Zstar:0.3f}")

# axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$k$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

# axs[1].plot(aa.iet.k_array/rs, aa.uii_k_eff_iet,'-', color=colors[0], label="AA")
# axs[1].plot(aa.iet.k_array/rs, 4*π*aa.Zstar**2/(aa.iet.k_array/rs)**2,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, 1/(aa.iet.k_array**2/rs**2/(4*π*aa.Zstar**2) + 1/aa.uii_k_eff_iet[0] ),'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, uii_test,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))


# axs[1].plot(npa.iet.k_array/rs, npa.uii_k_eff_iet,color=colors[1], label="NPA")
axs[1].plot(npa.iet.k_array/rs, 4*π*npa.Zstar**2/(npa.iet.k_array/rs)**2,'--', color=colors[1], label=r"NPA: $u_{{ii}}^0$, Z={0:0.3f}".format(npa.Zstar))



axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_ylim(0,1e5)
axs[1].set_xscale('log')
axs[1].set_xlabel(r"$k$ [au]")
axs[1].set_ylabel(r"$u^{\rm eff}_{ii}$ [au]")


for ax in axs:
    ax.legend(fontsize=12)
plt.tight_layout()

# %%
uii_test = aa.iet.FT_k_2_r(aa.uii_k_eff_iet)/rs**3

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.r_array*rs, -aa.Zstar/(aa.iet.r_array*rs), color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(aa.iet.r_array*rs, -aa.Uei_iet ,':',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.r_array*rs, -npa.Zstar/(npa.iet.r_array*rs),color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(npa.iet.r_array*rs, -npa.Uei_iet ,':',color=colors[1], label="NPA") # Need to muultiply by some rs power???
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Zstar/(npa.iet.r_array*rs),color=colors[2], label=f"Coulomb, Z={npa_2.Zstar:0.3f}")
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Uei_iet ,':',color=colors[2], label=r"NPA: $g_{AA}$") # Need to muultiply by some rs power???

axs[0].set_yscale('symlog',linthresh=1e-1)
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$r$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.r_array*rs, 1/aa.Te * aa.uii_r_eff_iet, color=colors[0],linestyle='-', label='AA')
axs[1].plot(aa.iet.r_array*rs, 1/aa.Te *aa.Zstar**2/(aa.iet.r_array*rs ), color=colors[0] ,linestyle='--', label=f'Coulomb Z={aa.Zstar:0.3f}')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.uii_r_eff_iet, color=colors[1],linestyle='-', label='NPA')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.Zstar**2/(npa.iet.r_array*rs ), color=colors[1],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )
# axs[1].plot(npa_2.iet.r_array*rs, 1/npa.Te *npa_2.uii_r_eff_iet, color=colors[2],linestyle='-', label=r"NPA: $g_{AA}$")
# axs[1].plot(npa_2.iet.r_array*rs, 1/npa.Te *npa_2.Zstar**2/(npa_2.iet.r_array*rs ), color=colors[2],linestyle='--', label=f'Coulomb Z={npa_2.Zstar:0.3f}' )

axs[1].set_yscale('symlog',linthresh=1e0)
axs[1].set_xscale('log')
axs[1].set_ylabel(r"$\beta U_{ii}$ [au]")
axs[1].set_xlabel(r"$r$ [au]")
axs[1].set_xlim(1,None)


for ax in axs:
    ax.legend(fontsize=10)
plt.tight_layout()

# %%
npa.make_gii()
npa.make_ρi()
# npa_2.make_gii()
# npa_2.make_ρi()

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, axs  = plt.subplots(1,2, figsize=(8,4))

# Data from community TCCW
upper_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Upper.txt", delim_whitespace=True, header=1)
lower_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Lower.txt", delim_whitespace=True, header=1)

ax = axs[0]
ax.fill_between(lower_data['r/ri'],lower_data['gii'], PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')

# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0] + 1, label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)
ax.plot(npa.iet.r_array, npa.iet.h_r_matrix[0,0] + 1, label=r"NPA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("g(r)")
ax.set_xlim(0.7,3)
# ax.set_ylim(0,2)
ax.legend(fontsize=10)

ax = axs[1]
ax.fill_between(lower_data['r/ri'],lower_data['gii']-1, PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')
# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii-1, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0], label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)
ax.plot(npa.iet.r_array, npa.iet.h_r_matrix[0,0], label=r"NPA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii-1, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("h(r)")
ax.set_xlim(0.7,10)
ax.set_ylim(-2.5,2.5)
ax.set_yscale('symlog', linthresh=1e-4)

ax.legend(fontsize=8, loc='upper right')
plt.tight_layout()

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, ax = plt.subplots(figsize=(5,3.5))#1,1, figsize=(8,4))

# Average atom effective potential to gii

ax.plot(aa.iet.k_array/rs/AU_to_Angstrom, aa.iet.S_k_matrix[0,0],'-', label="OFAA")
ax.plot(npa.iet.k_array/rs/AU_to_Angstrom, npa.iet.S_k_matrix[0,0],'-', label=r"OFNPA (Yukawa $g^0_{ii}$)")
# ax.plot(npa_2.iet.k_array/rs, npa_2.iet.S_k_matrix[0,0],'-', label=r"OFNPA (OFAA $g^0_{ii}$)")

ax.set_xlabel(r"$k r_i$")
ax.set_ylabel(r"$S_{ii}(k)$")
ax.legend(fontsize=12, loc='lower right')

ax.set_xlim(0,10)
ax.set_ylim(1-3/12,1.5+5/12)
plt.tight_layout()
