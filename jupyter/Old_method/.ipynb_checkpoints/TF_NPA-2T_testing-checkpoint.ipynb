# %%
import numpy as np
import pandas as pd


from average_atom.core.average_atom import NeutralPseudoAtom as NPA
from average_atom.core.misc import jacobi_relaxation, sor
from average_atom.core.grids import NonUniformGrid
from average_atom.core.physics import ThomasFermi, FermiDirac

from importlib import reload
try:
    reload(physics)
    reload(grids)
    reload(average_atom_geometric)
#     reload(average_atom)
    reload(misc)
except NameError as e:
    from average_atom.core import physics as physics
    from average_atom.core import average_atom as average_atom
    from average_atom.core import misc as misc
    from average_atom.core import grids as grids
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)

import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

import cProfile

plt.rcParams.update({'font.size': 10})
plt.rcParams["figure.figsize"] = (5,3.5)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14


color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# Error:  name 'physics' is not defined
# ModuleNotFoundError: No module named 'mendeleev'

# %%
# Aluminuma
name='Al'
Z, A = 13, 27 

ρ_solid = 2.699 #g/cc, the solid density of aluminum 
ρ = ρ_solid#8.1 # g/cc
ni_cc = ρ/(A*amu_to_AU*AU_to_g)
ni_AU = ni_cc*invcc_to_AU
rs = rs_from_n(ni_AU)

Ti_eV = 1 
Te_eV = 30

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

# Hydrogen
# name='H'
# Z, A = 1, 1.00784

# Te_eV = 2 
# Te_AU = Te_eV*eV_to_AU

# Ti_eV = 2
# Ti_AU = Ti_eV*eV_to_AU

# ρ_gpercc = 1
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)

# Carbon
# name = 'C'
# Z, A = 6, 12.011

# ρ_gpercc = 2.267
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)							print("YO")


# Ti_eV = 0.5 
# Te_eV = 0.5

# Te_AU = Te_eV*eV_to_AU
# Ti_AU = Ti_eV*eV_to_AU

####
R = 10*rs
rmin = rs/1000
ignore_vxc = False
fixed_Zstar = False

aa_kwargs = {'initialize':True, 'gradient_correction':None, 'μ_init' : 0.158, 'Zstar_init' : 'More', 'rmin': 1e-3,'Npoints':500,
             'name':name, 'ignore_vxc':ignore_vxc, 'fixed_Zstar':fixed_Zstar, 'iet_R_over_rs':R/rs, 'iet_N_bins':5000, 'use_full_ne_for_nf':False,
            'gii_init_type': 'step'}
npa_kwargs = {'initialize':True, 'gradient_correction':None,'μ_init' : 0.158, 'Zstar_init' : 'More', 'rmin':1e-3 ,'Npoints':1000, 
              'name':name,'ignore_vxc':ignore_vxc, 'fixed_Zstar':fixed_Zstar, 'iet_R_over_rs':R/rs, 'iet_N_bins':10000, 'use_full_ne_for_nf':False,
             'gii_init_type': 'iet', 'grid_spacing':'quadratic','N_stencil_oneside':2}

aa = NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aa_kwargs)
npa = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)
# npa_2 = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 4.208
# 	Intializing grid
# Initializing, True
# Initializing
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# Initialized
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 4.208
# 	Intializing grid
# Initializing, True
# Initializing
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 1.946e+03
# Exiting status 0, reverting to best index so far: 963
# Final iter:964, Total Error: 9.786e-13
# Intialized Potentials and Densities
# Initialized

# %% [markdown]
# ### Thomas Fermi (TF)

# %%
# %%time
npa.solve_TF(verbose=True, picard_alpha=0.5, tol=1e-6, nmax = 5000, n_wait_update_Zstar= 50)
npa.set_uii_eff()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = -1.199484779e+00, change: 2.828373848e-04 (converged=True)
# 	φe Err =       -inf, φe change =  1.671e-07
# 	ne Err =  1.365e-06, ne change =  5.065e-08
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  2.005e-04
# __________________________________________
# TF Iteration 1
# 	μ = -1.199483538e+00, change: 1.034904363e-06 (converged=True)
# 	φe Err =       -inf, φe change =  2.682e-06
# 	ne Err =  9.795e-07, ne change =  1.296e-08
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  3.380e-06
# __________________________________________
# TF Iteration 2
# 	μ = -1.199482304e+00, change: 1.028267932e-06 (converged=True)
# 	φe Err =       -inf, φe change =  1.434e-06
# 	ne Err =  7.687e-07, ne change =  1.107e-08
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  2.394e-06
# __________________________________________
# TF Iteration 3
# 	μ = -1.199481078e+00, change: 1.022153510e-06 (converged=True)
# 	φe Err =       -inf, φe change =  8.526e-07
# 	ne Err =  6.523e-07, ne change =  7.535e-09
# 	Q =  9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.857e-06
# __________________________________________
# TF Iteration 4
# 	μ = -1.199479859e+00, change: 1.016604903e-06 (converged=True)
# 	φe Err =       -inf, φe change =  5.717e-07
# 	ne Err =  5.874e-07, ne change =  4.610e-09
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.553e-06
# __________________________________________
# TF Iteration 5
# 	μ = -1.199478646e+00, change: 1.011529198e-06 (converged=True)
# 	φe Err =       -inf, φe change =  4.356e-07
# 	ne Err =  5.512e-07, ne change =  2.672e-09
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.384e-06
# __________________________________________
# TF Iteration 6
# 	μ = -1.199477438e+00, change: 1.006807946e-06 (converged=True)
# 	φe Err =       -inf, φe change =  3.638e-07
# 	ne Err =  5.310e-07, ne change =  1.537e-09
# 	Q = -9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.290e-06
# __________________________________________
# TF Iteration 7
# 	μ = -1.199476236e+00, change: 1.002338283e-06 (converged=True)
# 	φe Err =       -inf, φe change =  3.211e-07
# 	ne Err =  5.196e-07, ne change =  9.299e-10
# 	Q =  9.095e-13 ->  1.819e-12,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.235e-06
# __________________________________________
# TF Iteration 8
# 	μ = -1.199475039e+00, change: 9.980453239e-07 (converged=True)
# 	φe Err =       -inf, φe change =  2.928e-07
# 	ne Err =  5.129e-07, ne change =  6.269e-10
# 	Q =  1.819e-12 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.200e-06
# __________________________________________
# TF Iteration 9
# 	μ = -1.199473846e+00, change: 9.938761630e-07 (converged=True)
# 	φe Err =       -inf, φe change =  2.723e-07
# 	ne Err =  5.089e-07, ne change =  4.824e-10
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.174e-06
# __________________________________________
# TF Iteration 25
# 	μ = -1.199455404e+00, change: 9.331618300e-07 (converged=True)
# 	φe Err =       -inf, φe change =  1.602e-07
# 	ne Err =  4.835e-07, ne change =  1.356e-10
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  9.756e-07
# __________________________________________
# TF Iteration 50
# 	μ = -1.199428771e+00, change: 8.480615894e-07 (converged=True)
# 	φe Err =       -inf, φe change =  1.249e-07
# 	ne Err =  4.427e-07, ne change =  4.560e-11
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  8.476e-07
# __________________________________________
# TF Iteration 75
# 	μ = -1.199651464e+00, change: 2.050846219e-04 (converged=True)
# 	φe Err =       -inf, φe change =  1.095e-07
# 	ne Err =  6.203e-07, ne change =  1.092e-09
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  1.452e-04
# __________________________________________
# TF Iteration 100
# 	μ = -1.199511006e+00, change: 9.947059015e-05 (converged=True)
# 	φe Err =       -inf, φe change =  8.768e-08
# 	ne Err =  4.246e-07, ne change =  5.327e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  7.050e-05
# __________________________________________
# TF Iteration 125
# 	μ = -1.199451134e+00, change: 3.385231749e-05 (converged=True)
# 	φe Err =       -inf, φe change =  9.279e-08
# 	ne Err =  3.397e-07, ne change =  1.646e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  2.412e-05
# __________________________________________
# TF Iteration 150
# 	μ = -1.199029351e+00, change: 3.370482268e-04 (converged=True)
# 	φe Err =       -inf, φe change =  8.404e-08
# 	ne Err =  7.994e-07, ne change =  1.754e-09
# 	Q =  0.000e+00 ->  1.819e-12,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.994e+00 (converged=True)
# 	Change =  2.386e-04
# __________________________________________
# TF Iteration 175
# 	μ = -1.199363216e+00, change: 2.917927510e-04 (converged=True)
# 	φe Err =       -inf, φe change =  1.111e-07
# 	ne Err =  7.218e-07, ne change =  1.580e-09
# 	Q =  1.819e-12 ->  0.000e+00,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  2.065e-04
# __________________________________________
# TF Iteration 200
# 	μ = -1.199289092e+00, change: 4.976141108e-05 (converged=True)
# 	φe Err =       -inf, φe change =  6.041e-08
# 	ne Err =  2.731e-07, ne change =  2.841e-10
# 	Q =  1.819e-12 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  3.528e-05
# __________________________________________
# TF Iteration 225
# 	μ = -1.199255144e+00, change: 1.731633835e-05 (converged=True)
# 	φe Err =       -inf, φe change =  6.102e-08
# 	ne Err =  2.306e-07, ne change =  8.338e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  1.237e-05
# __________________________________________
# TF Iteration 250
# 	μ = -1.199288750e+00, change: 3.801812973e-05 (converged=True)
# 	φe Err =       -inf, φe change =  5.641e-08
# 	ne Err =  2.274e-07, ne change =  2.087e-10
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  2.700e-05
# __________________________________________
# TF Iteration 275
# 	μ = -1.199199968e+00, change: 6.494715323e-05 (converged=True)
# 	φe Err =       -inf, φe change =  4.785e-08
# 	ne Err =  2.345e-07, ne change =  3.380e-10
# 	Q =  9.095e-13 ->  1.819e-12,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  4.602e-05
# __________________________________________
# TF Iteration 300
# 	μ = -1.199152481e+00, change: 3.132380877e-05 (converged=True)
# 	φe Err =       -inf, φe change =  5.049e-08
# 	ne Err =  1.829e-07, ne change =  1.553e-10
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  2.225e-05
# __________________________________________
# TF Iteration 325
# 	μ = -1.199113628e+00, change: 2.487585519e-05 (converged=True)
# 	φe Err =       -inf, φe change =  4.527e-08
# 	ne Err =  1.638e-07, ne change =  1.230e-10
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.992e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.768e-05
# __________________________________________
# TF Iteration 350
# 	μ = -1.199092669e+00, change: 1.063482007e-05 (converged=True)
# 	φe Err =       -inf, φe change =  4.083e-08
# 	ne Err =  1.433e-07, ne change =  5.104e-11
# 	Q =  1.819e-12 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  7.602e-06
# __________________________________________
# TF Iteration 375
# 	μ = -1.199096145e+00, change: 9.122884800e-06 (converged=True)
# 	φe Err =       -inf, φe change =  3.602e-08
# 	ne Err =  1.318e-07, ne change =  5.531e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  6.523e-06
# __________________________________________
# TF Iteration 400
# 	μ = -1.199063120e+00, change: 2.188405945e-05 (converged=True)
# 	φe Err =       -inf, φe change =  3.103e-08
# 	ne Err =  1.258e-07, ne change =  1.115e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.554e-05
# __________________________________________
# TF Iteration 425
# 	μ = -1.199024605e+00, change: 2.697110909e-05 (converged=True)
# 	φe Err =       -inf, φe change =  3.018e-08
# 	ne Err =  1.207e-07, ne change =  1.363e-10
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.913e-05
# __________________________________________
# TF Iteration 450
# 	μ = -1.199014653e+00, change: 3.614061952e-06 (converged=True)
# 	φe Err =       -inf, φe change =  2.863e-08
# 	ne Err =  9.739e-08, ne change =  1.984e-11
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  2.613e-06
# __________________________________________
# TF Iteration 475
# 	μ = -1.199007641e+00, change: 1.588449549e-06 (converged=True)
# 	φe Err =       -inf, φe change =  2.447e-08
# 	ne Err =  8.852e-08, ne change =  8.716e-12
# 	Q =  1.819e-12 ->  1.819e-12,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.172e-06
# __________________________________________
# TF Iteration 500
# 	μ = -1.198995459e+00, change: 6.286524007e-06 (converged=True)
# 	φe Err =       -inf, φe change =  2.179e-08
# 	ne Err =  8.127e-08, ne change =  3.034e-11
# 	Q =  9.095e-13 ->  1.819e-12,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  4.489e-06
# __________________________________________
# TF Iteration 525
# 	μ = -1.199036095e+00, change: 3.741574315e-05 (converged=True)
# 	φe Err =       -inf, φe change =  2.007e-08
# 	ne Err =  1.131e-07, ne change =  1.995e-10
# 	Q = -9.095e-13 ->  1.819e-12,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.992e+00 (converged=True)
# 	Change =  2.650e-05
# __________________________________________
# TF Iteration 550
# 	μ = -1.198964122e+00, change: 5.682808785e-05 (converged=True)
# 	φe Err =       -inf, φe change =  1.590e-08
# 	ne Err =  1.416e-07, ne change =  2.997e-10
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  4.022e-05
# __________________________________________
# TF Iteration 575
# 	μ = -1.198949649e+00, change: 9.149095760e-06 (converged=True)
# 	φe Err =       -inf, φe change =  2.089e-08
# 	ne Err =  6.296e-08, ne change =  4.567e-11
# 	Q =  1.819e-12 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  6.511e-06
# __________________________________________
# TF Iteration 600
# 	μ = -1.198909064e+00, change: 3.119746295e-05 (converged=True)
# 	φe Err =       -inf, φe change =  1.641e-08
# 	ne Err =  8.681e-08, ne change =  1.602e-10
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  2.209e-05
# __________________________________________
# TF Iteration 625
# 	μ = -1.198930384e+00, change: 2.019972652e-05 (converged=True)
# 	φe Err =       -inf, φe change =  1.689e-08
# 	ne Err =  6.909e-08, ne change =  1.121e-10
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.432e-05
# __________________________________________
# TF Iteration 650
# 	μ = -1.198919051e+00, change: 7.261491055e-06 (converged=True)
# 	φe Err =       -inf, φe change =  1.149e-08
# 	ne Err =  4.793e-08, ne change =  3.800e-11
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  5.157e-06
# __________________________________________
# TF Iteration 675
# 	μ = -1.198908916e+00, change: 6.457115410e-06 (converged=True)
# 	φe Err =       -inf, φe change =  1.145e-08
# 	ne Err =  4.339e-08, ne change =  3.216e-11
# 	Q =  9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  4.589e-06
# __________________________________________
# TF Iteration 700
# 	μ = -1.198902063e+00, change: 3.900524047e-06 (converged=True)
# 	φe Err =       -inf, φe change =  1.066e-08
# 	ne Err =  3.839e-08, ne change =  1.895e-11
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  2.780e-06
# __________________________________________
# TF Iteration 725
# 	μ = -1.198872401e+00, change: 2.308956763e-05 (converged=True)
# 	φe Err =       -inf, φe change =  9.590e-09
# 	ne Err =  6.069e-08, ne change =  1.194e-10
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.635e-05
# __________________________________________
# TF Iteration 750
# 	μ = -1.198893706e+00, change: 1.927684143e-05 (converged=True)
# 	φe Err =       -inf, φe change =  1.072e-08
# 	ne Err =  5.441e-08, ne change =  1.051e-10
# 	Q =  1.819e-12 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.365e-05
# __________________________________________
# TF Iteration 775
# 	μ = -1.198886205e+00, change: 4.893799211e-06 (converged=True)
# 	φe Err =       -inf, φe change =  6.886e-09
# 	ne Err =  3.016e-08, ne change =  2.649e-11
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  3.473e-06
# __________________________________________
# TF Iteration 800
# 	μ = -1.198881215e+00, change: 2.919329342e-06 (converged=True)
# 	φe Err =       -inf, φe change =  7.020e-09
# 	ne Err =  2.640e-08, ne change =  1.435e-11
# 	Q =  1.819e-12 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  2.078e-06
# __________________________________________
# TF Iteration 825
# 	μ = -1.198872334e+00, change: 6.277939701e-06 (converged=True)
# 	φe Err =       -inf, φe change =  6.498e-09
# 	ne Err =  2.687e-08, ne change =  3.189e-11
# 	Q =  9.095e-13 ->  1.819e-12,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  4.452e-06
# __________________________________________
# TF Iteration 850
# 	μ = -1.198874321e+00, change: 2.685998146e-06 (converged=True)
# 	φe Err =       -inf, φe change =  6.282e-09
# 	ne Err =  2.244e-08, ne change =  1.587e-11
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.912e-06
# __________________________________________
# TF Iteration 875
# 	μ = -1.198870637e+00, change: 2.138574351e-06 (converged=True)
# 	φe Err =       -inf, φe change =  5.100e-09
# 	ne Err =  1.985e-08, ne change =  1.072e-11
# 	Q =  1.819e-12 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.522e-06
# __________________________________________
# TF Iteration 900
# 	μ = -1.198862061e+00, change: 6.303244408e-06 (converged=True)
# 	φe Err =       -inf, φe change =  4.853e-09
# 	ne Err =  2.215e-08, ne change =  3.230e-11
# 	Q = -9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  4.467e-06
# __________________________________________
# TF Iteration 925
# 	μ = -1.198864344e+00, change: 2.678306704e-06 (converged=True)
# 	φe Err =       -inf, φe change =  4.873e-09
# 	ne Err =  1.740e-08, ne change =  1.557e-11
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.904e-06
# __________________________________________
# TF Iteration 950
# 	μ = -1.198861480e+00, change: 1.685777571e-06 (converged=True)
# 	φe Err =       -inf, φe change =  3.818e-09
# 	ne Err =  1.497e-08, ne change =  8.501e-12
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.200e-06
# __________________________________________
# TF Iteration 975
# 	μ = -1.198856014e+00, change: 3.919432601e-06 (converged=True)
# 	φe Err =       -inf, φe change =  3.654e-09
# 	ne Err =  1.563e-08, ne change =  1.999e-11
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  2.779e-06
# __________________________________________
# TF Iteration 1000
# 	μ = -1.198856716e+00, change: 1.167683114e-06 (converged=True)
# 	φe Err =       -inf, φe change =  3.586e-09
# 	ne Err =  1.249e-08, ne change =  7.245e-12
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  8.329e-07
# __________________________________________
# TF Iteration 1025
# 	μ = -1.198854789e+00, change: 1.077788819e-06 (converged=True)
# 	φe Err =       -inf, φe change =  2.918e-09
# 	ne Err =  1.118e-08, ne change =  5.338e-12
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  7.679e-07
# __________________________________________
# TF Iteration 1050
# 	μ = -1.198845364e+00, change: 7.380649399e-06 (converged=True)
# 	φe Err =       -inf, φe change =  2.746e-09
# 	ne Err =  1.891e-08, ne change =  3.827e-11
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  5.225e-06
# __________________________________________
# TF Iteration 1075
# 	μ = -1.198851326e+00, change: 5.412561005e-06 (converged=True)
# 	φe Err =       -inf, φe change =  3.183e-09
# 	ne Err =  1.550e-08, ne change =  2.962e-11
# 	Q =  0.000e+00 ->  1.819e-12,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  3.834e-06
# __________________________________________
# TF Iteration 1100
# 	μ = -1.198849210e+00, change: 1.367912941e-06 (converged=True)
# 	φe Err =       -inf, φe change =  2.018e-09
# 	ne Err =  8.747e-09, ne change =  7.375e-12
# 	Q =  9.095e-13 ->  9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  9.710e-07
# __________________________________________
# TF Iteration 1125
# 	μ = -1.198847699e+00, change: 8.981305463e-07 (converged=True)
# 	φe Err =       -inf, φe change =  2.048e-09
# 	ne Err =  7.720e-09, ne change =  4.427e-12
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  6.392e-07
# __________________________________________
# TF Iteration 1150
# 	μ = -1.198845554e+00, change: 1.459379752e-06 (converged=True)
# 	φe Err =       -inf, φe change =  1.900e-09
# 	ne Err =  7.467e-09, ne change =  7.354e-12
# 	Q =  1.819e-12 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  1.036e-06
# __________________________________________
# TF Iteration 1175
# 	μ = -1.198845647e+00, change: 3.770963766e-07 (converged=True)
# 	φe Err =       -inf, φe change =  1.798e-09
# 	ne Err =  6.323e-09, ne change =  2.507e-12
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  2.703e-07
# __________________________________________
# TF Iteration 1200
# 	μ = -1.198844719e+00, change: 5.015641957e-07 (converged=True)
# 	φe Err =       -inf, φe change =  1.510e-09
# 	ne Err =  5.737e-09, ne change =  2.460e-12
# 	Q =  0.000e+00 ->  1.819e-12,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  3.577e-07
# __________________________________________
# TF Iteration 1221
# 	μ = -1.198844469e+00, change: 1.003417860e-08 (converged=True)
# 	φe Err =       -inf, φe change =  1.455e-09
# 	ne Err =  5.253e-09, ne change =  5.615e-13
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.993e+00. Current Zstar:  4.993e+00 (converged=True)
# 	Change =  9.988e-09
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 2.733e+03
# /home/zach/plasma/average_atom/core/average_atom.py:554: RuntimeWarning: divide by zero encountered in divide
#   rel_errs = (np.abs(A @ φe - b)[:-1]/b[:-1])
# Exiting status 0, reverting to best index so far: 4213
# Final iter:4214, Total Error: 9.990e-13
# CPU times: user 8min 23s, sys: 17min 11s, total: 25min 34s
# Wall time: 4min 18s

# %%
limiting_μ = npa.get_μ_infinite()
neutral_μ = npa.get_μ_neutral()
print(f"Neutral μ = {neutral_μ:0.9e}, vs. r->infinity μ={limiting_μ:0.9e}, {neutral_μ/limiting_μ - 1:0.9e}")
# Final μ = 5.66492e-01, vs. expected r->infinity μ=5.66507e-01, Err=-2.664e-05
# Out:
# KeyboardInterrupt

# %%
# %%time
from scipy.interpolate import interp1d
aa.solve_TF(verbose=True, picard_alpha=0.5, tol=1e-8, n_wait_update_Zstar= 10)
aa.set_uii_eff()
aa.iet.HNC_solve(iters_to_wait=1e5, alpha_Picard=1e-2, tol=1e-12, verbose=False, num_iterations=1e5)
aa.gii = interp1d(aa.iet.r_array*aa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(aa.grid.xs)
# npa_2.gii = interp1d(npa.iet.r_array*npa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(npa.grid.xs)
aa.make_ρi()

# %%
# %%time
# npa_2.solve_TF(verbose=True, picard_alpha=0.2, num_10folds_per_rs=0.5, tol=1e-7, nmax = 1000, n_wait_update_Zstar= 200)
# npa_2.set_uii_eff()

# %%
aa.run_empty_TF(verbose=True, picard_alpha=0.5, tol=1e-8, n_wait_update_Zstar= 10)

# %%
npa.run_empty_TF(verbose=True, picard_alpha=0.5, tol=1e-8, n_wait_update_Zstar= 10)

# %% [markdown]
# ### EOS

# %%
def get_Eii(aa):
    βVeff = aa.get_βVeff(aa.φe, aa.ne, aa.ne_bar)
    η = aa.μ/aa.Te - βVeff
    βU = aa.grid.integrate_f(βVeff*aa.ne)
    I_onehalf = FermiDirac.Ionehalf(η)
    I_threehalf = FermiDirac.Ithreehalf(η)
    
    βK = (2*aa.Te)**1.5/π**2 * aa.grid.integrate_f( η*I_onehalf - 2/3 * I_threehalf   )
    return βU, βK, βU + βK

def get_ETF(aa):
    
def get_Exc(aa):
    aa.vxc

def get_E_Hartree(aa):
    
    
    

# get_E(aa_tfd), get_E(npa_tfd)

# %%
def get_P(aa):
    aa_old_βu = aa.iet.βu_r_matrix.copy()
    # aa.iet.set_βu_matrix( np.array([[1/aa.Ti * aa.Zstar**2/(aa.iet.r_array*aa.rs) ]] ))
    P_id_hnc, P_ex_hnc, P_hnc = aa.iet.ideal_pressure(), aa.iet.excess_pressure(), aa.iet.total_pressure()
    P_id_AU, P_ex_AU, P_AU  = P_id_hnc/rs**3, P_ex_hnc/rs**3, P_hnc/rs**3
    aa.iet.set_βu_matrix(aa_old_βu)
    return P_id_AU, P_ex_AU, P_AU

aa_P_ions = get_P(aa_tfd)
aa_P_ions[1]/aa_P_ions[0]

# %% [markdown]
# ## Comparison

# %%
# npa.ne = npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar)
npa.make_plot_bound_free()

# %%
# npa.get_φe(npa.)
# npa.make_plots()

# %%
def plot_convergence(aa, axs=None):
    if axs is None:
        fig, axs = plt.subplots(ncols=3,figsize=(18,5),facecolor='w', dpi=200)
    
    # ELectric potential
    slice_by_num = 10
    ax = axs[0]
    colors = plt.cm.coolwarm(np.linspace(0, 1,len(aa.φe_list[::slice_by_num])))
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        if i ==0 or i==len(aa.φe_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, (φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\phi_e$'.format(i))
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\vec E$'.format(i))
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1, label=r'$\beta V_{{\rm eff}}$'.format(i))
        else:
            ax.plot(aa.grid.xs, φe+aa.φion,linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1)
    # ax.plot(aa.grid.xs, aa.get_φe( (aa.ρi - aa.ne) )[0] + aa.φion  ,'k:', label=r'$\phi$ check') 
    ax.set_yscale('symlog',linthresh=1e-10)
    ax.plot(aa.grid.xs, aa.φe_init + aa.φion, 'k:')

    # number density
    ax = axs[1]
    for i, (ne, ρi) in enumerate(zip(aa.ne_list[::slice_by_num], aa.ρi_list[::slice_by_num])):
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            if i==0: 
                ne_bar_0 = ne[-1]
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1, label=r'$Q(r)$'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, -ne + 0*ρi + ne[-1],linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ne_bar_0,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ρi[-1] + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # pass
        else:
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1)
            # print(ne[-1]-ne_bar_0)
            # ax.plot(aa.grid.xs, -ne + ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ne + ne_bar_0 ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ρi[-1]+ ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            pass
    # for i in range(int(aa.R/aa.rs)):
    #     ax.axvline(aa.rs*i, color='k', linestyle='--', alpha=0.2)
    # ax.set_xscale('log')
    # ax.plot(aa.grid.xs, (aa.gii)-1, 'k:')
    ax.set_yscale('symlog',linthresh=1e-4)

            
    # number density
    ax = axs[2]
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        ne_TF = aa.get_ne_TF(φe, ne, μ, ne_bar)
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            # ax.plot(aa.grid.xs, ne - 0*ne_TF,linewidth=1,color=colors[i],alpha=1, label=r'$n_e/n_e^{{TF}}-1$, iter: {0}'.format(i))
            # ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1, label=r'$n_e^{{TF}} - n_e^{{TF}}[-1]$, iter: {0}'.format(i*slice_by_num))
            ax.plot(aa.grid.xs, ne-ne[-1],linewidth=1,color=colors[i],linestyle='--',alpha=1, label=r'$n_e - n_e[-1]$, iter: {0}'.format(i))
            # pass
        else:
            # ax.plot(aa.grid.xs, ne - 0*ne_TF, linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1)
            ax.plot(aa.grid.xs, ne-ne[-1], linewidth=1,linestyle='--',color=colors[i],alpha=0.5)
            

            # print(np.abs(ne/ne_TF-1))
            # print(np.where( np.abs(ne/ne_TF-1)>1e-6 ))
            # print(aa.grid.xs[np.where( np.abs(ne/ne_TF-1) > 1e-8)][0]/10, 1/(np.sum(aa.grid.xs*np.abs(ne/ne_TF-1))/np.sum(np.abs(ne/ne_TF-1))))
    # ax.set_ylim()
    # ax.plot(aa.grid.xs, npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar) - npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar)[-1] , 'k:')
    ax.plot(aa.grid.xs, aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar) - aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar)[-1] , 'k:')
    ax.set_yscale('symlog',linthresh=1e-10)
    # ax.set_xscale('log')
    for ax in axs:
        ax.legend(fontsize=14)
        ax.tick_params(labelsize=14)
        ax.plot(aa.grid.xs, np.zeros_like(aa.ne),'k', alpha=0.2)
    plt.tight_layout()
    
# plot_convergence(aa)
plot_convergence(npa)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

petrov = pd.read_csv("../data/George_Petrov/GP_TFDW_Al_1eV_solid.dat",header=0, comment='#', delim_whitespace=True)

def compare_aa(aa_list, axs=None, name=''):
    eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
    if axs is None:
        fig, axs = plt.subplots(ncols=2,figsize=(20,8),facecolor='w')

    # Density * 4pi r^2 plot
    for ax in axs:
        for aa, color in zip( aa_list, colors):
            factor = 4*np.pi*aa.grid.xs**2
            ax.plot(np.array(petrov['r/R'])*rs, 4*π*(np.array(petrov['r/R'])*rs)**2*(petrov['ne']/m_to_AU**3), 'k--', label="Petrov AA")
            ax.plot(aa.grid.xs, aa.ne*factor ,'-',color=color, label=r'$n_e$: '+ name)
            ax.plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
            ax.plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
            # ax.plot(aa.grid.xs, aa.δn_f*factor,'-',color='b',  label=r'$n^{scr} = n^{PA} - n^{ion}$: ' + name)
            # ax.plot(aa.grid.xs, (aa.δn_f+aa.n_b)*factor,'--',color='b',  label=r'$n^{PA}=n-n^{empty}$: ' + name)
            # ax.plot(aa.grid.xs, (aa.ρi - aa.empty_ne )*factor,':',color='b',  label=r'$\rho^i - n^{empty}$: ' + name)
            if aa.rs != aa.R:
                ax.plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
                ax.plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)
        # axs[0].plot(aa.grid.xs, aa.δn_f*factor,'--',color='g',  label=r'$n_e^{sc}$: ' + name)


    axs[0].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[0].set_ylim(-1e1, 1e3)
    axs[0].set_yscale('symlog',linthresh=1e-1)
    axs[0].set_xscale('log')
    axs[0].set_xlim(aa.grid.xs[0],aa.grid.xs[-1])

    axs[1].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[1].set_ylim(0, 13)
    axs[1].set_xlim(0, np.min([aa.R,1.3*aa.rs]))

        
    for ax in axs:
        ax.set_xlabel(r'$|r-R_1|$ [A.U.]',fontsize=20)
        ax.legend(loc="upper right",fontsize=20,labelspacing = 0.1)
        ax.tick_params(labelsize=20)
        ax.grid(which='both',alpha=0.4)

        # make textbox
        text = ("{0}\n".format(aa.name)+ 
            r"$r_s$ = " + "{0},    ".format(np.round(aa.rs,2)) +
            r"$R_{NPA}$ = " + "{0}\n".format(aa.R)  +
                r"$T_e$ = " + "{0} [A.U.] = {1} eV\n".format(np.round(aa.Te,2),np.round(aa.Te/eV,2)) + r"$\mu$ = " + "{0} [A.U.]\n".format(np.round(aa.μ,2)) +
                r"$Z^\ast = $" + "{0}".format(np.round(aa.Zstar,2))  )

        props = dict(boxstyle='round', facecolor='w')
        ax.text(0.25,0.95, text, fontsize=15, transform=ax.transAxes, verticalalignment='top', bbox=props)

    plt.tight_layout()
    name = "NPA_densities_{0}_rs{1}_{2}eV_R{3}.png".format(aa.name, np.round(aa.rs,2), np.round(aa.Te/eV,2) ,np.round(aa.R))
    plt.savefig("/home/zach/plasma/atomic_forces/average_atom/media/" + name, dpi=300, bbox_inches='tight',facecolor="w")
    
    
    return axs


axs = compare_aa([npa])#, npa_2])
for ax in axs:
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), fontsize=16, loc='upper right')
# axs[1].set_ylim(1e-5,1e3)

# %%
npa.grid.integrate_f(npa.δn_f)

# %% [markdown]
# ## HNC and FT

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.k_array/rs, aa.Uei_iet_k*(aa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.k_array/rs, npa.Uei_iet_k*(npa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[1], label="NPA") # Need to muultiply by some rs power???
axs[0].plot(aa.iet.k_array/rs, aa.Zstar*np.ones_like(aa.iet.k_array),':', color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(npa.iet.k_array/rs, npa.Zstar*np.ones_like(npa.iet.k_array),':',color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")

# axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$k$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.k_array/rs, aa.uii_k_eff_iet,'-', color=colors[0], label="AA")
axs[1].plot(aa.iet.k_array/rs, 4*π*aa.Zstar**2/(aa.iet.k_array/rs)**2,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
axs[1].plot(aa.iet.k_array/rs, 1/(aa.iet.k_array**2/rs**2/(4*π*aa.Zstar**2) + 1/aa.uii_k_eff_iet[0] ),'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, uii_test,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))


# axs[1].plot(npa.iet.k_array/rs, npa.uii_k_eff_iet,color=colors[1], label="NPA")
axs[1].plot(npa.iet.k_array/rs, 4*π*npa.Zstar**2/(npa.iet.k_array/rs)**2,'--', color=colors[1], label=r"NPA: $u_{{ii}}^0$, Z={0:0.3f}".format(npa.Zstar))



axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_ylim(0,1e5)
axs[1].set_xscale('log')
axs[1].set_xlabel(r"$k$ [au]")
axs[1].set_ylabel(r"$u^{\rm eff}_{ii}$ [au]")


for ax in axs:
    ax.legend(fontsize=12)
plt.tight_layout()

# %%
uii_test = aa.iet.FT_k_2_r(aa.uii_k_eff_iet)/rs**3

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.r_array*rs, -aa.Zstar/(aa.iet.r_array*rs), color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(aa.iet.r_array*rs, -aa.Uei_iet ,':',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.r_array*rs, -npa.Zstar/(npa.iet.r_array*rs),color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(npa.iet.r_array*rs, -npa.Uei_iet ,':',color=colors[1], label="NPA") # Need to muultiply by some rs power???
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Zstar/(npa.iet.r_array*rs),color=colors[2], label=f"Coulomb, Z={npa.Zstar:0.3f}")
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Uei_iet ,':',color=colors[2], label=r"NPA: $g_{AA}$") # Need to muultiply by some rs power???



axs[0].set_yscale('symlog',linthresh=1e-1)
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$r$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.r_array*rs, 1/aa.Te * aa.uii_r_eff_iet, color=colors[0],linestyle='-', label='AA')
axs[1].plot(aa.iet.r_array*rs, 1/aa.Te *aa.Zstar**2/(aa.iet.r_array*rs ), color=colors[0] ,linestyle='--', label=f'Coulomb Z={aa.Zstar:0.3f}')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.uii_r_eff_iet, color=colors[1],linestyle='-', label='NPA')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.Zstar**2/(npa.iet.r_array*rs ), color=colors[1],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )
# axs[1].plot(npa_2.iet.r_array*rs, npa_2.uii_r_eff_iet, color=colors[2],linestyle='-', label=r"NPA: $g_{AA}$")
# axs[1].plot(npa_2.iet.r_array*rs, npa_2.Zstar**2/(npa_2.iet.r_array*rs ), color=colors[2],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )

axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_xscale('log')
axs[1].set_ylabel(r"$\beta U_{ii}$ [au]")
axs[1].set_xlabel(r"$r$ [au]")
axs[1].set_xlim(1,None)


for ax in axs:
    ax.legend(fontsize=10)
plt.tight_layout()

# %%
npa.make_gii()
npa.make_ρi()
# npa_2.make_gii()
# npa_2.make_ρi()

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, axs  = plt.subplots(1,2, figsize=(8,4))

# Data from community TCCW
upper_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Upper.txt", delim_whitespace=True, header=1)
lower_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Lower.txt", delim_whitespace=True, header=1)

ax = axs[0]
ax.fill_between(lower_data['r/ri'],lower_data['gii'], PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')

# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0] + 1, label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("g(r)")
ax.set_xlim(0.7,2.5)
ax.set_ylim(0,2.5)
ax.legend(fontsize=10)

ax = axs[1]
ax.fill_between(lower_data['r/ri'],lower_data['gii']-1, PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')
# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii-1, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii-1, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0], label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("h(r)")
ax.set_xlim(0.7,10)
ax.set_ylim(0,2.5)
ax.set_yscale('symlog', linthresh=1e-4)

ax.legend(fontsize=8, loc='upper right')
plt.tight_layout()
