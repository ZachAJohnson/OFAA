# %%
import numpy as np
import pandas as pd

# from atomic_forces.average_atom.python.average_atom import NeutralPseudoAtom as NPA
from atomic_forces.average_atom.python.average_atom_geometric import NeutralPseudoAtom as NPA
from atomic_forces.average_atom.python.average_atom_geometric import load_NPA
from atomic_forces.average_atom.python.misc import jacobi_relaxation, sor
from atomic_forces.average_atom.python.grids import NonUniformGrid
# from atomic_forces.average_atom.python.average_atom import load_NPA
from atomic_forces.atomOFDFT.python.physics import ThomasFermi, FermiDirac

from importlib import reload
try:
    reload(physics)
    reload(grids)
    reload(average_atom_geometric)
#     reload(average_atom)
    reload(misc)
except NameError as e:
    from atomic_forces.atomOFDFT.python import physics as physics
    from atomic_forces.average_atom.python import average_atom_geometric as average_atom_geometric
#     from atomic_forces.average_atom.python import average_atom as average_atom
    from atomic_forces.average_atom.python import misc as misc
    from atomic_forces.average_atom.python import grids as grids
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)


import matplotlib.pyplot as plt


import cProfile


eV = 0.0367512
# Out:
# ModuleNotFoundError: No module named 'atoMEC'
# Error:  name 'physics' is not defined

# %%
folder= "/home/zach/plasma/atomic_forces/average_atom/data/converged/Al_NPA_TFD_R3.0e+01_rs3.0e+00_T1.0e+00eV/"
fname = "Al_NPA_TFD_R3.0e+01_rs3.0e+00_T1.0e+00eV_Zstar2.1.dat"

atom  = load_NPA(folder + fname,TFW=True, ignore_vxc=False)
# atom  = load_NPA(Al.savefile, TFW=False, ignore_vxc=False)
# Out:
# Intializing grid
# Loading Data for Comparison (from George Petrov)
# Z err: 0.00427102231121748
# /home/zach/plasma/atomic_forces/GordonKim/python/atoms.py:75: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   Z_unnorm, err = quad(rho_integrand, 0, self.rs, limit=500, epsabs=1e-5, epsrel=1e-5)

# %%
atom.make_plots()
atom.make_plot_bound_free()

# %%
cProfile.run('atom.solve_TF(nmax=1, verbose=True)')
# Out:
# Beginning self-consistent electron solver.
# _________________________________
#          210 function calls (207 primitive calls) in 0.018 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(diag)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(diagonal)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(mean)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(shape)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(sum)
#         1    0.000    0.000    0.018    0.018 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 _base.py:1301(isspmatrix)
#         1    0.000    0.000    0.000    0.000 _basic.py:361(solve_banded)
#         3    0.000    0.000    0.000    0.000 _methods.py:163(_mean)
#         2    0.000    0.000    0.000    0.000 _methods.py:60(_all)
#         3    0.000    0.000    0.000    0.000 _methods.py:66(_count_reduce_items)
#         2    0.000    0.000    0.000    0.000 _misc.py:180(_datacopied)
#         2    0.000    0.000    0.000    0.000 _util.py:241(_asarray_validated)
#         1    0.000    0.000    0.000    0.000 average_atom_geometric.py:271(get_Q)
#         1    0.000    0.000    0.017    0.017 average_atom_geometric.py:344(update_φe)
#         1    0.010    0.010    0.016    0.016 average_atom_geometric.py:351(explicit_Ab)
#         1    0.000    0.000    0.000    0.000 average_atom_geometric.py:394(update_ne_W)
#         1    0.000    0.000    0.018    0.018 average_atom_geometric.py:535(solve_TF)
#         1    0.000    0.000    0.000    0.000 blas.py:259(find_best_blas_type)
#         1    0.000    0.000    0.000    0.000 blas.py:307(<listcomp>)
#         1    0.000    0.000    0.000    0.000 blas.py:325(_get_funcs)
#         1    0.000    0.000    0.000    0.000 blas.py:383(getter)
#         2    0.000    0.000    0.000    0.000 core.py:6425(isMaskedArray)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1548(_diagonal_dispatcher)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1552(diagonal)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1961(_shape_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1965(shape)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2157(_sum_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2162(sum)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3308(_mean_dispatcher)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3313(mean)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 function_base.py:561(asarray_chkfinite)
#         1    0.000    0.000    0.002    0.002 grids.py:106(matrix_d2fdx2)
#         1    0.001    0.001    0.007    0.007 grids.py:138(matrix_laplacian)
#         1    0.000    0.000    0.000    0.000 grids.py:87(integrate_f)
#         1    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#         4    0.000    0.000    0.000    0.000 iostream.py:429(_is_master_process)
#         4    0.000    0.000    0.000    0.000 iostream.py:448(_schedule_flush)
#         4    0.000    0.000    0.000    0.000 iostream.py:518(write)
#         1    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 lapack.py:870(get_lapack_funcs)
#         1    0.000    0.000    0.000    0.000 misc.py:9(tridiagsolve)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:282(issubclass_)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:356(issubdtype)
#         1    0.000    0.000    0.000    0.000 socket.py:545(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1066(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1133(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:536(is_set)
#         3    0.000    0.000    0.000    0.000 twodim_base.py:236(_diag_dispatcher)
#         3    0.000    0.000    0.000    0.000 twodim_base.py:240(diag)
#         1    0.000    0.000    0.018    0.018 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#      11/8    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         5    0.005    0.001    0.005    0.001 {built-in method numpy.zeros}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         4    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.001    0.001    0.001    0.001 {method 'copy' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         6    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         4    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 cProfile.run('atom.solve_TF(nmax=1, verbose=True)')
#
# File ~/.pyenv/versions/3.9.13/lib/python3.9/cProfile.py:16, in run(statement, filename, sort)
#      15 def run(statement, filename=None, sort=-1):
# ---> 16     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#
# File ~/.pyenv/versions/3.9.13/lib/python3.9/profile.py:53, in _Utils.run(self, statement, filename, sort)
#      51 prof = self.profiler()
#      52 try:
# ---> 53     prof.run(statement)
#      54 except SystemExit:
#      55     pass
#
# File ~/.pyenv/versions/3.9.13/lib/python3.9/cProfile.py:95, in Profile.run(self, cmd)
#      93 import __main__
#      94 dict = __main__.__dict__
# ---> 95 return self.runctx(cmd, dict, dict)
#
# File ~/.pyenv/versions/3.9.13/lib/python3.9/cProfile.py:100, in Profile.runctx(self, cmd, globals, locals)
#      98 self.enable()
#      99 try:
# --> 100     exec(cmd, globals, locals)
#     101 finally:
#     102     self.disable()
#
# File <string>:1
#
# File ~/plasma/atomic_forces/average_atom/python/average_atom_geometric.py:555, in NeutralPseudoAtom.solve_TF(self, verbose, nmax, tol)
#     552 poisson_err, gmres_code = self.update_φe()
#     553 if self.TFW:
#     554 	# self.update_ne_W_Jacobi(alpha=0.5, constant_hλ=False)
# --> 555 	self.update_ne_W()
#     556 	# self.update_ne(alpha=1e-3)
#     557 	#Update Chemical potential
#     558 else:
#     559 	self.update_ne(alpha=1e-2)
#
# File ~/plasma/atomic_forces/average_atom/python/average_atom_geometric.py:432, in NeutralPseudoAtom.update_ne_W(self, alpha, constant_hλ)
#     429 	Abanded, bbanded = banded_Ab()
#     431 	# A[:-1,:-1] =
# --> 432 A, b = explicit_Ab()
#     433 # γs = tridiagsolve(A, b)
#     434 γs = spsolve(A, b)
#
# NameError: name 'explicit_Ab' is not defined

# %% [markdown]
# ## For TFDW

# %%
def plot_gamma():

    fig, ax = plt.subplots(figsize=(12,8))
    eta = atom.TF.η_interp(atom.ne)
    aW, bW = atom.get_W_coeffs(eta, atom.ne, atom.T)
    grad_n = atom.grid.dfdx(atom.ne)
    laplace_ne = 1/atom.grid.xs**2 * atom.grid.dfdx(atom.grid.xs**2 * grad_n)
    laplace_ne = 2/atom.grid.xs*atom.grid.d2fdx2(atom.ne) + atom.grid.dfdx(atom.ne)

    ax.plot(atom.grid.xs, atom.grid.xs*np.sqrt(atom.ne), '--.', label=r'$\gamma$')
    ax.plot(atom.grid.xs, atom.grid.xs*np.sqrt(atom.get_ne_TF(atom.μ)), '--.', label=r'$\gamma$ from $I_{1/2}$')
#     ax.plot(atom.grid.xs, atom.get_eta_from_sum(atom.μ) , label='eta')
#     ax.plot(atom.grid.xs, (-atom.get_W())/atom.T,'--.', label='W')
#     ax.plot(atom.grid.xs, (-aW/atom.ne**2)/atom.T, label='a')
#     ax.plot(atom.grid.xs, (-bW/atom.ne**2 * grad_n**2)/atom.T, label='Wb')
#     ax.plot(atom.grid.xs, (-aW/atom.ne * laplace_ne)/atom.T, label='Wa')
#     ax.plot(atom.grid.xs, (-atom.vxc_f(atom.ne))/atom.T, label='vxc')
#     ax.plot(atom.grid.xs, (atom.μ + atom.φe + atom.φion)/atom.T/10, label=r'$\phi$')
    
    ax.legend(fontsize=20)
#     ax.set_xlim(8.97,9)
    ax.set_yscale('symlog',linthresh=1e-2)
    ax.tick_params(labelsize=20)
#     ax.set_ylim(-1,1e2)
    plt.show()
plot_gamma()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [3], line 26
#      24 #     ax.set_ylim(-1,1e2)
#      25     plt.show()
# ---> 26 plot_gamma()
#
# Cell In [3], line 11, in plot_gamma()
#       8     laplace_ne = 2/atom.grid.xs*atom.grid.d2fdx2(atom.ne) + atom.grid.dfdx(atom.ne)
#      10     ax.plot(atom.grid.xs, atom.grid.xs*np.sqrt(atom.ne), '--.', label=r'$\gamma$')
# ---> 11     ax.plot(atom.grid.xs, atom.grid.xs*np.sqrt(atom.get_ne_TF(atom.μ)), '--.', label=r'$\gamma$ from $I_{1/2}$')
#      12 #     ax.plot(atom.grid.xs, atom.get_eta_from_sum(atom.μ) , label='eta')
#      13 #     ax.plot(atom.grid.xs, (-atom.get_W())/atom.T,'--.', label='W')
#      14 #     ax.plot(atom.grid.xs, (-aW/atom.ne**2)/atom.T, label='a')
#    (...)
#      17 #     ax.plot(atom.grid.xs, (-atom.vxc_f(atom.ne))/atom.T, label='vxc')
#      18 #     ax.plot(atom.grid.xs, (atom.μ + atom.φe + atom.φion)/atom.T/10, label=r'$\phi$')
#      20     ax.legend(fontsize=20)
#
# TypeError: get_ne_TF() missing 1 required positional argument: 'μ'
