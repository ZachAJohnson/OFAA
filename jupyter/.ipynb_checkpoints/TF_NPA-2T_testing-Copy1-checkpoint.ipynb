# %%
import numpy as np
import pandas as pd

# from average_atom.python.average_atom import NeutralPseudoAtom as NPA
from average_atom.python.average_atom_geometric import NeutralPseudoAtom as NPA
# from average_atom.python.average_atom_geometric import load_NPA
from average_atom.python.misc import jacobi_relaxation, sor
from average_atom.python.grids import NonUniformGrid
# from average_atom.python.average_atom import load_NPA
from average_atom.python.physics import ThomasFermi, FermiDirac

from importlib import reload
try:
    reload(physics)
    reload(grids)
    reload(average_atom_geometric)
#     reload(average_atom)
    reload(misc)
except NameError as e:
    from average_atom.python import physics as physics
    from average_atom.python import average_atom_geometric as average_atom_geometric
#     from average_atom.python import average_atom as average_atom
    from average_atom.python import misc as misc
    from average_atom.python import grids as grids
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)


import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

import cProfile

plt.rcParams.update({'font.size': 14})
plt.rcParams["figure.figsize"] = (6,4)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14

# %%
# Aluminuma
name='Al'
Z, A = 13, 27 

Ti_eV = 1 
Te_eV = 1

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

rs = 2.985767276908717


# Hydrogen
# name='H'
# Z, A = 1, 1.00784

# Te_eV = 2 
# Te_AU = Te_eV*eV_to_AU

# Ti_eV = 2
# Ti_AU = Ti_eV*eV_to_AU

# ρ_gpercc = 1
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)


####
R = 20*rs

aa = NPA(Z, A, Ti_AU, Te_AU, rs, rs, initialize=True, gradient_correction=None, μ_init = 0.158, Zstar_init = 'More', rmin=1e-2 ,Npoints=300,
             name=name, ignore_vxc=True, fixed_Zstar=False, iet_R_over_rs=R/rs, use_full_ne_for_nf=False)
npa = NPA(Z, A, Ti_AU, Te_AU, rs, R, initialize=True, gradient_correction=None, μ_init = 0.158, Zstar_init = 'More', rmin=1e-2 ,Npoints=1000, 
              name=name,ignore_vxc=True, fixed_Zstar=False, iet_R_over_rs=R/rs*3, use_full_ne_for_nf=False)
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.501
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.501
# 	Intializing grid
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 3.110e+01
# Exiting status 0, reverting to best index so far: 1208
# Final iter:1209, Total Error: 9.881e-13
# Intialized Potentials and Densities

# %%
fig, ax = plt.subplots()

ax.plot(npa.grid.xs, npa.ρi - npa.ne)
ax.plot(npa.grid.xs, npa.ρi - npa.ρi[-1])
ax.plot(npa.grid.xs, npa.ne - npa.ne[-1])
ax.plot(npa.grid.xs, (npa.gii_initial-1))
ax.plot(npa.grid.xs, (npa.φe + npa.φion))


ax.set_yscale('symlog', linthresh=1e-12)

# %%
fig, axs  = plt.subplots(1,2,figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

short_distance_weight = np.exp(-(0.08*npa.kTF*npa.grid.xs)**4)
for ax in axs:
    ax.plot(npa.iet.r_array*rs, npa.iet.h_r_matrix[0,0], color=colors[0], label=r"$u_Y$")
    # ax.plot(aa.iet.r_array*rs, aa.iet.h_r_matrix[0,0],color=colors[1],  label=r"$u_Y$")
    ax.plot(npa.grid.xs, (npa.gii-1),'-',color=colors[3],  label=r"$u_Y$")
    # ax.plot(npa.grid.xs, short_distance_weight*(npa.gii-1),'--',color=colors[3],  label=r"$u_Y$ damped")
    			

    # ax.plot(aa.grid.xs, aa.gii-1,'--',color=colors[3],  label=r"$u_Y$")
    ax.axvline(npa.iet.r_array[-1]*rs,color='k')
    
ax = axs[0]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xlim(0,6)

ax = axs[1]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xscale('log')
ax.set_xlim(0.5,None)
ax.set_yscale('symlog', linthresh=1e-6)
for ax in axs:
    ax.legend(fontsize=12)
    ax.tick_params(labelsize=12)


plt.tight_layout()

# %% [markdown]
# ### Thomas Fermi (TF)

# %%
aa.solve_TF(verbose=True, picard_alpha=2e-1, tol=1e-7)
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	mu =     0.3772, change: 1.3874e+00 (converged=False)
# 	Poisson Err = -1.172e-12, rho Err =  2.876e-01
# 	Q =  0.000e+00 ->  2.442e-01,
# 	Zstar guess =  4.813e+00. Current Zstar:  2.963e+00 (converged=False)
# 	Change =  1.117e+00
# 	L_decay =  3.715e+00
# __________________________________________
# TF Iteration 1
# 	mu =     0.3635, change: 3.6314e-02 (converged=False)
# 	Poisson Err = -1.204e-12, rho Err =  2.317e-01
# 	Q =  2.442e-01 ->  2.047e-01,
# 	Zstar guess =  4.452e+00. Current Zstar:  3.261e+00 (converged=False)
# 	Change =  1.113e-01
# 	L_decay =  3.653e+00
# __________________________________________
# TF Iteration 2
# 	mu =     0.3840, change: 5.6350e-02 (converged=False)
# 	Poisson Err = -1.379e-12, rho Err =  1.863e-01
# 	Q =  2.047e-01 ->  2.190e-01,
# 	Zstar guess =  4.438e+00. Current Zstar:  3.496e+00 (converged=False)
# 	Change =  1.256e-01
# 	L_decay =  3.609e+00
# __________________________________________
# TF Iteration 3
# 	mu =     0.3897, change: 1.4907e-02 (converged=False)
# 	Poisson Err = -1.269e-12, rho Err =  1.482e-01
# 	Q =  2.190e-01 ->  2.221e-01,
# 	Zstar guess =  4.351e+00. Current Zstar:  3.667e+00 (converged=False)
# 	Change =  8.762e-02
# 	L_decay =  3.580e+00
# __________________________________________
# TF Iteration 4
# 	mu =     0.3920, change: 5.9032e-03 (converged=True)
# 	Poisson Err = -1.402e-12, rho Err =  1.187e-01
# 	Q =  2.221e-01 ->  2.256e-01,
# 	Zstar guess =  4.274e+00. Current Zstar:  3.789e+00 (converged=False)
# 	Change =  6.185e-02
# 	L_decay =  3.560e+00
# __________________________________________
# TF Iteration 5
# 	mu =     0.3920, change: 0.0000e+00 (converged=True)
# 	Poisson Err = -1.386e-12, rho Err =  9.546e-02
# 	Q =  2.256e-01 ->  2.241e-01,
# 	Zstar guess =  4.192e+00. Current Zstar:  3.869e+00 (converged=False)
# 	Change =  4.248e-02
# 	L_decay =  3.547e+00
# __________________________________________
# TF Iteration 6
# 	mu =     0.3920, change: 0.0000e+00 (converged=True)
# 	Poisson Err = -1.331e-12, rho Err =  7.741e-02
# 	Q =  2.241e-01 ->  2.171e-01,
# 	Zstar guess =  4.115e+00. Current Zstar:  3.918e+00 (converged=False)
# 	Change =  3.178e-02
# 	L_decay =  3.539e+00
# __________________________________________
# TF Iteration 7
# 	mu =     0.3920, change: 0.0000e+00 (converged=True)
# 	Poisson Err = -1.413e-12, rho Err =  6.343e-02
# 	Q =  2.171e-01 ->  2.039e-01,
# 	Zstar guess =  4.050e+00. Current Zstar:  3.945e+00 (converged=False)
# 	Change =  2.407e-02
# 	L_decay =  3.535e+00
# __________________________________________
# TF Iteration 8
# 	mu =     0.3920, change: 0.0000e+00 (converged=True)
# 	Poisson Err = -1.422e-12, rho Err =  5.262e-02
# 	Q =  2.039e-01 ->  1.854e-01,
# 	Zstar guess =  3.998e+00. Current Zstar:  3.955e+00 (converged=False)
# 	Change =  1.842e-02
# 	L_decay =  3.533e+00
# __________________________________________
# TF Iteration 9
# 	mu =     0.3920, change: 0.0000e+00 (converged=True)
# 	Poisson Err = -1.270e-12, rho Err =  4.421e-02
# 	Q =  1.854e-01 ->  1.635e-01,
# 	Zstar guess =  3.958e+00. Current Zstar:  3.956e+00 (converged=False)
# 	Change =  1.420e-02
# 	L_decay =  3.533e+00
# __________________________________________
# TF Iteration 25
# 	mu =     0.3730, change: 0.0000e+00 (converged=True)
# 	Poisson Err = -1.344e-12, rho Err =  4.309e-03
# 	Q =  1.123e-02 ->  8.265e-03,
# 	Zstar guess =  3.796e+00. Current Zstar:  3.815e+00 (converged=False)
# 	Change =  2.939e-04
# 	L_decay =  3.555e+00
# __________________________________________
# TF Iteration 50
# 	mu =     0.3696, change: 1.0795e-03 (converged=True)
# 	Poisson Err = -1.396e-12, rho Err =  3.054e-04
# 	Q = -4.430e-03 -> -4.473e-03,
# 	Zstar guess =  3.783e+00. Current Zstar:  3.784e+00 (converged=False)
# 	Change =  7.647e-04
# 	L_decay =  3.560e+00
# __________________________________________
# TF Iteration 75
# 	mu =     0.3693, change: 0.0000e+00 (converged=True)
# 	Poisson Err = -1.239e-12, rho Err =  3.599e-05
# 	Q = -1.120e-03 -> -1.061e-03,
# 	Zstar guess =  3.780e+00. Current Zstar:  3.780e+00 (converged=False)
# 	Change =  2.567e-07
# 	L_decay =  3.561e+00
# __________________________________________
# TF Iteration 100
# 	mu =     0.3692, change: 3.4311e-05 (converged=True)
# 	Poisson Err = -1.529e-12, rho Err =  1.321e-05
# 	Q = -2.622e-04 -> -2.529e-04,
# 	Zstar guess =  3.779e+00. Current Zstar:  3.779e+00 (converged=False)
# 	Change =  2.427e-05
# 	L_decay =  3.561e+00
# __________________________________________
# TF Iteration 125
# 	mu =     0.3692, change: 0.0000e+00 (converged=True)
# 	Poisson Err = -1.275e-12, rho Err =  2.068e-06
# 	Q = -4.939e-05 -> -4.643e-05,
# 	Zstar guess =  3.779e+00. Current Zstar:  3.779e+00 (converged=False)
# 	Change =  8.826e-09
# 	L_decay =  3.561e+00
# __________________________________________
# TF Iteration 150
# 	mu =     0.3692, change: 1.2299e-06 (converged=True)
# 	Poisson Err = -1.259e-12, rho Err =  5.535e-07
# 	Q = -1.030e-05 -> -9.888e-06,
# 	Zstar guess =  3.779e+00. Current Zstar:  3.779e+00 (converged=False)
# 	Change =  8.698e-07
# 	L_decay =  3.561e+00
# __________________________________________
# Final AA_TF Iteration: 175
# 	mu =     0.3692, change: 0.0000e+00 (converged=True)
# 	Poisson Err = -1.323e-12, rho Err =  9.324e-08
# 	Q = -2.004e-06 -> -1.869e-06,
# 	Zstar guess =  3.779e+00. Current Zstar:  3.779e+00 (converged=False)
# 	Change =  6.374e-10
# 	L_decay =  3.561e+00
# True

# %%
npa.solve_TF(verbose=True, picard_alpha=0.1, tol=1e-7, nmax = 1e3)
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	mu =     0.3786, change: 1.3963e+00 (converged=False)
# 	Poisson Err =        nan, rho Err =  1.516e+00
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.510e+00 (converged=False)
# 	Change =  1.509e+00
# 	L_decay =  3.825e+00
# __________________________________________
# TF Iteration 1
# 	mu =     0.3785, change: 3.3611e-04 (converged=True)
# 	Poisson Err =  3.304e-11, rho Err =  6.420e-01
# 	Q = -3.638e-12 ->  3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.509e+00 (converged=False)
# 	Change =  1.410e-01
# 	L_decay =  3.825e+00
# __________________________________________
# TF Iteration 2
# 	mu =     0.3784, change: 3.1647e-04 (converged=True)
# 	Poisson Err =  5.022e-13, rho Err =  5.889e-01
# 	Q =  3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.508e+00 (converged=False)
# 	Change =  1.252e-01
# 	L_decay =  3.825e+00
# __________________________________________
# TF Iteration 3
# 	mu =     0.3783, change: 2.9833e-04 (converged=True)
# 	Poisson Err =  2.779e-11, rho Err =  5.433e-01
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.507e+00 (converged=False)
# 	Change =  1.234e-01
# 	L_decay =  3.826e+00
# __________________________________________
# TF Iteration 4
# 	mu =     0.3782, change: 2.8156e-04 (converged=True)
# 	Poisson Err =  1.912e-11, rho Err =  4.954e-01
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.506e+00 (converged=False)
# 	Change =  1.216e-01
# 	L_decay =  3.826e+00
# __________________________________________
# TF Iteration 5
# 	mu =     0.3781, change: 2.6600e-04 (converged=True)
# 	Poisson Err =  1.274e-11, rho Err =  4.442e-01
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.505e+00 (converged=False)
# 	Change =  1.197e-01
# 	L_decay =  3.826e+00
# /home/zach/plasma/average_atom/python/average_atom_geometric.py:528: RuntimeWarning: divide by zero encountered in divide
#   rel_errs = (np.abs(A @ φe - b)[:-1]/b[:-1])
# /home/zach/plasma/average_atom/python/average_atom_geometric.py:528: RuntimeWarning: invalid value encountered in divide
#   rel_errs = (np.abs(A @ φe - b)[:-1]/b[:-1])
# /home/zach/plasma/average_atom/python/average_atom_geometric.py:803: RuntimeWarning: divide by zero encountered in divide
#   lengthscale_to_change_over = np.max([ self.grid.xs[np.where( np.abs(self.ne/TF_ne-1) > 1e-8)][0] , 1/(0.25*self.kTF) ])
# __________________________________________
# TF Iteration 6
# 	mu =     0.3780, change: 2.5152e-04 (converged=True)
# 	Poisson Err =  1.348e-11, rho Err =  3.888e-01
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.504e+00 (converged=False)
# 	Change =  1.177e-01
# 	L_decay =  3.827e+00
# __________________________________________
# TF Iteration 7
# 	mu =     0.3779, change: 2.3789e-04 (converged=True)
# 	Poisson Err =  1.240e-11, rho Err =  3.281e-01
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.503e+00 (converged=False)
# 	Change =  1.156e-01
# 	L_decay =  3.827e+00
# __________________________________________
# TF Iteration 8
# 	mu =     0.3778, change: 2.2467e-04 (converged=True)
# 	Poisson Err =  1.127e-11, rho Err =  2.603e-01
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.502e+00 (converged=False)
# 	Change =  1.136e-01
# 	L_decay =  3.827e+00
# __________________________________________
# TF Iteration 9
# 	mu =     0.3777, change: 2.1060e-04 (converged=True)
# 	Poisson Err =  8.681e-12, rho Err =  1.835e-01
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.501e+00 (converged=False)
# 	Change =  1.115e-01
# 	L_decay =  3.827e+00
# __________________________________________
# TF Iteration 25
# 	mu =     0.3776, change: 3.1058e-05 (converged=True)
# 	Poisson Err =  4.666e-11, rho Err =  3.771e-02
# 	Q = -7.276e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.501e+00 (converged=False)
# 	Change =  1.570e-02
# 	L_decay =  3.827e+00
# __________________________________________
# TF Iteration 50
# 	mu =     0.3776, change: 3.0000e-07 (converged=True)
# 	Poisson Err = -3.165e-09, rho Err =  2.947e-03
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.501e+00 (converged=False)
# 	Change =  6.420e-04
# 	L_decay =  3.827e+00
# __________________________________________
# TF Iteration 75
# 	mu =     0.3776, change: 4.4991e-08 (converged=True)
# 	Poisson Err =  2.252e-11, rho Err =  3.379e-03
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.501e+00 (converged=False)
# 	Change =  4.388e-05
# 	L_decay =  3.827e+00
# __________________________________________
# TF Iteration 100
# 	mu =     0.3776, change: 4.4884e-08 (converged=True)
# 	Poisson Err = -5.747e-11, rho Err =  2.939e-03
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.501e+00 (converged=False)
# 	Change =  3.381e-06
# 	L_decay =  3.827e+00
# __________________________________________
# TF Iteration 125
# 	mu =     0.5567, change: 2.8337e-03 (converged=True)
# 	Poisson Err =  1.093e-09, rho Err =  1.780e-03
# 	Q = -7.276e-12 -> -1.455e-11,
# 	Zstar guess =  4.618e+00. Current Zstar:  4.448e+00 (converged=False)
# 	Change =  2.011e-03
# 	L_decay =  3.463e+00
# __________________________________________
# TF Iteration 150
# 	mu =     0.5690, change: 1.5823e-04 (converged=True)
# 	Poisson Err = -8.317e-11, rho Err =  1.650e-03
# 	Q = -7.276e-12 ->  0.000e+00,
# 	Zstar guess =  4.604e+00. Current Zstar:  4.595e+00 (converged=False)
# 	Change =  1.125e-04
# 	L_decay =  3.443e+00
# __________________________________________
# TF Iteration 175
# 	mu =     0.5697, change: 1.0470e-05 (converged=True)
# 	Poisson Err =  4.417e-10, rho Err =  1.588e-03
# 	Q =  0.000e+00 -> -1.455e-11,
# 	Zstar guess =  4.604e+00. Current Zstar:  4.603e+00 (converged=False)
# 	Change =  7.587e-06
# 	L_decay =  3.442e+00
# __________________________________________
# TF Iteration 200
# 	mu =     0.5698, change: 1.1032e-06 (converged=True)
# 	Poisson Err = -9.348e-11, rho Err =  1.490e-03
# 	Q =  0.000e+00 ->  7.276e-12,
# 	Zstar guess =  4.604e+00. Current Zstar:  4.604e+00 (converged=False)
# 	Change =  9.782e-07
# 	L_decay =  3.442e+00
# __________________________________________
# TF Iteration 225
# 	mu =     0.5698, change: 6.8985e-09 (converged=True)
# 	Poisson Err =  9.364e-11, rho Err =  1.408e-03
# 	Q = -7.276e-12 -> -7.276e-12,
# 	Zstar guess =  4.604e+00. Current Zstar:  4.604e+00 (converged=True)
# 	Change =  1.511e-07
# 	L_decay =  3.442e+00
# __________________________________________
# TF Iteration 250
# 	mu =     0.5698, change: 6.0413e-09 (converged=True)
# 	Poisson Err = -1.146e-09, rho Err =  1.339e-03
# 	Q = -7.276e-12 ->  0.000e+00,
# 	Zstar guess =  4.604e+00. Current Zstar:  4.604e+00 (converged=True)
# 	Change =  1.212e-07
# 	L_decay =  3.442e+00
# KeyboardInterrupt

# %%
aa.set_uii_eff(), npa.set_uii_eff()
# Out:
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 2.734e+02
# Exiting status 0, reverting to best index so far: 4458
# Final iter:4459, Total Error: 9.989e-13
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 8.033e+01
# QUIT: Last 10 iterations error has been increasing
# Exiting status 2, reverting to best index so far: 1098
# Final iter:1111, Total Error: 8.134e-03
# (None, None)

# %%
from average_atom.python.physics import χ_TF
fake_nf = npa.Zstar/(4*π * 1/(npa.κ/rs)**2 * npa.grid.xs) * np.exp(-npa.grid.xs*npa.κ/rs)

# %%
fig, ax  = plt.subplots()

ax.plot(npa.grid.xs, npa.n_f - npa.n_f[-1] )
ax.plot(npa.grid.xs, fake_nf-fake_nf[-1] )
ax.set_yscale('symlog', linthresh=1e-7)
# ax.set_xlim(rs,None)
# ax.set_xscale('log')
ax.set_ylim(None, 1e3)
# Out:
# (-0.06964384229897536, 1000.0)

# %% [markdown]
# ### EOS

# %%
def get_E(aa):
    βVeff = aa.get_βVeff(aa.φe, aa.ne, aa.ne_bar)
    η = aa.μ/aa.Te - βVeff
    βU = aa.grid.integrate_f(βVeff*aa.ne)
    I_onehalf = FermiDirac.Ionehalf(η)
    I_threehalf = FermiDirac.Ithreehalf(η)
    
    βK = (2*aa.Te)**1.5/π**2 * aa.grid.integrate_f( η*I_onehalf - 2/3 * I_threehalf   )
    return βU, βK, βU + βK

get_E(aa_tfd), get_E(npa_tfd)
# Out:
# ((-12057.77785834938, 14625.110239229047, 2567.3323808796667),
#  (-10113.560084102695, 691800.7335095502, 681687.1734254475))

# %%
def get_P(aa):
    aa_old_βu = aa.iet.βu_r_matrix.copy()
    # aa.iet.set_βu_matrix( np.array([[1/aa.Ti * aa.Zstar**2/(aa.iet.r_array*aa.rs) ]] ))
    P_id_hnc, P_ex_hnc, P_hnc = aa.iet.ideal_pressure(), aa.iet.excess_pressure(), aa.iet.total_pressure()
    P_id_AU, P_ex_AU, P_AU  = P_id_hnc/rs**3, P_ex_hnc/rs**3, P_hnc/rs**3
    aa.iet.set_βu_matrix(aa_old_βu)
    return P_id_AU, P_ex_AU, P_AU

aa_P_ions = get_P(aa_tfd)
aa_P_ions[1]/aa_P_ions[0]

# %% [markdown]
# ## Comparison

# %%
npa.make_plots()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 npa_tfd.make_plots()
#
# File ~/plasma/average_atom/python/average_atom_geometric.py:1140, in make_plots(self, show)
#    1135 			ax.grid(which='both',alpha=0.4)
#    1137 			# make textbox
#    1138 			text = ("{0}, {1}\n".format(self.name, self.aa_type.replace("_", " "))+
#    1139 				r"$r_s$ = " + "{0:.2f},    ".format(self.rs,2) +
# -> 1140 				r"$R_{NPA}$ = " + "{0:.2f}\n".format(self.R)  +
#    1141         			r"$T_e$ = " + "{0:.3f} [A.U.] = {1:.2f} eV\n".format(self.Te, self.Te/eV) +
#    1142         			r"$\mu$ = " + "{0:.3f} [A.U.] = {1:.2f} eV\n".format(self.μ, self.μ/eV) +
#    1143         			r"$\mu-V(R)$ = " + "{0:.3f} [A.U.] = {1:.2f} eV\n".format(self.μ-self.vxc_f(self.ne)[-1],(self.μ-self.vxc_f(self.ne)[-1])/eV) +
#    1144         			r"$Z^\ast =$ " + "{0:.2f}".format(self.Zstar)  )
#    1145 			self.nice_text = text
#    1146 			props = dict(boxstyle='round', facecolor='w')
#
# AttributeError: 'NeutralPseudoAtom' object has no attribute 'vxc_f'

# %%
def plot_convergence(aa, axs=None):
    if axs is None:
        fig, axs = plt.subplots(ncols=3,figsize=(18,5),facecolor='w', dpi=200)
    
    # ELectric potential
    slice_by_num = 10
    ax = axs[0]
    colors = plt.cm.coolwarm(np.linspace(0, 1,len(aa.φe_list[::slice_by_num])))
    for i, φe in enumerate(aa.φe_list[::slice_by_num]):
        if i ==0 or i==len(aa.φe_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, (φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\phi_e$'.format(i))
        else:
            ax.plot(aa.grid.xs, φe+aa.φion,linewidth=1,color=colors[i],alpha=0.2)
    # ax.plot(aa.grid.xs, aa.get_φe( (aa.ρi - aa.ne) )[0] + aa.φion  ,'k:', label=r'$\phi$ check') 
    ax.set_yscale('symlog',linthresh=1e-7)

    # number density
    ax = axs[1]
    for i, (ne, ρi) in enumerate(zip(aa.ne_list[::slice_by_num], aa.ρi_list[::slice_by_num])):
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            if i==0: 
                ne_bar_0 = ne[-1]
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + 0*ρi + ne[-1],linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ne_bar_0,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ρi[-1] + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # pass
        else:
            # print(ne[-1]-ne_bar_0)
            # ax.plot(aa.grid.xs, -ne + ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ne + ne_bar_0 ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ρi[-1]+ ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            pass
    for i in range(int(aa.R/aa.rs)):
        ax.axvline(aa.rs*i, color='k', linestyle='--', alpha=0.5)
    # ax.set_xscale('log')
    # ax.plot(aa.grid.xs, (aa.gii)-1, 'k:')
    ax.set_yscale('symlog',linthresh=1e-4)

            
    # number density
    ax = axs[2]
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        ne_TF = aa.get_ne_TF(φe, ne, μ, ne_bar)
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            # ax.plot(aa.grid.xs, ne/ne_TF-1,linewidth=1,color=colors[i],alpha=1, label=r'$n_e/n_e^{{TF}}-1$, iter: {0}'.format(i))
            ax.plot(aa.grid.xs, ne-ne[-1],linewidth=1,color=colors[i],alpha=1, label=r'$n_e/n_e^{{TF}}-1$, iter: {0}'.format(i))
            # pass
        else:
            # ax.plot(aa.grid.xs, ne/ne_TF-1, linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            ax.plot(aa.grid.xs, ne-ne[-1], linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # print(np.abs(ne/ne_TF-1))
            # print(np.where( np.abs(ne/ne_TF-1)>1e-6 ))
            # print(aa.grid.xs[np.where( np.abs(ne/ne_TF-1) > 1e-8)][0]/10, 1/(np.sum(aa.grid.xs*np.abs(ne/ne_TF-1))/np.sum(np.abs(ne/ne_TF-1))))
    # ax.set_ylim()
    ax.set_yscale('symlog',linthresh=1e-8)
    # ax.set_xscale('log')
    for ax in axs:
        ax.legend(fontsize=14)
        ax.tick_params(labelsize=14)
        ax.plot(aa.grid.xs, np.zeros_like(aa.ne),'k--')
    plt.tight_layout()
# plot_convergence(aa_tfd)
plot_convergence(npa_tfd)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

def make_plot_bound_free(aa, axs=None, name='', color=colors[0]):
    eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
    if axs is None:
        fig, axs = plt.subplots(ncols=2,figsize=(20,8),facecolor='w')

    # Density * 4pi r^2 plot
    factor = 4*np.pi*aa.grid.xs**2
    axs[0].plot(aa.grid.xs, aa.ne*factor ,'-',color=color, label=r'$n_e$: '+ name)
    axs[0].plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
    axs[0].plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
    if aa.rs != aa.R:
        axs[0].plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
        axs[0].plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)
    # axs[0].plot(aa.grid.xs, aa.δn_f*factor,'--',color='g',  label=r'$n_e^{sc}$: ' + name)


    axs[0].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[0].set_ylim(1e-2, 1e3)
    axs[0].set_yscale('log')#,linthresh=1e-6)
    axs[0].set_xscale('log')
    axs[0].set_xlim(aa.grid.xs[0],aa.grid.xs[-1])

    
    # Density * 4pi r^2 plot
    factor = 4*np.pi*aa.grid.xs**2
    axs[1].plot(aa.grid.xs, aa.ne*factor ,'-',color=color, label=r'$n_e$: '+ name)
    axs[1].plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
    axs[1].plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
    if aa.rs != aa.R:
        axs[1].plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
        axs[1].plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)


    axs[1].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[1].set_ylim(0, 18)
    axs[1].set_xlim(0,aa.R)

        
    for ax in axs:
        ax.set_xlabel(r'$|r-R_1|$ [A.U.]',fontsize=20)
        ax.legend(loc="upper right",fontsize=20,labelspacing = 0.1)
        ax.tick_params(labelsize=20)
        ax.grid(which='both',alpha=0.4)

        # make textbox
        text = ("{0}\n".format(aa.name)+ 
            r"$r_s$ = " + "{0},    ".format(np.round(aa.rs,2)) +
            r"$R_{NPA}$ = " + "{0}\n".format(aa.R)  +
                r"$T_e$ = " + "{0} [A.U.] = {1} eV\n".format(np.round(aa.Te,2),np.round(aa.Te/eV,2)) + r"$\mu$ = " + "{0} [A.U.]\n".format(np.round(aa.μ,2)) +
                r"$Z^\ast = $" + "{0}".format(np.round(aa.Zstar,2))  )

        props = dict(boxstyle='round', facecolor='w')
        ax.text(0.05,0.95, text, fontsize=15, transform=ax.transAxes, verticalalignment='top', bbox=props)

    plt.tight_layout()
    name = "NPA_densities_{0}_rs{1}_{2}eV_R{3}.png".format(aa.name, np.round(aa.rs,2), np.round(aa.Te/eV,2) ,np.round(aa.R))
    plt.savefig("/home/zach/plasma/atomic_forces/average_atom/media/" + name, dpi=300, bbox_inches='tight',facecolor="w")
    
    
    return axs


axs = make_plot_bound_free(npa_tfd, color=colors[0])
for ax in axs:
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), fontsize=16, loc='upper right')
# axs[1].set_ylim(1e-5,1e3)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

def compare_aa(aa_list, axs=None, name=''):
    eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
    if axs is None:
        fig, axs = plt.subplots(ncols=2,figsize=(20,8),facecolor='w')

    # Density * 4pi r^2 plot
    for ax in axs:
        for aa, color in zip( aa_list, colors):
            factor = 4*np.pi*aa.grid.xs**2
            # ax.plot(aa.petrov.r_data, 4*np.pi*aa.petrov.r_data**2*(aa.petrov.rho_data + aa.petrov.rho_0), 'k-', label="Petrov AA")
            ax.plot(aa.grid.xs, aa.ne*factor ,'-',color=color, label=r'$n_e$: '+ name)
            ax.plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
            ax.plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
            if aa.rs != aa.R:
                ax.plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
                ax.plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)
        # axs[0].plot(aa.grid.xs, aa.δn_f*factor,'--',color='g',  label=r'$n_e^{sc}$: ' + name)


    axs[0].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[0].set_ylim(0, 1e3)
    axs[0].set_yscale('symlog',linthresh=1e-1)
    axs[0].set_xscale('log')
    axs[0].set_xlim(aa.grid.xs[0],aa.grid.xs[-1])

    axs[1].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[1].set_ylim(0, 13)
    axs[1].set_xlim(0, np.min([aa.R,1.3*aa.rs]))

        
    for ax in axs:
        ax.set_xlabel(r'$|r-R_1|$ [A.U.]',fontsize=20)
        ax.legend(loc="upper right",fontsize=20,labelspacing = 0.1)
        ax.tick_params(labelsize=20)
        ax.grid(which='both',alpha=0.4)

        # make textbox
        text = ("{0}\n".format(aa.name)+ 
            r"$r_s$ = " + "{0},    ".format(np.round(aa.rs,2)) +
            r"$R_{NPA}$ = " + "{0}\n".format(aa.R)  +
                r"$T_e$ = " + "{0} [A.U.] = {1} eV\n".format(np.round(aa.Te,2),np.round(aa.Te/eV,2)) + r"$\mu$ = " + "{0} [A.U.]\n".format(np.round(aa.μ,2)) +
                r"$Z^\ast = $" + "{0}".format(np.round(aa.Zstar,2))  )

        props = dict(boxstyle='round', facecolor='w')
        ax.text(0.25,0.95, text, fontsize=15, transform=ax.transAxes, verticalalignment='top', bbox=props)

    plt.tight_layout()
    name = "NPA_densities_{0}_rs{1}_{2}eV_R{3}.png".format(aa.name, np.round(aa.rs,2), np.round(aa.Te/eV,2) ,np.round(aa.R))
    plt.savefig("/home/zach/plasma/atomic_forces/average_atom/media/" + name, dpi=300, bbox_inches='tight',facecolor="w")
    
    
    return axs


axs = compare_aa([aa_tfd, npa_tfd])
for ax in axs:
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), fontsize=16, loc='upper right')
# axs[1].set_ylim(1e-5,1e3)

# %% [markdown]
# ## HNC and FT

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.k_array/rs, aa.Uei_iet_k*(aa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.k_array/rs, npa.Uei_iet_k*(npa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[1], label="NPA") # Need to muultiply by some rs power???
axs[0].plot(aa.iet.k_array/rs, aa.Zstar*np.ones_like(aa.iet.k_array),':', color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(npa.iet.k_array/rs, npa.Zstar*np.ones_like(npa.iet.k_array),':',color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")

# axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$k$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.k_array/rs, aa.uii_k_eff_iet,'-', color=colors[0], label="AA")
axs[1].plot(aa.iet.k_array/rs, 4*π*aa.Zstar**2/(aa.iet.k_array/rs)**2,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
axs[1].plot(aa.iet.k_array/rs, 1/(aa.iet.k_array**2/rs**2/(4*π*aa.Zstar**2) + 1/aa.uii_k_eff_iet[0] ),'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, uii_test,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))


axs[1].plot(npa.iet.k_array/rs, npa.uii_k_eff_iet,color=colors[1], label="NPA")
axs[1].plot(npa.iet.k_array/rs, 4*π*npa.Zstar**2/(npa.iet.k_array/rs)**2,'--', color=colors[1], label=r"NPA: $u_{{ii}}^0$, Z={0:0.3f}".format(npa.Zstar))



axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_ylim(0,1e5)
axs[1].set_xscale('log')
axs[1].set_xlabel(r"$k$ [au]")
axs[1].set_ylabel(r"$u^{\rm eff}_{ii}$ [au]")


for ax in axs:
    ax.legend(fontsize=12)
plt.tight_layout()

# %%
uii_test = aa.iet.FT_k_2_r(aa.uii_k_eff_iet)/rs**3

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.r_array*rs, -aa.Zstar/(aa.iet.r_array*rs), color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(npa.iet.r_array*rs, -npa.Zstar/(npa.iet.r_array*rs),color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(aa.iet.r_array*rs, -aa.Uei_iet ,':',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.r_array*rs, -npa.Uei_iet ,':',color=colors[1], label="NPA") # Need to muultiply by some rs power???


axs[0].set_yscale('symlog',linthresh=1e-1)
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$r$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.r_array*rs, aa.uii_r_eff_iet, color=colors[0],linestyle='-', label='AA')
# axs[1].plot(aa.iet.r_array*rs, uii_test, color=colors[0],linestyle='-', label='AA test')
axs[1].plot(aa.iet.r_array*rs, aa.Zstar**2/(aa.iet.r_array*rs ), color=colors[0] ,linestyle='--', label=f'Coulomb Z={aa.Zstar:0.3f}')
axs[1].plot(npa.iet.r_array*rs, npa.uii_r_eff_iet, color=colors[1],linestyle='-', label='NPA')
axs[1].plot(npa.iet.r_array*rs, npa.Zstar**2/(npa.iet.r_array*rs ), color=colors[1],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )

axs[1].set_yscale('symlog',linthresh=1e-3)
axs[1].set_xscale('log')


for ax in axs:
    ax.legend()
plt.tight_layout()

# %%
npa.make_gii()
npa.make_ρi()

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, ax  = plt.subplots()

# Data from community TCCW
upper_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Upper.txt", delim_whitespace=True, header=1)
lower_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Lower.txt", delim_whitespace=True, header=1)

ax.fill_between(lower_data['r/ri'],lower_data['gii'], PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')

# Average atom effective potential to gii
ax.plot(npa.iet.r_array, npa.iet.h_r_matrix[0,0] + 1,'--', label=r"NPA: $u_{ii}^{\rm eff}$", zorder=10)
ax.plot(npa.grid.xs/rs, npa.gii,'k-', label=r"NPA: $u_{ii}^{\rm Y initial}$", zorder=10)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0] + 1, label=r"AA: $u_{ii}^{\rm eff}$", zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("g(r)")
ax.set_xlim(0.7,4)
ax.set_ylim(0,2.5)
ax.legend(fontsize=14)
