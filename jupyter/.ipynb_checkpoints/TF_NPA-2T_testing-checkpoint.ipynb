# %%
import numpy as np
import pandas as pd


from average_atom.core.average_atom import NeutralPseudoAtom as NPA
from average_atom.core.misc import jacobi_relaxation, sor
from average_atom.core.grids import NonUniformGrid
from average_atom.core.physics import ThomasFermi, FermiDirac

from importlib import reload
try:
    reload(physics)
    reload(grids)
    reload(average_atom_geometric)
#     reload(average_atom)
    reload(misc)
except NameError as e:
    from average_atom.core import physics as physics
    from average_atom.core import average_atom as average_atom
    from average_atom.core import misc as misc
    from average_atom.core import grids as grids
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)

import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

import cProfile

plt.rcParams.update({'font.size': 14})
plt.rcParams["figure.figsize"] = (6,4)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14
# Out:
# Error:  name 'physics' is not defined

# %%
# Aluminuma
name='Al'
Z, A = 13, 27 

ρ_solid = 2.699 #g/cc, the solid density of aluminum 
ρ = ρ_solid#8.1 # g/cc
ni_cc = ρ/(A*amu_to_AU*AU_to_g)
ni_AU = ni_cc*invcc_to_AU
rs = rs_from_n(ni_AU)

Ti_eV = 1 
Te_eV = 1

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

# Hydrogen
# name='H'
# Z, A = 1, 1.00784

# Te_eV = 2 
# Te_AU = Te_eV*eV_to_AU

# Ti_eV = 2
# Ti_AU = Ti_eV*eV_to_AU

# ρ_gpercc = 1
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)


####
R = 30*rs
rmin = rs/500
ignore_vxc = True

aa_kwargs = {'initialize':True, 'gradient_correction':None, 'μ_init' : 0.158, 'Zstar_init' : 'More', 'rmin': rmin,'Npoints':300,
             'name':name, 'ignore_vxc':ignore_vxc, 'fixed_Zstar':False, 'iet_R_over_rs':R/rs, 'iet_N_bins':5000, 'use_full_ne_for_nf':False}
npa_kwargs = {'initialize':True, 'gradient_correction':None,'μ_init' : 0.158, 'Zstar_init' : 'More', 'rmin':1e-2 ,'Npoints':2000, 
              'name':name,'ignore_vxc':ignore_vxc, 'fixed_Zstar':False, 'iet_R_over_rs':R/rs, 'iet_N_bins':5000, 'use_full_ne_for_nf':False}

aa = NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aa_kwargs)
npa = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)
# npa_2 = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 1.454e+02
# Exiting status 0, reverting to best index so far: 1213
# Final iter:1214, Total Error: 9.812e-13
# Intialized Potentials and Densities

# %%
# %%time
npa.solve_TF(verbose=True, picard_alpha=0.5, num_10folds_per_rs=0.0, tol=1e-10, nmax = 1000, n_wait_update_Zstar= 200)
npa.set_uii_eff()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	mu =     0.3756, change: 1.7394e-04 (converged=True)
# 	φe Err = -5.148e-14, φe change =  5.440e-01
# 	ne Err =  1.415e-01, ne change =  2.324e-02
# 	Q =  0.000e+00 ->  4.032e-01,
# 	Zstar guess = -2.056e+00. Current Zstar:  2.040e+00 (converged=False)
# 	Change =  3.686e-01
# __________________________________________
# TF Iteration 1
# 	mu =     0.3520, change: 6.2854e-02 (converged=True)
# 	φe Err = -4.876e-14, φe change =  4.680e-02
# 	ne Err =  9.432e-04, ne change =  1.328e-02
# 	Q =  4.032e-01 -> -7.276e-12,
# 	Zstar guess = -2.056e+00. Current Zstar:  2.267e+00 (converged=False)
# 	Change =  1.088e-01
# __________________________________________
# TF Iteration 2
# 	mu =     0.3520, change: 5.5150e-06 (converged=True)
# 	φe Err = -5.834e-14, φe change =  1.877e-02
# 	ne Err =  5.811e-04, ne change =  5.727e-03
# 	Q = -7.276e-12 -> -7.276e-12,
# 	Zstar guess = -2.056e+00. Current Zstar:  2.267e+00 (converged=False)
# 	Change =  1.387e-02
# __________________________________________
# TF Iteration 3
# 	mu =     0.3520, change: 1.0014e-06 (converged=True)
# 	φe Err = -5.366e-14, φe change =  2.083e-02
# 	ne Err =  3.126e-04, ne change =  1.852e-03
# 	Q = -7.276e-12 -> -1.455e-11,
# 	Zstar guess = -2.056e+00. Current Zstar:  2.267e+00 (converged=False)
# 	Change =  1.486e-02
# __________________________________________
# TF Iteration 4
# 	mu =     0.3520, change: 4.6337e-07 (converged=True)
# 	φe Err = -5.494e-14, φe change =  1.423e-02
# 	ne Err =  1.634e-04, ne change =  3.136e-04
# 	Q = -1.455e-11 ->  7.276e-12,
# 	Zstar guess = -2.056e+00. Current Zstar:  2.267e+00 (converged=False)
# 	Change =  9.696e-03
# __________________________________________
# TF Iteration 5
# 	mu =     0.3520, change: 6.6023e-07 (converged=True)
# 	φe Err = -5.409e-14, φe change =  7.588e-03
# 	ne Err =  9.571e-05, ne change =  1.655e-04
# 	Q =  7.276e-12 ->  0.000e+00,
# 	Zstar guess = -2.056e+00. Current Zstar:  2.267e+00 (converged=False)
# 	Change =  5.683e-03
# __________________________________________
# TF Iteration 6
# 	mu =     0.3520, change: 4.4206e-07 (converged=True)
# 	φe Err = -5.220e-14, φe change =  3.311e-03
# 	ne Err =  6.497e-05, ne change =  1.874e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess = -2.056e+00. Current Zstar:  2.267e+00 (converged=False)
# 	Change =  2.861e-03
# __________________________________________
# TF Iteration 7
# 	mu =     0.3520, change: 1.7530e-07 (converged=True)
# 	φe Err = -5.826e-14, φe change =  1.188e-03
# 	ne Err =  4.608e-05, ne change =  1.149e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess = -2.056e+00. Current Zstar:  2.267e+00 (converged=False)
# 	Change =  1.099e-03
# __________________________________________
# TF Iteration 8
# 	mu =     0.3520, change: 2.0794e-08 (converged=True)
# 	φe Err = -6.085e-14, φe change =  4.682e-04
# 	ne Err =  3.228e-05, ne change =  4.948e-05
# 	Q =  0.000e+00 ->  7.276e-12,
# 	Zstar guess = -2.056e+00. Current Zstar:  2.267e+00 (converged=False)
# 	Change =  2.320e-04
# __________________________________________
# TF Iteration 9
# 	mu =     0.3520, change: 1.3476e-07 (converged=True)
# 	φe Err = -5.586e-14, φe change =  3.442e-04
# 	ne Err =  2.244e-05, ne change =  1.309e-05
# 	Q =  7.276e-12 ->  0.000e+00,
# 	Zstar guess = -2.056e+00. Current Zstar:  2.267e+00 (converged=False)
# 	Change =  1.710e-04
# __________________________________________
# TF Iteration 25
# 	mu =     0.3670, change: 1.9430e-07 (converged=True)
# 	φe Err = -5.307e-14, φe change =  2.671e-05
# 	ne Err =  1.156e-06, ne change =  1.232e-06
# 	Q = -7.276e-12 -> -7.276e-12,
# 	Zstar guess =  3.770e+00. Current Zstar:  2.411e+00 (converged=False)
# 	Change =  3.196e-05
# __________________________________________
# TF Iteration 50
# 	mu =     0.3811, change: 1.6594e-07 (converged=True)
# 	φe Err = -5.670e-14, φe change =  1.963e-06
# 	ne Err =  3.584e-02, ne change =  4.127e-06
# 	Q = -1.455e-11 -> -1.174e-01,
# 	Zstar guess =  3.875e+00. Current Zstar:  2.681e+00 (converged=False)
# 	Change =  4.088e-05
# __________________________________________
# TF Iteration 75
# 	mu =     0.4005, change: 1.5480e-07 (converged=True)
# 	φe Err = -5.338e-14, φe change =  2.045e-05
# 	ne Err =  6.244e-07, ne change =  9.841e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.934e+00. Current Zstar:  2.742e+00 (converged=False)
# 	Change =  2.351e-05
# __________________________________________
# TF Iteration 100
# 	mu =     0.4122, change: 1.3281e-07 (converged=True)
# 	φe Err = -5.739e-14, φe change =  1.374e-06
# 	ne Err =  2.787e-02, ne change =  3.587e-06
# 	Q =  0.000e+00 -> -1.020e-01,
# 	Zstar guess =  4.014e+00. Current Zstar:  2.978e+00 (converged=False)
# 	Change =  3.507e-05
# __________________________________________
# TF Iteration 125
# 	mu =     0.4284, change: 1.2276e-07 (converged=True)
# 	φe Err = -5.394e-14, φe change =  1.627e-05
# 	ne Err =  4.753e-07, ne change =  7.968e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.061e+00. Current Zstar:  3.030e+00 (converged=False)
# 	Change =  1.872e-05
# __________________________________________
# TF Iteration 150
# 	mu =     0.4382, change: 1.0532e-07 (converged=True)
# 	φe Err = -5.735e-14, φe change =  1.012e-06
# 	ne Err =  2.198e-02, ne change =  3.086e-06
# 	Q =  0.000e+00 -> -8.767e-02,
# 	Zstar guess =  4.124e+00. Current Zstar:  3.233e+00 (converged=False)
# 	Change =  2.990e-05
# __________________________________________
# TF Iteration 175
# 	mu =     0.4517, change: 9.6692e-08 (converged=True)
# 	φe Err = -5.827e-14, φe change =  1.301e-05
# 	ne Err =  3.680e-07, ne change =  6.464e-07
# 	Q =  0.000e+00 ->  1.455e-11,
# 	Zstar guess =  4.161e+00. Current Zstar:  3.278e+00 (converged=False)
# 	Change =  1.497e-05
# __________________________________________
# TF Iteration 200
# 	mu =     0.4599, change: 8.2914e-08 (converged=True)
# 	φe Err = -6.547e-14, φe change =  7.768e-07
# 	ne Err =  1.752e-02, ne change =  2.636e-06
# 	Q = -1.455e-11 -> -7.483e-02,
# 	Zstar guess =  4.211e+00. Current Zstar:  3.451e+00 (converged=False)
# 	Change =  2.538e-05
# __________________________________________
# TF Iteration 225
# 	mu =     0.5506, change: 2.2648e-03 (converged=True)
# 	φe Err = -6.176e-14, φe change =  4.567e-05
# 	ne Err =  1.338e-06, ne change =  4.489e-07
# 	Q =  2.910e-11 -> -1.455e-11,
# 	Zstar guess =  4.532e+00. Current Zstar:  4.399e+00 (converged=False)
# 	Change =  1.652e-03
# __________________________________________
# TF Iteration 250
# 	mu =     0.5648, change: 3.5353e-04 (converged=True)
# 	φe Err = -6.883e-14, φe change =  6.986e-06
# 	ne Err =  3.347e-04, ne change =  1.308e-07
# 	Q =  1.455e-11 -> -1.917e-03,
# 	Zstar guess =  4.591e+00. Current Zstar:  4.572e+00 (converged=False)
# 	Change =  2.586e-04
# __________________________________________
# TF Iteration 275
# 	mu =     0.5671, change: 5.4389e-05 (converged=True)
# 	φe Err = -6.675e-14, φe change =  1.118e-06
# 	ne Err =  3.810e-08, ne change =  1.111e-08
# 	Q =  0.000e+00 -> -1.455e-11,
# 	Zstar guess =  4.600e+00. Current Zstar:  4.597e+00 (converged=False)
# 	Change =  3.975e-05
# __________________________________________
# TF Iteration 300
# 	mu =     0.5674, change: 8.7509e-06 (converged=True)
# 	φe Err = -7.018e-14, φe change =  1.735e-07
# 	ne Err =  8.248e-06, ne change =  3.235e-09
# 	Q = -1.455e-11 -> -4.755e-05,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.601e+00 (converged=False)
# 	Change =  6.414e-06
# __________________________________________
# TF Iteration 325
# 	mu =     0.5675, change: 1.4613e-06 (converged=True)
# 	φe Err = -6.468e-14, φe change =  3.019e-08
# 	ne Err =  1.519e-08, ne change =  2.794e-10
# 	Q = -1.455e-11 ->  0.000e+00,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=False)
# 	Change =  1.076e-06
# __________________________________________
# TF Iteration 350
# 	mu =     0.5675, change: 4.0011e-08 (converged=True)
# 	φe Err = -5.770e-14, φe change =  3.573e-09
# 	ne Err =  8.045e-07, ne change =  1.558e-10
# 	Q = -1.455e-11 -> -4.644e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  3.851e-08
# __________________________________________
# TF Iteration 375
# 	mu =     0.5675, change: 3.4253e-08 (converged=True)
# 	φe Err = -6.065e-14, φe change =  3.243e-09
# 	ne Err =  1.112e-08, ne change =  3.182e-11
# 	Q = -1.455e-11 -> -1.455e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  3.241e-08
# __________________________________________
# TF Iteration 400
# 	mu =     0.5675, change: 2.9323e-08 (converged=True)
# 	φe Err = -6.699e-14, φe change =  2.619e-09
# 	ne Err =  9.001e-07, ne change =  1.773e-10
# 	Q =  0.000e+00 -> -5.194e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  2.883e-08
# __________________________________________
# TF Iteration 425
# 	mu =     0.5675, change: 2.5103e-08 (converged=True)
# 	φe Err = -6.532e-14, φe change =  2.456e-09
# 	ne Err =  8.150e-09, ne change =  3.301e-11
# 	Q = -1.455e-11 -> -1.455e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  2.396e-08
# __________________________________________
# TF Iteration 450
# 	mu =     0.5675, change: 2.1490e-08 (converged=True)
# 	φe Err = -7.032e-14, φe change =  1.917e-09
# 	ne Err =  9.179e-07, ne change =  1.825e-10
# 	Q = -1.455e-11 -> -5.295e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  2.162e-08
# __________________________________________
# TF Iteration 475
# 	mu =     0.5675, change: 1.8397e-08 (converged=True)
# 	φe Err = -6.412e-14, φe change =  1.875e-09
# 	ne Err =  5.973e-09, ne change =  3.230e-11
# 	Q = -2.910e-11 -> -1.455e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  1.773e-08
# __________________________________________
# TF Iteration 500
# 	mu =     0.5675, change: 1.5749e-08 (converged=True)
# 	φe Err = -6.753e-14, φe change =  1.404e-09
# 	ne Err =  8.875e-07, ne change =  1.774e-10
# 	Q =  0.000e+00 -> -5.119e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  1.626e-08
# __________________________________________
# TF Iteration 525
# 	mu =     0.5675, change: 1.3483e-08 (converged=True)
# 	φe Err = -6.184e-14, φe change =  1.444e-09
# 	ne Err =  4.378e-09, ne change =  3.045e-11
# 	Q = -1.455e-11 -> -1.455e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  1.314e-08
# __________________________________________
# TF Iteration 550
# 	mu =     0.5675, change: 1.1542e-08 (converged=True)
# 	φe Err = -6.182e-14, φe change =  1.027e-09
# 	ne Err =  8.291e-07, ne change =  1.664e-10
# 	Q =  0.000e+00 -> -4.782e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  1.226e-08
# __________________________________________
# TF Iteration 575
# 	mu =     0.5675, change: 9.8813e-09 (converged=True)
# 	φe Err = -6.581e-14, φe change =  1.123e-09
# 	ne Err =  3.208e-09, ne change =  2.797e-11
# 	Q =  0.000e+00 -> -1.455e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  9.752e-09
# __________________________________________
# TF Iteration 600
# 	mu =     0.5675, change: 8.4592e-09 (converged=True)
# 	φe Err = -5.718e-14, φe change =  7.521e-10
# 	ne Err =  7.562e-07, ne change =  1.521e-10
# 	Q = -2.910e-11 -> -4.361e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  9.266e-09
# __________________________________________
# TF Iteration 625
# 	mu =     0.5675, change: 7.2418e-09 (converged=True)
# 	φe Err = -6.276e-14, φe change =  8.818e-10
# 	ne Err =  2.351e-09, ne change =  2.520e-11
# 	Q = -1.455e-11 -> -1.455e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  7.247e-09
# __________________________________________
# TF Iteration 650
# 	mu =     0.5675, change: 6.1995e-09 (converged=True)
# 	φe Err = -6.050e-14, φe change =  5.505e-10
# 	ne Err =  6.778e-07, ne change =  1.366e-10
# 	Q =  0.000e+00 -> -3.909e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  7.027e-09
# __________________________________________
# TF Iteration 675
# 	mu =     0.5675, change: 5.3074e-09 (converged=True)
# 	φe Err = -7.016e-14, φe change =  6.989e-10
# 	ne Err =  1.723e-09, ne change =  2.237e-11
# 	Q = -1.455e-11 ->  0.000e+00,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  5.394e-09
# __________________________________________
# TF Iteration 700
# 	mu =     0.5675, change: 4.5435e-09 (converged=True)
# 	φe Err = -6.510e-14, φe change =  4.029e-10
# 	ne Err =  5.995e-07, ne change =  1.210e-10
# 	Q = -1.455e-11 -> -3.457e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  5.347e-09
# __________________________________________
# TF Iteration 725
# 	mu =     0.5675, change: 3.8897e-09 (converged=True)
# 	φe Err = -5.883e-14, φe change =  5.590e-10
# 	ne Err =  1.263e-09, ne change =  1.965e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  4.022e-09
# __________________________________________
# TF Iteration 750
# 	mu =     0.5675, change: 3.3299e-09 (converged=True)
# 	φe Err = -6.344e-14, φe change =  2.949e-10
# 	ne Err =  5.248e-07, ne change =  1.061e-10
# 	Q =  0.000e+00 -> -3.026e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  4.082e-09
# __________________________________________
# TF Iteration 775
# 	mu =     0.5675, change: 2.8507e-09 (converged=True)
# 	φe Err = -6.309e-14, φe change =  4.507e-10
# 	ne Err =  9.256e-10, ne change =  1.712e-11
# 	Q = -1.455e-11 -> -2.910e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  3.005e-09
# __________________________________________
# TF Iteration 800
# 	mu =     0.5675, change: 2.4404e-09 (converged=True)
# 	φe Err = -5.841e-14, φe change =  2.159e-10
# 	ne Err =  4.557e-07, ne change =  9.222e-11
# 	Q = -1.455e-11 -> -2.628e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  3.128e-09
# __________________________________________
# TF Iteration 825
# 	mu =     0.5675, change: 2.0893e-09 (converged=True)
# 	φe Err = -6.134e-14, φe change =  3.659e-10
# 	ne Err =  6.783e-10, ne change =  1.480e-11
# 	Q =  1.455e-11 ->  0.000e+00,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  2.250e-09
# __________________________________________
# TF Iteration 850
# 	mu =     0.5675, change: 1.7886e-09 (converged=True)
# 	φe Err = -6.034e-14, φe change =  1.581e-10
# 	ne Err =  3.931e-07, ne change =  7.961e-11
# 	Q =  0.000e+00 -> -2.267e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  2.405e-09
# __________________________________________
# TF Iteration 875
# 	mu =     0.5675, change: 1.5312e-09 (converged=True)
# 	φe Err = -5.974e-14, φe change =  2.988e-10
# 	ne Err =  4.972e-10, ne change =  1.272e-11
# 	Q =  0.000e+00 -> -1.455e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  1.689e-09
# __________________________________________
# TF Iteration 900
# 	mu =     0.5675, change: 1.3108e-09 (converged=True)
# 	φe Err = -6.576e-14, φe change =  1.158e-10
# 	ne Err =  3.373e-07, ne change =  6.835e-11
# 	Q =  0.000e+00 -> -1.945e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  1.857e-09
# __________________________________________
# TF Iteration 925
# 	mu =     0.5675, change: 1.1222e-09 (converged=True)
# 	φe Err = -6.654e-14, φe change =  2.451e-10
# 	ne Err =  3.644e-10, ne change =  1.088e-11
# 	Q = -1.455e-11 -> -1.455e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  1.271e-09
# __________________________________________
# TF Iteration 950
# 	mu =     0.5675, change: 9.6070e-10 (converged=True)
# 	φe Err = -6.083e-14, φe change =  8.483e-11
# 	ne Err =  2.881e-07, ne change =  5.841e-11
# 	Q =  0.000e+00 -> -1.661e-06,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  1.439e-09
# __________________________________________
# TF Iteration 975
# 	mu =     0.5675, change: 8.2248e-10 (converged=True)
# 	φe Err = -6.476e-14, φe change =  2.019e-10
# 	ne Err =  2.671e-10, ne change =  9.271e-12
# 	Q =  0.000e+00 -> -1.455e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  9.591e-10
# __________________________________________
# TF Iteration 1000
# 	mu =     0.5675, change: 7.0849e-10 (converged=True)
# 	φe Err = -6.645e-14, φe change =  6.374e-11
# 	ne Err =  2.300e-10, ne change =  6.737e-13
# 	Q =  0.000e+00 -> -1.455e-11,
# 	Zstar guess =  4.602e+00. Current Zstar:  4.602e+00 (converged=True)
# 	Change =  6.444e-10
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 4.542e+02
# Exiting status 0, reverting to best index so far: 5214
# Final iter:5215, Total Error: 9.951e-13
# CPU times: user 5min 49s, sys: 1min 40s, total: 7min 29s
# Wall time: 4min

# %%
limiting_μ = npa.TF.η_interp(npa.ne_bar)*npa.Te
print(f"Final μ = {npa.μ:0.5e}, vs. expected r->infinity μ={limiting_μ:0.5e}, Err={npa.μ/limiting_μ-1:0.3e}")
# Final μ = 5.66492e-01, vs. expected r->infinity μ=5.66507e-01, Err=-2.664e-05
# Out:
# Final μ = 5.67513e-01, vs. expected r->infinity μ=5.67518e-01, Err=-1.006e-05

# %%
fig, ax = plt.subplots()

ax.plot(npa.iet.r_array, npa.iet.h_r_matrix[0,0])
ax.set_yscale('symlog', linthresh=1e-10)

# %%
# %%time
from scipy.interpolate import interp1d
aa.solve_TF(verbose=True, picard_alpha=0.2, num_10folds_per_rs=0.0, tol=1e-7)
aa.set_uii_eff()
aa.iet.HNC_solve(iters_to_wait=1e5, alpha_Picard=1e-2, tol=1e-12, verbose=False, num_iterations=1e5)
aa.gii = interp1d(aa.iet.r_array*aa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(aa.grid.xs)
# npa_2.gii = interp1d(npa.iet.r_array*npa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(npa.grid.xs)
aa.make_ρi()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	mu =     0.0914, change: 6.8132e+00 (converged=False)
# 	φe Err = -1.608e-13, φe change =  1.107e-02
# 	ne Err =  9.319e-02, ne change =  1.222e-03
# 	Q =  0.000e+00 ->  1.119e+00,
# 	Zstar guess =  2.083e+00. Current Zstar:  2.675e+00 (converged=False)
# 	Change =  1.165e+00
# __________________________________________
# TF Iteration 1
# 	mu =     0.1271, change: 3.8973e-01 (converged=False)
# 	φe Err = -1.779e-13, φe change =  8.925e-03
# 	ne Err =  6.664e-02, ne change =  8.737e-04
# 	Q =  1.119e+00 ->  9.801e-01,
# 	Zstar guess =  1.841e+00. Current Zstar:  2.508e+00 (converged=False)
# 	Change =  2.354e-01
# __________________________________________
# TF Iteration 2
# 	mu =     0.1571, change: 2.3649e-01 (converged=False)
# 	φe Err = -2.086e-13, φe change =  6.554e-03
# 	ne Err =  4.814e-02, ne change =  6.318e-04
# 	Q =  9.801e-01 ->  8.564e-01,
# 	Zstar guess =  1.889e+00. Current Zstar:  2.384e+00 (converged=False)
# 	Change =  1.542e-01
# __________________________________________
# TF Iteration 3
# 	mu =     0.1831, change: 1.6552e-01 (converged=False)
# 	φe Err = -1.600e-13, φe change =  4.602e-03
# 	ne Err =  3.604e-02, ne change =  4.578e-04
# 	Q =  8.564e-01 ->  7.481e-01,
# 	Zstar guess =  2.087e+00. Current Zstar:  2.325e+00 (converged=False)
# 	Change =  1.115e-01
# __________________________________________
# TF Iteration 4
# 	mu =     0.2061, change: 1.2560e-01 (converged=False)
# 	φe Err = -1.693e-13, φe change =  3.088e-03
# 	ne Err =  2.860e-02, ne change =  3.334e-04
# 	Q =  7.481e-01 ->  6.544e-01,
# 	Zstar guess =  2.298e+00. Current Zstar:  2.320e+00 (converged=False)
# 	Change =  8.567e-02
# __________________________________________
# TF Iteration 5
# 	mu =     0.2061, change: 8.2332e-05 (converged=True)
# 	φe Err = -1.557e-13, φe change =  1.980e-03
# 	ne Err =  1.808e-02, ne change =  2.450e-04
# 	Q =  6.544e-01 ->  5.739e-01,
# 	Zstar guess =  2.493e+00. Current Zstar:  2.354e+00 (converged=False)
# 	Change =  1.230e-03
# __________________________________________
# TF Iteration 6
# 	mu =     0.2061, change: 0.0000e+00 (converged=True)
# 	φe Err = -2.233e-13, φe change =  1.231e-03
# 	ne Err =  1.283e-02, ne change =  1.857e-04
# 	Q =  5.739e-01 ->  5.542e-01,
# 	Zstar guess =  2.668e+00. Current Zstar:  2.417e+00 (converged=False)
# 	Change =  4.229e-04
# __________________________________________
# TF Iteration 7
# 	mu =     0.2061, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.996e-13, φe change =  8.137e-04
# 	ne Err =  1.163e-02, ne change =  1.427e-04
# 	Q =  5.542e-01 ->  5.767e-01,
# 	Zstar guess =  2.819e+00. Current Zstar:  2.497e+00 (converged=False)
# 	Change =  4.259e-04
# __________________________________________
# TF Iteration 8
# 	mu =     0.2061, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.966e-13, φe change =  5.856e-04
# 	ne Err =  1.201e-02, ne change =  1.108e-04
# 	Q =  5.767e-01 ->  6.261e-01,
# 	Zstar guess =  2.942e+00. Current Zstar:  2.586e+00 (converged=False)
# 	Change =  5.077e-04
# __________________________________________
# TF Iteration 9
# 	mu =     0.2061, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.540e-13, φe change =  4.407e-04
# 	ne Err =  1.230e-02, ne change =  8.661e-05
# 	Q =  6.261e-01 ->  6.902e-01,
# 	Zstar guess =  3.038e+00. Current Zstar:  2.677e+00 (converged=False)
# 	Change =  4.696e-04
# __________________________________________
# TF Iteration 25
# 	mu =     0.3349, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.693e-13, φe change =  1.774e-04
# 	ne Err =  3.697e-03, ne change =  2.151e-06
# 	Q =  2.209e-01 ->  1.999e-01,
# 	Zstar guess =  3.570e+00. Current Zstar:  3.477e+00 (converged=False)
# 	Change =  2.330e-04
# __________________________________________
# TF Iteration 50
# 	mu =     0.3634, change: 9.8163e-03 (converged=True)
# 	φe Err = -1.896e-13, φe change =  6.020e-06
# 	ne Err =  1.377e-03, ne change =  2.449e-07
# 	Q =  3.974e-02 ->  4.076e-02,
# 	Zstar guess =  3.737e+00. Current Zstar:  3.725e+00 (converged=False)
# 	Change =  6.915e-03
# __________________________________________
# TF Iteration 75
# 	mu =     0.3658, change: 0.0000e+00 (converged=True)
# 	φe Err = -2.010e-13, φe change =  3.058e-06
# 	ne Err =  6.667e-05, ne change =  1.593e-08
# 	Q =  4.085e-03 ->  3.753e-03,
# 	Zstar guess =  3.758e+00. Current Zstar:  3.756e+00 (converged=False)
# 	Change =  4.029e-06
# __________________________________________
# TF Iteration 100
# 	mu =     0.3663, change: 1.7806e-04 (converged=True)
# 	φe Err = -2.317e-13, φe change =  1.061e-07
# 	ne Err =  2.551e-05, ne change =  4.321e-09
# 	Q =  7.364e-04 ->  7.550e-04,
# 	Zstar guess =  3.761e+00. Current Zstar:  3.761e+00 (converged=False)
# 	Change =  1.260e-04
# __________________________________________
# TF Iteration 125
# 	mu =     0.3663, change: 0.0000e+00 (converged=True)
# 	φe Err = -2.126e-13, φe change =  5.623e-08
# 	ne Err =  1.227e-06, ne change =  2.914e-10
# 	Q =  7.509e-05 ->  6.898e-05,
# 	Zstar guess =  3.761e+00. Current Zstar:  3.761e+00 (converged=False)
# 	Change =  7.407e-08
# __________________________________________
# TF Iteration 150
# 	mu =     0.3663, change: 3.2686e-06 (converged=True)
# 	φe Err = -2.246e-13, φe change =  1.948e-09
# 	ne Err =  4.685e-07, ne change =  7.938e-11
# 	Q =  1.352e-05 ->  1.386e-05,
# 	Zstar guess =  3.761e+00. Current Zstar:  3.761e+00 (converged=False)
# 	Change =  2.314e-06
# __________________________________________
# TF Iteration 157
# 	mu =     0.3663, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.909e-13, φe change =  4.216e-09
# 	ne Err =  8.481e-08, ne change =  4.427e-11
# 	Q =  6.267e-06 ->  5.991e-06,
# 	Zstar guess =  3.761e+00. Current Zstar:  3.761e+00 (converged=False)
# 	Change =  5.660e-09
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 3.156e+02
# Exiting status 0, reverting to best index so far: 4369
# Final iter:4370, Total Error: 9.997e-13
# 0: Initial condition Total Error: 9.997e-13
# Exiting status 0, reverting to best index so far: 1
# Final iter:2, Total Error: 9.994e-13

# %%
fig, axs  = plt.subplots(1,2,figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

short_distance_weight = np.exp(-(0.08*npa.kTF*npa.grid.xs)**4)
for ax in axs:
    # ax.plot(npa.iet.r_array*rs, npa.iet.h_r_matrix[0,0], color=colors[0], label=r"NPA: $u_Y$")
    ax.plot(npa.grid.xs, npa.gii-1, color=colors[0], label=r"NPA: $u_Y$")
    # ax.plot(npa_2.grid.xs, npa_2.gii-1,'--', color=colors[0], label=r"NPA: $u_{AA}$",zorder=10)
    ax.plot(aa.iet.r_array*rs, aa.iet.h_r_matrix[0,0],color=colors[1],  label=r"$u_{AA}$")
    # ax.plot(npa.grid.xs, short_distance_weight*(npa.gii-1),'--',color=colors[3],  label=r"$u_Y$ damped")
    			

    # ax.plot(aa.grid.xs, aa.gii-1,'--',color=colors[3],  label=r"$u_Y$")
    ax.axvline(npa.iet.r_array[-1]*rs,color='k')
    
ax = axs[0]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xlim(0,3*rs)

ax = axs[1]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xscale('log')
ax.set_xlim(0.5,None)
ax.set_yscale('symlog', linthresh=1e-6)
for ax in axs:
    ax.legend(fontsize=12)
    ax.tick_params(labelsize=12)


plt.tight_layout()

# %% [markdown]
# ### Thomas Fermi (TF)

# %%
# 2000: -5.419e-02, 4000: 1.592e-02

# %%
# %%time
npa_2.solve_TF(verbose=True, picard_alpha=0.2, num_10folds_per_rs=0.5, tol=1e-7, nmax = 1000, n_wait_update_Zstar= 200)
npa_2.set_uii_eff()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1
#
# NameError: name 'npa_2' is not defined

# %% [markdown]
# ### EOS

# %%
def get_Eii(aa):
    βVeff = aa.get_βVeff(aa.φe, aa.ne, aa.ne_bar)
    η = aa.μ/aa.Te - βVeff
    βU = aa.grid.integrate_f(βVeff*aa.ne)
    I_onehalf = FermiDirac.Ionehalf(η)
    I_threehalf = FermiDirac.Ithreehalf(η)
    
    βK = (2*aa.Te)**1.5/π**2 * aa.grid.integrate_f( η*I_onehalf - 2/3 * I_threehalf   )
    return βU, βK, βU + βK

def get_ETF(aa):
    
def get_Exc(aa):
    aa.vxc

def get_E_Hartree(aa):
    
    
    

# get_E(aa_tfd), get_E(npa_tfd)

# %%
def get_P(aa):
    aa_old_βu = aa.iet.βu_r_matrix.copy()
    # aa.iet.set_βu_matrix( np.array([[1/aa.Ti * aa.Zstar**2/(aa.iet.r_array*aa.rs) ]] ))
    P_id_hnc, P_ex_hnc, P_hnc = aa.iet.ideal_pressure(), aa.iet.excess_pressure(), aa.iet.total_pressure()
    P_id_AU, P_ex_AU, P_AU  = P_id_hnc/rs**3, P_ex_hnc/rs**3, P_hnc/rs**3
    aa.iet.set_βu_matrix(aa_old_βu)
    return P_id_AU, P_ex_AU, P_AU

aa_P_ions = get_P(aa_tfd)
aa_P_ions[1]/aa_P_ions[0]

# %% [markdown]
# ## Comparison

# %%
npa.make_plots()
# Out:
# (<Figure size 4000x1600 with 2 Axes>,
#  array([<Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$\\phi$ [A.U.]'>,
#         <Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$n$ [A.U.]'>],
#        dtype=object))

# %%
fig, ax = plt.subplots()

# ax.plot(npa.φe_list[0] + npa.φion)#/npa.φe_init
ax.plot(npa.get_φe(npa.ρi - npa.ne)[0] + npa.φion)#/npa.φe_init
ax.plot(npa.φe_init + npa.φion,'--')#/npa.φe_init
ax.set_yscale('symlog', linthresh=1e-8)

# %%
def plot_convergence(aa, axs=None):
    if axs is None:
        fig, axs = plt.subplots(ncols=3,figsize=(18,5),facecolor='w', dpi=200)
    
    # ELectric potential
    slice_by_num = 10
    ax = axs[0]
    colors = plt.cm.coolwarm(np.linspace(0, 1,len(aa.φe_list[::slice_by_num])))
    for i, φe in enumerate(aa.φe_list[::slice_by_num]):
        if i ==0 or i==len(aa.φe_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, (φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\phi_e$'.format(i))
        else:
            ax.plot(aa.grid.xs, φe+aa.φion,linewidth=1,color=colors[i],alpha=1)
    # ax.plot(aa.grid.xs, aa.get_φe( (aa.ρi - aa.ne) )[0] + aa.φion  ,'k:', label=r'$\phi$ check') 
    ax.set_yscale('symlog',linthresh=1e-10)
    ax.plot(aa.grid.xs, aa.φe_init + aa.φion, 'k:')

    # number density
    ax = axs[1]
    for i, (ne, ρi) in enumerate(zip(aa.ne_list[::slice_by_num], aa.ρi_list[::slice_by_num])):
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            if i==0: 
                ne_bar_0 = ne[-1]
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1, label=r'$Q(r)$'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, -ne + 0*ρi + ne[-1],linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ne_bar_0,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ρi[-1] + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # pass
        else:
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1)
            # print(ne[-1]-ne_bar_0)
            # ax.plot(aa.grid.xs, -ne + ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ne + ne_bar_0 ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ρi[-1]+ ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            pass
    # for i in range(int(aa.R/aa.rs)):
    #     ax.axvline(aa.rs*i, color='k', linestyle='--', alpha=0.2)
    # ax.set_xscale('log')
    # ax.plot(aa.grid.xs, (aa.gii)-1, 'k:')
    ax.set_yscale('symlog',linthresh=1e-4)

            
    # number density
    ax = axs[2]
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        ne_TF = aa.get_ne_TF(φe, ne, μ, ne_bar)
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            # ax.plot(aa.grid.xs, ne/ne_TF-1,linewidth=1,color=colors[i],alpha=1, label=r'$n_e/n_e^{{TF}}-1$, iter: {0}'.format(i))
            ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1, label=r'$n_e^{{TF}} - n_e^{{TF}}[-1]$, iter: {0}'.format(i*slice_by_num))
            ax.plot(aa.grid.xs, ne-ne[-1],linewidth=1,color=colors[i],linestyle='--',alpha=1, label=r'$n_e - n_e[-1]$, iter: {0}'.format(i))
            # pass
        else:
            # ax.plot(aa.grid.xs, ne/ne_TF-1, linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            ax.plot(aa.grid.xs, ne-ne[-1], linewidth=1,linestyle='--',color=colors[i],alpha=0.5)
            ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1)

            # print(np.abs(ne/ne_TF-1))
            # print(np.where( np.abs(ne/ne_TF-1)>1e-6 ))
            # print(aa.grid.xs[np.where( np.abs(ne/ne_TF-1) > 1e-8)][0]/10, 1/(np.sum(aa.grid.xs*np.abs(ne/ne_TF-1))/np.sum(np.abs(ne/ne_TF-1))))
    # ax.set_ylim()
    # ax.plot(aa.grid.xs, npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar) - npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar)[-1] , 'k:')
    ax.plot(aa.grid.xs, aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar) - aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar)[-1] , 'k:')
    ax.set_yscale('symlog',linthresh=1e-10)
    # ax.set_xscale('log')
    for ax in axs:
        ax.legend(fontsize=14)
        ax.tick_params(labelsize=14)
        ax.plot(aa.grid.xs, np.zeros_like(aa.ne),'k', alpha=0.2)
    plt.tight_layout()
# plot_convergence(aa)
plot_convergence(npa)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

petrov = pd.read_csv("../data/GP_TFDW_Al_1eV_solid.dat",header=0, comment='#', delim_whitespace=True)

def compare_aa(aa_list, axs=None, name=''):
    eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
    if axs is None:
        fig, axs = plt.subplots(ncols=2,figsize=(20,8),facecolor='w')

    # Density * 4pi r^2 plot
    for ax in axs:
        for aa, color in zip( aa_list, colors):
            factor = 4*np.pi*aa.grid.xs**2
            ax.plot(np.array(petrov['r/R'])*rs, 4*π*(np.array(petrov['r/R'])*rs)**2*(petrov['ne']/m_to_AU**3), 'k--', label="Petrov AA")
            ax.plot(aa.grid.xs, aa.ne*factor ,'-',color=color, label=r'$n_e$: '+ name)
            ax.plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
            ax.plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
            if aa.rs != aa.R:
                ax.plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
                ax.plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)
        # axs[0].plot(aa.grid.xs, aa.δn_f*factor,'--',color='g',  label=r'$n_e^{sc}$: ' + name)


    axs[0].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[0].set_ylim(0, 1e3)
    axs[0].set_yscale('symlog',linthresh=1e-1)
    axs[0].set_xscale('log')
    axs[0].set_xlim(aa.grid.xs[0],aa.grid.xs[-1])

    axs[1].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[1].set_ylim(0, 13)
    axs[1].set_xlim(0, np.min([aa.R,1.3*aa.rs]))

        
    for ax in axs:
        ax.set_xlabel(r'$|r-R_1|$ [A.U.]',fontsize=20)
        ax.legend(loc="upper right",fontsize=20,labelspacing = 0.1)
        ax.tick_params(labelsize=20)
        ax.grid(which='both',alpha=0.4)

        # make textbox
        text = ("{0}\n".format(aa.name)+ 
            r"$r_s$ = " + "{0},    ".format(np.round(aa.rs,2)) +
            r"$R_{NPA}$ = " + "{0}\n".format(aa.R)  +
                r"$T_e$ = " + "{0} [A.U.] = {1} eV\n".format(np.round(aa.Te,2),np.round(aa.Te/eV,2)) + r"$\mu$ = " + "{0} [A.U.]\n".format(np.round(aa.μ,2)) +
                r"$Z^\ast = $" + "{0}".format(np.round(aa.Zstar,2))  )

        props = dict(boxstyle='round', facecolor='w')
        ax.text(0.25,0.95, text, fontsize=15, transform=ax.transAxes, verticalalignment='top', bbox=props)

    plt.tight_layout()
    name = "NPA_densities_{0}_rs{1}_{2}eV_R{3}.png".format(aa.name, np.round(aa.rs,2), np.round(aa.Te/eV,2) ,np.round(aa.R))
    plt.savefig("/home/zach/plasma/atomic_forces/average_atom/media/" + name, dpi=300, bbox_inches='tight',facecolor="w")
    
    
    return axs


axs = compare_aa([aa, npa])#, npa_2])
for ax in axs:
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), fontsize=16, loc='upper right')
# axs[1].set_ylim(1e-5,1e3)

# %% [markdown]
# ## HNC and FT

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.k_array/rs, aa.Uei_iet_k*(aa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.k_array/rs, npa.Uei_iet_k*(npa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[1], label="NPA") # Need to muultiply by some rs power???
axs[0].plot(aa.iet.k_array/rs, aa.Zstar*np.ones_like(aa.iet.k_array),':', color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(npa.iet.k_array/rs, npa.Zstar*np.ones_like(npa.iet.k_array),':',color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")

# axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$k$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.k_array/rs, aa.uii_k_eff_iet,'-', color=colors[0], label="AA")
axs[1].plot(aa.iet.k_array/rs, 4*π*aa.Zstar**2/(aa.iet.k_array/rs)**2,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
axs[1].plot(aa.iet.k_array/rs, 1/(aa.iet.k_array**2/rs**2/(4*π*aa.Zstar**2) + 1/aa.uii_k_eff_iet[0] ),'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, uii_test,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))


# axs[1].plot(npa.iet.k_array/rs, npa.uii_k_eff_iet,color=colors[1], label="NPA")
axs[1].plot(npa.iet.k_array/rs, 4*π*npa.Zstar**2/(npa.iet.k_array/rs)**2,'--', color=colors[1], label=r"NPA: $u_{{ii}}^0$, Z={0:0.3f}".format(npa.Zstar))



axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_ylim(0,1e5)
axs[1].set_xscale('log')
axs[1].set_xlabel(r"$k$ [au]")
axs[1].set_ylabel(r"$u^{\rm eff}_{ii}$ [au]")


for ax in axs:
    ax.legend(fontsize=12)
plt.tight_layout()

# %%
uii_test = aa.iet.FT_k_2_r(aa.uii_k_eff_iet)/rs**3

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.r_array*rs, -aa.Zstar/(aa.iet.r_array*rs), color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(aa.iet.r_array*rs, -aa.Uei_iet ,':',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.r_array*rs, -npa.Zstar/(npa.iet.r_array*rs),color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(npa.iet.r_array*rs, -npa.Uei_iet ,':',color=colors[1], label="NPA") # Need to muultiply by some rs power???
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Zstar/(npa.iet.r_array*rs),color=colors[2], label=f"Coulomb, Z={npa.Zstar:0.3f}")
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Uei_iet ,':',color=colors[2], label=r"NPA: $g_{AA}$") # Need to muultiply by some rs power???



axs[0].set_yscale('symlog',linthresh=1e-1)
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$r$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.r_array*rs, 1/aa.Te * aa.uii_r_eff_iet, color=colors[0],linestyle='-', label='AA')
axs[1].plot(aa.iet.r_array*rs, 1/aa.Te *aa.Zstar**2/(aa.iet.r_array*rs ), color=colors[0] ,linestyle='--', label=f'Coulomb Z={aa.Zstar:0.3f}')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.uii_r_eff_iet, color=colors[1],linestyle='-', label='NPA')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.Zstar**2/(npa.iet.r_array*rs ), color=colors[1],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )
# axs[1].plot(npa_2.iet.r_array*rs, npa_2.uii_r_eff_iet, color=colors[2],linestyle='-', label=r"NPA: $g_{AA}$")
# axs[1].plot(npa_2.iet.r_array*rs, npa_2.Zstar**2/(npa_2.iet.r_array*rs ), color=colors[2],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )

axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_xscale('log')
axs[1].set_ylabel(r"$\beta U_{ii}$ [au]")
axs[1].set_xlabel(r"$r$ [au]")
axs[1].set_xlim(1,None)


for ax in axs:
    ax.legend(fontsize=10)
plt.tight_layout()

# %%
npa.make_gii()
npa.make_ρi()
# npa_2.make_gii()
# npa_2.make_ρi()
# Out:
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 9.951e-13
# Exiting status 0, reverting to best index so far: 1
# Final iter:2, Total Error: 9.891e-13

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, axs  = plt.subplots(1,2, figsize=(8,4))

# Data from community TCCW
upper_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Upper.txt", delim_whitespace=True, header=1)
lower_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Lower.txt", delim_whitespace=True, header=1)

ax = axs[0]
ax.fill_between(lower_data['r/ri'],lower_data['gii'], PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')

# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0] + 1, label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("g(r)")
ax.set_xlim(0.7,3)
# ax.set_ylim(0,2)
ax.legend(fontsize=10)

ax = axs[1]
ax.fill_between(lower_data['r/ri'],lower_data['gii']-1, PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')
# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii-1, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii-1, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0], label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("h(r)")
ax.set_xlim(0.7,10)
ax.set_ylim(0,2.5)
ax.set_yscale('symlog', linthresh=1e-4)

ax.legend(fontsize=8, loc='upper right')
plt.tight_layout()
