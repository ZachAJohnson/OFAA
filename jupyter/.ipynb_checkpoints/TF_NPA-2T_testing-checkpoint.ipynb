# %%
import numpy as np
import pandas as pd


from average_atom.core.average_atom import NeutralPseudoAtom as NPA
from average_atom.core.misc import jacobi_relaxation, sor
from average_atom.core.grids import NonUniformGrid
from average_atom.core.physics import ThomasFermi, FermiDirac

from importlib import reload
try:
    reload(physics)
    reload(grids)
    reload(average_atom_geometric)
#     reload(average_atom)
    reload(misc)
except NameError as e:
    from average_atom.core import physics as physics
    from average_atom.core import average_atom as average_atom
    from average_atom.core import misc as misc
    from average_atom.core import grids as grids
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)

import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

import cProfile

plt.rcParams.update({'font.size': 14})
plt.rcParams["figure.figsize"] = (6,4)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14
# Out:
# Error:  name 'physics' is not defined
# ModuleNotFoundError: No module named 'mendeleev'

# %%
# Aluminuma
name='Al'
Z, A = 13, 27 

Ti_eV = 1 
Te_eV = 1

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

rs = 2.985767276908717


# Hydrogen
# name='H'
# Z, A = 1, 1.00784

# Te_eV = 2 
# Te_AU = Te_eV*eV_to_AU

# Ti_eV = 2
# Ti_AU = Ti_eV*eV_to_AU

# ρ_gpercc = 1
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)


####
R = 10*rs

aa_kwargs = {'initialize':True, 'gradient_correction':None, 'μ_init' : 0.158, 'Zstar_init' : 'More', 'rmin':2e-2 ,'Npoints':300,
             'name':name, 'ignore_vxc':False, 'fixed_Zstar':False, 'iet_R_over_rs':R/rs*3, 'iet_N_bins':5000, 'use_full_ne_for_nf':False}
npa_kwargs = {'initialize':True, 'gradient_correction':None,'μ_init' : 0.158, 'Zstar_init' : 'More', 'rmin':1e-2 ,'Npoints':1000, 
              'name':name,'ignore_vxc':False, 'fixed_Zstar':False, 'iet_R_over_rs':R/rs*3, 'iet_N_bins':5000, 'use_full_ne_for_nf':False}

aa = NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aa_kwargs)
npa = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)
npa_2 = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.501
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.501
# 	Intializing grid
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 1.463e+02
# Exiting status 0, reverting to best index so far: 1223
# Final iter:1224, Total Error: 9.941e-13
# Intialized Potentials and Densities

# %%
# %%time
aa.solve_TF(verbose=True, picard_alpha=0.2, num_10folds_per_rs=0.5, tol=1e-7)
aa.set_uii_eff()
npa.make_gii()
npa.make_ρi()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	mu =     1.1249, change: 1.5239e+00 (converged=False)
# 	φe Err = -1.646e+10, φe change =  7.391e-01
# 	ne Err =  5.041e-01, ne change =  1.757e-02
# 	Q =  0.000e+00 ->  1.659e+00,
# 	Zstar guess =  9.216e+00. Current Zstar:  3.844e+00 (converged=False)
# 	Change =  2.060e+00
# __________________________________________
# TF Iteration 1
# 	mu =     0.6199, change: 4.4887e-01 (converged=False)
# 	φe Err = -1.398e+10, φe change =  7.754e-02
# 	ne Err =  3.318e-01, ne change =  1.020e-02
# 	Q =  1.659e+00 ->  1.316e+00,
# 	Zstar guess =  6.537e+00. Current Zstar:  4.382e+00 (converged=False)
# 	Change =  4.902e-01
# __________________________________________
# TF Iteration 2
# 	mu =     0.5434, change: 1.2342e-01 (converged=False)
# 	φe Err = -3.943e-12, φe change =  3.373e-02
# 	ne Err =  2.459e-01, ne change =  7.578e-03
# 	Q =  1.316e+00 ->  1.352e+00,
# 	Zstar guess =  5.603e+00. Current Zstar:  4.627e+00 (converged=False)
# 	Change =  1.360e-01
# __________________________________________
# TF Iteration 3
# 	mu =     0.4497, change: 1.7251e-01 (converged=False)
# 	φe Err = -2.762e-12, φe change =  2.841e-02
# 	ne Err =  1.776e-01, ne change =  5.374e-03
# 	Q =  1.352e+00 ->  1.274e+00,
# 	Zstar guess =  4.653e+00. Current Zstar:  4.632e+00 (converged=False)
# 	Change =  1.689e-01
# __________________________________________
# TF Iteration 4
# 	mu =     0.3969, change: 1.1736e-01 (converged=False)
# 	φe Err = -2.047e-12, φe change =  1.923e-02
# 	ne Err =  1.320e-01, ne change =  3.854e-03
# 	Q =  1.274e+00 ->  1.200e+00,
# 	Zstar guess =  4.056e+00. Current Zstar:  4.517e+00 (converged=False)
# 	Change =  1.120e-01
# __________________________________________
# TF Iteration 5
# 	mu =     0.3969, change: 7.0353e-05 (converged=True)
# 	φe Err = -2.210e-12, φe change =  1.356e-02
# 	ne Err =  1.069e-01, ne change =  2.760e-03
# 	Q =  1.200e+00 ->  1.117e+00,
# 	Zstar guess =  3.642e+00. Current Zstar:  4.342e+00 (converged=False)
# 	Change =  1.684e-02
# __________________________________________
# TF Iteration 6
# 	mu =     0.3969, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.868e-12, φe change =  9.354e-03
# 	ne Err =  9.000e-02, ne change =  1.960e-03
# 	Q =  1.117e+00 ->  9.924e-01,
# 	Zstar guess =  3.367e+00. Current Zstar:  4.147e+00 (converged=False)
# 	Change =  1.138e-02
# __________________________________________
# TF Iteration 7
# 	mu =     0.3969, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.684e-12, φe change =  5.976e-03
# 	ne Err =  7.636e-02, ne change =  1.406e-03
# 	Q =  9.924e-01 ->  8.567e-01,
# 	Zstar guess =  3.246e+00. Current Zstar:  3.967e+00 (converged=False)
# 	Change =  7.029e-03
# __________________________________________
# TF Iteration 8
# 	mu =     0.3969, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.868e-12, φe change =  3.915e-03
# 	ne Err =  6.474e-02, ne change =  1.017e-03
# 	Q =  8.567e-01 ->  7.253e-01,
# 	Zstar guess =  3.221e+00. Current Zstar:  3.817e+00 (converged=False)
# 	Change =  4.386e-03
# __________________________________________
# TF Iteration 9
# 	mu =     0.3969, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.721e-12, φe change =  2.642e-03
# 	ne Err =  5.481e-02, ne change =  7.405e-04
# 	Q =  7.253e-01 ->  6.053e-01,
# 	Zstar guess =  3.242e+00. Current Zstar:  3.702e+00 (converged=False)
# 	Change =  2.776e-03
# __________________________________________
# TF Iteration 25
# 	mu =     0.3496, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.364e-12, φe change =  3.634e-05
# 	ne Err =  5.232e-03, ne change =  5.255e-06
# 	Q =  1.950e-01 ->  1.849e-01,
# 	Zstar guess =  3.380e+00. Current Zstar:  3.360e+00 (converged=False)
# 	Change =  3.558e-05
# __________________________________________
# TF Iteration 50
# 	mu =     0.3600, change: 2.8593e-03 (converged=True)
# 	φe Err = -1.557e-12, φe change =  2.188e-06
# 	ne Err =  2.271e-03, ne change =  9.317e-08
# 	Q =  4.848e-02 ->  4.609e-02,
# 	Zstar guess =  3.436e+00. Current Zstar:  3.432e+00 (converged=False)
# 	Change =  2.019e-03
# __________________________________________
# TF Iteration 75
# 	mu =     0.3603, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.492e-12, φe change =  2.499e-07
# 	ne Err =  6.574e-04, ne change =  1.789e-08
# 	Q =  9.234e-03 ->  8.592e-03,
# 	Zstar guess =  3.443e+00. Current Zstar:  3.443e+00 (converged=False)
# 	Change =  6.271e-08
# __________________________________________
# TF Iteration 100
# 	mu =     0.3600, change: 2.4417e-04 (converged=True)
# 	φe Err = -1.524e-12, φe change =  4.917e-08
# 	ne Err =  1.712e-04, ne change =  5.866e-09
# 	Q =  1.238e-03 ->  1.093e-03,
# 	Zstar guess =  3.443e+00. Current Zstar:  3.443e+00 (converged=False)
# 	Change =  1.727e-04
# __________________________________________
# TF Iteration 125
# 	mu =     0.3599, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.505e-12, φe change =  9.175e-08
# 	ne Err =  4.592e-05, ne change =  5.060e-09
# 	Q =  6.747e-05 ->  5.242e-05,
# 	Zstar guess =  3.442e+00. Current Zstar:  3.442e+00 (converged=False)
# 	Change =  1.276e-07
# __________________________________________
# TF Iteration 150
# 	mu =     0.3598, change: 2.7853e-05 (converged=True)
# 	φe Err = -1.426e-12, φe change =  9.862e-09
# 	ne Err =  1.215e-05, ne change =  6.029e-10
# 	Q = -5.667e-05 -> -6.019e-05,
# 	Zstar guess =  3.442e+00. Current Zstar:  3.442e+00 (converged=False)
# 	Change =  1.970e-05
# __________________________________________
# TF Iteration 175
# 	mu =     0.3598, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.536e-12, φe change =  7.877e-09
# 	ne Err =  3.296e-06, ne change =  4.193e-10
# 	Q = -2.434e-05 -> -2.355e-05,
# 	Zstar guess =  3.442e+00. Current Zstar:  3.442e+00 (converged=False)
# 	Change =  1.102e-08
# __________________________________________
# TF Iteration 200
# 	mu =     0.3598, change: 1.8070e-06 (converged=True)
# 	φe Err = -1.379e-12, φe change =  8.221e-10
# 	ne Err =  9.673e-07, ne change =  4.352e-11
# 	Q = -9.182e-06 -> -9.045e-06,
# 	Zstar guess =  3.442e+00. Current Zstar:  3.442e+00 (converged=False)
# 	Change =  1.278e-06
# __________________________________________
# TF Iteration 225
# 	mu =     0.3598, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.272e-12, φe change =  4.716e-10
# 	ne Err =  2.738e-07, ne change =  2.492e-11
# 	Q = -2.482e-06 -> -2.363e-06,
# 	Zstar guess =  3.442e+00. Current Zstar:  3.442e+00 (converged=False)
# 	Change =  6.577e-10
# __________________________________________
# TF Iteration 247
# 	mu =     0.3598, change: 0.0000e+00 (converged=True)
# 	φe Err = -1.401e-12, φe change =  9.178e-11
# 	ne Err =  9.852e-08, ne change =  7.030e-12
# 	Q = -8.231e-07 -> -7.855e-07,
# 	Zstar guess =  3.442e+00. Current Zstar:  3.442e+00 (converged=False)
# 	Change =  1.101e-10
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 2.689e+02
# Exiting status 0, reverting to best index so far: 3666
# Final iter:3667, Total Error: 9.977e-13
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 9.941e-13
# Exiting status 0, reverting to best index so far: 1
# Final iter:2, Total Error: 9.709e-13
# CPU times: user 1min 30s, sys: 3min 29s, total: 4min 59s
# Wall time: 42.9 s

# %%
from scipy.interpolate import interp1d

aa.set_uii_eff()
aa.make_gii()
aa.make_ρi()

gii_iet = aa.iet.h_r_matrix[0,0]+1
npa_2.gii = interp1d(npa.iet.r_array*npa.rs, gii_iet, bounds_error=False, fill_value='extrapolate')(npa.grid.xs)
# Out:
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 2.689e+02
# Exiting status 0, reverting to best index so far: 3666
# Final iter:3667, Total Error: 9.977e-13

# %%
fig, axs  = plt.subplots(1,2,figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

short_distance_weight = np.exp(-(0.08*npa.kTF*npa.grid.xs)**4)
for ax in axs:
    # ax.plot(npa.iet.r_array*rs, npa.iet.h_r_matrix[0,0], color=colors[0], label=r"NPA: $u_Y$")
    ax.plot(npa.grid.xs, npa.gii-1, color=colors[0], label=r"NPA: $u_Y$")
    ax.plot(npa_2.grid.xs, npa_2.gii-1,'--', color=colors[0], label=r"NPA: $u_{AA}$",zorder=10)
    ax.plot(aa.iet.r_array*rs, aa.iet.h_r_matrix[0,0],color=colors[1],  label=r"$u_{AA}$")
    # ax.plot(npa.grid.xs, short_distance_weight*(npa.gii-1),'--',color=colors[3],  label=r"$u_Y$ damped")
    			

    # ax.plot(aa.grid.xs, aa.gii-1,'--',color=colors[3],  label=r"$u_Y$")
    ax.axvline(npa.iet.r_array[-1]*rs,color='k')
    
ax = axs[0]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xlim(0,3*rs)

ax = axs[1]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xscale('log')
ax.set_xlim(0.5,None)
ax.set_yscale('symlog', linthresh=1e-6)
for ax in axs:
    ax.legend(fontsize=12)
    ax.tick_params(labelsize=12)


plt.tight_layout()

# %% [markdown]
# ### Thomas Fermi (TF)

# %%
# %%time
npa.solve_TF(verbose=True, picard_alpha=0.2, num_10folds_per_rs=0.5, tol=1e-7, nmax = 1000, n_wait_update_Zstar= 200)
npa.set_uii_eff()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	mu =     0.3771, change: 3.8976e-03 (converged=True)
# 	φe Err =  2.726e-11, φe change =  7.409e-01
# 	ne Err =  2.872e-01, ne change =  1.405e-02
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.131e-01
# __________________________________________
# TF Iteration 1
# 	mu =     0.3765, change: 1.3657e-03 (converged=True)
# 	φe Err =  3.364e-12, φe change =  1.004e-01
# 	ne Err =  2.384e-01, ne change =  9.117e-03
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.490e+00 (converged=False)
# 	Change =  1.204e-01
# __________________________________________
# TF Iteration 2
# 	mu =     0.3761, change: 1.1855e-03 (converged=True)
# 	φe Err =  2.626e-11, φe change =  9.074e-02
# 	ne Err =  1.826e-01, ne change =  5.567e-03
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.486e+00 (converged=False)
# 	Change =  1.071e-01
# __________________________________________
# TF Iteration 3
# 	mu =     0.3757, change: 9.9512e-04 (converged=True)
# 	φe Err =  2.111e-11, φe change =  7.874e-02
# 	ne Err =  1.183e-01, ne change =  3.124e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.482e+00 (converged=False)
# 	Change =  9.327e-02
# __________________________________________
# TF Iteration 4
# 	mu =     0.3754, change: 7.4964e-04 (converged=True)
# 	φe Err =  2.639e-11, φe change =  6.462e-02
# 	ne Err =  4.983e-02, ne change =  1.535e-03
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.479e+00 (converged=False)
# 	Change =  7.809e-02
# __________________________________________
# TF Iteration 5
# 	mu =     0.3753, change: 4.0681e-04 (converged=True)
# 	φe Err =  4.907e-11, φe change =  4.875e-02
# 	ne Err =  3.520e-02, ne change =  5.881e-04
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.478e+00 (converged=False)
# 	Change =  6.059e-02
# __________________________________________
# TF Iteration 6
# 	mu =     0.3753, change: 6.4892e-05 (converged=True)
# 	φe Err = -1.992e-11, φe change =  3.142e-02
# 	ne Err =  7.169e-02, ne change =  1.267e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.478e+00 (converged=False)
# 	Change =  3.954e-02
# __________________________________________
# TF Iteration 7
# 	mu =     0.3753, change: 1.2648e-04 (converged=True)
# 	φe Err =  5.640e-11, φe change =  1.517e-02
# 	ne Err =  7.969e-02, ne change =  1.132e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.478e+00 (converged=False)
# 	Change =  1.877e-02
# __________________________________________
# TF Iteration 8
# 	mu =     0.3754, change: 1.4255e-04 (converged=True)
# 	φe Err =  8.749e-11, φe change =  4.731e-03
# 	ne Err =  6.798e-02, ne change =  1.215e-04
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.479e+00 (converged=False)
# 	Change =  4.683e-03
# __________________________________________
# TF Iteration 9
# 	mu =     0.3754, change: 1.1373e-04 (converged=True)
# 	φe Err =  1.513e-10, φe change =  1.921e-03
# 	ne Err =  5.439e-02, ne change =  9.810e-05
# 	Q = -4.547e-13 ->  4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.479e+00 (converged=False)
# 	Change =  5.822e-04
# __________________________________________
# TF Iteration 25
# 	mu =     0.3756, change: 4.7016e-06 (converged=True)
# 	φe Err =  1.811e-10, φe change =  5.037e-05
# 	ne Err =  4.769e-03, ne change =  4.316e-06
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  3.689e-05
# __________________________________________
# TF Iteration 50
# 	mu =     0.3756, change: 5.1930e-07 (converged=True)
# 	φe Err =  1.223e-11, φe change =  1.817e-06
# 	ne Err =  2.037e-03, ne change =  2.587e-08
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  1.134e-06
# __________________________________________
# TF Iteration 75
# 	mu =     0.3756, change: 3.4283e-07 (converged=True)
# 	φe Err = -9.383e-11, φe change =  7.658e-07
# 	ne Err =  1.396e-03, ne change =  2.880e-09
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  7.351e-07
# __________________________________________
# TF Iteration 100
# 	mu =     0.3756, change: 2.3309e-07 (converged=True)
# 	φe Err =  1.613e-10, φe change =  4.638e-07
# 	ne Err =  9.652e-04, ne change =  1.116e-09
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  5.267e-07
# __________________________________________
# TF Iteration 125
# 	mu =     0.3756, change: 1.5412e-07 (converged=True)
# 	φe Err = -3.663e-10, φe change =  2.847e-07
# 	ne Err =  6.857e-04, ne change =  5.485e-10
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  3.472e-07
# __________________________________________
# TF Iteration 150
# 	mu =     0.3756, change: 1.0303e-07 (converged=True)
# 	φe Err = -2.257e-10, φe change =  1.762e-07
# 	ne Err =  5.077e-04, ne change =  3.051e-10
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  2.257e-07
# __________________________________________
# TF Iteration 175
# 	mu =     0.3756, change: 7.0946e-08 (converged=True)
# 	φe Err =  4.613e-10, φe change =  1.113e-07
# 	ne Err =  3.925e-04, ne change =  1.821e-10
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  1.493e-07
# __________________________________________
# TF Iteration 200
# 	mu =     0.3756, change: 5.0687e-08 (converged=True)
# 	φe Err = -3.169e-10, φe change =  7.251e-08
# 	ne Err =  3.154e-04, ne change =  1.140e-10
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  1.018e-07
# __________________________________________
# TF Iteration 225
# 	mu =     0.5118, change: 3.0155e-03 (converged=True)
# 	φe Err = -1.549e-10, φe change =  2.359e-05
# 	ne Err =  5.370e-04, ne change =  7.507e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.083e+00. Current Zstar:  3.924e+00 (converged=False)
# 	Change =  2.150e-03
# __________________________________________
# TF Iteration 250
# 	mu =     0.5261, change: 2.8685e-04 (converged=True)
# 	φe Err =  2.015e-09, φe change =  3.185e-06
# 	ne Err =  2.456e-04, ne change =  6.414e-08
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.105e+00. Current Zstar:  4.089e+00 (converged=False)
# 	Change =  2.042e-04
# __________________________________________
# TF Iteration 275
# 	mu =     0.5275, change: 2.6140e-05 (converged=True)
# 	φe Err = -3.087e-08, φe change =  5.757e-07
# 	ne Err =  2.034e-04, ne change =  6.788e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.105e+00 (converged=False)
# 	Change =  1.852e-05
# __________________________________________
# TF Iteration 300
# 	mu =     0.5276, change: 2.1702e-06 (converged=True)
# 	φe Err = -3.824e-10, φe change =  1.685e-07
# 	ne Err =  1.655e-04, ne change =  1.124e-09
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=False)
# 	Change =  1.574e-06
# __________________________________________
# TF Iteration 325
# 	mu =     0.5276, change: 1.8824e-08 (converged=True)
# 	φe Err = -7.241e-10, φe change =  8.169e-08
# 	ne Err =  1.302e-04, ne change =  3.981e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  5.532e-08
# __________________________________________
# TF Iteration 350
# 	mu =     0.5276, change: 1.2275e-08 (converged=True)
# 	φe Err =  1.362e-10, φe change =  4.516e-08
# 	ne Err =  1.079e-04, ne change =  2.030e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  3.686e-08
# __________________________________________
# TF Iteration 375
# 	mu =     0.5276, change: 8.0381e-09 (converged=True)
# 	φe Err = -5.000e-09, φe change =  2.554e-08
# 	ne Err =  9.469e-05, ne change =  1.218e-10
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  2.182e-08
# __________________________________________
# TF Iteration 400
# 	mu =     0.5276, change: 5.7244e-09 (converged=True)
# 	φe Err = -1.705e-09, φe change =  1.541e-08
# 	ne Err =  8.623e-05, ne change =  8.060e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  1.310e-08
# __________________________________________
# TF Iteration 425
# 	mu =     0.5276, change: 4.5359e-09 (converged=True)
# 	φe Err =  6.334e-09, φe change =  1.046e-08
# 	ne Err =  8.009e-05, ne change =  5.704e-11
# 	Q = -9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  8.598e-09
# __________________________________________
# TF Iteration 450
# 	mu =     0.5276, change: 3.9303e-09 (converged=True)
# 	φe Err = -5.693e-09, φe change =  8.024e-09
# 	ne Err =  7.516e-05, ne change =  4.248e-11
# 	Q = -9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  6.418e-09
# __________________________________________
# TF Iteration 475
# 	mu =     0.5276, change: 3.6047e-09 (converged=True)
# 	φe Err =  4.740e-11, φe change =  6.689e-09
# 	ne Err =  7.090e-05, ne change =  3.290e-11
# 	Q =  9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  5.405e-09
# __________________________________________
# TF Iteration 500
# 	mu =     0.5276, change: 3.4027e-09 (converged=True)
# 	φe Err = -4.158e-09, φe change =  5.833e-09
# 	ne Err =  6.706e-05, ne change =  2.626e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  4.941e-09
# __________________________________________
# TF Iteration 525
# 	mu =     0.5276, change: 3.2479e-09 (converged=True)
# 	φe Err = -1.901e-09, φe change =  5.212e-09
# 	ne Err =  6.352e-05, ne change =  2.145e-11
# 	Q = -9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  4.711e-09
# __________________________________________
# TF Iteration 550
# 	mu =     0.5276, change: 3.1058e-09 (converged=True)
# 	φe Err = -2.542e-09, φe change =  4.723e-09
# 	ne Err =  6.025e-05, ne change =  1.784e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  4.561e-09
# __________________________________________
# TF Iteration 575
# 	mu =     0.5276, change: 2.9626e-09 (converged=True)
# 	φe Err = -8.450e-10, φe change =  4.317e-09
# 	ne Err =  5.721e-05, ne change =  1.506e-11
# 	Q = -9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  4.423e-09
# __________________________________________
# TF Iteration 600
# 	mu =     0.5276, change: 2.8145e-09 (converged=True)
# 	φe Err = -7.344e-10, φe change =  3.965e-09
# 	ne Err =  5.441e-05, ne change =  1.287e-11
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  4.271e-09
# __________________________________________
# TF Iteration 625
# 	mu =     0.5276, change: 2.6623e-09 (converged=True)
# 	φe Err = -1.910e-09, φe change =  3.651e-09
# 	ne Err =  5.184e-05, ne change =  1.110e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  4.096e-09
# __________________________________________
# TF Iteration 650
# 	mu =     0.5276, change: 2.5081e-09 (converged=True)
# 	φe Err = -1.464e-09, φe change =  3.365e-09
# 	ne Err =  4.949e-05, ne change =  9.656e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  3.903e-09
# __________________________________________
# TF Iteration 675
# 	mu =     0.5276, change: 2.3545e-09 (converged=True)
# 	φe Err =  2.581e-09, φe change =  3.102e-09
# 	ne Err =  4.736e-05, ne change =  8.460e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  3.696e-09
# __________________________________________
# TF Iteration 700
# 	mu =     0.5276, change: 2.2039e-09 (converged=True)
# 	φe Err = -2.098e-09, φe change =  2.856e-09
# 	ne Err =  4.544e-05, ne change =  7.457e-12
# 	Q = -9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  3.480e-09
# __________________________________________
# TF Iteration 725
# 	mu =     0.5276, change: 2.0582e-09 (converged=True)
# 	φe Err = -1.425e-09, φe change =  2.628e-09
# 	ne Err =  4.372e-05, ne change =  6.610e-12
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  3.263e-09
# __________________________________________
# TF Iteration 750
# 	mu =     0.5276, change: 1.9187e-09 (converged=True)
# 	φe Err =  1.336e-09, φe change =  2.415e-09
# 	ne Err =  4.218e-05, ne change =  5.886e-12
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  3.047e-09
# __________________________________________
# TF Iteration 775
# 	mu =     0.5276, change: 1.7863e-09 (converged=True)
# 	φe Err = -2.057e-09, φe change =  2.216e-09
# 	ne Err =  4.082e-05, ne change =  5.264e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  2.838e-09
# __________________________________________
# TF Iteration 800
# 	mu =     0.5276, change: 1.6617e-09 (converged=True)
# 	φe Err = -8.472e-10, φe change =  2.032e-09
# 	ne Err =  3.961e-05, ne change =  4.725e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  2.636e-09
# __________________________________________
# TF Iteration 825
# 	mu =     0.5276, change: 1.5450e-09 (converged=True)
# 	φe Err = -1.006e-09, φe change =  1.861e-09
# 	ne Err =  3.855e-05, ne change =  4.255e-12
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  2.444e-09
# __________________________________________
# TF Iteration 850
# 	mu =     0.5276, change: 1.4363e-09 (converged=True)
# 	φe Err = -8.026e-11, φe change =  1.703e-09
# 	ne Err =  3.761e-05, ne change =  3.844e-12
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  2.262e-09
# __________________________________________
# TF Iteration 875
# 	mu =     0.5276, change: 1.3355e-09 (converged=True)
# 	φe Err =  6.363e-08, φe change =  1.558e-09
# 	ne Err =  3.679e-05, ne change =  3.483e-12
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  2.092e-09
# __________________________________________
# TF Iteration 900
# 	mu =     0.5276, change: 1.2422e-09 (converged=True)
# 	φe Err = -2.128e-09, φe change =  1.423e-09
# 	ne Err =  3.607e-05, ne change =  3.163e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  1.934e-09
# __________________________________________
# TF Iteration 925
# 	mu =     0.5276, change: 1.1562e-09 (converged=True)
# 	φe Err = -1.799e-09, φe change =  1.300e-09
# 	ne Err =  3.544e-05, ne change =  2.880e-12
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  1.787e-09
# __________________________________________
# TF Iteration 950
# 	mu =     0.5276, change: 1.0771e-09 (converged=True)
# 	φe Err = -1.318e-09, φe change =  1.187e-09
# 	ne Err =  3.489e-05, ne change =  2.627e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  1.650e-09
# __________________________________________
# TF Iteration 975
# 	mu =     0.5276, change: 1.0044e-09 (converged=True)
# 	φe Err = -7.464e-09, φe change =  1.084e-09
# 	ne Err =  3.441e-05, ne change =  2.402e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  1.525e-09
# __________________________________________
# TF Iteration 1000
# 	mu =     0.5276, change: 9.4035e-10 (converged=True)
# 	φe Err = -7.925e-10, φe change =  9.927e-10
# 	ne Err =  3.400e-05, ne change =  2.208e-12
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.106e+00. Current Zstar:  4.106e+00 (converged=True)
# 	Change =  1.413e-09
# CPU times: user 1min 54s, sys: 4min 38s, total: 6min 32s
# Wall time: 48.8 s
# False

# %%
# %%time
npa_2.solve_TF(verbose=True, picard_alpha=0.2, num_10folds_per_rs=0.5, tol=1e-7, nmax = 1000, n_wait_update_Zstar= 200)
npa_2.set_uii_eff()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	mu =     0.3771, change: 3.8976e-03 (converged=True)
# 	φe Err =  6.093e-11, φe change =  7.409e-01
# 	ne Err =  2.872e-01, ne change =  1.405e-02
# 	Q =  0.000e+00 -> -1.879e-01,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.131e-01
# __________________________________________
# TF Iteration 1
# 	mu =     0.3766, change: 1.3158e-03 (converged=True)
# 	φe Err =  1.842e-11, φe change =  9.789e-02
# 	ne Err =  2.421e-01, ne change =  9.156e-03
# 	Q = -1.879e-01 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.490e+00 (converged=False)
# 	Change =  1.168e-01
# __________________________________________
# TF Iteration 2
# 	mu =     0.3761, change: 1.1872e-03 (converged=True)
# 	φe Err = -2.058e-11, φe change =  9.063e-02
# 	ne Err =  1.847e-01, ne change =  5.595e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.486e+00 (converged=False)
# 	Change =  1.070e-01
# __________________________________________
# TF Iteration 3
# 	mu =     0.3757, change: 9.9895e-04 (converged=True)
# 	φe Err =  2.260e-11, φe change =  7.864e-02
# 	ne Err =  1.210e-01, ne change =  3.142e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.482e+00 (converged=False)
# 	Change =  9.301e-02
# __________________________________________
# TF Iteration 4
# 	mu =     0.3755, change: 7.6120e-04 (converged=True)
# 	φe Err =  2.664e-11, φe change =  6.466e-02
# 	ne Err =  5.304e-02, ne change =  1.545e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.479e+00 (converged=False)
# 	Change =  7.797e-02
# __________________________________________
# TF Iteration 5
# 	mu =     0.3753, change: 4.1943e-04 (converged=True)
# 	φe Err = -3.078e-11, φe change =  4.903e-02
# 	ne Err =  3.299e-02, ne change =  5.899e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.478e+00 (converged=False)
# 	Change =  6.082e-02
# __________________________________________
# TF Iteration 6
# 	mu =     0.3753, change: 8.5330e-05 (converged=True)
# 	φe Err = -4.291e-12, φe change =  3.189e-02
# 	ne Err =  6.984e-02, ne change =  1.228e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.478e+00 (converged=False)
# 	Change =  4.006e-02
# __________________________________________
# TF Iteration 7
# 	mu =     0.3753, change: 1.0463e-04 (converged=True)
# 	φe Err =  1.141e-11, φe change =  1.607e-02
# 	ne Err =  7.993e-02, ne change =  1.243e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.478e+00 (converged=False)
# 	Change =  1.998e-02
# __________________________________________
# TF Iteration 8
# 	mu =     0.3754, change: 1.4203e-04 (converged=True)
# 	φe Err = -8.200e-12, φe change =  5.791e-03
# 	ne Err =  7.057e-02, ne change =  1.404e-04
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.479e+00 (converged=False)
# 	Change =  6.297e-03
# __________________________________________
# TF Iteration 9
# 	mu =     0.3754, change: 1.1858e-04 (converged=True)
# 	φe Err =  1.481e-12, φe change =  2.188e-03
# 	ne Err =  5.708e-02, ne change =  1.141e-04
# 	Q = -4.547e-13 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.479e+00 (converged=False)
# 	Change =  1.030e-03
# __________________________________________
# TF Iteration 25
# 	mu =     0.3756, change: 4.5379e-06 (converged=True)
# 	φe Err = -2.532e-11, φe change =  6.007e-05
# 	ne Err =  5.360e-03, ne change =  4.541e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  3.485e-05
# __________________________________________
# TF Iteration 50
# 	mu =     0.3756, change: 4.9771e-07 (converged=True)
# 	φe Err =  1.202e-09, φe change =  3.932e-06
# 	ne Err =  2.890e-03, ne change =  3.644e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  4.924e-07
# __________________________________________
# TF Iteration 75
# 	mu =     0.3756, change: 4.3885e-07 (converged=True)
# 	φe Err =  3.264e-12, φe change =  1.640e-06
# 	ne Err =  2.063e-03, ne change =  9.118e-09
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  8.296e-07
# __________________________________________
# TF Iteration 100
# 	mu =     0.3756, change: 2.9667e-07 (converged=True)
# 	φe Err = -3.980e-11, φe change =  9.353e-07
# 	ne Err =  1.490e-03, ne change =  4.285e-09
# 	Q =  4.547e-13 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  6.982e-07
# __________________________________________
# TF Iteration 125
# 	mu =     0.3756, change: 1.7436e-07 (converged=True)
# 	φe Err =  1.030e-10, φe change =  5.490e-07
# 	ne Err =  1.161e-03, ne change =  2.411e-09
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  4.358e-07
# __________________________________________
# TF Iteration 150
# 	mu =     0.3756, change: 9.7205e-08 (converged=True)
# 	φe Err =  1.327e-10, φe change =  3.233e-07
# 	ne Err =  9.810e-04, ne change =  1.528e-09
# 	Q = -4.547e-13 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  2.428e-07
# __________________________________________
# TF Iteration 175
# 	mu =     0.3756, change: 5.4256e-08 (converged=True)
# 	φe Err = -1.161e-11, φe change =  1.971e-07
# 	ne Err =  8.730e-04, ne change =  1.053e-09
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  1.276e-07
# __________________________________________
# TF Iteration 200
# 	mu =     0.3756, change: 3.2234e-08 (converged=True)
# 	φe Err =  2.888e-13, φe change =  1.297e-07
# 	ne Err =  7.988e-04, ne change =  7.699e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.481e+00 (converged=False)
# 	Change =  6.554e-08
# __________________________________________
# TF Iteration 225
# 	mu =     0.5196, change: 2.9613e-03 (converged=True)
# 	φe Err = -1.482e-11, φe change =  2.524e-05
# 	ne Err =  1.775e-03, ne change =  8.655e-07
# 	Q =  0.000e+00 ->  4.547e-13,
# 	Zstar guess =  4.173e+00. Current Zstar:  4.014e+00 (converged=False)
# 	Change =  2.108e-03
# __________________________________________
# TF Iteration 250
# 	mu =     0.5332, change: 2.3666e-04 (converged=True)
# 	φe Err =  1.119e-11, φe change =  5.015e-06
# 	ne Err =  1.320e-03, ne change =  6.567e-08
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.171e+00 (converged=False)
# 	Change =  1.683e-04
# __________________________________________
# TF Iteration 275
# 	mu =     0.5342, change: 1.7784e-05 (converged=True)
# 	φe Err =  5.555e-11, φe change =  1.444e-06
# 	ne Err =  1.092e-03, ne change =  1.101e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.183e+00 (converged=False)
# 	Change =  1.275e-05
# __________________________________________
# TF Iteration 300
# 	mu =     0.5343, change: 1.0496e-06 (converged=True)
# 	φe Err = -6.098e-11, φe change =  6.424e-07
# 	ne Err =  9.393e-04, ne change =  4.133e-09
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=False)
# 	Change =  8.458e-07
# __________________________________________
# TF Iteration 325
# 	mu =     0.5343, change: 2.3236e-08 (converged=True)
# 	φe Err =  2.402e-11, φe change =  3.634e-07
# 	ne Err =  8.383e-04, ne change =  2.186e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  9.360e-08
# __________________________________________
# TF Iteration 350
# 	mu =     0.5343, change: 6.7699e-09 (converged=True)
# 	φe Err =  1.752e-11, φe change =  2.297e-07
# 	ne Err =  7.670e-04, ne change =  1.390e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  2.957e-08
# __________________________________________
# TF Iteration 375
# 	mu =     0.5343, change: 6.5503e-10 (converged=True)
# 	φe Err =  8.564e-12, φe change =  1.623e-07
# 	ne Err =  7.119e-04, ne change =  9.856e-10
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  4.747e-09
# __________________________________________
# TF Iteration 400
# 	mu =     0.5343, change: 2.6391e-10 (converged=True)
# 	φe Err = -5.954e-13, φe change =  1.246e-07
# 	ne Err =  6.669e-04, ne change =  7.455e-10
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.427e-08
# __________________________________________
# TF Iteration 425
# 	mu =     0.5343, change: 2.1675e-09 (converged=True)
# 	φe Err =  3.653e-12, φe change =  9.973e-08
# 	ne Err =  6.291e-04, ne change =  5.881e-10
# 	Q =  9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.540e-08
# __________________________________________
# TF Iteration 450
# 	mu =     0.5343, change: 4.5503e-09 (converged=True)
# 	φe Err =  1.236e-11, φe change =  8.167e-08
# 	ne Err =  5.963e-04, ne change =  4.777e-10
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.287e-08
# __________________________________________
# TF Iteration 475
# 	mu =     0.5343, change: 6.6129e-09 (converged=True)
# 	φe Err =  4.304e-12, φe change =  6.809e-08
# 	ne Err =  5.670e-04, ne change =  3.965e-10
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  9.229e-09
# __________________________________________
# TF Iteration 500
# 	mu =     0.5343, change: 8.0882e-09 (converged=True)
# 	φe Err =  3.614e-11, φe change =  5.781e-08
# 	ne Err =  5.406e-04, ne change =  3.347e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  5.795e-09
# __________________________________________
# TF Iteration 525
# 	mu =     0.5343, change: 8.9582e-09 (converged=True)
# 	φe Err =  2.162e-11, φe change =  4.998e-08
# 	ne Err =  5.165e-04, ne change =  2.865e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.006e-08
# __________________________________________
# TF Iteration 550
# 	mu =     0.5343, change: 9.3059e-09 (converged=True)
# 	φe Err =  1.180e-11, φe change =  4.394e-08
# 	ne Err =  4.945e-04, ne change =  2.482e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.292e-08
# __________________________________________
# TF Iteration 575
# 	mu =     0.5343, change: 9.2446e-09 (converged=True)
# 	φe Err = -1.746e-11, φe change =  3.913e-08
# 	ne Err =  4.744e-04, ne change =  2.171e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.458e-08
# __________________________________________
# TF Iteration 600
# 	mu =     0.5343, change: 8.8845e-09 (converged=True)
# 	φe Err =  1.135e-11, φe change =  3.519e-08
# 	ne Err =  4.560e-04, ne change =  1.915e-10
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.527e-08
# __________________________________________
# TF Iteration 625
# 	mu =     0.5343, change: 8.3208e-09 (converged=True)
# 	φe Err =  2.195e-11, φe change =  3.183e-08
# 	ne Err =  4.393e-04, ne change =  1.703e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.525e-08
# __________________________________________
# TF Iteration 650
# 	mu =     0.5343, change: 7.6303e-09 (converged=True)
# 	φe Err =  7.727e-12, φe change =  2.891e-08
# 	ne Err =  4.241e-04, ne change =  1.524e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.471e-08
# __________________________________________
# TF Iteration 675
# 	mu =     0.5343, change: 6.8722e-09 (converged=True)
# 	φe Err =  8.811e-12, φe change =  2.631e-08
# 	ne Err =  4.102e-04, ne change =  1.373e-10
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.383e-08
# __________________________________________
# TF Iteration 700
# 	mu =     0.5343, change: 6.0905e-09 (converged=True)
# 	φe Err =  1.186e-11, φe change =  2.397e-08
# 	ne Err =  3.976e-04, ne change =  1.243e-10
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.273e-08
# __________________________________________
# TF Iteration 725
# 	mu =     0.5343, change: 5.3167e-09 (converged=True)
# 	φe Err =  4.224e-12, φe change =  2.186e-08
# 	ne Err =  3.860e-04, ne change =  1.131e-10
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.152e-08
# __________________________________________
# TF Iteration 750
# 	mu =     0.5343, change: 4.5727e-09 (converged=True)
# 	φe Err =  4.045e-11, φe change =  1.994e-08
# 	ne Err =  3.754e-04, ne change =  1.033e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.026e-08
# __________________________________________
# TF Iteration 775
# 	mu =     0.5343, change: 3.8730e-09 (converged=True)
# 	φe Err =  1.824e-11, φe change =  1.820e-08
# 	ne Err =  3.656e-04, ne change =  9.483e-11
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  9.006e-09
# __________________________________________
# TF Iteration 800
# 	mu =     0.5343, change: 3.2263e-09 (converged=True)
# 	φe Err =  2.268e-11, φe change =  1.663e-08
# 	ne Err =  3.566e-04, ne change =  8.733e-11
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  7.795e-09
# __________________________________________
# TF Iteration 825
# 	mu =     0.5343, change: 2.6372e-09 (converged=True)
# 	φe Err = -4.444e-11, φe change =  1.522e-08
# 	ne Err =  3.482e-04, ne change =  8.070e-11
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  6.650e-09
# __________________________________________
# TF Iteration 850
# 	mu =     0.5343, change: 2.1074e-09 (converged=True)
# 	φe Err =  1.711e-12, φe change =  1.395e-08
# 	ne Err =  3.403e-04, ne change =  7.481e-11
# 	Q = -9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  5.585e-09
# __________________________________________
# TF Iteration 875
# 	mu =     0.5343, change: 1.6362e-09 (converged=True)
# 	φe Err = -7.981e-12, φe change =  1.282e-08
# 	ne Err =  3.329e-04, ne change =  6.954e-11
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  4.609e-09
# __________________________________________
# TF Iteration 900
# 	mu =     0.5343, change: 1.2216e-09 (converged=True)
# 	φe Err =  8.314e-12, φe change =  1.181e-08
# 	ne Err =  3.260e-04, ne change =  6.482e-11
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  3.724e-09
# __________________________________________
# TF Iteration 925
# 	mu =     0.5343, change: 8.6087e-10 (converged=True)
# 	φe Err =  1.563e-11, φe change =  1.091e-08
# 	ne Err =  3.194e-04, ne change =  6.058e-11
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  2.930e-09
# __________________________________________
# TF Iteration 950
# 	mu =     0.5343, change: 5.5032e-10 (converged=True)
# 	φe Err =  9.936e-13, φe change =  1.012e-08
# 	ne Err =  3.132e-04, ne change =  5.674e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  2.225e-09
# __________________________________________
# TF Iteration 975
# 	mu =     0.5343, change: 2.8615e-10 (converged=True)
# 	φe Err =  4.741e-12, φe change =  9.414e-09
# 	ne Err =  3.073e-04, ne change =  5.326e-11
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.604e-09
# __________________________________________
# TF Iteration 1000
# 	mu =     0.5343, change: 7.2477e-11 (converged=True)
# 	φe Err = -8.358e-13, φe change =  8.815e-09
# 	ne Err =  3.019e-04, ne change =  5.022e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.184e+00. Current Zstar:  4.184e+00 (converged=True)
# 	Change =  1.083e-09
# CPU times: user 1min 52s, sys: 4min 36s, total: 6min 29s
# Wall time: 46.8 s
# False

# %% [markdown]
# ### EOS

# %%
def get_E(aa):
    βVeff = aa.get_βVeff(aa.φe, aa.ne, aa.ne_bar)
    η = aa.μ/aa.Te - βVeff
    βU = aa.grid.integrate_f(βVeff*aa.ne)
    I_onehalf = FermiDirac.Ionehalf(η)
    I_threehalf = FermiDirac.Ithreehalf(η)
    
    βK = (2*aa.Te)**1.5/π**2 * aa.grid.integrate_f( η*I_onehalf - 2/3 * I_threehalf   )
    return βU, βK, βU + βK

get_E(aa_tfd), get_E(npa_tfd)

# %%
def get_P(aa):
    aa_old_βu = aa.iet.βu_r_matrix.copy()
    # aa.iet.set_βu_matrix( np.array([[1/aa.Ti * aa.Zstar**2/(aa.iet.r_array*aa.rs) ]] ))
    P_id_hnc, P_ex_hnc, P_hnc = aa.iet.ideal_pressure(), aa.iet.excess_pressure(), aa.iet.total_pressure()
    P_id_AU, P_ex_AU, P_AU  = P_id_hnc/rs**3, P_ex_hnc/rs**3, P_hnc/rs**3
    aa.iet.set_βu_matrix(aa_old_βu)
    return P_id_AU, P_ex_AU, P_AU

aa_P_ions = get_P(aa_tfd)
aa_P_ions[1]/aa_P_ions[0]

# %% [markdown]
# ## Comparison

# %%
aa.make_plots()
# Out:
# (<Figure size 4000x1600 with 2 Axes>,
#  array([<Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$\\phi$ [A.U.]'>,
#         <Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$n$ [A.U.]'>],
#        dtype=object))

# %%
fig, ax = plt.subplots()

# ax.plot(npa.φe_list[0] + npa.φion)#/npa.φe_init
ax.plot(npa.get_φe(npa.ρi - npa.ne)[0] + npa.φion)#/npa.φe_init
ax.plot(npa.φe_init + npa.φion,'--')#/npa.φe_init
ax.set_yscale('symlog', linthresh=1e-8)

# %%
def plot_convergence(aa, axs=None):
    if axs is None:
        fig, axs = plt.subplots(ncols=3,figsize=(18,5),facecolor='w', dpi=200)
    
    # ELectric potential
    slice_by_num = 10
    ax = axs[0]
    colors = plt.cm.coolwarm(np.linspace(0, 1,len(aa.φe_list[::slice_by_num])))
    for i, φe in enumerate(aa.φe_list[::slice_by_num]):
        if i ==0 or i==len(aa.φe_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, (φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\phi_e$'.format(i))
        else:
            ax.plot(aa.grid.xs, φe+aa.φion,linewidth=1,color=colors[i],alpha=1)
    # ax.plot(aa.grid.xs, aa.get_φe( (aa.ρi - aa.ne) )[0] + aa.φion  ,'k:', label=r'$\phi$ check') 
    ax.set_yscale('symlog',linthresh=1e-10)
    ax.plot(aa.grid.xs, aa.φe_init + aa.φion, 'k:')

    # number density
    ax = axs[1]
    for i, (ne, ρi) in enumerate(zip(aa.ne_list[::slice_by_num], aa.ρi_list[::slice_by_num])):
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            if i==0: 
                ne_bar_0 = ne[-1]
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1, label=r'$Q(r)$'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, -ne + 0*ρi + ne[-1],linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ne_bar_0,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ρi[-1] + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # pass
        else:
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1)
            # print(ne[-1]-ne_bar_0)
            # ax.plot(aa.grid.xs, -ne + ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ne + ne_bar_0 ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ρi[-1]+ ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            pass
    # for i in range(int(aa.R/aa.rs)):
    #     ax.axvline(aa.rs*i, color='k', linestyle='--', alpha=0.2)
    # ax.set_xscale('log')
    # ax.plot(aa.grid.xs, (aa.gii)-1, 'k:')
    ax.set_yscale('symlog',linthresh=1e-4)

            
    # number density
    ax = axs[2]
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        ne_TF = aa.get_ne_TF(φe, ne, μ, ne_bar)
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            # ax.plot(aa.grid.xs, ne/ne_TF-1,linewidth=1,color=colors[i],alpha=1, label=r'$n_e/n_e^{{TF}}-1$, iter: {0}'.format(i))
            ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1, label=r'$n_e^{{TF}} - n_e^{{TF}}[-1]$, iter: {0}'.format(i*slice_by_num))
            ax.plot(aa.grid.xs, ne-ne[-1],linewidth=1,color=colors[i],linestyle='--',alpha=1, label=r'$n_e - n_e[-1]$, iter: {0}'.format(i))
            # pass
        else:
            # ax.plot(aa.grid.xs, ne/ne_TF-1, linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            ax.plot(aa.grid.xs, ne-ne[-1], linewidth=1,linestyle='--',color=colors[i],alpha=0.5)
            ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1)

            # print(np.abs(ne/ne_TF-1))
            # print(np.where( np.abs(ne/ne_TF-1)>1e-6 ))
            # print(aa.grid.xs[np.where( np.abs(ne/ne_TF-1) > 1e-8)][0]/10, 1/(np.sum(aa.grid.xs*np.abs(ne/ne_TF-1))/np.sum(np.abs(ne/ne_TF-1))))
    # ax.set_ylim()
    # ax.plot(aa.grid.xs, npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar) - npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar)[-1] , 'k:')
    ax.plot(aa.grid.xs, aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar) - aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar)[-1] , 'k:')
    ax.set_yscale('symlog',linthresh=1e-10)
    # ax.set_xscale('log')
    for ax in axs:
        ax.legend(fontsize=14)
        ax.tick_params(labelsize=14)
        ax.plot(aa.grid.xs, np.zeros_like(aa.ne),'k', alpha=0.2)
    plt.tight_layout()
# plot_convergence(aa)
plot_convergence(npa)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

petrov = pd.read_csv("../data/GP_TFDW_Al_1eV_solid.dat",header=0, comment='#', delim_whitespace=True)

def compare_aa(aa_list, axs=None, name=''):
    eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
    if axs is None:
        fig, axs = plt.subplots(ncols=2,figsize=(20,8),facecolor='w')

    # Density * 4pi r^2 plot
    for ax in axs:
        for aa, color in zip( aa_list, colors):
            factor = 4*np.pi*aa.grid.xs**2
            ax.plot(np.array(petrov['r/R'])*rs, 4*π*(np.array(petrov['r/R'])*rs)**2*(petrov['ne']/m_to_AU**3), 'k--', label="Petrov AA")
            ax.plot(aa.grid.xs, aa.ne*factor ,'-',color=color, label=r'$n_e$: '+ name)
            ax.plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
            ax.plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
            if aa.rs != aa.R:
                ax.plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
                ax.plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)
        # axs[0].plot(aa.grid.xs, aa.δn_f*factor,'--',color='g',  label=r'$n_e^{sc}$: ' + name)


    axs[0].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[0].set_ylim(0, 1e3)
    axs[0].set_yscale('symlog',linthresh=1e-1)
    axs[0].set_xscale('log')
    axs[0].set_xlim(aa.grid.xs[0],aa.grid.xs[-1])

    axs[1].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[1].set_ylim(0, 13)
    axs[1].set_xlim(0, np.min([aa.R,1.3*aa.rs]))

        
    for ax in axs:
        ax.set_xlabel(r'$|r-R_1|$ [A.U.]',fontsize=20)
        ax.legend(loc="upper right",fontsize=20,labelspacing = 0.1)
        ax.tick_params(labelsize=20)
        ax.grid(which='both',alpha=0.4)

        # make textbox
        text = ("{0}\n".format(aa.name)+ 
            r"$r_s$ = " + "{0},    ".format(np.round(aa.rs,2)) +
            r"$R_{NPA}$ = " + "{0}\n".format(aa.R)  +
                r"$T_e$ = " + "{0} [A.U.] = {1} eV\n".format(np.round(aa.Te,2),np.round(aa.Te/eV,2)) + r"$\mu$ = " + "{0} [A.U.]\n".format(np.round(aa.μ,2)) +
                r"$Z^\ast = $" + "{0}".format(np.round(aa.Zstar,2))  )

        props = dict(boxstyle='round', facecolor='w')
        ax.text(0.25,0.95, text, fontsize=15, transform=ax.transAxes, verticalalignment='top', bbox=props)

    plt.tight_layout()
    name = "NPA_densities_{0}_rs{1}_{2}eV_R{3}.png".format(aa.name, np.round(aa.rs,2), np.round(aa.Te/eV,2) ,np.round(aa.R))
    plt.savefig("/home/zach/plasma/atomic_forces/average_atom/media/" + name, dpi=300, bbox_inches='tight',facecolor="w")
    
    
    return axs


axs = compare_aa([aa, npa, npa_2])
for ax in axs:
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), fontsize=16, loc='upper right')
# axs[1].set_ylim(1e-5,1e3)

# %% [markdown]
# ## HNC and FT

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.k_array/rs, aa.Uei_iet_k*(aa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.k_array/rs, npa.Uei_iet_k*(npa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[1], label="NPA") # Need to muultiply by some rs power???
axs[0].plot(aa.iet.k_array/rs, aa.Zstar*np.ones_like(aa.iet.k_array),':', color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(npa.iet.k_array/rs, npa.Zstar*np.ones_like(npa.iet.k_array),':',color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")

# axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$k$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.k_array/rs, aa.uii_k_eff_iet,'-', color=colors[0], label="AA")
axs[1].plot(aa.iet.k_array/rs, 4*π*aa.Zstar**2/(aa.iet.k_array/rs)**2,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
axs[1].plot(aa.iet.k_array/rs, 1/(aa.iet.k_array**2/rs**2/(4*π*aa.Zstar**2) + 1/aa.uii_k_eff_iet[0] ),'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, uii_test,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))


axs[1].plot(npa.iet.k_array/rs, npa.uii_k_eff_iet,color=colors[1], label="NPA")
axs[1].plot(npa.iet.k_array/rs, 4*π*npa.Zstar**2/(npa.iet.k_array/rs)**2,'--', color=colors[1], label=r"NPA: $u_{{ii}}^0$, Z={0:0.3f}".format(npa.Zstar))



axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_ylim(0,1e5)
axs[1].set_xscale('log')
axs[1].set_xlabel(r"$k$ [au]")
axs[1].set_ylabel(r"$u^{\rm eff}_{ii}$ [au]")


for ax in axs:
    ax.legend(fontsize=12)
plt.tight_layout()

# %%
uii_test = aa.iet.FT_k_2_r(aa.uii_k_eff_iet)/rs**3

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.r_array*rs, -aa.Zstar/(aa.iet.r_array*rs), color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(aa.iet.r_array*rs, -aa.Uei_iet ,':',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.r_array*rs, -npa.Zstar/(npa.iet.r_array*rs),color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(npa.iet.r_array*rs, -npa.Uei_iet ,':',color=colors[1], label="NPA") # Need to muultiply by some rs power???
axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Zstar/(npa.iet.r_array*rs),color=colors[2], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Uei_iet ,':',color=colors[2], label=r"NPA: $g_{AA}$") # Need to muultiply by some rs power???



axs[0].set_yscale('symlog',linthresh=1e-1)
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$r$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.r_array*rs, aa.uii_r_eff_iet, color=colors[0],linestyle='-', label='AA')
axs[1].plot(aa.iet.r_array*rs, aa.Zstar**2/(aa.iet.r_array*rs ), color=colors[0] ,linestyle='--', label=f'Coulomb Z={aa.Zstar:0.3f}')
axs[1].plot(npa.iet.r_array*rs, npa.uii_r_eff_iet, color=colors[1],linestyle='-', label='NPA')
axs[1].plot(npa.iet.r_array*rs, npa.Zstar**2/(npa.iet.r_array*rs ), color=colors[1],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )
axs[1].plot(npa_2.iet.r_array*rs, npa_2.uii_r_eff_iet, color=colors[2],linestyle='-', label=r"NPA: $g_{AA}$")
axs[1].plot(npa_2.iet.r_array*rs, npa_2.Zstar**2/(npa_2.iet.r_array*rs ), color=colors[2],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )

axs[1].set_yscale('symlog',linthresh=1e-6)
axs[1].set_xscale('log')
axs[1].set_ylabel(r"$U_{ii}$ [au]")
axs[1].set_xlabel(r"$r$ [au]")
axs[1].set_xlim(1,None)


for ax in axs:
    ax.legend(fontsize=10)
plt.tight_layout()

# %%
npa.make_gii()
npa.make_ρi()
npa_2.make_gii()
npa_2.make_ρi()
# Out:
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 9.984e-13
# Exiting status 0, reverting to best index so far: 1
# Final iter:2, Total Error: 9.915e-13
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 9.975e-13
# Exiting status 0, reverting to best index so far: 1
# Final iter:2, Total Error: 9.857e-13

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, axs  = plt.subplots(1,2, figsize=(8,4))

# Data from community TCCW
upper_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Upper.txt", delim_whitespace=True, header=1)
lower_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Lower.txt", delim_whitespace=True, header=1)

ax = axs[0]
ax.fill_between(lower_data['r/ri'],lower_data['gii'], PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')

# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
ax.plot(npa_2.grid.xs/rs, npa_2.gii, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0] + 1, label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("g(r)")
ax.set_xlim(0.7,3)
ax.set_ylim(0,2)
ax.legend(fontsize=10)

ax = axs[1]
ax.fill_between(lower_data['r/ri'],lower_data['gii']-1, PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')
# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii-1, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
ax.plot(npa_2.grid.xs/rs, npa_2.gii-1, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0], label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("h(r)")
ax.set_xlim(0.7,10)
# ax.set_ylim(0,2.5)
ax.set_yscale('symlog', linthresh=1e-4)

ax.legend(fontsize=8, loc='upper right')
plt.tight_layout()
