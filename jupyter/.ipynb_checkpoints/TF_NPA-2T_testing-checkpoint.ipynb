# %%
import numpy as np
import pandas as pd


from average_atom.core.average_atom import NeutralPseudoAtom as NPA
from average_atom.core.misc import jacobi_relaxation, sor
from average_atom.core.grids import NonUniformGrid
from average_atom.core.physics import ThomasFermi, FermiDirac

from importlib import reload
try:
    reload(physics)
    reload(grids)
    reload(average_atom_geometric)
#     reload(average_atom)
    reload(misc)
except NameError as e:
    from average_atom.core import physics as physics
    from average_atom.core import average_atom as average_atom
    from average_atom.core import misc as misc
    from average_atom.core import grids as grids
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)

import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

import cProfile

plt.rcParams.update({'font.size': 10})
plt.rcParams["figure.figsize"] = (5,3.5)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14

color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# Error:  name 'physics' is not defined

# %%
# Aluminuma
# name='Al'
# Z, A = 13, 27 

# ρ_solid = 2.699 #g/cc, the solid density of aluminum 
# ρ = ρ_solid#8.1 # g/cc
# ni_cc = ρ/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_cc*invcc_to_AU
# rs = rs_from_n(ni_AU)

# Ti_eV = 1 
# Te_eV = 1

# Te_AU = Te_eV*eV_to_AU
# Ti_AU = Ti_eV*eV_to_AU

# Hydrogen
# name='H'
# Z, A = 1, 1.00784

# Te_eV = 2 
# Te_AU = Te_eV*eV_to_AU

# Ti_eV = 2
# Ti_AU = Ti_eV*eV_to_AU

# ρ_gpercc = 1
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)

# Carbon
Z, A = 6, 12.011

ρ_gpercc = 2.267
ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
ni_AU = ni_invcc*invcc_to_AU
rs = rs_from_n(ni_AU)

Ti_eV = 0.5 
Te_eV = 0.5

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

####
R = 20*rs
rmin = rs/1000
ignore_vxc = True
fixed_Zstar = False

aa_kwargs = {'initialize':True, 'gradient_correction':None, 'μ_init' : 0.158, 'Zstar_init' : 'More', 'rmin': rmin,'Npoints':300,
             'name':name, 'ignore_vxc':ignore_vxc, 'fixed_Zstar':fixed_Zstar, 'iet_R_over_rs':R/rs, 'iet_N_bins':5000, 'use_full_ne_for_nf':False,
            'gii_init_type': 'step'}
npa_kwargs = {'initialize':True, 'gradient_correction':None,'μ_init' : 0.158, 'Zstar_init' : 'More', 'rmin':1e-2 ,'Npoints':5000, 
              'name':name,'ignore_vxc':ignore_vxc, 'fixed_Zstar':fixed_Zstar, 'iet_R_over_rs':R/rs, 'iet_N_bins':10000, 'use_full_ne_for_nf':False,
             'gii_init_type': 'step', 'grid_spacing':'geometric'}

aa = NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aa_kwargs)
npa = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)
# npa_2 = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)
# Out:
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# Using More TF fit for initial Zstar = 2.495
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities

# %%
# from scipy.interpolate import interp1d
# ρ = npa.ρi - npa.ne
# # ρ = interp1d(npa.grid.xs, ρ, bounds_error=False, fill_value='extrapolate')(npa.iet.r_array*npa.rs)# ρ = -np.exp(-npa.grid.xs**2/(2*1**2))*npa.grid.xs**5
# # ρ *= -13/np.sum(4*π*npa.iet.r_array**2*rs**3*ρ*npa.iet.del_r)

# Q = np.array([np.sum((4*π*npa.iet.r_array**2*rs**3*ρ*npa.iet.del_r)[:i]) for i in range(len(npa.iet.r_array))])
# E_from_Q = (Z + Q)/npa.iet.r_array**2/rs**2

# fig,ax = plt.subplots()
# ax.plot(npa.iet.r_array*rs, E_from_Q, zorder=10)
# φe = npa.iet.FT_k_2_r((npa.iet.FT_r_2_k(ρ)*4*π/(npa.iet.k_array/npa.rs)**2))
# φi = Z/npa.iet.r_array/rs 
# φ = φe + φi
# ax.plot(npa.iet.r_array[1:]*rs, -(φ[1:]-φ[:-1])/npa.iet.del_r/rs )
# ax.plot(npa.iet.r_array*rs, -np.gradient(φ, npa.iet.r_array*rs) )

# ax.plot(npa.iet.r_array[1:]*rs, -(φ[1:]-φ[:-1])/npa.iet.del_r/rs )
# ax.plot(npa.iet.r_array*rs, -np.gradient(φ, npa.iet.r_array*rs) )

# ax.set_yscale('symlog', linthresh=1e-12)
# ax.set_xscale('log')
# # ax.set_xlim(1,2)

# %%
from scipy.interpolate import interp1d
ρ = npa.ρi - npa.ne
# ρ = interp1d(npa.grid.xs, ρ, bounds_error=False, fill_value='extrapolate')(npa.iet.r_array*npa.rs)# ρ = -np.exp(-npa.grid.xs**2/(2*1**2))*npa.grid.xs**5
# ρ = -np.exp(-npa.grid.xs/1)
ρ *= np.abs(Z/npa.grid.integrate_f(ρ))#*(1+1e-6)

ρ_iet = interp1d(npa.grid.xs, ρ, kind='cubic', bounds_error=False, fill_value='extrapolate')(npa.iet.r_array*rs)
ρ_iet *= np.abs(Z/np.sum( (4*π*npa.iet.r_array**2*rs**3*npa.iet.del_r*ρ_iet)))

# ρ = npa.ρ0_r_iet

print("Q_err: ", -Z/npa.grid.integrate_f(ρ)-1)

print(np.min(npa.φe))
npa.φe = npa.get_φe_iet(ρ)[0].copy()
# npa.φe = npa.get_φe_screened(npa.ρi - npa.ne)[0].copy()
print(np.min(npa.φe))
φe_iet = npa.get_φe_iet(ρ)[0].copy()
φe_iet = φe_iet - φe_iet[-1]
φe_tri = npa.get_φe(ρ)[0].copy()
φe_tri = φe_tri - φe_tri[-1]


fig, ax = plt.subplots()


# ax.plot(npa.grid.xs, ρ)
# ax.plot(npa.grid.xs, npa.ρ0_r_iet/npa.grid.xs)
# ax.plot(npa.iet.r_array*rs, npa.iet.ρ_r - npa.iet.ρ0_r)
Qs = npa.get_Q_profile(ρ)
Qs_iet = np.array([np.sum( (4*π*npa.iet.r_array**2*rs**3*npa.iet.del_r*ρ_iet)[:i] ) for i in range(len(npa.iet.r_array))  ])
E_from_Q = (Qs + Z)/npa.grid.xs**2
E_from_Q_iet = (  Qs_iet + Z)/npa.iet.r_array**2/rs**2

ax.plot(npa.grid.xs, ρ, ':', label=r'$\rho$' ,zorder=1)
ax.plot(npa.grid.xs, npa.ρi, ':', label=r'$\rho_i$' ,zorder=1)
ax.plot(npa.grid.xs, npa.ne, ':', label=r'$-\rho_e$' ,zorder=1)

ax.plot(npa.grid.xs, Qs, '--.', label=r'$Q/r^2$' ,zorder=1)
ax.plot(npa.iet.r_array*rs, Qs_iet, '--.', label=r'$Q/r^2$ iet' ,zorder=1)
ax.plot(npa.grid.xs, E_from_Q, '-',color=color_cycle[0], label=r'$Q/r^2$' ,zorder=1)
ax.plot(npa.iet.r_array*rs, E_from_Q_iet, '--.',color=color_cycle[0], label=r'$Q/r^2$' ,zorder=1)
# ax.plot(npa.grid.xs, npa.grid.integrate_f(E_from_Q) - npa.get_Q_profile(E_from_Q), '-',color=color_cycle[0], label=r'$Q/r^2$' ,zorder=1)
# ax.plot(npa.grid.xs, -npa.grid.dfdx(npa.φe0_iet + npa.φion), '--',color=color_cycle[3], label=r'$\vec{E_0}_{tri}$',zorder=2)
# ax.plot(npa.grid.xs, -npa.grid.dfdx(φe_iet-npa.φe0_iet), ':',color=color_cycle[3], label=r'$\delta\vec{E}_{iet}$',zorder=2)
ax.plot(npa.grid.xs, -npa.grid.dfdx(φe_iet + npa.φion), '--',color=color_cycle[3], label=r'$\vec{E}_{iet}$',zorder=10)
ax.plot(npa.grid.xs, -npa.grid.dfdx(φe_tri + npa.φion), ':',color=color_cycle[2], label=r'$\vec{E}_{tri}$',zorder=20)

# ax.plot(npa.grid.xs, -φe_iet,'-', color=color_cycle[5] ,label=r'$\phi$ iet')
# ax.plot(npa.grid.xs, npa.φion,':', color=color_cycle[6] ,label=r'$\phi$ iet')

# ax.plot(npa.grid.xs, -npa.grid.dfdx(-φe_iet),'--', color=color_cycle[4] ,label=r'$E_e$ iet')
# ax.plot(npa.grid.xs, -npa.grid.dfdx(-φe_tri),'--', color=color_cycle[5] ,label=r'$E_e$ tri')
# ax.plot(npa.grid.xs, -npa.grid.dfdx(npa.φion),':', color=color_cycle[6] ,label=r'$E_i$')

# ax.plot(npa.grid.xs, npa.φion,'-', color=color_cycle[1] ,label=r'$\phi_i$')
# ax.plot(npa.grid.xs, φe_iet + npa.φion,'-', color=color_cycle[2] ,label=r'$\phi$ iet')
# ax.plot(npa.grid.xs, npa.φe0_iet-npa.φe0_iet[-1] + npa.φion,':', color=color_cycle[2] ,label=r'$\phi_0$ iet')
# ax.plot(npa.iet.r_array*rs, npa.iet.δφe_r,'--', color=color_cycle[2] ,label=r'$\delta \phi$ iet')
# ax.plot(npa.grid.xs, φe_tri + npa.φion,'--', color=color_cycle[3], label=r'$\phi$ tridiag')
# ax.plot(npa.grid.xs, φe_tri - φe_iet,':', color='k', label=r'$\phi Error$ ')


# ax.set_ylabel('E')
ax.set_xlabel('r [au]')
ax.set_yscale('symlog', linthresh=1e-12)
ax.set_xscale('log')
# ax.set_xlim(0.07,0.12)
ax.legend()
ax.grid(which='both', alpha=0.2)
# ax.set_ylim(-1, None)
# Out:
# Q_err:  0.0
# -13.27993260752578
# -41.436754324162514
# /home/zach/plasma/average_atom/core/average_atom.py:532: RuntimeWarning: divide by zero encountered in divide
#   rel_errs = (np.abs(A @ φe - b)[:-1]/b[:-1])
# /home/zach/plasma/average_atom/core/average_atom.py:532: RuntimeWarning: invalid value encountered in divide
#   rel_errs = (np.abs(A @ φe - b)[:-1]/b[:-1])

# %%
# %%time
npa.solve_TF(verbose=True, picard_alpha=0.01, tol=1e-12, nmax = 5000, n_wait_update_Zstar= 2000)
npa.set_uii_eff()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 3.756564629e-01, change: 1.184348083e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.827e-06
# 	ne Err =  1.076e-03, ne change =  4.894e-04
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.793e-04
# __________________________________________
# TF Iteration 1
# 	μ = 3.756564657e-01, change: 7.434076466e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.818e-05
# 	ne Err =  1.064e-03, ne change =  4.842e-04
# 	Q = -3.638e-12 ->  3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  5.183e-04
# __________________________________________
# TF Iteration 2
# 	μ = 3.756564586e-01, change: 1.876928546e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.731e-05
# 	ne Err =  1.053e-03, ne change =  4.790e-04
# 	Q =  3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  5.127e-04
# __________________________________________
# TF Iteration 3
# 	μ = 3.756564668e-01, change: 2.173680325e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.645e-05
# 	ne Err =  1.041e-03, ne change =  4.738e-04
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  5.071e-04
# __________________________________________
# TF Iteration 4
# 	μ = 3.756564593e-01, change: 1.980919739e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.560e-05
# 	ne Err =  1.030e-03, ne change =  4.687e-04
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  5.017e-04
# __________________________________________
# TF Iteration 5
# 	μ = 3.756564664e-01, change: 1.879270140e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.477e-05
# 	ne Err =  1.018e-03, ne change =  4.637e-04
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.962e-04
# __________________________________________
# TF Iteration 6
# 	μ = 3.756564596e-01, change: 1.798090510e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.393e-05
# 	ne Err =  1.007e-03, ne change =  4.587e-04
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.909e-04
# __________________________________________
# TF Iteration 7
# 	μ = 3.756564660e-01, change: 1.693986218e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.311e-05
# 	ne Err =  9.961e-04, ne change =  4.538e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.856e-04
# __________________________________________
# TF Iteration 8
# 	μ = 3.756564599e-01, change: 1.614926359e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.230e-05
# 	ne Err =  9.852e-04, ne change =  4.490e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.803e-04
# __________________________________________
# TF Iteration 9
# 	μ = 3.756564657e-01, change: 1.528944527e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.150e-05
# 	ne Err =  9.744e-04, ne change =  4.441e-04
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.752e-04
# __________________________________________
# TF Iteration 25
# 	μ = 3.756564641e-01, change: 6.635956895e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.974e-05
# 	ne Err =  8.174e-04, ne change =  3.742e-04
# 	Q =  0.000e+00 ->  3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.997e-04
# __________________________________________
# TF Iteration 50
# 	μ = 3.756564626e-01, change: 1.805303573e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.504e-05
# 	ne Err =  6.221e-04, ne change =  2.872e-04
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.056e-04
# __________________________________________
# TF Iteration 75
# 	μ = 3.756564630e-01, change: 4.949385346e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.392e-05
# 	ne Err =  4.742e-04, ne change =  2.210e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.342e-04
# __________________________________________
# TF Iteration 100
# 	μ = 3.756564629e-01, change: 1.367940206e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.554e-05
# 	ne Err =  3.619e-04, ne change =  1.704e-04
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.797e-04
# __________________________________________
# TF Iteration 125
# 	μ = 3.756564629e-01, change: 3.794320413e-11 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.923e-05
# 	ne Err =  2.765e-04, ne change =  1.316e-04
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.381e-04
# __________________________________________
# TF Iteration 150
# 	μ = 3.756564629e-01, change: 1.029865082e-11 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.449e-05
# 	ne Err =  2.114e-04, ne change =  1.018e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.063e-04
# __________________________________________
# TF Iteration 175
# 	μ = 3.756564629e-01, change: 2.951638933e-12 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.093e-05
# 	ne Err =  1.618e-04, ne change =  7.879e-05
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  8.189e-05
# __________________________________________
# TF Iteration 200
# 	μ = 3.756564629e-01, change: 7.018829962e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.244e-06
# 	ne Err =  1.240e-04, ne change =  6.103e-05
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.313e-05
# __________________________________________
# TF Iteration 225
# 	μ = 3.756564629e-01, change: 1.401101457e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.225e-06
# 	ne Err =  9.503e-05, ne change =  4.731e-05
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.870e-05
# __________________________________________
# TF Iteration 250
# 	μ = 3.756564629e-01, change: 5.551115123e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.704e-06
# 	ne Err =  7.290e-05, ne change =  3.669e-05
# 	Q =  3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.759e-05
# __________________________________________
# TF Iteration 275
# 	μ = 3.756564629e-01, change: 8.881784197e-16 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.558e-06
# 	ne Err =  5.595e-05, ne change =  2.846e-05
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.903e-05
# __________________________________________
# TF Iteration 300
# 	μ = 3.756564629e-01, change: 1.247890680e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.693e-06
# 	ne Err =  4.297e-05, ne change =  2.208e-05
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.243e-05
# __________________________________________
# TF Iteration 325
# 	μ = 3.756564629e-01, change: 2.549072065e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.040e-06
# 	ne Err =  3.301e-05, ne change =  1.714e-05
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.734e-05
# __________________________________________
# TF Iteration 350
# 	μ = 3.756564629e-01, change: 1.962874308e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.546e-06
# 	ne Err =  2.538e-05, ne change =  1.331e-05
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.340e-05
# __________________________________________
# TF Iteration 375
# 	μ = 3.756564629e-01, change: 5.373479439e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.173e-06
# 	ne Err =  1.952e-05, ne change =  1.033e-05
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.037e-05
# __________________________________________
# TF Iteration 400
# 	μ = 3.756564629e-01, change: 2.186029135e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.901e-07
# 	ne Err =  1.502e-05, ne change =  8.022e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  8.018e-06
# __________________________________________
# TF Iteration 425
# 	μ = 3.756564629e-01, change: 3.004263505e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.760e-07
# 	ne Err =  1.156e-05, ne change =  6.230e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.203e-06
# __________________________________________
# TF Iteration 450
# 	μ = 3.756564629e-01, change: 5.110356582e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.137e-07
# 	ne Err =  8.898e-06, ne change =  4.838e-06
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.800e-06
# __________________________________________
# TF Iteration 475
# 	μ = 3.756564629e-01, change: 2.873257188e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.907e-07
# 	ne Err =  6.853e-06, ne change =  3.758e-06
# 	Q = -7.276e-12 ->  3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.715e-06
# __________________________________________
# TF Iteration 500
# 	μ = 3.756564629e-01, change: 2.496891582e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.972e-07
# 	ne Err =  5.279e-06, ne change =  2.919e-06
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.876e-06
# __________________________________________
# TF Iteration 525
# 	μ = 3.756564629e-01, change: 2.566835633e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.263e-07
# 	ne Err =  4.069e-06, ne change =  2.267e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.227e-06
# __________________________________________
# TF Iteration 550
# 	μ = 3.756564629e-01, change: 7.005507285e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.724e-07
# 	ne Err =  3.136e-06, ne change =  1.761e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.724e-06
# __________________________________________
# TF Iteration 575
# 	μ = 3.756564629e-01, change: 1.496580637e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.313e-07
# 	ne Err =  2.418e-06, ne change =  1.368e-06
# 	Q = -7.276e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.335e-06
# __________________________________________
# TF Iteration 600
# 	μ = 3.756564629e-01, change: 1.549871342e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.001e-07
# 	ne Err =  1.865e-06, ne change =  1.063e-06
# 	Q =  0.000e+00 -> -7.276e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.034e-06
# __________________________________________
# TF Iteration 625
# 	μ = 3.756564629e-01, change: 2.220446049e-15 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.636e-08
# 	ne Err =  1.439e-06, ne change =  8.257e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  8.010e-07
# __________________________________________
# TF Iteration 650
# 	μ = 3.756564629e-01, change: 1.680877659e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.829e-08
# 	ne Err =  1.110e-06, ne change =  6.415e-07
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.206e-07
# __________________________________________
# TF Iteration 675
# 	μ = 3.756564629e-01, change: 1.820765760e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.449e-08
# 	ne Err =  8.567e-07, ne change =  4.984e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.808e-07
# __________________________________________
# TF Iteration 700
# 	μ = 3.756564629e-01, change: 1.432187702e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.399e-08
# 	ne Err =  6.613e-07, ne change =  3.872e-07
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.725e-07
# __________________________________________
# TF Iteration 725
# 	μ = 3.756564629e-01, change: 3.308464613e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.599e-08
# 	ne Err =  5.106e-07, ne change =  3.008e-07
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.887e-07
# __________________________________________
# TF Iteration 750
# 	μ = 3.756564629e-01, change: 5.262457137e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.985e-08
# 	ne Err =  3.943e-07, ne change =  2.337e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.237e-07
# __________________________________________
# TF Iteration 775
# 	μ = 3.756564629e-01, change: 2.664535259e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.518e-08
# 	ne Err =  3.045e-07, ne change =  1.816e-07
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.734e-07
# __________________________________________
# TF Iteration 800
# 	μ = 3.756564629e-01, change: 1.255662241e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.159e-08
# 	ne Err =  2.352e-07, ne change =  1.411e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.344e-07
# __________________________________________
# TF Iteration 825
# 	μ = 3.756564629e-01, change: 2.486899575e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.877e-09
# 	ne Err =  1.817e-07, ne change =  1.096e-07
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.042e-07
# __________________________________________
# TF Iteration 850
# 	μ = 3.756564629e-01, change: 2.009503675e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.797e-09
# 	ne Err =  1.404e-07, ne change =  8.519e-08
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  8.074e-08
# __________________________________________
# TF Iteration 875
# 	μ = 3.756564629e-01, change: 2.442490654e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.203e-09
# 	ne Err =  1.085e-07, ne change =  6.620e-08
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.259e-08
# __________________________________________
# TF Iteration 900
# 	μ = 3.756564629e-01, change: 1.134647931e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.983e-09
# 	ne Err =  8.386e-08, ne change =  5.144e-08
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.853e-08
# __________________________________________
# TF Iteration 925
# 	μ = 3.756564629e-01, change: 1.202371536e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.049e-09
# 	ne Err =  6.483e-08, ne change =  3.997e-08
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.762e-08
# __________________________________________
# TF Iteration 950
# 	μ = 3.756564629e-01, change: 9.614531393e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.330e-09
# 	ne Err =  5.012e-08, ne change =  3.106e-08
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.917e-08
# __________________________________________
# TF Iteration 975
# 	μ = 3.756564629e-01, change: 1.274536032e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.785e-09
# 	ne Err =  3.875e-08, ne change =  2.413e-08
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.262e-08
# __________________________________________
# TF Iteration 1000
# 	μ = 3.756564629e-01, change: 3.474998067e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.380e-09
# 	ne Err =  2.997e-08, ne change =  1.875e-08
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.755e-08
# __________________________________________
# TF Iteration 1025
# 	μ = 3.756564629e-01, change: 7.216449660e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.058e-09
# 	ne Err =  2.318e-08, ne change =  1.457e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.361e-08
# __________________________________________
# TF Iteration 1050
# 	μ = 3.756564629e-01, change: 1.005862060e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.091e-10
# 	ne Err =  1.793e-08, ne change =  1.132e-08
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.055e-08
# __________________________________________
# TF Iteration 1075
# 	μ = 3.756564629e-01, change: 6.661338148e-15 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.052e-10
# 	ne Err =  1.387e-08, ne change =  8.800e-09
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  8.170e-09
# __________________________________________
# TF Iteration 1100
# 	μ = 3.756564629e-01, change: 5.817568649e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.740e-10
# 	ne Err =  1.073e-08, ne change =  6.838e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.345e-09
# __________________________________________
# TF Iteration 1125
# 	μ = 3.756564629e-01, change: 2.486899575e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.780e-10
# 	ne Err =  8.299e-09, ne change =  5.314e-09
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.933e-09
# __________________________________________
# TF Iteration 1150
# 	μ = 3.756564629e-01, change: 1.554312234e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.698e-10
# 	ne Err =  6.422e-09, ne change =  4.130e-09
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.809e-09
# __________________________________________
# TF Iteration 1175
# 	μ = 3.756564629e-01, change: 3.763656053e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.237e-10
# 	ne Err =  4.969e-09, ne change =  3.209e-09
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.969e-09
# __________________________________________
# TF Iteration 1200
# 	μ = 3.756564629e-01, change: 6.472600234e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.698e-10
# 	ne Err =  3.846e-09, ne change =  2.494e-09
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.301e-09
# __________________________________________
# TF Iteration 1225
# 	μ = 3.756564629e-01, change: 4.596323322e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.285e-10
# 	ne Err =  2.977e-09, ne change =  1.938e-09
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.784e-09
# __________________________________________
# TF Iteration 1250
# 	μ = 3.756564629e-01, change: 1.756372825e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.698e-11
# 	ne Err =  2.304e-09, ne change =  1.506e-09
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.363e-09
# __________________________________________
# TF Iteration 1275
# 	μ = 3.756564629e-01, change: 3.952393968e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.347e-11
# 	ne Err =  1.784e-09, ne change =  1.171e-09
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.072e-09
# __________________________________________
# TF Iteration 1300
# 	μ = 3.756564629e-01, change: 1.418865025e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.013e-11
# 	ne Err =  1.381e-09, ne change =  9.097e-10
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  8.258e-10
# __________________________________________
# TF Iteration 1325
# 	μ = 3.756564629e-01, change: 3.352873534e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.821e-11
# 	ne Err =  1.069e-09, ne change =  7.070e-10
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.210e-10
# __________________________________________
# TF Iteration 1350
# 	μ = 3.756564629e-01, change: 6.217248938e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.107e-11
# 	ne Err =  8.277e-10, ne change =  5.495e-10
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  5.201e-10
# __________________________________________
# TF Iteration 1375
# 	μ = 3.756564629e-01, change: 5.817568649e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.768e-11
# 	ne Err =  6.410e-10, ne change =  4.271e-10
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.763e-10
# __________________________________________
# TF Iteration 1400
# 	μ = 3.756564629e-01, change: 2.886579864e-15 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.358e-11
# 	ne Err =  4.963e-10, ne change =  3.319e-10
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.919e-10
# __________________________________________
# TF Iteration 1425
# 	μ = 3.756564629e-01, change: 6.372680161e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.841e-11
# 	ne Err =  3.843e-10, ne change =  2.579e-10
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.432e-10
# __________________________________________
# TF Iteration 1450
# 	μ = 3.756564629e-01, change: 9.103828802e-15 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.382e-11
# 	ne Err =  2.977e-10, ne change =  2.005e-10
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.831e-10
# __________________________________________
# TF Iteration 1475
# 	μ = 3.756564629e-01, change: 5.084821453e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.365e-11
# 	ne Err =  2.306e-10, ne change =  1.558e-10
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.631e-10
# __________________________________________
# TF Iteration 1500
# 	μ = 3.756564629e-01, change: 9.992007222e-16 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.746e-11
# 	ne Err =  1.787e-10, ne change =  1.211e-10
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.227e-10
# __________________________________________
# TF Iteration 1525
# 	μ = 3.756564629e-01, change: 8.804068585e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.126e-11
# 	ne Err =  1.383e-10, ne change =  9.408e-11
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.013e-10
# __________________________________________
# TF Iteration 1550
# 	μ = 3.756564629e-01, change: 8.992806499e-15 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.008e-12
# 	ne Err =  1.072e-10, ne change =  7.315e-11
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.685e-11
# __________________________________________
# TF Iteration 1575
# 	μ = 3.756564629e-01, change: 4.418687638e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.549e-11
# 	ne Err =  8.306e-11, ne change =  5.687e-11
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.381e-11
# __________________________________________
# TF Iteration 1600
# 	μ = 3.756564629e-01, change: 1.114663917e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.729e-11
# 	ne Err =  6.432e-11, ne change =  4.418e-11
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  4.908e-11
# __________________________________________
# TF Iteration 1625
# 	μ = 3.756564629e-01, change: 5.950795412e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.590e-11
# 	ne Err =  4.980e-11, ne change =  3.432e-11
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.955e-11
# __________________________________________
# TF Iteration 1650
# 	μ = 3.756564629e-01, change: 4.440892099e-15 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.389e-11
# 	ne Err =  3.865e-11, ne change =  2.671e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.108e-11
# __________________________________________
# TF Iteration 1675
# 	μ = 3.756564629e-01, change: 3.863576126e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.709e-11
# 	ne Err =  2.992e-11, ne change =  2.074e-11
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.449e-11
# __________________________________________
# TF Iteration 1700
# 	μ = 3.756564629e-01, change: 4.629630013e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.357e-11
# 	ne Err =  2.318e-11, ne change =  1.612e-11
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.192e-11
# __________________________________________
# TF Iteration 1725
# 	μ = 3.756564629e-01, change: 1.219024881e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.293e-11
# 	ne Err =  1.793e-11, ne change =  1.251e-11
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.876e-11
# __________________________________________
# TF Iteration 1750
# 	μ = 3.756564629e-01, change: 2.375877273e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.501e-12
# 	ne Err =  1.396e-11, ne change =  9.764e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.243e-11
# __________________________________________
# TF Iteration 1775
# 	μ = 3.756564629e-01, change: 2.231548279e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.296e-11
# 	ne Err =  1.078e-11, ne change =  7.563e-12
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.427e-11
# __________________________________________
# TF Iteration 1800
# 	μ = 3.756564629e-01, change: 2.886579864e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.577e-11
# 	ne Err =  8.379e-12, ne change =  5.893e-12
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.456e-11
# __________________________________________
# TF Iteration 1825
# 	μ = 3.756564629e-01, change: 6.949996134e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.621e-12
# 	ne Err =  6.531e-12, ne change =  4.603e-12
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.723e-12
# __________________________________________
# TF Iteration 1850
# 	μ = 3.756564629e-01, change: 5.817568649e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.346e-12
# 	ne Err =  5.067e-12, ne change =  3.580e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.956e-12
# __________________________________________
# TF Iteration 1875
# 	μ = 3.756564629e-01, change: 1.145750161e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.319e-12
# 	ne Err =  3.919e-12, ne change =  2.777e-12
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  6.926e-12
# __________________________________________
# TF Iteration 1900
# 	μ = 3.756564629e-01, change: 2.220446049e-15 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.234e-11
# 	ne Err =  3.038e-12, ne change =  2.159e-12
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.536e-11
# __________________________________________
# TF Iteration 1925
# 	μ = 3.756564629e-01, change: 1.583178033e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.932e-11
# 	ne Err =  2.278e-12, ne change =  1.626e-12
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  1.321e-11
# __________________________________________
# TF Iteration 1950
# 	μ = 3.756564629e-01, change: 4.196643033e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.744e-12
# 	ne Err =  1.757e-12, ne change =  1.258e-12
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  2.753e-12
# __________________________________________
# TF Iteration 1975
# 	μ = 3.756564629e-01, change: 5.206945985e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.120e-12
# 	ne Err =  1.366e-12, ne change =  9.806e-13
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  3.974e-12
# __________________________________________
# TF Iteration 2000
# 	μ = 3.756564629e-01, change: 6.106226635e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.140e-11
# 	ne Err =  1.084e-12, ne change =  7.793e-13
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  0.000e+00. Current Zstar:  2.495e+00 (converged=False)
# 	Change =  7.620e-12
# __________________________________________
# TF Iteration 2025
# 	μ = 3.881906063e-01, change: 3.470112894e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.699e-04
# 	ne Err =  1.809e-03, ne change =  7.335e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  2.676e-03
# __________________________________________
# TF Iteration 2050
# 	μ = 3.893065562e-01, change: 2.315634577e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.082e-04
# 	ne Err =  1.205e-03, ne change =  1.116e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  1.774e-03
# __________________________________________
# TF Iteration 2075
# 	μ = 3.885627877e-01, change: 1.541887488e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.277e-05
# 	ne Err =  8.028e-04, ne change =  3.760e-08
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  1.184e-03
# __________________________________________
# TF Iteration 2100
# 	μ = 3.890594940e-01, change: 1.033371595e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.877e-05
# 	ne Err =  5.380e-04, ne change =  8.195e-09
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  7.928e-04
# __________________________________________
# TF Iteration 2125
# 	μ = 3.887265091e-01, change: 6.931075219e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.260e-05
# 	ne Err =  3.609e-04, ne change =  1.552e-08
# 	Q =  0.000e+00 ->  3.638e-12,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  5.320e-04
# __________________________________________
# TF Iteration 2150
# 	μ = 3.889494776e-01, change: 4.629552564e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.189e-05
# 	ne Err =  2.409e-04, ne change =  3.327e-09
# 	Q =  3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  3.553e-04
# __________________________________________
# TF Iteration 2175
# 	μ = 3.888012819e-01, change: 3.056272135e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.437e-05
# 	ne Err =  1.591e-04, ne change =  5.932e-09
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  2.345e-04
# __________________________________________
# TF Iteration 2200
# 	μ = 3.888989380e-01, change: 2.008658861e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.496e-06
# 	ne Err =  1.045e-04, ne change =  1.424e-09
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  1.542e-04
# __________________________________________
# TF Iteration 2225
# 	μ = 3.888347762e-01, change: 1.319413052e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.204e-06
# 	ne Err =  6.867e-05, ne change =  2.167e-09
# 	Q = -7.276e-12 -> -3.638e-12,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  1.012e-04
# __________________________________________
# TF Iteration 2250
# 	μ = 3.888769289e-01, change: 8.669185864e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.097e-06
# 	ne Err =  4.511e-05, ne change =  7.100e-10
# 	Q = -3.638e-12 ->  3.638e-12,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  6.655e-05
# __________________________________________
# TF Iteration 2275
# 	μ = 3.888492355e-01, change: 5.695051398e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.679e-06
# 	ne Err =  2.964e-05, ne change =  7.656e-10
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  4.370e-05
# __________________________________________
# TF Iteration 2300
# 	μ = 3.888674294e-01, change: 3.741705931e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.768e-06
# 	ne Err =  1.947e-05, ne change =  3.801e-10
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  2.872e-05
# __________________________________________
# TF Iteration 2325
# 	μ = 3.888554764e-01, change: 2.458145912e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.157e-06
# 	ne Err =  1.279e-05, ne change =  2.597e-10
# 	Q = -7.276e-12 ->  0.000e+00,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  1.886e-05
# __________________________________________
# TF Iteration 2350
# 	μ = 3.888633293e-01, change: 1.614983646e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.625e-07
# 	ne Err =  8.405e-06, ne change =  2.028e-10
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.801e+00. Current Zstar:  2.626e+00 (converged=False)
# 	Change =  1.240e-05
# __________________________________________
# TF Iteration 2375
# 	μ = 4.022309587e-01, change: 5.315708747e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.355e-04
# 	ne Err =  2.811e-03, ne change =  1.166e-07
# 	Q =  0.000e+00 -> -7.276e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.749e+00 (converged=False)
# 	Change =  4.046e-03
# __________________________________________
# TF Iteration 2400
# 	μ = 3.996045348e-01, change: 7.689404602e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.770e-04
# 	ne Err =  4.074e-03, ne change =  1.183e-07
# 	Q = -7.276e-12 ->  3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.749e+00 (converged=False)
# 	Change =  5.941e-03
# __________________________________________
# TF Iteration 2425
# 	μ = 4.034358350e-01, change: 1.126722151e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.439e-04
# 	ne Err =  5.955e-03, ne change =  9.964e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.749e+00 (converged=False)
# 	Change =  8.619e-03
# __________________________________________
# TF Iteration 2450
# 	μ = 3.979195329e-01, change: 1.604098039e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.852e-04
# 	ne Err =  8.502e-03, ne change =  1.910e-07
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.750e+00 (converged=False)
# 	Change =  1.244e-02
# __________________________________________
# TF Iteration 2475
# 	μ = 4.058818509e-01, change: 2.336154956e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.122e-03
# 	ne Err =  1.232e-02, ne change =  2.443e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.749e+00 (converged=False)
# 	Change =  1.776e-02
# __________________________________________
# TF Iteration 2500
# 	μ = 3.947591632e-01, change: 3.175896848e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.567e-03
# 	ne Err =  1.684e-02, ne change =  3.549e-07
# 	Q =  3.638e-12 ->  3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.750e+00 (converged=False)
# 	Change =  2.482e-02
# __________________________________________
# TF Iteration 2525
# 	μ = 4.101465624e-01, change: 4.442666534e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.110e-03
# 	ne Err =  2.334e-02, ne change =  4.743e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.749e+00 (converged=False)
# 	Change =  3.342e-02
# __________________________________________
# TF Iteration 2550
# 	μ = 3.903935240e-01, change: 5.375548166e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.680e-03
# 	ne Err =  2.848e-02, ne change =  5.973e-07
# 	Q =  3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.752e+00 (converged=False)
# 	Change =  4.248e-02
# __________________________________________
# TF Iteration 2575
# 	μ = 4.149244429e-01, change: 6.777628004e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.180e-03
# 	ne Err =  3.540e-02, ne change =  7.160e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.750e+00 (converged=False)
# 	Change =  5.040e-02
# __________________________________________
# TF Iteration 2600
# 	μ = 3.872508095e-01, change: 7.034264170e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.536e-03
# 	ne Err =  3.719e-02, ne change =  7.875e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.754e+00 (converged=False)
# 	Change =  5.604e-02
# __________________________________________
# TF Iteration 2625
# 	μ = 4.177399323e-01, change: 8.070169901e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.762e-03
# 	ne Err =  4.200e-02, ne change =  8.421e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.753e+00 (converged=False)
# 	Change =  5.962e-02
# __________________________________________
# TF Iteration 2650
# 	μ = 3.861508943e-01, change: 7.725971329e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.899e-03
# 	ne Err =  4.080e-02, ne change =  8.706e-07
# 	Q = -3.638e-12 ->  3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.758e+00 (converged=False)
# 	Change =  6.177e-02
# __________________________________________
# TF Iteration 2675
# 	μ = 4.190875771e-01, change: 8.580249743e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.992e-03
# 	ne Err =  4.460e-02, ne change =  8.908e-07
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.756e+00 (converged=False)
# 	Change =  6.323e-02
# __________________________________________
# TF Iteration 2700
# 	μ = 3.858683683e-01, change: 8.030630327e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.062e-03
# 	ne Err =  4.240e-02, ne change =  9.075e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.761e+00 (converged=False)
# 	Change =  6.430e-02
# __________________________________________
# TF Iteration 2725
# 	μ = 4.200406436e-01, change: 8.871297910e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.124e-03
# 	ne Err =  4.609e-02, ne change =  9.198e-07
# 	Q =  3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.760e+00 (converged=False)
# 	Change =  6.529e-02
# __________________________________________
# TF Iteration 2750
# 	μ = 3.857741584e-01, change: 8.252541874e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.182e-03
# 	ne Err =  4.357e-02, ne change =  9.338e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.765e+00 (converged=False)
# 	Change =  6.616e-02
# __________________________________________
# TF Iteration 2775
# 	μ = 4.209447320e-01, change: 9.124770324e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.240e-03
# 	ne Err =  4.738e-02, ne change =  9.457e-07
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.764e+00 (converged=False)
# 	Change =  6.707e-02
# __________________________________________
# TF Iteration 2800
# 	μ = 3.857213155e-01, change: 8.463502933e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.297e-03
# 	ne Err =  4.469e-02, ne change =  9.589e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.769e+00 (converged=False)
# 	Change =  6.793e-02
# __________________________________________
# TF Iteration 2825
# 	μ = 4.218709517e-01, change: 9.377503253e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.356e-03
# 	ne Err =  4.868e-02, ne change =  9.715e-07
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.768e+00 (converged=False)
# 	Change =  6.885e-02
# __________________________________________
# TF Iteration 2850
# 	μ = 3.856838873e-01, change: 8.676627442e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.414e-03
# 	ne Err =  4.581e-02, ne change =  9.844e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.774e+00 (converged=False)
# 	Change =  6.971e-02
# __________________________________________
# TF Iteration 2875
# 	μ = 4.228325317e-01, change: 9.635787868e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.474e-03
# 	ne Err =  5.000e-02, ne change =  9.978e-07
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.772e+00 (converged=False)
# 	Change =  7.066e-02
# __________________________________________
# TF Iteration 2900
# 	μ = 3.856585816e-01, change: 8.894011331e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.533e-03
# 	ne Err =  4.696e-02, ne change =  1.011e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.778e+00 (converged=False)
# 	Change =  7.154e-02
# __________________________________________
# TF Iteration 2925
# 	μ = 4.238328368e-01, change: 9.900673054e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.595e-03
# 	ne Err =  5.136e-02, ne change =  1.025e-06
# 	Q =  7.276e-12 -> -7.276e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.777e+00 (converged=False)
# 	Change =  7.251e-02
# __________________________________________
# TF Iteration 2950
# 	μ = 3.856458149e-01, change: 9.115968587e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.656e-03
# 	ne Err =  4.813e-02, ne change =  1.038e-06
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.783e+00 (converged=False)
# 	Change =  7.342e-02
# __________________________________________
# TF Iteration 2975
# 	μ = 4.248739423e-01, change: 1.017245390e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.719e-03
# 	ne Err =  5.274e-02, ne change =  1.052e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.781e+00 (converged=False)
# 	Change =  7.440e-02
# __________________________________________
# TF Iteration 3000
# 	μ = 3.856465767e-01, change: 9.342561027e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.782e-03
# 	ne Err =  4.933e-02, ne change =  1.065e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.788e+00 (converged=False)
# 	Change =  7.533e-02
# __________________________________________
# TF Iteration 3025
# 	μ = 4.259577079e-01, change: 1.045128653e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.847e-03
# 	ne Err =  5.417e-02, ne change =  1.080e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.786e+00 (converged=False)
# 	Change =  7.634e-02
# __________________________________________
# TF Iteration 3050
# 	μ = 3.856619717e-01, change: 9.573823355e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.911e-03
# 	ne Err =  5.055e-02, ne change =  1.094e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.793e+00 (converged=False)
# 	Change =  7.729e-02
# __________________________________________
# TF Iteration 3075
# 	μ = 4.270860338e-01, change: 1.073730497e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.978e-03
# 	ne Err =  5.563e-02, ne change =  1.109e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.792e+00 (converged=False)
# 	Change =  7.833e-02
# __________________________________________
# TF Iteration 3100
# 	μ = 3.856931737e-01, change: 9.809786215e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.044e-03
# 	ne Err =  5.179e-02, ne change =  1.123e-06
# 	Q =  0.000e+00 ->  3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.799e+00 (converged=False)
# 	Change =  7.930e-02
# __________________________________________
# TF Iteration 3125
# 	μ = 4.282609065e-01, change: 1.103063961e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.112e-03
# 	ne Err =  5.712e-02, ne change =  1.139e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.798e+00 (converged=False)
# 	Change =  8.036e-02
# __________________________________________
# TF Iteration 3150
# 	μ = 3.857414311e-01, change: 1.005047364e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.180e-03
# 	ne Err =  5.306e-02, ne change =  1.153e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.805e+00 (converged=False)
# 	Change =  8.135e-02
# __________________________________________
# TF Iteration 3175
# 	μ = 4.294844163e-01, change: 1.133142261e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.250e-03
# 	ne Err =  5.865e-02, ne change =  1.169e-06
# 	Q = -3.638e-12 -> -7.276e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.803e+00 (converged=False)
# 	Change =  8.243e-02
# __________________________________________
# TF Iteration 3200
# 	μ = 3.858080664e-01, change: 1.029590433e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.319e-03
# 	ne Err =  5.436e-02, ne change =  1.183e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.811e+00 (converged=False)
# 	Change =  8.344e-02
# __________________________________________
# TF Iteration 3225
# 	μ = 4.307587421e-01, change: 1.163977879e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.391e-03
# 	ne Err =  6.022e-02, ne change =  1.200e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.810e+00 (converged=False)
# 	Change =  8.455e-02
# __________________________________________
# TF Iteration 3250
# 	μ = 3.858944890e-01, change: 1.054608540e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.462e-03
# 	ne Err =  5.567e-02, ne change =  1.214e-06
# 	Q =  3.638e-12 -> -7.276e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.818e+00 (converged=False)
# 	Change =  8.558e-02
# __________________________________________
# TF Iteration 3275
# 	μ = 4.320861764e-01, change: 1.195583475e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.536e-03
# 	ne Err =  6.183e-02, ne change =  1.231e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.816e+00 (converged=False)
# 	Change =  8.672e-02
# __________________________________________
# TF Iteration 3300
# 	μ = 3.860021747e-01, change: 1.080102543e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.609e-03
# 	ne Err =  5.701e-02, ne change =  1.246e-06
# 	Q =  0.000e+00 ->  3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.825e+00 (converged=False)
# ...
# 	Change =  1.178e-01
# __________________________________________
# TF Iteration 3925
# 	μ = 4.554301146e-01, change: 1.681171749e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.784e-03
# 	ne Err =  8.628e-02, ne change =  1.717e-06
# 	Q = -3.638e-12 ->  3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.946e+00 (converged=False)
# 	Change =  1.193e-01
# __________________________________________
# TF Iteration 3950
# 	μ = 3.901836430e-01, change: 1.453824766e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.883e-03
# 	ne Err =  7.653e-02, ne change =  1.736e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.960e+00 (converged=False)
# 	Change =  1.206e-01
# __________________________________________
# TF Iteration 3975
# 	μ = 4.578088197e-01, change: 1.724464832e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.987e-03
# 	ne Err =  8.844e-02, ne change =  1.761e-06
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.960e+00 (converged=False)
# 	Change =  1.221e-01
# __________________________________________
# TF Iteration 4000
# 	μ = 3.908007522e-01, change: 1.485579384e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.089e-03
# 	ne Err =  7.817e-02, ne change =  1.780e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.974e+00 (converged=False)
# 	Change =  1.234e-01
# __________________________________________
# TF Iteration 4025
# 	μ = 4.602904462e-01, change: 1.768619774e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.195e-03
# 	ne Err =  9.065e-02, ne change =  1.805e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.975e+00 (converged=False)
# 	Change =  1.250e-01
# __________________________________________
# TF Iteration 4050
# 	μ = 3.914743443e-01, change: 1.517704481e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.299e-03
# 	ne Err =  7.982e-02, ne change =  1.824e-06
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.990e+00 (converged=False)
# 	Change =  1.263e-01
# __________________________________________
# TF Iteration 4075
# 	μ = 4.628792364e-01, change: 1.813609029e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.408e-03
# 	ne Err =  9.288e-02, ne change =  1.850e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  2.991e+00 (converged=False)
# 	Change =  1.279e-01
# __________________________________________
# TF Iteration 4100
# 	μ = 3.922076683e-01, change: 1.550187988e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.514e-03
# 	ne Err =  8.149e-02, ne change =  1.869e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.006e+00 (converged=False)
# 	Change =  1.293e-01
# __________________________________________
# TF Iteration 4125
# 	μ = 4.655800971e-01, change: 1.859432074e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.625e-03
# 	ne Err =  9.516e-02, ne change =  1.895e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.007e+00 (converged=False)
# 	Change =  1.309e-01
# __________________________________________
# TF Iteration 4150
# 	μ = 3.930046046e-01, change: 1.583001977e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.734e-03
# 	ne Err =  8.317e-02, ne change =  1.915e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.024e+00 (converged=False)
# 	Change =  1.322e-01
# __________________________________________
# TF Iteration 4175
# 	μ = 4.683980023e-01, change: 1.906079710e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.848e-03
# 	ne Err =  9.748e-02, ne change =  1.942e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.025e+00 (converged=False)
# 	Change =  1.339e-01
# __________________________________________
# TF Iteration 4200
# 	μ = 3.938688500e-01, change: 1.616128932e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.958e-03
# 	ne Err =  8.487e-02, ne change =  1.962e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.042e+00 (converged=False)
# 	Change =  1.353e-01
# __________________________________________
# TF Iteration 4225
# 	μ = 4.713378758e-01, change: 1.953525943e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.074e-03
# 	ne Err =  9.983e-02, ne change =  1.989e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.043e+00 (converged=False)
# 	Change =  1.369e-01
# __________________________________________
# TF Iteration 4250
# 	μ = 3.948043055e-01, change: 1.649547229e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.187e-03
# 	ne Err =  8.657e-02, ne change =  2.010e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.061e+00 (converged=False)
# 	Change =  1.383e-01
# __________________________________________
# TF Iteration 4275
# 	μ = 4.744051743e-01, change: 2.001756870e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.306e-03
# 	ne Err =  1.022e-01, ne change =  2.037e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.063e+00 (converged=False)
# 	Change =  1.400e-01
# __________________________________________
# TF Iteration 4300
# 	μ = 3.958151275e-01, change: 1.683234605e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.421e-03
# 	ne Err =  8.828e-02, ne change =  2.058e-06
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.082e+00 (converged=False)
# 	Change =  1.414e-01
# __________________________________________
# TF Iteration 4325
# 	μ = 4.776055047e-01, change: 2.050753303e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.543e-03
# 	ne Err =  1.046e-01, ne change =  2.086e-06
# 	Q = -3.638e-12 ->  3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.084e+00 (converged=False)
# 	Change =  1.431e-01
# __________________________________________
# TF Iteration 4350
# 	μ = 3.969057184e-01, change: 1.717162069e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.660e-03
# 	ne Err =  8.999e-02, ne change =  2.107e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.103e+00 (converged=False)
# 	Change =  1.445e-01
# __________________________________________
# TF Iteration 4375
# 	μ = 4.809444227e-01, change: 2.100484885e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.784e-03
# 	ne Err =  1.071e-01, ne change =  2.136e-06
# 	Q =  0.000e+00 -> -7.276e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.105e+00 (converged=False)
# 	Change =  1.463e-01
# __________________________________________
# TF Iteration 4400
# 	μ = 3.980805662e-01, change: 1.751303384e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.903e-03
# 	ne Err =  9.171e-02, ne change =  2.156e-06
# 	Q =  3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.126e+00 (converged=False)
# 	Change =  1.477e-01
# __________________________________________
# TF Iteration 4425
# 	μ = 4.844281051e-01, change: 2.150929301e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.003e-02
# 	ne Err =  1.096e-01, ne change =  2.186e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.128e+00 (converged=False)
# 	Change =  1.495e-01
# __________________________________________
# TF Iteration 4450
# 	μ = 3.993444286e-01, change: 1.785628614e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.015e-02
# 	ne Err =  9.343e-02, ne change =  2.207e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.150e+00 (converged=False)
# 	Change =  1.509e-01
# __________________________________________
# TF Iteration 4475
# 	μ = 4.880625843e-01, change: 2.202050009e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.028e-02
# 	ne Err =  1.121e-01, ne change =  2.237e-06
# 	Q =  3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.153e+00 (converged=False)
# 	Change =  1.527e-01
# __________________________________________
# TF Iteration 4500
# 	μ = 4.007021977e-01, change: 1.820109766e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.040e-02
# 	ne Err =  9.515e-02, ne change =  2.258e-06
# 	Q =  3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.175e+00 (converged=False)
# 	Change =  1.541e-01
# __________________________________________
# TF Iteration 4525
# 	μ = 4.918542561e-01, change: 2.253810185e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.054e-02
# 	ne Err =  1.146e-01, ne change =  2.288e-06
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.178e+00 (converged=False)
# 	Change =  1.559e-01
# __________________________________________
# TF Iteration 4550
# 	μ = 4.021590538e-01, change: 1.854712307e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.066e-02
# 	ne Err =  9.686e-02, ne change =  2.309e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.201e+00 (converged=False)
# 	Change =  1.574e-01
# __________________________________________
# TF Iteration 4575
# 	μ = 4.958099037e-01, change: 2.306178054e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.080e-02
# 	ne Err =  1.172e-01, ne change =  2.340e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.205e+00 (converged=False)
# 	Change =  1.592e-01
# __________________________________________
# TF Iteration 4600
# 	μ = 4.037203763e-01, change: 1.889401096e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.092e-02
# 	ne Err =  9.857e-02, ne change =  2.361e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.229e+00 (converged=False)
# 	Change =  1.606e-01
# __________________________________________
# TF Iteration 4625
# 	μ = 4.999363506e-01, change: 2.359106926e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.106e-02
# 	ne Err =  1.198e-01, ne change =  2.393e-06
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.234e+00 (converged=False)
# 	Change =  1.625e-01
# __________________________________________
# TF Iteration 4650
# 	μ = 4.053915873e-01, change: 1.924146380e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.119e-02
# 	ne Err =  1.003e-01, ne change =  2.413e-06
# 	Q = -7.276e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.259e+00 (converged=False)
# 	Change =  1.639e-01
# __________________________________________
# TF Iteration 4675
# 	μ = 5.042407523e-01, change: 2.412552522e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.133e-02
# 	ne Err =  1.224e-01, ne change =  2.446e-06
# 	Q = -7.276e-12 ->  3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.263e+00 (converged=False)
# 	Change =  1.658e-01
# __________________________________________
# TF Iteration 4700
# 	μ = 4.071785829e-01, change: 1.958908158e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.146e-02
# 	ne Err =  1.020e-01, ne change =  2.466e-06
# 	Q =  3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.290e+00 (converged=False)
# 	Change =  1.672e-01
# __________________________________________
# TF Iteration 4725
# 	μ = 5.087305667e-01, change: 2.466467819e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.160e-02
# 	ne Err =  1.250e-01, ne change =  2.499e-06
# 	Q =  0.000e+00 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.295e+00 (converged=False)
# 	Change =  1.691e-01
# __________________________________________
# TF Iteration 4750
# 	μ = 4.090871936e-01, change: 1.993655258e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.173e-02
# 	ne Err =  1.036e-01, ne change =  2.519e-06
# 	Q =  0.000e+00 -> -7.276e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.322e+00 (converged=False)
# 	Change =  1.705e-01
# __________________________________________
# TF Iteration 4775
# 	μ = 5.134135025e-01, change: 2.520804378e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.188e-02
# 	ne Err =  1.277e-01, ne change =  2.552e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.328e+00 (converged=False)
# 	Change =  1.724e-01
# __________________________________________
# TF Iteration 4800
# 	μ = 4.111236151e-01, change: 2.028351772e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.201e-02
# 	ne Err =  1.053e-01, ne change =  2.572e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.357e+00 (converged=False)
# 	Change =  1.739e-01
# __________________________________________
# TF Iteration 4825
# 	μ = 5.182975927e-01, change: 2.575510024e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.216e-02
# 	ne Err =  1.303e-01, ne change =  2.606e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.363e+00 (converged=False)
# 	Change =  1.757e-01
# __________________________________________
# TF Iteration 4850
# 	μ = 4.132942261e-01, change: 2.062961326e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.229e-02
# 	ne Err =  1.070e-01, ne change =  2.625e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.393e+00 (converged=False)
# 	Change =  1.772e-01
# __________________________________________
# TF Iteration 4875
# 	μ = 5.233913670e-01, change: 2.630537218e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.244e-02
# 	ne Err =  1.330e-01, ne change =  2.660e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.400e+00 (converged=False)
# 	Change =  1.791e-01
# __________________________________________
# TF Iteration 4900
# 	μ = 4.156054985e-01, change: 2.097453846e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.258e-02
# 	ne Err =  1.086e-01, ne change =  2.678e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.432e+00 (converged=False)
# 	Change =  1.805e-01
# __________________________________________
# TF Iteration 4925
# 	μ = 5.287035783e-01, change: 2.685835947e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.273e-02
# 	ne Err =  1.357e-01, ne change =  2.713e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.439e+00 (converged=False)
# 	Change =  1.824e-01
# __________________________________________
# TF Iteration 4950
# 	μ = 4.180641583e-01, change: 2.131797322e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.287e-02
# 	ne Err =  1.102e-01, ne change =  2.731e-06
# 	Q = -7.276e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.472e+00 (converged=False)
# 	Change =  1.838e-01
# __________________________________________
# TF Iteration 4975
# 	μ = 5.342435753e-01, change: 2.741360793e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.302e-02
# 	ne Err =  1.384e-01, ne change =  2.767e-06
# 	Q = -3.638e-12 ->  0.000e+00,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.480e+00 (converged=False)
# 	Change =  1.857e-01
# __________________________________________
# TF Iteration 5000
# 	mu =     0.5370, change: 2.7681e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.316e-02
# 	ne Err =  1.397e-01, ne change =  2.792e-06
# 	Q = -3.638e-12 -> -3.638e-12,
# 	Zstar guess =  3.862e+00. Current Zstar:  3.501e+00 (converged=False)
# 	Change =  1.873e-01
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 2.290e+05
# QUIT: Total error infinite.
# Exiting status 1, reverting to best index so far: 1
# Final iter:21, Total Error: 4.478e+04
# CPU times: user 35.4 s, sys: 1.22 s, total: 36.7 s
# Wall time: 35.5 s
# /home/zach/plasma/hnc/hnc/hnc.py:648: RuntimeWarning: overflow encountered in exp
#   hnc_err = np.linalg.norm(- 1 - self.h_r_matrix   + np.exp( -self.βu_r_matrix + self.h_r_matrix - self.c_r_matrix ))/np.sqrt(self.N_bins*self.N_species**2)
# /home/zach/plasma/hnc/hnc/hnc.py:432: RuntimeWarning: overflow encountered in exp
#   tot_eqn =  1 + h_r_matrix  - np.exp(-self.βu_s_r_matrix + h_r_matrix - c_s_r_matrix )
# /home/zach/plasma/hnc/hnc/hnc.py:518: RuntimeWarning: overflow encountered in exp
#   h_r_matrix = -1 + np.exp(γs_r_matrix - self.βu_s_r_matrix) # 2. γ_r,u_s_r  -> h_r   (HNC)
# /home/zach/plasma/hnc/hnc/hnc.py:656: RuntimeWarning: invalid value encountered in subtract
#   Δ_err = np.array(self.tot_err_list[-iters_to_check:-2]) - np.array(self.tot_err_list[-iters_to_check + 1:-1])

# %%
limiting_μ = npa.get_μ_infinite()
neutral_μ = npa.get_μ_neutral()
print(f"Neutral μ = {neutral_μ:0.9e}, vs. r->infinity μ={limiting_μ:0.9e}, {neutral_μ/limiting_μ - 1:0.9e}")
# Final μ = 5.66492e-01, vs. expected r->infinity μ=5.66507e-01, Err=-2.664e-05
# Out:
# Neutral μ = 5.580668535e-01, vs. r->infinity μ=5.579922573e-01, 1.336867315e-04

# %%
# %%time
from scipy.interpolate import interp1d
aa.solve_TF(verbose=True, picard_alpha=0.2, tol=1e-12)
aa.set_uii_eff()
aa.iet.HNC_solve(iters_to_wait=1e5, alpha_Picard=1e-2, tol=1e-12, verbose=False, num_iterations=1e5)
aa.gii = interp1d(aa.iet.r_array*aa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(aa.grid.xs)
# npa_2.gii = interp1d(npa.iet.r_array*npa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(npa.grid.xs)
aa.make_ρi()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 9.164708467e-01, change: 1.417829784e+00 (converged=False)
# 	φe Err =  0.000e+00, φe change =  7.635e-01
# 	ne Err =  5.679e-01, ne change =  4.000e-03
# 	Q =  0.000e+00 ->  2.108e+00,
# 	Zstar guess =  9.849e+00. Current Zstar:  3.966e+00 (converged=False)
# 	Change =  2.025e+00
# __________________________________________
# TF Iteration 1
# 	μ = 4.851105479e-01, change: 4.706754180e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  9.006e-02
# 	ne Err =  3.197e-01, ne change =  2.458e-03
# 	Q =  2.108e+00 ->  2.720e-01,
# 	Zstar guess =  5.970e+00. Current Zstar:  4.367e+00 (converged=False)
# 	Change =  5.180e-01
# __________________________________________
# TF Iteration 2
# 	μ = -7.315851771e+00, change: 1.608079303e+01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.000e+00
# 	ne Err =  2.922e-01, ne change =  2.403e-03
# 	Q =  2.720e-01 -> -1.073e+01,
# 	Zstar guess = -1.013e+01. Current Zstar:  1.468e+00 (converged=False)
# 	Change =  2.069e+00
# __________________________________________
# TF Iteration 3
# 	μ = -7.315850473e+00, change: 1.774100294e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.826e-01
# 	ne Err =  2.352e-01, ne change =  1.182e-03
# 	Q = -1.073e+01 -> -8.586e+00,
# 	Zstar guess = -8.149e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  6.645e-01
# __________________________________________
# TF Iteration 4
# 	μ = -7.315850473e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.938e-02
# 	ne Err =  1.887e-01, ne change =  9.447e-04
# 	Q = -8.586e+00 -> -6.868e+00,
# 	Zstar guess = -6.547e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  8.375e-02
# __________________________________________
# TF Iteration 5
# 	μ = -7.315850473e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.790e-02
# 	ne Err =  1.510e-01, ne change =  7.550e-04
# 	Q = -6.868e+00 -> -5.495e+00,
# 	Zstar guess = -5.255e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  9.335e-02
# __________________________________________
# TF Iteration 6
# 	μ = -7.315850473e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.059e-01
# 	ne Err =  1.207e-01, ne change =  6.035e-04
# 	Q = -5.495e+00 -> -4.396e+00,
# 	Zstar guess = -4.215e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.022e-01
# __________________________________________
# TF Iteration 7
# 	μ = -7.315850473e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.133e-01
# 	ne Err =  9.648e-02, ne change =  4.825e-04
# 	Q = -4.396e+00 -> -3.517e+00,
# 	Zstar guess = -3.378e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.103e-01
# __________________________________________
# TF Iteration 8
# 	μ = -7.315850473e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.199e-01
# 	ne Err =  7.708e-02, ne change =  3.858e-04
# 	Q = -3.517e+00 -> -2.813e+00,
# 	Zstar guess = -2.707e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.175e-01
# __________________________________________
# TF Iteration 9
# 	μ = -7.315850473e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.258e-01
# 	ne Err =  6.158e-02, ne change =  3.085e-04
# 	Q = -2.813e+00 -> -2.251e+00,
# 	Zstar guess = -2.168e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.239e-01
# __________________________________________
# TF Iteration 25
# 	μ = -7.315864266e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.551e-01
# 	ne Err =  1.721e-03, ne change =  8.677e-06
# 	Q = -7.920e-02 -> -6.337e-02,
# 	Zstar guess = -6.193e-02. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.551e-01
# __________________________________________
# TF Iteration 50
# 	μ = -7.327305341e+00, change: 1.397742628e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.564e-01
# 	ne Err =  4.196e-04, ne change =  2.132e-06
# 	Q = -7.003e-03 -> -9.025e-03,
# 	Zstar guess = -9.659e-03. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.574e-01
# __________________________________________
# TF Iteration 75
# 	μ = -8.511285818e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.428e-01
# 	ne Err =  1.436e-01, ne change =  9.742e-04
# 	Q = -1.785e+00 -> -2.856e+00,
# 	Zstar guess = -2.856e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  2.467e-01
# __________________________________________
# TF Iteration 100
# 	μ = -7.315850455e+00, change: 1.113344175e+01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.813e-02
# 	ne Err =  6.907e-01, ne change =  9.244e-04
# 	Q = -5.004e+01 -> -5.213e+01,
# 	Zstar guess = -4.269e+01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.114e+00
# __________________________________________
# TF Iteration 125
# 	μ = -7.315853860e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.524e-01
# 	ne Err =  4.354e-03, ne change =  7.643e-07
# 	Q = -2.462e-01 -> -1.970e-01,
# 	Zstar guess = -1.936e-01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.522e-01
# __________________________________________
# TF Iteration 150
# 	μ = -7.318889589e+00, change: 3.708613321e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.562e-01
# 	ne Err =  1.213e-04, ne change =  5.566e-07
# 	Q = -2.710e-03 -> -3.076e-03,
# 	Zstar guess = -3.700e-03. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.565e-01
# __________________________________________
# TF Iteration 175
# 	μ = -7.591822222e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.719e-01
# 	ne Err =  2.421e-02, ne change =  1.591e-04
# 	Q = -3.494e-01 -> -4.903e-01,
# 	Zstar guess = -4.910e-01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.725e-01
# __________________________________________
# TF Iteration 200
# 	μ = -2.338382213e+00, change: 7.979238546e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.978e-02
# 	ne Err =  5.890e-01, ne change =  2.248e-03
# 	Q =  9.513e+00 ->  9.499e+00,
# 	Zstar guess =  9.499e+00. Current Zstar:  9.748e+00 (converged=False)
# 	Change =  8.288e-01
# __________________________________________
# TF Iteration 225
# 	μ = -7.349213086e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.885e-02
# 	ne Err =  2.295e-01, ne change =  6.973e-05
# 	Q = -1.167e+01 -> -9.333e+00,
# 	Zstar guess = -9.329e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  4.086e-02
# __________________________________________
# TF Iteration 250
# 	μ = -1.525391680e+01, change: 9.769155447e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.949e-01
# 	ne Err =  2.172e-01, ne change =  1.482e-03
# 	Q = -3.406e+00 -> -5.620e+00,
# 	Zstar guess = -5.621e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  7.427e-01
# __________________________________________
# TF Iteration 275
# 	μ = -9.132410226e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.186e-02
# 	ne Err =  8.282e-02, ne change =  2.892e-04
# 	Q =  4.596e+00 ->  4.893e+00,
# 	Zstar guess =  4.893e+00. Current Zstar:  5.827e+00 (converged=False)
# 	Change =  7.260e-02
# __________________________________________
# TF Iteration 300
# 	μ = -7.315849684e+00, change: 4.404750453e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.581e-02
# 	ne Err =  9.708e-02, ne change =  2.375e-05
# 	Q = -5.136e+00 -> -4.109e+00,
# 	Zstar guess = -4.090e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  9.172e-02
# __________________________________________
# TF Iteration 325
# 	μ = -7.315843742e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.559e-01
# 	ne Err =  3.768e-04, ne change =  9.174e-08
# 	Q = -1.940e-02 -> -1.551e-02,
# 	Zstar guess = -1.608e-02. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.558e-01
# __________________________________________
# TF Iteration 350
# 	μ = -7.310993675e+00, change: 5.924934544e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.561e-01
# 	ne Err =  1.760e-04, ne change =  8.900e-07
# 	Q =  2.771e-03 ->  3.667e-03,
# 	Zstar guess =  3.032e-03. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.565e-01
# __________________________________________
# TF Iteration 375
# 	μ = -6.922644978e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.368e-01
# 	ne Err =  2.796e-02, ne change =  1.851e-04
# 	Q =  4.526e-01 ->  5.974e-01,
# 	Zstar guess =  5.968e-01. Current Zstar:  3.396e-01 (converged=False)
# 	Change =  1.368e-01
# __________________________________________
# TF Iteration 400
# 	μ = -5.250812350e-01, change: 7.263750377e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.031e-03
# 	ne Err =  2.012e-01, ne change =  3.127e-04
# 	Q =  4.689e+00 ->  4.791e+00,
# 	Zstar guess =  4.792e+00. Current Zstar:  4.313e+00 (converged=False)
# 	Change =  7.042e-01
# __________________________________________
# TF Iteration 425
# 	μ = -7.317684784e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.366e-01
# 	ne Err =  2.749e-02, ne change =  9.132e-06
# 	Q = -1.318e+00 -> -1.056e+00,
# 	Zstar guess = -1.055e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.353e-01
# __________________________________________
# TF Iteration 450
# 	μ = -8.505500453e+00, change: 1.456176940e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.804e-01
# 	ne Err =  4.136e-02, ne change =  2.200e-04
# 	Q = -6.614e-01 -> -8.968e-01,
# 	Zstar guess = -8.975e-01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  2.773e-01
# __________________________________________
# TF Iteration 475
# 	μ = 6.363749416e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.069e-02
# 	ne Err =  2.806e-01, ne change =  2.843e-03
# 	Q = -2.729e+01 -> -3.351e+01,
# 	Zstar guess = -3.107e+01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  7.260e-02
# __________________________________________
# TF Iteration 500
# 	μ = -7.315854170e+00, change: 4.896480712e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.455e-01
# 	ne Err =  1.291e-02, ne change =  2.304e-06
# 	Q = -7.240e-01 -> -5.792e-01,
# 	Zstar guess = -5.691e-01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.448e-01
# __________________________________________
# TF Iteration 525
# 	μ = -7.316202024e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.562e-01
# 	ne Err =  4.377e-05, ne change =  1.856e-07
# 	Q = -3.163e-03 -> -2.772e-03,
# 	Zstar guess = -3.370e-03. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.561e-01
# __________________________________________
# TF Iteration 550
# 	μ = -7.614686102e+00, change: 3.650056097e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.624e-01
# 	ne Err =  1.076e-02, ne change =  5.492e-05
# 	Q = -1.724e-01 -> -2.279e-01,
# 	Zstar guess = -2.286e-01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.880e-01
# __________________________________________
# TF Iteration 575
# 	μ = -1.219003835e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.612e-02
# 	ne Err =  5.656e-01, ne change =  1.590e-03
# 	Q =  2.557e+00 ->  4.250e+00,
# 	Zstar guess =  9.070e+00. Current Zstar:  9.980e+00 (converged=False)
# 	Change =  9.925e-02
# __________________________________________
# TF Iteration 600
# 	μ = -7.315891960e+00, change: 1.716931679e+01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.347e-02
# 	ne Err =  5.695e-01, ne change =  6.321e-04
# 	Q = -3.017e+01 -> -3.155e+01,
# 	Zstar guess = -3.152e+01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  9.595e-01
# __________________________________________
# TF Iteration 625
# 	μ = -7.316280691e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.538e-01
# 	ne Err =  3.068e-03, ne change =  7.543e-07
# 	Q = -1.495e-01 -> -1.199e-01,
# 	Zstar guess = -1.204e-01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.537e-01
# __________________________________________
# TF Iteration 650
# 	μ = -7.666715558e+00, change: 4.286042920e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.635e-01
# 	ne Err =  1.261e-02, ne change =  6.451e-05
# 	Q = -2.024e-01 -> -2.678e-01,
# 	Zstar guess = -2.684e-01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.935e-01
# __________________________________________
# TF Iteration 675
# 	μ = -1.390087073e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.884e-02
# 	ne Err =  3.137e-01, ne change =  2.518e-03
# 	Q =  8.392e+00 ->  8.908e+00,
# 	Zstar guess =  8.907e+00. Current Zstar:  9.922e+00 (converged=False)
# 	Change =  1.072e-01
# __________________________________________
# TF Iteration 700
# 	μ = -7.315757900e+00, change: 8.420105091e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.190e-01
# 	ne Err =  6.195e-01, ne change =  9.819e-05
# 	Q = -3.884e+01 -> -3.740e+01,
# 	Zstar guess = -3.697e+01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.007e+00
# __________________________________________
# TF Iteration 725
# 	μ = -7.314996537e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.532e-01
# 	ne Err =  3.778e-03, ne change =  3.704e-06
# 	Q = -1.757e-01 -> -1.400e-01,
# 	Zstar guess = -1.405e-01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.531e-01
# __________________________________________
# TF Iteration 750
# 	μ = -6.732025083e+00, change: 7.105918323e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.438e-01
# 	ne Err =  2.171e-02, ne change =  1.063e-04
# 	Q =  3.519e-01 ->  4.527e-01,
# 	Zstar guess =  4.521e-01. Current Zstar:  2.333e-01 (converged=False)
# 	Change =  1.957e-01
# __________________________________________
# TF Iteration 775
# 	μ = -1.529409510e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.720e-03
# 	ne Err =  4.735e-02, ne change =  4.890e-04
# 	Q =  3.934e+00 ->  4.069e+00,
# 	Zstar guess =  4.100e+00. Current Zstar:  3.871e+00 (converged=False)
# 	Change =  1.018e-02
# __________________________________________
# TF Iteration 800
# 	μ = -7.315889808e+00, change: 2.004223185e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.027e-01
# 	ne Err =  8.622e-02, ne change =  2.981e-05
# 	Q = -4.277e+00 -> -3.422e+00,
# 	Zstar guess = -3.419e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  9.902e-02
# __________________________________________
# TF Iteration 825
# 	μ = -7.318129333e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.560e-01
# 	ne Err =  2.810e-04, ne change =  1.106e-06
# 	Q = -1.891e-02 -> -1.669e-02,
# 	Zstar guess = -1.732e-02. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.560e-01
# __________________________________________
# TF Iteration 850
# 	μ = -9.989852023e+00, change: 3.285667280e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.090e-01
# 	ne Err =  8.751e-02, ne change =  4.982e-04
# 	Q = -1.380e+00 -> -1.966e+00,
# 	Zstar guess = -1.966e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  4.092e-01
# __________________________________________
# TF Iteration 875
# 	μ = -2.182660710e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.131e-02
# 	ne Err =  9.632e-02, ne change =  3.993e-03
# 	Q =  5.838e+00 ->  5.701e+00,
# 	Zstar guess =  5.701e+00. Current Zstar:  7.846e+00 (converged=False)
# 	Change =  2.751e-02
# __________________________________________
# TF Iteration 900
# 	μ = -7.327632820e+00, change: 6.579884138e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.063e-01
# 	ne Err =  8.104e-02, ne change =  1.976e-05
# 	Q = -3.895e+00 -> -3.117e+00,
# 	Zstar guess = -3.116e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.033e-01
# __________________________________________
# TF Iteration 925
# 	μ = -8.098917160e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.061e-01
# 	ne Err =  8.072e-02, ne change =  5.363e-04
# 	Q = -1.088e+00 -> -1.615e+00,
# 	Zstar guess = -1.616e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  2.083e-01
# __________________________________________
# TF Iteration 950
# 	μ = -2.230047975e+00, change: 7.244777974e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.046e-03
# 	ne Err =  4.821e-01, ne change =  1.480e-03
# 	Q =  8.615e+00 ->  8.546e+00,
# 	Zstar guess =  8.546e+00. Current Zstar:  9.131e+00 (converged=False)
# 	Change =  7.012e-01
# __________________________________________
# TF Iteration 975
# 	μ = -7.329813464e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.838e-02
# 	ne Err =  2.305e-01, ne change =  7.223e-05
# 	Q = -1.176e+01 -> -9.411e+00,
# 	Zstar guess = -9.407e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  4.035e-02
# __________________________________________
# TF Iteration 1000
# 	μ = -9.152482188e+00, change: 2.242000747e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.923e-01
# 	ne Err =  6.249e-02, ne change =  3.394e-04
# 	Q = -1.024e+00 -> -1.395e+00,
# 	Zstar guess = -1.396e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  3.358e-01
# __________________________________________
# TF Iteration 1025
# 	μ = -7.315849711e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.247e-01
# 	ne Err =  9.099e-01, ne change =  3.026e-03
# 	Q = -2.165e+02 -> -1.732e+02,
# 	Zstar guess = -4.396e+01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.367e-01
# __________________________________________
# TF Iteration 1050
# 	μ = -7.315849740e+00, change: 6.206256842e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.433e-01
# 	ne Err =  1.627e-02, ne change =  1.156e-05
# 	Q = -8.179e-01 -> -6.543e-01,
# 	Zstar guess = -6.532e-01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.426e-01
# __________________________________________
# TF Iteration 1075
# 	μ = -7.315845299e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.561e-01
# 	ne Err =  6.204e-05, ne change =  4.579e-08
# 	Q = -3.084e-03 -> -2.464e-03,
# 	Zstar guess = -3.097e-03. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.561e-01
# __________________________________________
# TF Iteration 1100
# 	μ = -7.312222311e+00, change: 4.425927578e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.561e-01
# 	ne Err =  1.320e-04, ne change =  6.648e-07
# 	Q =  2.113e-03 ->  2.774e-03,
# 	Zstar guess =  2.138e-03. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.564e-01
# __________________________________________
# TF Iteration 1125
# 	μ = -7.017105620e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.412e-01
# 	ne Err =  2.186e-02, ne change =  1.445e-04
# 	Q =  3.482e-01 ->  4.630e-01,
# 	Zstar guess =  4.625e-01. Current Zstar:  2.605e-01 (converged=False)
# 	Change =  1.412e-01
# __________________________________________
# TF Iteration 1150
# 	μ = -6.379950359e-01, change: 7.134913414e-01 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.661e-03
# 	ne Err =  2.115e-01, ne change =  3.699e-04
# 	Q =  4.787e+00 ->  4.916e+00,
# 	Zstar guess =  4.917e+00. Current Zstar:  4.312e+00 (converged=False)
# 	Change =  6.910e-01
# __________________________________________
# TF Iteration 1175
# 	μ = -7.350001314e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.386e-01
# 	ne Err =  2.560e-02, ne change =  6.540e-06
# 	Q = -1.284e+00 -> -1.043e+00,
# 	Zstar guess = -1.043e+00. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.373e-01
# __________________________________________
# TF Iteration 1200
# 	μ = -1.036984115e+01, change: 7.573159779e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.437e-01
# 	ne Err =  9.463e-01, ne change =  2.753e-03
# 	Q = -7.914e+00 -> -3.828e+00,
# 	Zstar guess =  1.241e+01. Current Zstar:  8.488e+00 (converged=False)
# 	Change =  1.539e-01
# __________________________________________
# TF Iteration 1225
# 	μ = -4.199135873e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.330e-02
# 	ne Err =  2.590e-01, ne change =  1.971e-03
# 	Q = -1.588e+01 -> -2.006e+01,
# 	Zstar guess = -2.004e+01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  2.874e-02
# __________________________________________
# TF Iteration 1250
# 	μ = -7.316546824e+00, change: 8.046596257e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.491e-01
# 	ne Err =  9.368e-03, ne change =  2.583e-06
# 	Q = -4.515e-01 -> -3.614e-01,
# 	Zstar guess = -3.617e-01. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.487e-01
# __________________________________________
# TF Iteration 1275
# 	μ = -7.373952916e+00, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.593e-01
# 	ne Err =  4.730e-03, ne change =  3.123e-05
# 	Q = -7.284e-02 -> -9.901e-02,
# 	Zstar guess = -9.964e-02. Current Zstar:  1.000e-02 (converged=False)
# 	Change =  1.594e-01
# __________________________________________
# TF Iteration 1300
# 	μ = -4.067277526e+01, change: 1.009014241e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.471e-01
# 	ne Err =  7.210e-01, ne change =  6.709e-03
# 	Q =  7.747e+00 ->  8.720e+00,
# 	Zstar guess =  1.245e+01. Current Zstar:  1.133e+01 (converged=False)
# 	Change =  1.667e-01
# __________________________________________
# TF Iteration 1325
# 	μ = -4.066337242e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.755e-04
# 	ne Err =  6.329e-03, ne change =  1.572e-04
# 	Q =  1.168e+01 ->  1.168e+01,
# 	Zstar guess =  1.168e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  1.176e-03
# __________________________________________
# TF Iteration 1350
# 	μ = -4.064731131e+01, change: 1.318235630e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.218e-06
# 	ne Err =  1.263e-04, ne change =  8.281e-07
# 	Q =  1.168e+01 ->  1.168e+01,
# 	Zstar guess =  1.168e+01. Current Zstar:  1.168e+01 (converged=False)
# 	Change =  9.460e-05
# __________________________________________
# TF Iteration 1375
# 	μ = -4.063658481e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.309e-06
# 	ne Err =  2.673e-05, ne change =  1.535e-07
# 	Q =  1.168e+01 ->  1.168e+01,
# 	Zstar guess =  1.168e+01. Current Zstar:  1.168e+01 (converged=False)
# 	Change =  7.748e-06
# __________________________________________
# TF Iteration 1400
# 	μ = -4.062047166e+01, change: 1.322851517e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.529e-06
# 	ne Err =  1.019e-04, ne change =  3.087e-08
# 	Q =  1.168e+01 ->  1.168e+01,
# 	Zstar guess =  1.168e+01. Current Zstar:  1.168e+01 (converged=False)
# 	Change =  9.542e-05
# __________________________________________
# TF Iteration 1425
# 	μ = -4.060971392e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.334e-06
# 	ne Err =  2.673e-05, ne change =  1.504e-07
# 	Q =  1.168e+01 ->  1.168e+01,
# 	Zstar guess =  1.168e+01. Current Zstar:  1.168e+01 (converged=False)
# 	Change =  7.773e-06
# __________________________________________
# TF Iteration 1450
# 	μ = -4.059355575e+01, change: 1.326951855e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.534e-06
# 	ne Err =  1.022e-04, ne change =  3.092e-08
# 	Q =  1.168e+01 ->  1.168e+01,
# 	Zstar guess =  1.168e+01. Current Zstar:  1.168e+01 (converged=False)
# 	Change =  9.572e-05
# __________________________________________
# TF Iteration 1475
# 	μ = -4.058277242e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.351e-06
# 	ne Err =  2.680e-05, ne change =  1.507e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  7.793e-06
# __________________________________________
# TF Iteration 1500
# 	μ = -4.056657114e+01, change: 1.331681184e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.538e-06
# 	ne Err =  1.026e-04, ne change =  3.096e-08
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  9.606e-05
# __________________________________________
# TF Iteration 1525
# 	μ = -4.055575594e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.373e-06
# 	ne Err =  2.690e-05, ne change =  1.511e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  7.819e-06
# __________________________________________
# TF Iteration 1550
# 	μ = -4.053950902e+01, change: 1.336417421e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.542e-06
# 	ne Err =  1.029e-04, ne change =  3.102e-08
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  9.640e-05
# __________________________________________
# TF Iteration 1575
# 	μ = -4.052866608e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.390e-06
# 	ne Err =  2.697e-05, ne change =  1.514e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  7.839e-06
# __________________________________________
# TF Iteration 1600
# 	μ = -4.051237967e+01, change: 1.340710662e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.546e-06
# 	ne Err =  1.032e-04, ne change =  3.107e-08
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  9.671e-05
# __________________________________________
# TF Iteration 1625
# 	μ = -4.050150433e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.411e-06
# 	ne Err =  2.706e-05, ne change =  1.518e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  7.865e-06
# __________________________________________
# TF Iteration 1650
# 	μ = -4.048516828e+01, change: 1.345651937e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.551e-06
# 	ne Err =  1.036e-04, ne change =  3.113e-08
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  9.706e-05
# __________________________________________
# TF Iteration 1675
# 	μ = -4.047426122e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.433e-06
# 	ne Err =  2.715e-05, ne change =  1.522e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  7.892e-06
# __________________________________________
# TF Iteration 1700
# 	μ = -4.045788046e+01, change: 1.350059384e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.556e-06
# 	ne Err =  1.039e-04, ne change =  3.119e-08
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  9.738e-05
# __________________________________________
# TF Iteration 1725
# 	μ = -4.044694578e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.452e-06
# 	ne Err =  2.723e-05, ne change =  1.526e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  7.914e-06
# __________________________________________
# TF Iteration 1750
# 	μ = -4.043051613e+01, change: 1.354988344e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.561e-06
# 	ne Err =  1.043e-04, ne change =  3.125e-08
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  9.774e-05
# __________________________________________
# TF Iteration 1775
# 	μ = -4.041954974e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.472e-06
# 	ne Err =  2.732e-05, ne change =  1.529e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  7.938e-06
# __________________________________________
# TF Iteration 1800
# 	μ = -4.040308049e+01, change: 1.359124769e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.565e-06
# 	ne Err =  1.046e-04, ne change =  3.130e-08
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  9.803e-05
# __________________________________________
# TF Iteration 1825
# 	μ = -4.039208641e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.490e-06
# 	ne Err =  2.739e-05, ne change =  1.533e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  7.959e-06
# __________________________________________
# TF Iteration 1850
# 	μ = -4.037557166e+01, change: 1.363920207e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.569e-06
# 	ne Err =  1.049e-04, ne change =  3.137e-08
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  9.838e-05
# __________________________________________
# TF Iteration 1875
# 	μ = -4.036454612e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.510e-06
# 	ne Err =  2.748e-05, ne change =  1.537e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  7.985e-06
# __________________________________________
# TF Iteration 1900
# 	μ = -4.034797672e+01, change: 1.369553346e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.575e-06
# 	ne Err =  1.054e-04, ne change =  3.145e-08
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  9.878e-05
# __________________________________________
# TF Iteration 1925
# 	μ = -4.033691590e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.533e-06
# 	ne Err =  2.758e-05, ne change =  1.541e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  8.012e-06
# __________________________________________
# TF Iteration 1950
# 	μ = -4.032029614e+01, change: 1.374772949e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.579e-06
# 	ne Err =  1.057e-04, ne change =  3.151e-08
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  9.916e-05
# __________________________________________
# TF Iteration 1975
# 	μ = -4.030919812e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.556e-06
# 	ne Err =  2.768e-05, ne change =  1.546e-07
# 	Q =  1.167e+01 ->  1.167e+01,
# 	Zstar guess =  1.167e+01. Current Zstar:  1.167e+01 (converged=False)
# 	Change =  8.041e-06
# __________________________________________
# TF Iteration 2000
# 	μ = -4.029252158e+01, change: 1.380535821e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.584e-06
# 	ne Err =  1.062e-04, ne change =  3.161e-08
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  9.957e-05
# __________________________________________
# TF Iteration 2025
# 	μ = -4.028138434e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.582e-06
# 	ne Err =  2.780e-05, ne change =  1.552e-07
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  8.073e-06
# __________________________________________
# TF Iteration 2050
# 	μ = -4.026464166e+01, change: 1.387015940e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.590e-06
# 	ne Err =  1.066e-04, ne change =  3.174e-08
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  1.000e-04
# __________________________________________
# TF Iteration 2075
# 	μ = -4.025345421e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.611e-06
# 	ne Err =  2.793e-05, ne change =  1.559e-07
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  8.110e-06
# __________________________________________
# TF Iteration 2100
# 	μ = -4.023663484e+01, change: 1.394678048e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.597e-06
# 	ne Err =  1.072e-04, ne change =  3.189e-08
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  1.006e-04
# __________________________________________
# TF Iteration 2125
# 	μ = -4.022539523e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.641e-06
# 	ne Err =  2.807e-05, ne change =  1.566e-07
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  8.148e-06
# __________________________________________
# TF Iteration 2150
# 	μ = -4.020848860e+01, change: 1.402963855e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.605e-06
# 	ne Err =  1.078e-04, ne change =  3.207e-08
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  1.012e-04
# __________________________________________
# TF Iteration 2175
# 	μ = -4.019718882e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.678e-06
# 	ne Err =  2.824e-05, ne change =  1.575e-07
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  8.195e-06
# __________________________________________
# TF Iteration 2200
# 	μ = -4.018019491e+01, change: 1.411101859e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.613e-06
# 	ne Err =  1.084e-04, ne change =  3.226e-08
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  1.018e-04
# __________________________________________
# TF Iteration 2225
# 	μ = -4.016883906e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.710e-06
# 	ne Err =  2.839e-05, ne change =  1.583e-07
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  8.237e-06
# __________________________________________
# TF Iteration 2250
# 	μ = -4.015175382e+01, change: 1.419491409e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.621e-06
# 	ne Err =  1.091e-04, ne change =  3.245e-08
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  1.024e-04
# __________________________________________
# TF Iteration 2275
# 	μ = -4.014033454e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.746e-06
# 	ne Err =  2.856e-05, ne change =  1.592e-07
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  8.284e-06
# __________________________________________
# TF Iteration 2300
# 	μ = -4.012316819e+01, change: 1.427190165e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.628e-06
# 	ne Err =  1.096e-04, ne change =  3.263e-08
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  1.029e-04
# __________________________________________
# TF Iteration 2325
# 	μ = -4.011169287e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.781e-06
# 	ne Err =  2.872e-05, ne change =  1.600e-07
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  8.328e-06
# __________________________________________
# TF Iteration 2350
# 	μ = -4.009443875e+01, change: 1.435536744e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.636e-06
# 	ne Err =  1.103e-04, ne change =  3.281e-08
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  1.035e-04
# __________________________________________
# TF Iteration 2375
# 	μ = -4.008291042e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.810e-06
# 	ne Err =  2.885e-05, ne change =  1.607e-07
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  8.365e-06
# __________________________________________
# TF Iteration 2400
# 	μ = -4.006558173e+01, change: 1.442897185e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.643e-06
# 	ne Err =  1.108e-04, ne change =  3.296e-08
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  1.041e-04
# __________________________________________
# TF Iteration 2425
# 	μ = -4.005400159e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.842e-06
# 	ne Err =  2.900e-05, ne change =  1.615e-07
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  8.406e-06
# __________________________________________
# TF Iteration 2450
# 	μ = -4.003659292e+01, change: 1.450297304e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.650e-06
# 	ne Err =  1.114e-04, ne change =  3.312e-08
# 	Q =  1.166e+01 ->  1.166e+01,
# 	Zstar guess =  1.166e+01. Current Zstar:  1.166e+01 (converged=False)
# 	Change =  1.046e-04
# __________________________________________
# TF Iteration 2475
# 	μ = -4.002496610e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.869e-06
# 	ne Err =  2.913e-05, ne change =  1.621e-07
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  8.440e-06
# __________________________________________
# TF Iteration 2500
# 	μ = -4.000748697e+01, change: 1.457234918e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.656e-06
# 	ne Err =  1.119e-04, ne change =  3.326e-08
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  1.051e-04
# __________________________________________
# TF Iteration 2525
# 	μ = -3.999581279e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.897e-06
# 	ne Err =  2.926e-05, ne change =  1.628e-07
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  8.475e-06
# __________________________________________
# TF Iteration 2550
# 	μ = -3.997826065e+01, change: 1.464588111e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.663e-06
# 	ne Err =  1.125e-04, ne change =  3.339e-08
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  1.056e-04
# __________________________________________
# TF Iteration 2575
# 	μ = -3.996653418e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.928e-06
# 	ne Err =  2.940e-05, ne change =  1.635e-07
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  8.515e-06
# __________________________________________
# TF Iteration 2600
# 	μ = -3.994891452e+01, change: 1.471422853e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.669e-06
# 	ne Err =  1.130e-04, ne change =  3.352e-08
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  1.061e-04
# __________________________________________
# TF Iteration 2625
# 	μ = -3.993714140e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.956e-06
# 	ne Err =  2.953e-05, ne change =  1.641e-07
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  8.550e-06
# __________________________________________
# TF Iteration 2650
# 	μ = -3.991944732e+01, change: 1.478660223e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.675e-06
# 	ne Err =  1.135e-04, ne change =  3.365e-08
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  1.066e-04
# __________________________________________
# TF Iteration 2675
# 	μ = -3.990762859e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.983e-06
# 	ne Err =  2.966e-05, ne change =  1.647e-07
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  8.584e-06
# __________________________________________
# TF Iteration 2700
# 	μ = -3.988987087e+01, change: 1.484833473e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.681e-06
# 	ne Err =  1.140e-04, ne change =  3.377e-08
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  1.071e-04
# __________________________________________
# TF Iteration 2725
# 	μ = -3.987800770e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.012e-06
# 	ne Err =  2.979e-05, ne change =  1.653e-07
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  8.619e-06
# __________________________________________
# TF Iteration 2750
# 	μ = -3.986018112e+01, change: 1.491618774e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.688e-06
# 	ne Err =  1.145e-04, ne change =  3.389e-08
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  1.076e-04
# __________________________________________
# TF Iteration 2775
# 	μ = -3.984827611e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.037e-06
# 	ne Err =  2.991e-05, ne change =  1.659e-07
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  8.651e-06
# __________________________________________
# TF Iteration 2800
# 	μ = -3.983038360e+01, change: 1.498607978e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.693e-06
# 	ne Err =  1.150e-04, ne change =  3.402e-08
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  1.081e-04
# __________________________________________
# TF Iteration 2825
# 	μ = -3.981843395e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.063e-06
# 	ne Err =  3.003e-05, ne change =  1.666e-07
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  8.684e-06
# __________________________________________
# TF Iteration 2850
# 	μ = -3.980047942e+01, change: 1.504180193e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.699e-06
# 	ne Err =  1.154e-04, ne change =  3.414e-08
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  1.085e-04
# __________________________________________
# TF Iteration 2875
# 	μ = -3.978848874e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.089e-06
# 	ne Err =  3.015e-05, ne change =  1.671e-07
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  8.716e-06
# __________________________________________
# TF Iteration 2900
# 	μ = -3.977046690e+01, change: 1.510952899e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.706e-06
# 	ne Err =  1.159e-04, ne change =  3.425e-08
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  1.089e-04
# __________________________________________
# TF Iteration 2925
# 	μ = -3.975843340e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.115e-06
# 	ne Err =  3.027e-05, ne change =  1.677e-07
# 	Q =  1.165e+01 ->  1.165e+01,
# 	Zstar guess =  1.165e+01. Current Zstar:  1.165e+01 (converged=False)
# 	Change =  8.749e-06
# __________________________________________
# TF Iteration 2950
# 	μ = -3.974034689e+01, change: 1.517886995e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.711e-06
# 	ne Err =  1.165e-04, ne change =  3.437e-08
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  1.094e-04
# __________________________________________
# TF Iteration 2975
# 	μ = -3.972826723e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.143e-06
# 	ne Err =  3.041e-05, ne change =  1.683e-07
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  8.784e-06
# __________________________________________
# TF Iteration 3000
# 	μ = -3.971011590e+01, change: 1.524624324e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.717e-06
# 	ne Err =  1.170e-04, ne change =  3.449e-08
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  1.099e-04
# __________________________________________
# TF Iteration 3025
# 	μ = -3.969799665e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.165e-06
# 	ne Err =  3.051e-05, ne change =  1.688e-07
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  8.811e-06
# __________________________________________
# TF Iteration 3050
# 	μ = -3.967978778e+01, change: 1.531043648e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.722e-06
# 	ne Err =  1.174e-04, ne change =  3.458e-08
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  1.104e-04
# __________________________________________
# TF Iteration 3075
# 	μ = -3.966762119e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.196e-06
# 	ne Err =  3.065e-05, ne change =  1.694e-07
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  8.849e-06
# __________________________________________
# TF Iteration 3100
# 	μ = -3.964934429e+01, change: 1.537276005e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.729e-06
# 	ne Err =  1.179e-04, ne change =  3.470e-08
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  1.108e-04
# __________________________________________
# TF Iteration 3125
# 	μ = -3.963714093e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.218e-06
# 	ne Err =  3.075e-05, ne change =  1.699e-07
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  8.876e-06
# __________________________________________
# TF Iteration 3150
# 	μ = -3.961879868e+01, change: 1.543819415e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.735e-06
# 	ne Err =  1.184e-04, ne change =  3.481e-08
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  1.113e-04
# __________________________________________
# TF Iteration 3175
# 	μ = -3.960655144e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.246e-06
# 	ne Err =  3.089e-05, ne change =  1.706e-07
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  8.912e-06
# __________________________________________
# TF Iteration 3200
# 	μ = -3.958815044e+01, change: 1.549928674e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.740e-06
# 	ne Err =  1.188e-04, ne change =  3.491e-08
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  1.117e-04
# __________________________________________
# TF Iteration 3225
# 	μ = -3.957585801e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.273e-06
# 	ne Err =  3.102e-05, ne change =  1.711e-07
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  8.945e-06
# __________________________________________
# TF Iteration 3250
# 	μ = -3.955739054e+01, change: 1.556752626e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.746e-06
# 	ne Err =  1.193e-04, ne change =  3.502e-08
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  1.122e-04
# __________________________________________
# TF Iteration 3275
# 	μ = -3.954506267e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.293e-06
# 	ne Err =  3.111e-05, ne change =  1.716e-07
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  8.970e-06
# __________________________________________
# TF Iteration 3300
# 	μ = -3.952654210e+01, change: 1.562697252e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.751e-06
# 	ne Err =  1.198e-04, ne change =  3.513e-08
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  1.127e-04
# __________________________________________
# TF Iteration 3325
# 	μ = -3.951417132e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.320e-06
# 	ne Err =  3.124e-05, ne change =  1.722e-07
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  9.003e-06
# __________________________________________
# TF Iteration 3350
# 	μ = -3.949558801e+01, change: 1.569318761e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.757e-06
# 	ne Err =  1.202e-04, ne change =  3.523e-08
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  1.131e-04
# __________________________________________
# TF Iteration 3375
# 	μ = -3.948317832e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.345e-06
# 	ne Err =  3.135e-05, ne change =  1.727e-07
# 	Q =  1.164e+01 ->  1.164e+01,
# 	Zstar guess =  1.164e+01. Current Zstar:  1.164e+01 (converged=False)
# 	Change =  9.034e-06
# __________________________________________
# TF Iteration 3400
# 	μ = -3.946453155e+01, change: 1.575700985e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.763e-06
# 	ne Err =  1.207e-04, ne change =  3.533e-08
# 	Q =  1.163e+01 ->  1.163e+01,
# 	Zstar guess =  1.163e+01. Current Zstar:  1.163e+01 (converged=False)
# 	Change =  1.136e-04
# __________________________________________
# TF Iteration 3425
# 	μ = -3.945208086e+01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.369e-06
# 	ne Err =  3.147e-05, ne change =  1.732e-07
# 	Q =  1.163e+01 ->  1.163e+01,
# 	Zstar guess =  1.163e+01. Current Zstar:  1.163e+01 (converged=False)
# 	Change =  9.064e-06
# __________________________________________
# TF Iteration 3450
# 	μ = -3.943337667e+01, change: 1.582207251e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.768e-06
# 	ne Err =  1.212e-04, ne change =  3.542e-08
# 	Q =  1.163e+01 ->  1.163e+01,
# 	Zstar guess =  1.163e+01. Current Zstar:  1.163e+01 (converged=False)
# 	Change =  1.141e-04
# KeyboardInterrupt

# %%
# fig, axs  = plt.subplots(1,2,figsize=(10,4))

# colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# short_distance_weight = np.exp(-(0.08*npa.kTF*npa.grid.xs)**4)
# for ax in axs:
#     # ax.plot(npa.iet.r_array*rs, npa.iet.h_r_matrix[0,0], color=colors[0], label=r"NPA: $u_Y$")
#     ax.plot(npa.grid.xs, npa.gii-1, color=colors[0], label=r"NPA: $u_Y$")
#     # ax.plot(npa_2.grid.xs, npa_2.gii-1,'--', color=colors[0], label=r"NPA: $u_{AA}$",zorder=10)
#     ax.plot(aa.iet.r_array*rs, aa.iet.h_r_matrix[0,0],color=colors[1],  label=r"$u_{AA}$")
#     # ax.plot(npa.grid.xs, short_distance_weight*(npa.gii-1),'--',color=colors[3],  label=r"$u_Y$ damped")
    			

#     # ax.plot(aa.grid.xs, aa.gii-1,'--',color=colors[3],  label=r"$u_Y$")
#     ax.axvline(npa.iet.r_array[-1]*rs,color='k')
    
# ax = axs[0]
# ax.set_xlabel(r"$r/r_i$",fontsize=12)
# ax.set_ylabel("h(r)",fontsize=12)
# ax.set_xlim(0,3*rs)

# ax = axs[1]
# ax.set_xlabel(r"$r/r_i$",fontsize=12)
# ax.set_ylabel("h(r)",fontsize=12)
# ax.set_xscale('log')
# ax.set_xlim(0.5,None)
# ax.set_yscale('symlog', linthresh=1e-6)
# for ax in axs:
#     ax.legend(fontsize=12)
#     ax.tick_params(labelsize=12)


# plt.tight_layout()

# %%
# ρ_iet = interp1d(npa.grid.xs, npa.ρi - npa.ne, bounds_error=False, fill_value=( (npa.ρi - npa.ne)[0],  (npa.ρi - npa.ne)[-1]))(npa.iet.r_array*rs)
# δφe_k = 4*π*npa.iet.FT_r_2_k(ρ_iet)/(npa.iet.k_array/rs)**2
# δφe_r = npa.iet.FT_k_2_r(δφe_k)
# φe = interp1d(npa.iet.r_array*rs, δφe_r, bounds_error=False, fill_value='extrapolate')(npa.grid.xs)
# ne_iet = npa.get_ne_TF(φe-φe[-1], npa.ne, npa.μ, npa.ne_bar)

# %%
# fig, ax = plt.subplots(figsize=(5,3.5))

# # φ
# # ax.plot(npa.grid.xs, φe)
# # ax.plot(npa.grid.xs, npa.φe)

# # n
# ax.plot(npa.grid.xs, npa.ne)
# ax.plot(npa.grid.xs, ne_iet)


# ax.set_yscale('symlog', linthresh=1e-8)
# ax.set_xscale('log')

# %% [markdown]
# ### Thomas Fermi (TF)

# %%
# 2000: -5.419e-02, 4000: 1.592e-02

# %%
# %%time
# npa_2.solve_TF(verbose=True, picard_alpha=0.2, num_10folds_per_rs=0.5, tol=1e-7, nmax = 1000, n_wait_update_Zstar= 200)
# npa_2.set_uii_eff()

# %% [markdown]
# ### EOS

# %%
def get_Eii(aa):
    βVeff = aa.get_βVeff(aa.φe, aa.ne, aa.ne_bar)
    η = aa.μ/aa.Te - βVeff
    βU = aa.grid.integrate_f(βVeff*aa.ne)
    I_onehalf = FermiDirac.Ionehalf(η)
    I_threehalf = FermiDirac.Ithreehalf(η)
    
    βK = (2*aa.Te)**1.5/π**2 * aa.grid.integrate_f( η*I_onehalf - 2/3 * I_threehalf   )
    return βU, βK, βU + βK

def get_ETF(aa):
    
def get_Exc(aa):
    aa.vxc

def get_E_Hartree(aa):
    
    
    

# get_E(aa_tfd), get_E(npa_tfd)

# %%
def get_P(aa):
    aa_old_βu = aa.iet.βu_r_matrix.copy()
    # aa.iet.set_βu_matrix( np.array([[1/aa.Ti * aa.Zstar**2/(aa.iet.r_array*aa.rs) ]] ))
    P_id_hnc, P_ex_hnc, P_hnc = aa.iet.ideal_pressure(), aa.iet.excess_pressure(), aa.iet.total_pressure()
    P_id_AU, P_ex_AU, P_AU  = P_id_hnc/rs**3, P_ex_hnc/rs**3, P_hnc/rs**3
    aa.iet.set_βu_matrix(aa_old_βu)
    return P_id_AU, P_ex_AU, P_AU

aa_P_ions = get_P(aa_tfd)
aa_P_ions[1]/aa_P_ions[0]

# %% [markdown]
# ## Comparison

# %%
npa.make_plots()
# Out:
# (<Figure size 4000x1600 with 2 Axes>,
#  array([<Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$\\phi$ [A.U.]'>,
#         <Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$n$ [A.U.]'>],
#        dtype=object))

# %%
def plot_convergence(aa, axs=None):
    if axs is None:
        fig, axs = plt.subplots(ncols=3,figsize=(18,5),facecolor='w', dpi=200)
    
    # ELectric potential
    slice_by_num = 10
    ax = axs[0]
    colors = plt.cm.coolwarm(np.linspace(0, 1,len(aa.φe_list[::slice_by_num])))
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        if i ==0 or i==len(aa.φe_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, (φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\phi_e$'.format(i))
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\vec E$'.format(i))
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1, label=r'$\beta V_{{\rm eff}}$'.format(i))
        else:
            ax.plot(aa.grid.xs, φe+aa.φion,linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1)
    # ax.plot(aa.grid.xs, aa.get_φe( (aa.ρi - aa.ne) )[0] + aa.φion  ,'k:', label=r'$\phi$ check') 
    ax.set_yscale('symlog',linthresh=1e-10)
    ax.plot(aa.grid.xs, aa.φe_init + aa.φion, 'k:')

    # number density
    ax = axs[1]
    for i, (ne, ρi) in enumerate(zip(aa.ne_list[::slice_by_num], aa.ρi_list[::slice_by_num])):
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            if i==0: 
                ne_bar_0 = ne[-1]
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1, label=r'$Q(r)$'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, -ne + 0*ρi + ne[-1],linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ne_bar_0,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ρi[-1] + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # pass
        else:
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1)
            # print(ne[-1]-ne_bar_0)
            # ax.plot(aa.grid.xs, -ne + ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ne + ne_bar_0 ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ρi[-1]+ ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            pass
    # for i in range(int(aa.R/aa.rs)):
    #     ax.axvline(aa.rs*i, color='k', linestyle='--', alpha=0.2)
    # ax.set_xscale('log')
    # ax.plot(aa.grid.xs, (aa.gii)-1, 'k:')
    ax.set_yscale('symlog',linthresh=1e-4)

            
    # number density
    ax = axs[2]
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        ne_TF = aa.get_ne_TF(φe, ne, μ, ne_bar)
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, ne - 1*ne_TF,linewidth=1,color=colors[i],alpha=1, label=r'$n_e/n_e^{{TF}}-1$, iter: {0}'.format(i))
            # ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1, label=r'$n_e^{{TF}} - n_e^{{TF}}[-1]$, iter: {0}'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, ne-ne[-1],linewidth=1,color=colors[i],linestyle='--',alpha=1, label=r'$n_e - n_e[-1]$, iter: {0}'.format(i))
            # pass
        else:
            ax.plot(aa.grid.xs, ne - 1*ne_TF, linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, ne-ne[-1], linewidth=1,linestyle='--',color=colors[i],alpha=0.5)
            

            # print(np.abs(ne/ne_TF-1))
            # print(np.where( np.abs(ne/ne_TF-1)>1e-6 ))
            # print(aa.grid.xs[np.where( np.abs(ne/ne_TF-1) > 1e-8)][0]/10, 1/(np.sum(aa.grid.xs*np.abs(ne/ne_TF-1))/np.sum(np.abs(ne/ne_TF-1))))
    # ax.set_ylim()
    # ax.plot(aa.grid.xs, npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar) - npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar)[-1] , 'k:')
    ax.plot(aa.grid.xs, aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar) - aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar)[-1] , 'k:')
    ax.set_yscale('symlog',linthresh=1e-10)
    # ax.set_xscale('log')
    for ax in axs:
        ax.legend(fontsize=14)
        ax.tick_params(labelsize=14)
        ax.plot(aa.grid.xs, np.zeros_like(aa.ne),'k', alpha=0.2)
    plt.tight_layout()
    
# plot_convergence(aa)
plot_convergence(npa)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

petrov = pd.read_csv("../data/GP_TFDW_Al_1eV_solid.dat",header=0, comment='#', delim_whitespace=True)

def compare_aa(aa_list, axs=None, name=''):
    eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
    if axs is None:
        fig, axs = plt.subplots(ncols=2,figsize=(20,8),facecolor='w')

    # Density * 4pi r^2 plot
    for ax in axs:
        for aa, color in zip( aa_list, colors):
            factor = 4*np.pi*aa.grid.xs**2
            ax.plot(np.array(petrov['r/R'])*rs, 4*π*(np.array(petrov['r/R'])*rs)**2*(petrov['ne']/m_to_AU**3), 'k--', label="Petrov AA")
            ax.plot(aa.grid.xs, aa.ne*factor ,'-',color=color, label=r'$n_e$: '+ name)
            ax.plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
            ax.plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
            if aa.rs != aa.R:
                ax.plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
                ax.plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)
        # axs[0].plot(aa.grid.xs, aa.δn_f*factor,'--',color='g',  label=r'$n_e^{sc}$: ' + name)


    axs[0].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[0].set_ylim(0, 1e3)
    axs[0].set_yscale('symlog',linthresh=1e-1)
    axs[0].set_xscale('log')
    axs[0].set_xlim(aa.grid.xs[0],aa.grid.xs[-1])

    axs[1].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[1].set_ylim(0, 13)
    axs[1].set_xlim(0, np.min([aa.R,1.3*aa.rs]))

        
    for ax in axs:
        ax.set_xlabel(r'$|r-R_1|$ [A.U.]',fontsize=20)
        ax.legend(loc="upper right",fontsize=20,labelspacing = 0.1)
        ax.tick_params(labelsize=20)
        ax.grid(which='both',alpha=0.4)

        # make textbox
        text = ("{0}\n".format(aa.name)+ 
            r"$r_s$ = " + "{0},    ".format(np.round(aa.rs,2)) +
            r"$R_{NPA}$ = " + "{0}\n".format(aa.R)  +
                r"$T_e$ = " + "{0} [A.U.] = {1} eV\n".format(np.round(aa.Te,2),np.round(aa.Te/eV,2)) + r"$\mu$ = " + "{0} [A.U.]\n".format(np.round(aa.μ,2)) +
                r"$Z^\ast = $" + "{0}".format(np.round(aa.Zstar,2))  )

        props = dict(boxstyle='round', facecolor='w')
        ax.text(0.25,0.95, text, fontsize=15, transform=ax.transAxes, verticalalignment='top', bbox=props)

    plt.tight_layout()
    name = "NPA_densities_{0}_rs{1}_{2}eV_R{3}.png".format(aa.name, np.round(aa.rs,2), np.round(aa.Te/eV,2) ,np.round(aa.R))
    plt.savefig("/home/zach/plasma/atomic_forces/average_atom/media/" + name, dpi=300, bbox_inches='tight',facecolor="w")
    
    
    return axs


axs = compare_aa([aa, npa])#, npa_2])
for ax in axs:
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), fontsize=16, loc='upper right')
# axs[1].set_ylim(1e-5,1e3)

# %% [markdown]
# ## HNC and FT

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.k_array/rs, aa.Uei_iet_k*(aa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.k_array/rs, npa.Uei_iet_k*(npa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[1], label="NPA") # Need to muultiply by some rs power???
axs[0].plot(aa.iet.k_array/rs, aa.Zstar*np.ones_like(aa.iet.k_array),':', color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(npa.iet.k_array/rs, npa.Zstar*np.ones_like(npa.iet.k_array),':',color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")

# axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$k$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.k_array/rs, aa.uii_k_eff_iet,'-', color=colors[0], label="AA")
axs[1].plot(aa.iet.k_array/rs, 4*π*aa.Zstar**2/(aa.iet.k_array/rs)**2,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
axs[1].plot(aa.iet.k_array/rs, 1/(aa.iet.k_array**2/rs**2/(4*π*aa.Zstar**2) + 1/aa.uii_k_eff_iet[0] ),'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, uii_test,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))


# axs[1].plot(npa.iet.k_array/rs, npa.uii_k_eff_iet,color=colors[1], label="NPA")
axs[1].plot(npa.iet.k_array/rs, 4*π*npa.Zstar**2/(npa.iet.k_array/rs)**2,'--', color=colors[1], label=r"NPA: $u_{{ii}}^0$, Z={0:0.3f}".format(npa.Zstar))



axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_ylim(0,1e5)
axs[1].set_xscale('log')
axs[1].set_xlabel(r"$k$ [au]")
axs[1].set_ylabel(r"$u^{\rm eff}_{ii}$ [au]")


for ax in axs:
    ax.legend(fontsize=12)
plt.tight_layout()

# %%
uii_test = aa.iet.FT_k_2_r(aa.uii_k_eff_iet)/rs**3

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.r_array*rs, -aa.Zstar/(aa.iet.r_array*rs), color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(aa.iet.r_array*rs, -aa.Uei_iet ,':',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.r_array*rs, -npa.Zstar/(npa.iet.r_array*rs),color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(npa.iet.r_array*rs, -npa.Uei_iet ,':',color=colors[1], label="NPA") # Need to muultiply by some rs power???
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Zstar/(npa.iet.r_array*rs),color=colors[2], label=f"Coulomb, Z={npa.Zstar:0.3f}")
# axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Uei_iet ,':',color=colors[2], label=r"NPA: $g_{AA}$") # Need to muultiply by some rs power???



axs[0].set_yscale('symlog',linthresh=1e-1)
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$r$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.r_array*rs, 1/aa.Te * aa.uii_r_eff_iet, color=colors[0],linestyle='-', label='AA')
axs[1].plot(aa.iet.r_array*rs, 1/aa.Te *aa.Zstar**2/(aa.iet.r_array*rs ), color=colors[0] ,linestyle='--', label=f'Coulomb Z={aa.Zstar:0.3f}')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.uii_r_eff_iet, color=colors[1],linestyle='-', label='NPA')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.Zstar**2/(npa.iet.r_array*rs ), color=colors[1],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )
# axs[1].plot(npa_2.iet.r_array*rs, npa_2.uii_r_eff_iet, color=colors[2],linestyle='-', label=r"NPA: $g_{AA}$")
# axs[1].plot(npa_2.iet.r_array*rs, npa_2.Zstar**2/(npa_2.iet.r_array*rs ), color=colors[2],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )

axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_xscale('log')
axs[1].set_ylabel(r"$\beta U_{ii}$ [au]")
axs[1].set_xlabel(r"$r$ [au]")
axs[1].set_xlim(1,None)


for ax in axs:
    ax.legend(fontsize=10)
plt.tight_layout()

# %%
npa.make_gii()
npa.make_ρi()
# npa_2.make_gii()
# npa_2.make_ρi()

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, axs  = plt.subplots(1,2, figsize=(8,4))

# Data from community TCCW
upper_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Upper.txt", delim_whitespace=True, header=1)
lower_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Lower.txt", delim_whitespace=True, header=1)

ax = axs[0]
ax.fill_between(lower_data['r/ri'],lower_data['gii'], PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')

# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0] + 1, label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("g(r)")
ax.set_xlim(0.7,3)
# ax.set_ylim(0,2)
ax.legend(fontsize=10)

ax = axs[1]
ax.fill_between(lower_data['r/ri'],lower_data['gii']-1, PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')
# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii-1, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
# ax.plot(npa_2.grid.xs/rs, npa_2.gii-1, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0], label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("h(r)")
ax.set_xlim(0.7,10)
ax.set_ylim(0,2.5)
ax.set_yscale('symlog', linthresh=1e-4)

ax.legend(fontsize=8, loc='upper right')
plt.tight_layout()
