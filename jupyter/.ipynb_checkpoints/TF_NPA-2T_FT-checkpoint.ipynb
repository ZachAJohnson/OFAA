# %%
import numpy as np
import pandas as pd


from average_atom.core.average_atom_kspace import NeutralPseudoAtom as NPA
from average_atom.core.misc import jacobi_relaxation, sor
from average_atom.core.grids import FourierGrid
from average_atom.core.physics import ThomasFermi, FermiDirac

from importlib import reload
try:
    reload(physics)
    reload(grids)
    reload(average_atom_geometric)
#     reload(average_atom)
    reload(misc)
except NameError as e:
    from average_atom.core import physics as physics
    from average_atom.core import average_atom_kspace as average_atom
    from average_atom.core import misc as misc
    from average_atom.core import grids as grids
    print("Error: ",e)
except Exception as e:
    print("Unexpected error during reload")
    print(e)

import matplotlib.pyplot as plt

from hnc.hnc.constants import *
from hnc.hnc.misc import rs_from_n, n_from_rs

import cProfile

plt.rcParams.update({'font.size': 10})
plt.rcParams["figure.figsize"] = (5,3.5)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['xtick.labelsize']=14

color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# Error:  name 'physics' is not defined
# ModuleNotFoundError: No module named 'mendeleev'

# %%
# Aluminuma
name='Al'
Z, A = 13, 27 

ρ_solid = 2.699 #g/cc, the solid density of aluminum 
ρ = ρ_solid#8.1 # g/cc
ni_cc = ρ/(A*amu_to_AU*AU_to_g)
ni_AU = ni_cc*invcc_to_AU
rs = rs_from_n(ni_AU)

Ti_eV = 1 
Te_eV = 1

Te_AU = Te_eV*eV_to_AU
Ti_AU = Ti_eV*eV_to_AU

# Hydrogen
# name='H'
# Z, A = 1, 1.00784

# Te_eV = 2 
# Te_AU = Te_eV*eV_to_AU

# Ti_eV = 2
# Ti_AU = Ti_eV*eV_to_AU

# ρ_gpercc = 1
# ni_invcc = ρ_gpercc/(A*amu_to_AU*AU_to_g)
# ni_AU = ni_invcc*invcc_to_AU
# rs = rs_from_n(ni_AU)


####
R = 10*rs
ignore_vxc = False
fixed_Zstar = False
Zstar_init = 3.5 # 'More'

aa_kwargs = {'initialize':True, 'gradient_correction':None, 'μ_init' : 0.158, 'Zstar_init' : Zstar_init, 'Npoints':1000,
             'name':name, 'ignore_vxc':ignore_vxc, 'fixed_Zstar':fixed_Zstar, 'iet_R_over_rs':R/rs, 'iet_N_bins':5000, 'use_full_ne_for_nf':False,
            'gii_init_type': 'step'}

aaW_kwargs = aa_kwargs.copy()
aaW_kwargs.update({'gradient_correction':'W', 'Weizsacker_λ':1/9})

npa_kwargs = aa_kwargs.copy()
npa_kwargs.update({'Npoints':10000, 'iet_N_bins':10000, 'gii_init_type': 'iet', 'grid_spacing':'linear'})

npaW_kwargs = npa_kwargs.copy()
npaW_kwargs.update({'gradient_correction':'W', 'Weizsacker_λ':1/9})

aa = NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aa_kwargs)
aaW =NPA(Z, A, Ti_AU, Te_AU, rs, rs, **aaW_kwargs)
npa = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npa_kwargs)                           
npaW = NPA(Z, A, Ti_AU, Te_AU, rs, R, **npaW_kwargs)
# Out:
# ________________________
# Generating NPA
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# 	Intializing grid
# 	Creating Integral Equation Solver
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# 	Intializing grid
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 1.358e+03
# Exiting status 0, reverting to best index so far: 2148
# Final iter:2149, Total Error: 9.985e-13
# Intialized Potentials and Densities
# ________________________
# Generating NPA
# 	Intializing grid
# 	Creating Integral Equation Solver
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 1.358e+03
# Exiting status 0, reverting to best index so far: 2148
# Final iter:2149, Total Error: 9.985e-13
# Intialized Potentials and Densities

# %%
fig, axs  = plt.subplots(1,2,figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

short_distance_weight = np.exp(-(0.08*npa.kTF*npa.grid.xs)**4)
for ax in axs:
    # ax.plot(npa.iet.r_array*rs, npa.iet.h_r_matrix[0,0], color=colors[0], label=r"NPA: $u_Y$")
    ax.plot(npa.grid.xs, npa.gii-1, color=colors[0], label=r"NPA: $u_Y$")
    # ax.plot(npa_2.grid.xs, npa_2.gii-1,'--', color=colors[0], label=r"NPA: $u_{AA}$",zorder=10)
    ax.plot(aa.iet.r_array*rs, aa.iet.h_r_matrix[0,0],color=colors[1],  label=r"$u_{AA}$")
    # ax.plot(npa.grid.xs, short_distance_weight*(npa.gii-1),'--',color=colors[3],  label=r"$u_Y$ damped")
    			

    # ax.plot(aa.grid.xs, aa.gii-1,'--',color=colors[3],  label=r"$u_Y$")
    ax.axvline(npa.iet.r_array[-1]*rs,color='k')
    
ax = axs[0]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xlim(0,3*rs)

ax = axs[1]
ax.set_xlabel(r"$r/r_i$",fontsize=12)
ax.set_ylabel("h(r)",fontsize=12)
ax.set_xscale('log')
ax.set_xlim(0.5,None)
ax.set_yscale('symlog', linthresh=1e-6)
for ax in axs:
    ax.legend(fontsize=12)
    ax.tick_params(labelsize=12)


plt.tight_layout()

# %% [markdown]
# ### Thomas Fermi (TF)

# %%
# %%time
from scipy.interpolate import interp1d
aa.solve_TF(verbose=True, picard_alpha=0.2, tol=1e-9)
aa.set_uii_eff()
# aa.iet.HNC_solve(iters_to_wait=1e5, alpha_Picard=1e-2, tol=1e-12, verbose=False, num_iterations=1e5)
# aa.gii = interp1d(aa.iet.r_array*aa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(aa.grid.xs)
# npa_2.gii = interp1d(aa.iet.r_array*aa.rs, aa.iet.h_r_matrix[0,0]+1, bounds_error=False, fill_value='extrapolate')(npa.grid.xs)
# aa.make_ρi()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 2.105182904e+00, change: 3.458886207e+00 (converged=False)
# 	φe Err =  0.000e+00, φe change =  7.578e-01
# 	ne Err =  8.229e-01, ne change =  3.710e-03
# 	Q =  0.000e+00 -> -1.166e+01,
# 	Zstar guess =  1.113e+01. Current Zstar:  5.027e+00 (converged=False)
# 	Change =  1.496e+00
# __________________________________________
# TF Iteration 1
# 	μ = 1.723881961e+00, change: 1.811248527e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.209e-01
# 	ne Err =  6.239e-01, ne change =  2.163e-03
# 	Q = -1.166e+01 -> -1.034e+01,
# 	Zstar guess =  1.029e+01. Current Zstar:  6.080e+00 (converged=False)
# 	Change =  2.781e-01
# __________________________________________
# TF Iteration 2
# 	μ = 1.435514653e+00, change: 1.672778727e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  9.214e-02
# 	ne Err =  4.364e-01, ne change =  1.338e-03
# 	Q = -1.034e+01 -> -9.169e+00,
# 	Zstar guess =  9.254e+00. Current Zstar:  6.715e+00 (converged=False)
# 	Change =  2.328e-01
# __________________________________________
# TF Iteration 3
# 	μ = 1.139882485e+00, change: 2.059415886e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  6.628e-02
# 	ne Err =  3.072e-01, ne change =  8.254e-04
# 	Q = -9.169e+00 -> -8.276e+00,
# 	Zstar guess =  8.088e+00. Current Zstar:  6.990e+00 (converged=False)
# 	Change =  2.375e-01
# __________________________________________
# TF Iteration 4
# 	μ = 9.374680342e-01, change: 1.775748409e-01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  4.141e-02
# 	ne Err =  2.725e-01, ne change =  5.300e-04
# 	Q = -8.276e+00 -> -7.244e+00,
# 	Zstar guess =  7.067e+00. Current Zstar:  7.005e+00 (converged=False)
# 	Change =  1.855e-01
# __________________________________________
# TF Iteration 5
# 	μ = 9.373409813e-01, change: 1.355277940e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.719e-02
# 	ne Err =  1.618e-01, ne change =  3.460e-04
# 	Q = -7.244e+00 -> -6.245e+00,
# 	Zstar guess =  6.217e+00. Current Zstar:  6.848e+00 (converged=False)
# 	Change =  3.301e-02
# __________________________________________
# TF Iteration 6
# 	μ = 9.373409813e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.744e-02
# 	ne Err =  9.215e-02, ne change =  2.183e-04
# 	Q = -6.245e+00 -> -5.762e+00,
# 	Zstar guess =  5.561e+00. Current Zstar:  6.590e+00 (converged=False)
# 	Change =  2.180e-02
# __________________________________________
# TF Iteration 7
# 	μ = 9.373409813e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.092e-03
# 	ne Err =  6.341e-02, ne change =  1.494e-04
# 	Q = -5.762e+00 -> -5.508e+00,
# 	Zstar guess =  5.278e+00. Current Zstar:  6.328e+00 (converged=False)
# 	Change =  8.885e-03
# __________________________________________
# TF Iteration 8
# 	μ = 9.373409813e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.856e-03
# 	ne Err =  4.784e-02, ne change =  1.077e-04
# 	Q = -5.508e+00 -> -5.359e+00,
# 	Zstar guess =  5.169e+00. Current Zstar:  6.096e+00 (converged=False)
# 	Change =  3.502e-03
# __________________________________________
# TF Iteration 9
# 	μ = 9.373409813e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.240e-03
# 	ne Err =  3.706e-02, ne change =  8.008e-05
# 	Q = -5.359e+00 -> -5.263e+00,
# 	Zstar guess =  5.131e+00. Current Zstar:  5.903e+00 (converged=False)
# 	Change =  1.383e-03
# __________________________________________
# TF Iteration 25
# 	μ = 4.534732377e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.274e-04
# 	ne Err =  3.501e-02, ne change =  2.092e-06
# 	Q = -1.170e+00 -> -1.080e+00,
# 	Zstar guess =  3.777e+00. Current Zstar:  4.066e+00 (converged=False)
# 	Change =  2.351e-04
# __________________________________________
# TF Iteration 50
# 	μ = 3.610146302e-01, change: 2.467139956e-02 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.289e-05
# 	ne Err =  7.333e-03, ne change =  3.733e-08
# 	Q = -1.342e-01 -> -1.297e-01,
# 	Zstar guess =  3.449e+00. Current Zstar:  3.470e+00 (converged=False)
# 	Change =  1.767e-02
# __________________________________________
# TF Iteration 75
# 	μ = 3.562904120e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.883e-06
# 	ne Err =  3.594e-04, ne change =  1.993e-08
# 	Q = -9.779e-03 -> -8.946e-03,
# 	Zstar guess =  3.396e+00. Current Zstar:  3.399e+00 (converged=False)
# 	Change =  1.628e-06
# __________________________________________
# TF Iteration 100
# 	μ = 3.555844484e-01, change: 1.761838181e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.968e-08
# 	ne Err =  5.305e-05, ne change =  3.074e-10
# 	Q = -9.476e-04 -> -9.108e-04,
# 	Zstar guess =  3.393e+00. Current Zstar:  3.393e+00 (converged=False)
# 	Change =  1.247e-04
# __________________________________________
# TF Iteration 125
# 	μ = 3.555535094e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.204e-08
# 	ne Err =  2.456e-06, ne change =  1.280e-10
# 	Q = -6.347e-05 -> -5.790e-05,
# 	Zstar guess =  3.393e+00. Current Zstar:  3.393e+00 (converged=False)
# 	Change =  1.019e-08
# __________________________________________
# TF Iteration 150
# 	μ = 3.555490844e-01, change: 1.085393541e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.233e-10
# 	ne Err =  3.316e-07, ne change =  1.970e-12
# 	Q = -5.885e-06 -> -5.649e-06,
# 	Zstar guess =  3.393e+00. Current Zstar:  3.393e+00 (converged=False)
# 	Change =  7.680e-07
# __________________________________________
# TF Iteration 175
# 	μ = 3.555488954e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.326e-11
# 	ne Err =  1.514e-08, ne change =  7.794e-13
# 	Q = -3.874e-07 -> -3.532e-07,
# 	Zstar guess =  3.393e+00. Current Zstar:  3.393e+00 (converged=False)
# 	Change =  6.181e-11
# __________________________________________
# TF Iteration 200
# 	μ = 3.555488709e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.836e-12
# 	ne Err =  9.605e-10, ne change =  1.556e-14
# 	Q = -3.737e-08 -> -3.560e-08,
# 	Zstar guess =  3.393e+00. Current Zstar:  3.393e+00 (converged=False)
# 	Change =  3.930e-12
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 8.763e+02
# Exiting status 0, reverting to best index so far: 3604
# Final iter:3605, Total Error: 9.954e-13
# CPU times: user 1min 11s, sys: 145 ms, total: 1min 11s
# Wall time: 1min 11s

# %%
cutoff_point = 0.02
cutoff_index = np.argmin(np.abs(  cutoff_point - np.array([aa.grid.integrate_f(aa.ne, end_index = i) for i in range(len(aa.ne))])))
guess_tfdw_ne = 1/(  1/aa.ne + 1/aa.ne[cutoff_index])
aaW.ne = guess_tfdw_ne.copy()
aaW.μ  = aa.μ
aaW.Zstar = aa.Zstar

aaW.solve_TF(verbose=True, picard_alpha=1e-3, tol=1e-9)
aaW.set_uii_eff()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = -2.393071972e+02, change: 6.740641462e+02 (converged=False)
# 	φe Err =  0.000e+00, φe change =  5.718e-01
# 	ne Err =  9.996e-01, ne change =  9.506e-04
# 	Q =  0.000e+00 ->  8.987e-02,
# 	Zstar guess =  1.486e+00. Current Zstar:  3.011e+00 (converged=False)
# 	Change =  1.461e+00
# __________________________________________
# TF Iteration 1
# 	μ = -1.390303953e+04, change: 5.709703882e+01 (converged=False)
# 	φe Err =  0.000e+00, φe change =  1.434e-04
# 	ne Err =  9.996e-01, ne change =  7.491e-04
# 	Q =  8.987e-02 ->  8.978e-02,
# 	Zstar guess =  1.505e+00. Current Zstar:  2.710e+00 (converged=False)
# 	Change =  9.829e-01
# __________________________________________
# TF Iteration 2
# 	μ = -1.390303953e+04, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.814e-04
# 	ne Err =  1.000e+00, ne change =  7.075e-04
# 	Q =  8.978e-02 ->  8.969e-02,
# 	Zstar guess =  1.495e+00. Current Zstar:  2.467e+00 (converged=False)
# 	Change =  1.397e-03
# __________________________________________
# TF Iteration 3
# 	μ = -1.390303953e+04, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.073e-04
# 	ne Err =  1.000e+00, ne change =  7.075e-04
# 	Q =  8.969e-02 ->  1.026e-01,
# 	Zstar guess =  1.485e+00. Current Zstar:  2.271e+00 (converged=False)
# 	Change =  1.414e-03
# __________________________________________
# TF Iteration 4
# 	μ = -1.390303953e+04, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.075e-04
# 	ne Err =  1.000e+00, ne change =  7.075e-04
# 	Q =  1.026e-01 ->  1.155e-01,
# 	Zstar guess =  1.476e+00. Current Zstar:  2.112e+00 (converged=False)
# 	Change =  1.415e-03
# __________________________________________
# TF Iteration 5
# 	μ = -1.390303953e+04, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.075e-04
# 	ne Err =  1.000e+00, ne change =  7.075e-04
# 	Q =  1.155e-01 ->  1.284e-01,
# 	Zstar guess =  1.470e+00. Current Zstar:  1.983e+00 (converged=False)
# 	Change =  1.415e-03
# __________________________________________
# TF Iteration 6
# 	μ = -1.390303953e+04, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.075e-04
# 	ne Err =  1.000e+00, ne change =  7.075e-04
# 	Q =  1.284e-01 ->  1.413e-01,
# 	Zstar guess =  1.465e+00. Current Zstar:  1.880e+00 (converged=False)
# 	Change =  1.415e-03
# __________________________________________
# TF Iteration 7
# 	μ = -1.390303953e+04, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.075e-04
# 	ne Err =  1.000e+00, ne change =  7.075e-04
# 	Q =  1.413e-01 ->  1.541e-01,
# 	Zstar guess =  1.463e+00. Current Zstar:  1.796e+00 (converged=False)
# 	Change =  1.415e-03
# __________________________________________
# TF Iteration 8
# 	μ = -1.390303953e+04, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.075e-04
# 	ne Err =  1.000e+00, ne change =  7.075e-04
# 	Q =  1.541e-01 ->  1.670e-01,
# 	Zstar guess =  1.461e+00. Current Zstar:  1.729e+00 (converged=False)
# 	Change =  1.415e-03
# __________________________________________
# TF Iteration 9
# 	μ = -1.390303953e+04, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.075e-04
# 	ne Err =  1.000e+00, ne change =  7.075e-04
# 	Q =  1.670e-01 ->  1.798e-01,
# 	Zstar guess =  1.461e+00. Current Zstar:  1.676e+00 (converged=False)
# 	Change =  1.415e-03
# KeyboardInterrupt

# %%
# %%time
npa.solve_TF(verbose=True, picard_alpha=1e-2, tol=1e-9, nmax = 5000, n_wait_update_Zstar= 500)
npa.set_uii_eff()
# Out:
# Beginning self-consistent electron solver.
# _________________________________
# __________________________________________
# TF Iteration 0
# 	μ = 4.722039679e-01, change: 1.524121357e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.886e-01
# 	ne Err =  3.443e-03, ne change =  4.831e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  1.745e-01
# __________________________________________
# TF Iteration 1
# 	μ = 4.721155039e-01, change: 1.873427243e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.518e-04
# 	ne Err =  3.394e-03, ne change =  4.750e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  4.589e-03
# __________________________________________
# TF Iteration 2
# 	μ = 4.720906908e-01, change: 5.255727723e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.383e-04
# 	ne Err =  3.350e-03, ne change =  4.671e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  4.328e-03
# __________________________________________
# TF Iteration 3
# 	μ = 4.720902000e-01, change: 1.039627105e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.295e-04
# 	ne Err =  3.306e-03, ne change =  4.593e-03
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  4.176e-03
# __________________________________________
# TF Iteration 4
# 	μ = 4.720977436e-01, change: 1.597905220e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.220e-04
# 	ne Err =  3.263e-03, ne change =  4.518e-03
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  4.095e-03
# __________________________________________
# TF Iteration 5
# 	μ = 4.721066887e-01, change: 1.894760714e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.151e-04
# 	ne Err =  3.221e-03, ne change =  4.444e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  4.020e-03
# __________________________________________
# TF Iteration 6
# 	μ = 4.721145884e-01, change: 1.673275643e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.084e-04
# 	ne Err =  3.180e-03, ne change =  4.372e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  3.965e-03
# __________________________________________
# TF Iteration 7
# 	μ = 4.721207562e-01, change: 1.306421481e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.018e-04
# 	ne Err =  3.140e-03, ne change =  4.302e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  3.909e-03
# __________________________________________
# TF Iteration 8
# 	μ = 4.721252038e-01, change: 9.420493606e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.954e-04
# 	ne Err =  3.100e-03, ne change =  4.233e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  3.852e-03
# __________________________________________
# TF Iteration 9
# 	μ = 4.721281840e-01, change: 6.312434308e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.890e-04
# 	ne Err =  3.061e-03, ne change =  4.165e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  3.796e-03
# __________________________________________
# TF Iteration 25
# 	μ = 4.721237808e-01, change: 7.434273600e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.948e-04
# 	ne Err =  2.507e-03, ne change =  3.259e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  3.022e-03
# __________________________________________
# TF Iteration 50
# 	μ = 4.721239457e-01, change: 1.247033898e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.728e-04
# 	ne Err =  1.837e-03, ne change =  2.297e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  2.154e-03
# __________________________________________
# TF Iteration 75
# 	μ = 4.721243545e-01, change: 1.069898725e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.795e-04
# 	ne Err =  1.346e-03, ne change =  1.664e-03
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  1.568e-03
# __________________________________________
# TF Iteration 100
# 	μ = 4.721242132e-01, change: 7.328484486e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.093e-04
# 	ne Err =  9.876e-04, ne change =  1.228e-03
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  1.159e-03
# __________________________________________
# TF Iteration 125
# 	μ = 4.721241837e-01, change: 4.350340088e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.567e-04
# 	ne Err =  7.256e-04, ne change =  9.184e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  8.660e-04
# __________________________________________
# TF Iteration 150
# 	μ = 4.721241938e-01, change: 8.085538905e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.174e-04
# 	ne Err =  5.344e-04, ne change =  6.932e-04
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  6.525e-04
# __________________________________________
# TF Iteration 175
# 	μ = 4.721241983e-01, change: 0.000000000e+00 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.807e-05
# 	ne Err =  3.946e-04, ne change =  5.269e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  4.947e-04
# __________________________________________
# TF Iteration 200
# 	μ = 4.721241959e-01, change: 3.401420257e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.612e-05
# 	ne Err =  2.923e-04, ne change =  4.025e-04
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  3.768e-04
# __________________________________________
# TF Iteration 225
# 	μ = 4.721241916e-01, change: 3.561573259e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.970e-05
# 	ne Err =  2.173e-04, ne change =  3.087e-04
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  2.880e-04
# __________________________________________
# TF Iteration 250
# 	μ = 4.721241879e-01, change: 2.721597392e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.739e-05
# 	ne Err =  1.620e-04, ne change =  2.375e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  2.208e-04
# __________________________________________
# TF Iteration 275
# 	μ = 4.721241852e-01, change: 1.899187474e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.816e-05
# 	ne Err =  1.213e-04, ne change =  1.831e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  1.696e-04
# __________________________________________
# TF Iteration 300
# 	μ = 4.721241834e-01, change: 2.633825380e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.122e-05
# 	ne Err =  9.112e-05, ne change =  1.414e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  1.305e-04
# __________________________________________
# TF Iteration 325
# 	μ = 4.721241821e-01, change: 5.985212326e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.601e-05
# 	ne Err =  6.872e-05, ne change =  1.093e-04
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  1.005e-04
# __________________________________________
# TF Iteration 350
# 	μ = 4.721241812e-01, change: 1.295297203e-12 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.209e-05
# 	ne Err =  5.203e-05, ne change =  8.463e-05
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  7.752e-05
# __________________________________________
# TF Iteration 375
# 	μ = 4.721241804e-01, change: 2.072346739e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.140e-06
# 	ne Err =  3.955e-05, ne change =  6.557e-05
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  5.984e-05
# __________________________________________
# TF Iteration 400
# 	μ = 4.721241799e-01, change: 8.978373600e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.914e-06
# 	ne Err =  3.018e-05, ne change =  5.083e-05
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  4.622e-05
# __________________________________________
# TF Iteration 425
# 	μ = 4.721241796e-01, change: 1.897593194e-12 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.234e-06
# 	ne Err =  2.312e-05, ne change =  3.942e-05
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  3.572e-05
# __________________________________________
# TF Iteration 450
# 	μ = 4.721241792e-01, change: 1.844112640e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.966e-06
# 	ne Err =  1.778e-05, ne change =  3.059e-05
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  2.762e-05
# __________________________________________
# TF Iteration 475
# 	μ = 4.721241791e-01, change: 1.393329896e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.007e-06
# 	ne Err =  1.373e-05, ne change =  2.374e-05
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  2.136e-05
# __________________________________________
# TF Iteration 500
# 	μ = 4.721241790e-01, change: 1.443067887e-12 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.282e-06
# 	ne Err =  1.064e-05, ne change =  1.843e-05
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  0.000e+00. Current Zstar:  3.500e+00 (converged=False)
# 	Change =  1.653e-05
# __________________________________________
# TF Iteration 525
# 	μ = 4.798139399e-01, change: 1.051394033e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.914e-05
# 	ne Err =  1.944e-04, ne change =  1.427e-05
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  3.969e+00. Current Zstar:  3.585e+00 (converged=False)
# 	Change =  1.048e-04
# __________________________________________
# TF Iteration 550
# 	μ = 4.903486205e-01, change: 6.754584678e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.034e-05
# 	ne Err =  1.668e-04, ne change =  1.114e-05
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  4.034e+00. Current Zstar:  3.703e+00 (converged=False)
# 	Change =  4.844e-03
# __________________________________________
# TF Iteration 575
# 	μ = 4.962230504e-01, change: 6.182525077e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.555e-05
# 	ne Err =  2.135e-04, ne change =  8.617e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.056e+00. Current Zstar:  3.769e+00 (converged=False)
# 	Change =  8.724e-05
# __________________________________________
# TF Iteration 600
# 	μ = 5.034909176e-01, change: 4.425321199e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.234e-05
# 	ne Err =  1.764e-04, ne change =  6.746e-06
# 	Q = -4.547e-13 ->  4.547e-13,
# 	Zstar guess =  4.078e+00. Current Zstar:  3.851e+00 (converged=False)
# 	Change =  3.183e-03
# __________________________________________
# TF Iteration 625
# 	μ = 5.073825197e-01, change: 3.169403084e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.505e-05
# 	ne Err =  1.789e-04, ne change =  5.215e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.087e+00. Current Zstar:  3.896e+00 (converged=False)
# 	Change =  5.794e-05
# __________________________________________
# TF Iteration 650
# 	μ = 5.121253615e-01, change: 2.823699413e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.177e-05
# 	ne Err =  1.448e-04, ne change =  4.086e-06
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  4.098e+00. Current Zstar:  3.950e+00 (converged=False)
# 	Change =  2.034e-03
# __________________________________________
# TF Iteration 675
# 	μ = 5.146486221e-01, change: 1.682727199e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.950e-05
# 	ne Err =  1.352e-04, ne change =  3.155e-06
# 	Q = -4.547e-13 ->  0.000e+00,
# 	Zstar guess =  4.104e+00. Current Zstar:  3.979e+00 (converged=False)
# 	Change =  3.732e-05
# __________________________________________
# TF Iteration 700
# 	μ = 5.177206153e-01, change: 1.807406327e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.420e-05
# 	ne Err =  1.081e-04, ne change =  2.473e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.111e+00. Current Zstar:  4.014e+00 (converged=False)
# 	Change =  1.303e-03
# __________________________________________
# TF Iteration 725
# 	μ = 5.193558851e-01, change: 9.481732682e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.918e-05
# 	ne Err =  9.704e-05, ne change =  1.907e-06
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  4.114e+00. Current Zstar:  4.033e+00 (converged=False)
# 	Change =  2.400e-05
# __________________________________________
# TF Iteration 750
# 	μ = 5.213505653e-01, change: 1.165576972e-03 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.240e-06
# 	ne Err =  7.706e-05, ne change =  1.496e-06
# 	Q =  4.547e-13 -> -4.547e-13,
# 	Zstar guess =  4.119e+00. Current Zstar:  4.056e+00 (converged=False)
# 	Change =  8.406e-04
# __________________________________________
# TF Iteration 775
# 	μ = 5.224142409e-01, change: 5.574941252e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.249e-05
# 	ne Err =  6.764e-05, ne change =  1.153e-06
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.122e+00. Current Zstar:  4.068e+00 (converged=False)
# 	Change =  1.550e-05
# __________________________________________
# TF Iteration 800
# 	μ = 5.237142549e-01, change: 7.562351967e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.028e-06
# 	ne Err =  5.350e-05, ne change =  9.050e-07
# 	Q =  0.000e+00 -> -4.547e-13,
# 	Zstar guess =  4.125e+00. Current Zstar:  4.083e+00 (converged=False)
# 	Change =  5.455e-04
# __________________________________________
# TF Iteration 825
# 	μ = 5.244089326e-01, change: 3.411099864e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.163e-06
# 	ne Err =  4.634e-05, ne change =  6.963e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.126e+00. Current Zstar:  4.091e+00 (converged=False)
# 	Change =  1.005e-05
# __________________________________________
# TF Iteration 850
# 	μ = 5.252587979e-01, change: 4.932556166e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.944e-06
# 	ne Err =  3.657e-05, ne change =  5.474e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.128e+00. Current Zstar:  4.101e+00 (converged=False)
# 	Change =  3.558e-04
# __________________________________________
# TF Iteration 875
# 	μ = 5.257136167e-01, change: 2.119411173e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.349e-06
# 	ne Err =  3.140e-05, ne change =  4.206e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.129e+00. Current Zstar:  4.107e+00 (converged=False)
# 	Change =  6.544e-06
# __________________________________________
# TF Iteration 900
# 	μ = 5.262707805e-01, change: 3.226580476e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.588e-06
# 	ne Err =  2.475e-05, ne change =  3.312e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.131e+00. Current Zstar:  4.113e+00 (converged=False)
# 	Change =  2.328e-04
# __________________________________________
# TF Iteration 925
# 	μ = 5.265690130e-01, change: 1.322596289e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.512e-06
# 	ne Err =  2.113e-05, ne change =  2.541e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.132e+00. Current Zstar:  4.117e+00 (converged=False)
# 	Change =  4.270e-06
# __________________________________________
# TF Iteration 950
# 	μ = 5.269348396e-01, change: 2.117382641e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.700e-06
# 	ne Err =  1.664e-05, ne change =  2.005e-07
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.132e+00. Current Zstar:  4.121e+00 (converged=False)
# 	Change =  1.527e-04
# __________________________________________
# TF Iteration 975
# 	μ = 5.271308992e-01, change: 8.617774938e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.309e-06
# 	ne Err =  1.415e-05, ne change =  1.535e-07
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.133e+00. Current Zstar:  4.123e+00 (converged=False)
# 	Change =  2.794e-06
# __________________________________________
# TF Iteration 1000
# 	μ = 5.273714933e-01, change: 1.391452370e-04 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.119e-06
# 	ne Err =  1.114e-05, ne change =  1.214e-07
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.134e+00. Current Zstar:  4.126e+00 (converged=False)
# 	Change =  1.004e-04
# __________________________________________
# TF Iteration 1025
# 	μ = 5.275004007e-01, change: 5.502860079e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.519e-06
# 	ne Err =  9.445e-06, ne change =  9.276e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.134e+00. Current Zstar:  4.127e+00 (converged=False)
# 	Change =  1.830e-06
# __________________________________________
# TF Iteration 1050
# 	μ = 5.276585326e-01, change: 9.141635501e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.364e-07
# 	ne Err =  7.433e-06, ne change =  7.356e-08
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.134e+00. Current Zstar:  4.129e+00 (converged=False)
# 	Change =  6.594e-05
# __________________________________________
# TF Iteration 1075
# 	μ = 5.277433249e-01, change: 3.546558203e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.000e-06
# 	ne Err =  6.289e-06, ne change =  5.606e-08
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.134e+00. Current Zstar:  4.130e+00 (converged=False)
# 	Change =  1.199e-06
# __________________________________________
# TF Iteration 1100
# 	μ = 5.278474374e-01, change: 6.016964169e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.851e-07
# 	ne Err =  4.950e-06, ne change =  4.460e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.135e+00. Current Zstar:  4.131e+00 (converged=False)
# 	Change =  4.340e-05
# __________________________________________
# TF Iteration 1125
# 	μ = 5.279032772e-01, change: 2.330819870e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.589e-07
# 	ne Err =  4.181e-06, ne change =  3.389e-08
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.135e+00. Current Zstar:  4.132e+00 (converged=False)
# 	Change =  7.872e-07
# __________________________________________
# TF Iteration 1150
# 	μ = 5.279718530e-01, change: 3.962465004e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.196e-07
# 	ne Err =  3.291e-06, ne change =  2.706e-08
# 	Q =  9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.135e+00. Current Zstar:  4.133e+00 (converged=False)
# 	Change =  2.858e-05
# __________________________________________
# TF Iteration 1175
# 	μ = 5.280086400e-01, change: 1.533254446e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.341e-07
# 	ne Err =  2.776e-06, ne change =  2.049e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.135e+00. Current Zstar:  4.133e+00 (converged=False)
# 	Change =  5.170e-07
# __________________________________________
# TF Iteration 1200
# 	μ = 5.280538241e-01, change: 2.610549826e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.107e-07
# 	ne Err =  2.185e-06, ne change =  1.643e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.135e+00. Current Zstar:  4.134e+00 (converged=False)
# 	Change =  1.883e-05
# __________________________________________
# TF Iteration 1225
# 	μ = 5.280780664e-01, change: 1.009499828e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.861e-07
# 	ne Err =  1.841e-06, ne change =  1.239e-08
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.135e+00. Current Zstar:  4.134e+00 (converged=False)
# 	Change =  3.398e-07
# __________________________________________
# TF Iteration 1250
# 	μ = 5.281078458e-01, change: 1.720426401e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.389e-07
# 	ne Err =  1.450e-06, ne change =  9.983e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.135e+00. Current Zstar:  4.134e+00 (converged=False)
# 	Change =  1.241e-05
# __________________________________________
# TF Iteration 1275
# 	μ = 5.281238252e-01, change: 6.650029860e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.886e-07
# 	ne Err =  1.221e-06, ne change =  7.495e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.135e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  2.234e-07
# __________________________________________
# TF Iteration 1300
# 	μ = 5.281434563e-01, change: 1.134095504e-05 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.157e-08
# 	ne Err =  9.610e-07, ne change =  6.072e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.135e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  8.178e-06
# __________________________________________
# TF Iteration 1325
# 	μ = 5.281539912e-01, change: 4.382577190e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.244e-07
# 	ne Err =  8.087e-07, ne change =  4.534e-09
# 	Q = -9.095e-13 ->  0.000e+00,
# 	Zstar guess =  4.135e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  1.470e-07
# __________________________________________
# TF Iteration 1350
# 	μ = 5.281669347e-01, change: 7.477392457e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.039e-08
# 	ne Err =  6.368e-07, ne change =  3.697e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  5.392e-06
# __________________________________________
# TF Iteration 1375
# 	μ = 5.281738813e-01, change: 2.889070094e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.203e-08
# 	ne Err =  5.356e-07, ne change =  2.744e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  9.671e-08
# __________________________________________
# TF Iteration 1400
# 	μ = 5.281824167e-01, change: 4.930859498e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.983e-08
# 	ne Err =  4.218e-07, ne change =  2.254e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  3.556e-06
# __________________________________________
# TF Iteration 1425
# 	μ = 5.281869979e-01, change: 1.905029468e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.410e-08
# 	ne Err =  3.546e-07, ne change =  1.660e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  6.366e-08
# __________________________________________
# TF Iteration 1450
# 	μ = 5.281926273e-01, change: 3.252041997e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.627e-08
# 	ne Err =  2.794e-07, ne change =  1.376e-09
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  2.345e-06
# __________________________________________
# TF Iteration 1475
# 	μ = 5.281956488e-01, change: 1.256345361e-09 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.569e-08
# 	ne Err =  2.347e-07, ne change =  1.005e-09
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  4.191e-08
# __________________________________________
# TF Iteration 1500
# 	μ = 5.281993620e-01, change: 2.145078404e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.733e-08
# 	ne Err =  1.849e-07, ne change =  8.414e-10
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  1.547e-06
# __________________________________________
# TF Iteration 1525
# 	μ = 5.282013551e-01, change: 8.286746844e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.354e-08
# 	ne Err =  1.554e-07, ne change =  6.085e-10
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.135e+00 (converged=False)
# 	Change =  2.760e-08
# __________________________________________
# TF Iteration 1550
# 	μ = 5.282038046e-01, change: 1.415067822e-06 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.143e-08
# 	ne Err =  1.224e-07, ne change =  5.153e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  1.020e-06
# __________________________________________
# TF Iteration 1575
# 	μ = 5.282051195e-01, change: 5.466803676e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.553e-08
# 	ne Err =  1.028e-07, ne change =  3.685e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  1.818e-08
# __________________________________________
# TF Iteration 1600
# 	μ = 5.282067355e-01, change: 9.335851854e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  7.544e-09
# 	ne Err =  8.103e-08, ne change =  3.162e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  6.731e-07
# __________________________________________
# TF Iteration 1625
# 	μ = 5.282076030e-01, change: 3.606593912e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.025e-08
# 	ne Err =  6.803e-08, ne change =  2.232e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  1.198e-08
# __________________________________________
# TF Iteration 1650
# 	μ = 5.282086692e-01, change: 6.159853052e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.978e-09
# 	ne Err =  5.363e-08, ne change =  1.944e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  4.441e-07
# __________________________________________
# TF Iteration 1675
# 	μ = 5.282092417e-01, change: 2.379921815e-10 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.762e-09
# 	ne Err =  4.501e-08, ne change =  1.352e-10
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  7.896e-09
# __________________________________________
# TF Iteration 1700
# 	μ = 5.282099452e-01, change: 4.064656096e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.285e-09
# 	ne Err =  3.549e-08, ne change =  1.198e-10
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  2.930e-07
# __________________________________________
# TF Iteration 1725
# 	μ = 5.282103230e-01, change: 1.620481527e-12 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.462e-09
# 	ne Err =  2.978e-08, ne change =  8.194e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  5.095e-09
# __________________________________________
# TF Iteration 1750
# 	μ = 5.282107872e-01, change: 2.682332267e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.168e-09
# 	ne Err =  2.349e-08, ne change =  7.406e-11
# 	Q =  9.095e-13 -> -9.095e-13,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  1.934e-07
# __________________________________________
# TF Iteration 1775
# 	μ = 5.282110366e-01, change: 7.108758027e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.945e-09
# 	ne Err =  1.970e-08, ne change =  4.966e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  3.358e-09
# __________________________________________
# TF Iteration 1800
# 	μ = 5.282113429e-01, change: 1.770250411e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.431e-09
# 	ne Err =  1.554e-08, ne change =  4.589e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  1.276e-07
# __________________________________________
# TF Iteration 1825
# 	μ = 5.282115075e-01, change: 3.110844915e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.944e-09
# 	ne Err =  1.304e-08, ne change =  3.011e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  2.214e-09
# __________________________________________
# TF Iteration 1850
# 	μ = 5.282117097e-01, change: 1.168394768e-07 (converged=True)
# 	φe Err =  0.000e+00, φe change =  9.443e-10
# 	ne Err =  1.029e-08, ne change =  2.852e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  8.423e-08
# __________________________________________
# TF Iteration 1875
# 	μ = 5.282118183e-01, change: 1.360023205e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.283e-09
# 	ne Err =  8.625e-09, ne change =  1.826e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  1.460e-09
# __________________________________________
# TF Iteration 1900
# 	μ = 5.282119517e-01, change: 7.725621787e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  6.233e-10
# 	ne Err =  6.806e-09, ne change =  1.778e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  5.569e-08
# __________________________________________
# TF Iteration 1925
# 	μ = 5.282120234e-01, change: 5.928590951e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  8.468e-10
# 	ne Err =  5.707e-09, ne change =  1.108e-11
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  9.630e-10
# __________________________________________
# TF Iteration 1950
# 	μ = 5.282121115e-01, change: 5.090983257e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  4.116e-10
# 	ne Err =  4.504e-09, ne change =  1.112e-11
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  3.670e-08
# __________________________________________
# TF Iteration 1975
# 	μ = 5.282121588e-01, change: 2.586819647e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  5.590e-10
# 	ne Err =  3.776e-09, ne change =  6.723e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  6.352e-10
# __________________________________________
# TF Iteration 2000
# 	μ = 5.282122170e-01, change: 3.366811163e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.716e-10
# 	ne Err =  2.981e-09, ne change =  6.981e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  2.427e-08
# __________________________________________
# TF Iteration 2025
# 	μ = 5.282122482e-01, change: 1.132427485e-14 (converged=True)
# 	φe Err =  0.000e+00, φe change =  3.690e-10
# 	ne Err =  2.499e-09, ne change =  4.082e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  4.191e-10
# __________________________________________
# TF Iteration 2050
# 	μ = 5.282122866e-01, change: 2.219008044e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.795e-10
# 	ne Err =  1.973e-09, ne change =  4.398e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  1.600e-08
# __________________________________________
# TF Iteration 2075
# 	μ = 5.282123073e-01, change: 1.584843368e-12 (converged=True)
# 	φe Err =  0.000e+00, φe change =  2.437e-10
# 	ne Err =  1.658e-09, ne change =  2.479e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  2.777e-10
# __________________________________________
# TF Iteration 2100
# 	μ = 5.282123326e-01, change: 1.465156552e-08 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.185e-10
# 	ne Err =  1.306e-09, ne change =  2.780e-12
# 	Q =  0.000e+00 -> -9.095e-13,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  1.056e-08
# __________________________________________
# TF Iteration 2125
# 	μ = 5.282123463e-01, change: 7.003286839e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.609e-10
# 	ne Err =  1.098e-09, ne change =  1.506e-12
# 	Q =  0.000e+00 ->  0.000e+00,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  1.830e-10
# __________________________________________
# TF Iteration 2137
# 	μ = 5.282123523e-01, change: 3.369526880e-13 (converged=True)
# 	φe Err =  0.000e+00, φe change =  1.266e-10
# 	ne Err =  9.926e-10, ne change =  1.358e-12
# 	Q =  0.000e+00 ->  9.095e-13,
# 	Zstar guess =  4.136e+00. Current Zstar:  4.136e+00 (converged=False)
# 	Change =  1.301e-10
# 	-------------------
# 	Solving IET.
# 0: Initial condition Total Error: 1.888e+03
# Exiting status 0, reverting to best index so far: 4385
# Final iter:4386, Total Error: 9.935e-13
# CPU times: user 7min 16s, sys: 103 ms, total: 7min 16s
# Wall time: 7min 16s

# %%
# %%time
cutoff_point = 0.02
cutoff_index = np.argmin(np.abs(  cutoff_point - np.array([npa.grid.integrate_f(npa.ne, end_index = i) for i in range(len(npa.ne))])))
guess_tfdw_ne = 1/(  1/npa.ne + 1/npa.ne[cutoff_index])

npaW.ne = guess_tfdw_ne.copy()
npaW.μ  = npa.μ
npaW.Zstar = npa.Zstar
npaW.φe = npa.φe.copy()
# npaW.solve_TF(verbose=True, picard_alpha=1e-2, tol=1e-9, nmax = 5000, n_wait_update_Zstar= 500)
# npaW.set_uii_eff()
# Out:
# CPU times: user 63 ms, sys: 3.97 ms, total: 67 ms
# Wall time: 66.1 ms

# %% [markdown]
# ### EOS

# %%
def get_Eii(aa):
    βVeff = aa.get_βVeff(aa.φe, aa.ne, aa.ne_bar)
    η = aa.μ/aa.Te - βVeff
    βU = aa.grid.integrate_f(βVeff*aa.ne)
    I_onehalf = FermiDirac.Ionehalf(η)
    I_threehalf = FermiDirac.Ithreehalf(η)
    
    βK = (2*aa.Te)**1.5/π**2 * aa.grid.integrate_f( η*I_onehalf - 2/3 * I_threehalf   )
    return βU, βK, βU + βK

def get_ETF(aa):
    
def get_Exc(aa):
    aa.vxc

def get_E_Hartree(aa):
    
    
    

# get_E(aa_tfd), get_E(npa_tfd)

# %%
def get_P(aa):
    aa_old_βu = aa.iet.βu_r_matrix.copy()
    # aa.iet.set_βu_matrix( np.array([[1/aa.Ti * aa.Zstar**2/(aa.iet.r_array*aa.rs) ]] ))
    P_id_hnc, P_ex_hnc, P_hnc = aa.iet.ideal_pressure(), aa.iet.excess_pressure(), aa.iet.total_pressure()
    P_id_AU, P_ex_AU, P_AU  = P_id_hnc/rs**3, P_ex_hnc/rs**3, P_hnc/rs**3
    aa.iet.set_βu_matrix(aa_old_βu)
    return P_id_AU, P_ex_AU, P_AU

aa_P_ions = get_P(aa_tfd)
aa_P_ions[1]/aa_P_ions[0]

# %% [markdown]
# ## Comparison

# %%
npaW.make_plots()
# Out:
# (<Figure size 4000x1600 with 2 Axes>,
#  array([<Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$\\phi$ [A.U.]'>,
#         <Axes: xlabel='$|r-R_1|$ [A.U.]', ylabel='$n$ [A.U.]'>],
#        dtype=object))

# %%
def plot_convergence(aa, axs=None):
    if axs is None:
        fig, axs = plt.subplots(ncols=3,figsize=(18,5),facecolor='w', dpi=200)
    
    # ELectric potential
    slice_by_num = 100
    ax = axs[0]
    colors = plt.cm.coolwarm(np.linspace(0, 1,len(aa.φe_list[::slice_by_num])))
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        if i ==0 or i==len(aa.φe_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, (φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\phi_e$'.format(i))
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1, label=r'$\vec E$'.format(i))
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1, label=r'$\beta V_{{\rm eff}}$'.format(i))
        else:
            ax.plot(aa.grid.xs, φe+aa.φion,linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, -aa.grid.dfdx(φe+aa.φion),linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, aa.get_βVeff(φe, ne, ne_bar),linewidth=1,color=colors[i],alpha=1)
    # ax.plot(aa.grid.xs, aa.get_φe( (aa.ρi - aa.ne) )[0] + aa.φion  ,'k:', label=r'$\phi$ check') 
    ax.set_yscale('symlog',linthresh=1e-10)
    ax.plot(aa.grid.xs, aa.φe_init + aa.φion, 'k:')

    # number density
    ax = axs[1]
    for i, (ne, ρi) in enumerate(zip(aa.ne_list[::slice_by_num], aa.ρi_list[::slice_by_num])):
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            if i==0: 
                ne_bar_0 = ne[-1]
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1, label=r'$Q(r)$'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, -ne + 0*ρi + ne[-1],linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ne + ne_bar_0,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # ax.plot(aa.grid.xs, -ρi[-1] + ρi,linewidth=1,color=colors[i],alpha=1, label=r'$\rho$'.format(i))
            # pass
        else:
            ax.plot(aa.grid.xs, [aa.grid.integrate_f(-ne + ρi, end_index = index) + aa.Z for index in range(len(aa.grid.xs))],linewidth=1,color=colors[i],alpha=1)
            # print(ne[-1]-ne_bar_0)
            # ax.plot(aa.grid.xs, -ne + ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ne + ne_bar_0 ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, -ρi[-1]+ ρi ,linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            pass
    # for i in range(int(aa.R/aa.rs)):
    #     ax.axvline(aa.rs*i, color='k', linestyle='--', alpha=0.2)
    # ax.set_xscale('log')
    # ax.plot(aa.grid.xs, (aa.gii)-1, 'k:')
    ax.set_yscale('symlog',linthresh=1e-4)

            
    # number density
    ax = axs[2]
    for i, (φe, ne, μ, ne_bar) in enumerate(zip(aa.φe_list[::slice_by_num], aa.ne_list[::slice_by_num], aa.μ_list[::slice_by_num],aa.ne_bar_list[::slice_by_num])):
        ne_TF = aa.get_ne_TF(φe, ne, μ, ne_bar)
        if i ==0 or i==len(aa.ne_list[::slice_by_num])-1:
            ax.plot(aa.grid.xs, ne - ne_TF,linewidth=1,color=colors[i],alpha=1, label=r'$n_e/n_e^{{TF}}-1$, iter: {0}'.format(i))
            # ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1, label=r'$n_e^{{TF}} - n_e^{{TF}}[-1]$, iter: {0}'.format(i*slice_by_num))
            # ax.plot(aa.grid.xs, ne-ne[-1],linewidth=1,color=colors[i],linestyle='--',alpha=1, label=r'$n_e - n_e[-1]$, iter: {0}'.format(i))
            # pass
        else:
            ax.plot(aa.grid.xs, ne - ne_TF, linewidth=1,linestyle='-',color=colors[i],alpha=0.5)
            # ax.plot(aa.grid.xs, ne_TF-ne_TF[-1],linewidth=1,color=colors[i],alpha=1)
            # ax.plot(aa.grid.xs, ne-ne[-1], linewidth=1,linestyle='--',color=colors[i],alpha=0.5)
            

            # print(np.abs(ne/ne_TF-1))
            # print(np.where( np.abs(ne/ne_TF-1)>1e-6 ))
            # print(aa.grid.xs[np.where( np.abs(ne/ne_TF-1) > 1e-8)][0]/10, 1/(np.sum(aa.grid.xs*np.abs(ne/ne_TF-1))/np.sum(np.abs(ne/ne_TF-1))))
    # ax.set_ylim()
    # ax.plot(aa.grid.xs, npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar) - npa.get_ne_TF(npa.φe, npa.ne, npa.μ, npa.ne_bar)[-1] , 'k:')
    ax.plot(aa.grid.xs, aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar) - aa.get_ne_TF(aa.φe, aa.ne_bar*np.ones_like(aa.ne), aa.μ, aa.ne_bar)[-1] , 'k:')
    ax.set_yscale('symlog',linthresh=1e-10)
    # ax.set_xscale('log')
    for ax in axs:
        ax.legend(fontsize=14)
        ax.tick_params(labelsize=14)
        ax.plot(aa.grid.xs, np.zeros_like(aa.ne),'k', alpha=0.2)
    plt.tight_layout()
    
# plot_convergence(aa)
plot_convergence(aaW)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

petrov = pd.read_csv("../data/GP_TFDW_Al_1eV_solid.dat",header=0, comment='#', delim_whitespace=True)

def compare_aa(aa_list, axs=None, name=''):
    eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
    if axs is None:
        fig, axs = plt.subplots(ncols=2,figsize=(20,8),facecolor='w')

    # Density * 4pi r^2 plot
    for ax in axs:
        for aa, color in zip( aa_list, colors):
            factor = 4*np.pi*aa.grid.xs**2
            ax.plot(np.array(petrov['r/R'])*rs, 4*π*(np.array(petrov['r/R'])*rs)**2*(petrov['ne']/m_to_AU**3), 'k--', label="Petrov AA")
            ax.plot(aa.grid.xs, aa.ne*factor ,'--.',color=color, label=r'$n_e$: '+ name)
            ax.plot(aa.grid.xs, aa.n_b*factor,'--',color=color,  label=r'$n_b$: ' + name)
            ax.plot(aa.grid.xs, aa.n_f*factor,':',color=color,  label=r'$n_f$: ' + name)
            if aa.rs != aa.R:
                ax.plot(aa.grid.xs, aa.ρi*factor,'-',color='r',  label=r'$\rho_i$: ' + name)
                ax.plot(aa.grid.xs, (aa.ρi-aa.ne)*factor,'--',color='r',  label=r'$\rho_i+\rho_e$: ' + name)
        # axs[0].plot(aa.grid.xs, aa.δn_f*factor,'--',color='g',  label=r'$n_e^{sc}$: ' + name)


    axs[0].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[0].set_ylim(0, 1e3)
    axs[0].set_yscale('symlog',linthresh=1e-1)
    axs[0].set_xscale('log')
    axs[0].set_xlim(aa.grid.xs[0],aa.grid.xs[-1])

    axs[1].set_ylabel(r'$4 \pi r^2 n_e(r) $ [A.U.]',fontsize=20)
    axs[1].set_ylim(0, 13)
    axs[1].set_xlim(0, np.min([aa.R,1.3*aa.rs]))

        
    for ax in axs:
        ax.set_xlabel(r'$|r-R_1|$ [A.U.]',fontsize=20)
        ax.legend(loc="upper right",fontsize=20,labelspacing = 0.1)
        ax.tick_params(labelsize=20)
        ax.grid(which='both',alpha=0.4)

        # make textbox
        text = ("{0}\n".format(aa.name)+ 
            r"$r_s$ = " + "{0},    ".format(np.round(aa.rs,2)) +
            r"$R_{NPA}$ = " + "{0}\n".format(aa.R)  +
                r"$T_e$ = " + "{0} [A.U.] = {1} eV\n".format(np.round(aa.Te,2),np.round(aa.Te/eV,2)) + r"$\mu$ = " + "{0} [A.U.]\n".format(np.round(aa.μ,2)) +
                r"$Z^\ast = $" + "{0}".format(np.round(aa.Zstar,2))  )

        props = dict(boxstyle='round', facecolor='w')
        ax.text(0.25,0.95, text, fontsize=15, transform=ax.transAxes, verticalalignment='top', bbox=props)

    plt.tight_layout()
    name = "NPA_densities_{0}_rs{1}_{2}eV_R{3}.png".format(aa.name, np.round(aa.rs,2), np.round(aa.Te/eV,2) ,np.round(aa.R))
    plt.savefig("/home/zach/plasma/atomic_forces/average_atom/media/" + name, dpi=300, bbox_inches='tight',facecolor="w")
    
    
    return axs


axs = compare_aa([aaW])#, npa, npa_2])
for ax in axs:
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), fontsize=16, loc='upper right')
# axs[1].set_ylim(1e-5,1e3)

# %% [markdown]
# ## HNC and FT

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.k_array/rs, aa.Uei_iet_k*(aa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.k_array/rs, npa.Uei_iet_k*(npa.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[1], label="NPA") # Need to muultiply by some rs power???
axs[0].plot(npa_2.iet.k_array/rs, npa_2.Uei_iet_k*(npa_2.iet.k_array/rs)**2/(4*π) ,'--.',color=colors[2], label="NPA 2") # Need to muultiply by some rs power???
axs[0].plot(aa.iet.k_array/rs, aa.Zstar*np.ones_like(aa.iet.k_array),':', color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(npa.iet.k_array/rs, npa.Zstar*np.ones_like(npa.iet.k_array),':',color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(npa_2.iet.k_array/rs, npa_2.Zstar*np.ones_like(npa_2.iet.k_array),':',color=colors[2], label=f"Coulomb, Z={npa_2.Zstar:0.3f}")

# axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$k$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

# axs[1].plot(aa.iet.k_array/rs, aa.uii_k_eff_iet,'-', color=colors[0], label="AA")
# axs[1].plot(aa.iet.k_array/rs, 4*π*aa.Zstar**2/(aa.iet.k_array/rs)**2,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, 1/(aa.iet.k_array**2/rs**2/(4*π*aa.Zstar**2) + 1/aa.uii_k_eff_iet[0] ),'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))
# axs[1].plot(aa.iet.k_array/rs, uii_test,'--', color=colors[0], label=r"AA: $u_{{ii}}^0$, Z={0:0.3f}".format(aa.Zstar))


# axs[1].plot(npa.iet.k_array/rs, npa.uii_k_eff_iet,color=colors[1], label="NPA")
axs[1].plot(npa.iet.k_array/rs, 4*π*npa.Zstar**2/(npa.iet.k_array/rs)**2,'--', color=colors[1], label=r"NPA: $u_{{ii}}^0$, Z={0:0.3f}".format(npa.Zstar))



axs[1].set_yscale('symlog',linthresh=1e-4)
axs[1].set_ylim(0,1e5)
axs[1].set_xscale('log')
axs[1].set_xlabel(r"$k$ [au]")
axs[1].set_ylabel(r"$u^{\rm eff}_{ii}$ [au]")


for ax in axs:
    ax.legend(fontsize=12)
plt.tight_layout()

# %%
uii_test = aa.iet.FT_k_2_r(aa.uii_k_eff_iet)/rs**3

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['font.size'] =  16
plt.rcParams['legend.fontsize'] = 12
# Plot and Compare
fig, axs = plt.subplots(1,2, figsize=(10,4))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

axs[0].plot(aa.iet.r_array*rs, -aa.Zstar/(aa.iet.r_array*rs), color=colors[0], label=f"Coulomb, Z={aa.Zstar:0.3f}")
axs[0].plot(aa.iet.r_array*rs, -aa.Uei_iet ,':',color=colors[0], label="AA" ) # Need to muultiply by some rs power???
axs[0].plot(npa.iet.r_array*rs, -npa.Zstar/(npa.iet.r_array*rs),color=colors[1], label=f"Coulomb, Z={npa.Zstar:0.3f}")
axs[0].plot(npa.iet.r_array*rs, -npa.Uei_iet ,':',color=colors[1], label="NPA") # Need to muultiply by some rs power???
axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Zstar/(npa.iet.r_array*rs),color=colors[2], label=f"Coulomb, Z={npa_2.Zstar:0.3f}")
axs[0].plot(npa_2.iet.r_array*rs, -npa_2.Uei_iet ,':',color=colors[2], label=r"NPA: $g_{AA}$") # Need to muultiply by some rs power???

axs[0].set_yscale('symlog',linthresh=1e-1)
axs[0].set_xscale('log')
axs[0].set_xlabel(r"$r$ [au]")
axs[0].set_ylabel(r"$U_{ei}$ [au]")

axs[1].plot(aa.iet.r_array*rs, 1/aa.Te * aa.uii_r_eff_iet, color=colors[0],linestyle='-', label='AA')
axs[1].plot(aa.iet.r_array*rs, 1/aa.Te *aa.Zstar**2/(aa.iet.r_array*rs ), color=colors[0] ,linestyle='--', label=f'Coulomb Z={aa.Zstar:0.3f}')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.uii_r_eff_iet, color=colors[1],linestyle='-', label='NPA')
axs[1].plot(npa.iet.r_array*rs, 1/npa.Te *npa.Zstar**2/(npa.iet.r_array*rs ), color=colors[1],linestyle='--', label=f'Coulomb Z={npa.Zstar:0.3f}' )
axs[1].plot(npa_2.iet.r_array*rs, 1/npa.Te *npa_2.uii_r_eff_iet, color=colors[2],linestyle='-', label=r"NPA: $g_{AA}$")
axs[1].plot(npa_2.iet.r_array*rs, 1/npa.Te *npa_2.Zstar**2/(npa_2.iet.r_array*rs ), color=colors[2],linestyle='--', label=f'Coulomb Z={npa_2.Zstar:0.3f}' )

axs[1].set_yscale('symlog',linthresh=1e-2)
axs[1].set_xscale('log')
axs[1].set_ylabel(r"$\beta U_{ii}$ [au]")
axs[1].set_xlabel(r"$r$ [au]")
axs[1].set_xlim(1,None)


for ax in axs:
    ax.legend(fontsize=10)
plt.tight_layout()

# %%
npa.make_gii()
npa.make_ρi()
npa_2.make_gii()
npa_2.make_ρi()

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, axs  = plt.subplots(1,2, figsize=(8,4))

# Data from community TCCW
upper_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Upper.txt", delim_whitespace=True, header=1)
lower_data = read_csv("/home/zach/plasma/hnc/TCCW/Final_TCCW/Fig5c_Lower.txt", delim_whitespace=True, header=1)

ax = axs[0]
ax.fill_between(lower_data['r/ri'],lower_data['gii'], PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')

# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
ax.plot(npa_2.grid.xs/rs, npa_2.gii, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0] + 1, label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)
ax.plot(npa.iet.r_array, npa.iet.h_r_matrix[0,0] + 1, label=r"NPA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("g(r)")
ax.set_xlim(0.7,3)
# ax.set_ylim(0,2)
ax.legend(fontsize=10)

ax = axs[1]
ax.fill_between(lower_data['r/ri'],lower_data['gii']-1, PchipInterpolator(upper_data['r/ri'], upper_data['gii'])(lower_data['r/ri']), alpha=0.5, color='k', label='Workshop DFT Spread')
# Average atom effective potential to gii
ax.plot(npa.grid.xs/rs, npa.gii-1, label=r"NPA: $u_{ii}^{\rm Y initial}$",linewidth=1, zorder=2)
ax.plot(npa_2.grid.xs/rs, npa_2.gii-1, label=r"NPA: $u_{ii}^{\rm AA initial}$",linewidth=1, zorder=2)
ax.plot(aa.iet.r_array, aa.iet.h_r_matrix[0,0], label=r"AA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)
ax.plot(npa.iet.r_array, npa.iet.h_r_matrix[0,0], label=r"NPA: $u_{ii}^{\rm eff}$",linewidth=1, zorder=5)

ax.set_xlabel(r"$r/r_i$")
ax.set_ylabel("h(r)")
ax.set_xlim(0.7,10)
ax.set_ylim(-2.5,2.5)
ax.set_yscale('symlog', linthresh=1e-4)

ax.legend(fontsize=8, loc='upper right')
plt.tight_layout()

# %%
from scipy.interpolate import PchipInterpolator
from pandas import read_csv

fig, ax = plt.subplots(figsize=(5,3.5))#1,1, figsize=(8,4))

# Average atom effective potential to gii

ax.plot(aa.iet.k_array/rs, aa.iet.S_k_matrix[0,0],'-', label="OFAA")
ax.plot(npa.iet.k_array/rs, npa.iet.S_k_matrix[0,0],'-', label=r"OFNPA (Yukawa $g^0_{ii}$)")
ax.plot(npa_2.iet.k_array/rs, npa_2.iet.S_k_matrix[0,0],'-', label=r"OFNPA (OFAA $g^0_{ii}$)")

ax.set_xlabel(r"$k r_i$")
ax.set_ylabel(r"$S_{ii}(k)$")
ax.legend(fontsize=12, loc='lower right')

ax.set_xlim(0,5)
plt.tight_layout()
